# %%
import numpy as np
import os
import pickle
import matplotlib.pyplot as plt

# %%
curr_dir = os.getcwd() 

num_epochs = 30
logL = np.log2([16, 64, 256, 1024])

# %% [markdown]
# # ViT

# %%
log_name_16 = '\log\\fashion_mnist\ViT\L_16.pkl'
log_path_16 = curr_dir + log_name_16
with open(log_path_16, 'rb') as file:
    history16 = pickle.load(file)
train_acc_16 = history16['accuracy']  
train_loss_16 = history16['loss']
val_acc_16 = history16['val_accuracy']  
val_loss_16 = history16['val_loss']

log_name_64 = '\log\\fashion_mnist\ViT\L_64.pkl'
log_path_64 = curr_dir + log_name_64
with open(log_path_64, 'rb') as file:
    history64 = pickle.load(file)
train_acc_64 = history64['accuracy']      
train_loss_64 = history64['loss']
val_acc_64 = history64['val_accuracy']      
val_loss_64 = history64['val_loss']

log_name_256 = '\log\\fashion_mnist\ViT\L_256.pkl'
log_path_256 = curr_dir + log_name_256
with open(log_path_256, 'rb') as file:
    history256 = pickle.load(file)
train_acc_256 = history256['accuracy']  
train_loss_256 = history256['loss']
val_acc_256 = history256['val_accuracy']  
val_loss_256 = history256['val_loss']

log_name_1024 = '\log\\fashion_mnist\ViT\L_1024.pkl'
log_path_1024 = curr_dir + log_name_1024
with open(log_path_1024, 'rb') as file:
    history1024 = pickle.load(file)
train_acc_1024 = history1024['accuracy']  
train_loss_1024 = history1024['loss']
val_acc_1024 = history1024['val_accuracy']  
val_loss_1024 = history1024['val_loss']

total_inf_time = '\log\\fashion_mnist\ViT\\total_inf_time'
total_inf_time = curr_dir + total_inf_time
with open(total_inf_time, 'rb') as file:
    history_time = pickle.load(file)
total_time = history_time[0]  
inference_time = history_time[1]

# %%
fig, ax1 = plt.subplots()
plt.title("Train Accuracy and Loss Over Epochs")
plt.xlabel("Epochs")

ax1.plot(train_acc_16, color='r', label='L=16')
ax1.plot(train_acc_64, color='g', label='L=64')
ax1.plot(train_acc_256, color='m', label='L=256')
ax1.plot(train_acc_1024, color='c', label='L=1024')
ax1.set_ylabel("Accuracy")

ax2 = ax1.twinx()
ax2.plot(train_loss_16, '-.', color='r', label='L=16')
ax2.plot(train_loss_64, '-.', color='g', label='L=64')
ax2.plot(train_loss_256, '-.', color='m', label='L=256')
ax2.plot(train_loss_1024, '-.', color='c', label='L=1024')
ax2.set_ylabel("Loss")

acc_handle = plt.Line2D([], [], linestyle='-')
loss_handle = plt.Line2D([], [], linestyle='-.')
red_proxy = plt.Rectangle((0, 0), 1, 1, fc='r')
green_proxy = plt.Rectangle((0, 0), 1, 1, fc='g')
m_proxy = plt.Rectangle((0, 0), 1, 1, fc='m')
c_proxy = plt.Rectangle((0, 0), 1, 1, fc='c')

plt.legend(handles=[red_proxy, green_proxy, m_proxy, c_proxy, acc_handle, loss_handle],
          labels=['L=16', 'L=64', 'L=256', 'L=1024', 'Accuracy', 'Loss'],
          loc='upper left')
plt.grid()

# %%
fig, ax1 = plt.subplots()
plt.title("Validation Accuracy and Loss Over Epochs")
plt.xlabel("Epochs")

ax1.plot(val_acc_16, color='r', label='L=16')
ax1.plot(val_acc_64, color='g', label='L=64')
ax1.plot(val_acc_256, color='m', label='L=256')
ax1.plot(val_acc_1024, color='c', label='L=1024')
ax1.set_ylabel("Accuracy")

ax2 = ax1.twinx()
ax2.plot(val_loss_16, '-.', color='r', label='L=16')
ax2.plot(val_loss_64, '-.', color='g', label='L=64')
ax2.plot(val_loss_256, '-.', color='m', label='L=256')
ax2.plot(val_loss_1024, '-.', color='c', label='L=1024')
ax2.set_ylabel("Loss")

acc_handle = plt.Line2D([], [], linestyle='-')
loss_handle = plt.Line2D([], [], linestyle='-.')
red_proxy = plt.Rectangle((0, 0), 1, 1, fc='r')
green_proxy = plt.Rectangle((0, 0), 1, 1, fc='g')
m_proxy = plt.Rectangle((0, 0), 1, 1, fc='m')
c_proxy = plt.Rectangle((0, 0), 1, 1, fc='c')

plt.legend(handles=[red_proxy, green_proxy, m_proxy, c_proxy, acc_handle, loss_handle],
          labels=['L=16', 'L=64', 'L=256', 'L=1024', 'Accuracy', 'Loss'],
          loc='upper left')
plt.grid()

# %% [markdown]
# # ViP

# %% [markdown]
# ## random_feature=16 (softmax)

# %%
log_name_16 = '\log\\fashion_mnist\ViP\\random_feature_16\L_16.pkl'
log_path_16 = curr_dir + log_name_16
with open(log_path_16, 'rb') as file:
    history16 = pickle.load(file)
train_acc_16_rf16 = history16['accuracy']  
train_loss_16_rf16 = history16['loss']
val_acc_16_rf16 = history16['val_accuracy']  
val_loss_16_rf16 = history16['val_loss']

log_name_64 = '\log\\fashion_mnist\ViP\\random_feature_16\L_64.pkl'
log_path_64 = curr_dir + log_name_64
with open(log_path_64, 'rb') as file:
    history64 = pickle.load(file)
train_acc_64_rf16 = history64['accuracy']      
train_loss_64_rf16 = history64['loss']
val_acc_64_rf16 = history64['val_accuracy']      
val_loss_64_rf16 = history64['val_loss']

log_name_256 = '\log\\fashion_mnist\ViP\\random_feature_16\L_256.pkl'
log_path_256 = curr_dir + log_name_256
with open(log_path_256, 'rb') as file:
    history256 = pickle.load(file)
train_acc_256_rf16 = history256['accuracy']  
train_loss_256_rf16 = history256['loss']
val_acc_256_rf16 = history256['val_accuracy']  
val_loss_256_rf16 = history256['val_loss']

log_name_1024 = '\log\\fashion_mnist\ViP\\random_feature_16\L_1024.pkl'
log_path_1024 = curr_dir + log_name_1024
with open(log_path_1024, 'rb') as file:
    history1024 = pickle.load(file)
train_acc_1024_rf16 = history1024['accuracy']  
train_loss_1024_rf16 = history1024['loss']
val_acc_1024_rf16 = history1024['val_accuracy']  
val_loss_1024_rf16 = history1024['val_loss']

total_inf_time = '\log\\fashion_mnist\ViP\\random_feature_16\\total_inf_time'
total_inf_time = curr_dir + total_inf_time
with open(total_inf_time, 'rb') as file:
    history_time_rf16 = pickle.load(file)
total_time_rf16 = history_time_rf16[0]  
inference_time_rf16 = history_time_rf16[1]

# %%
fig, ax1 = plt.subplots()
plt.title("Train Accuracy and Loss Over Epochs (rf=16 and softmax)")
plt.xlabel("Epochs")

ax1.plot(train_acc_16_rf16, color='r', label='L=16')
ax1.plot(train_acc_64_rf16, color='g', label='L=64')
ax1.plot(train_acc_256_rf16, color='m', label='L=256')
ax1.plot(train_acc_1024_rf16, color='c', label='L=1024')
ax1.set_ylabel("Accuracy")

ax2 = ax1.twinx()
ax2.plot(train_loss_16_rf16, '-.', color='r', label='L=16')
ax2.plot(train_loss_64_rf16, '-.', color='g', label='L=64')
ax2.plot(train_loss_256_rf16, '-.', color='m', label='L=256')
ax2.plot(train_loss_1024_rf16, '-.', color='c', label='L=1024')
ax2.set_ylabel("Loss")

acc_handle = plt.Line2D([], [], linestyle='-')
loss_handle = plt.Line2D([], [], linestyle='-.')
red_proxy = plt.Rectangle((0, 0), 1, 1, fc='r')
green_proxy = plt.Rectangle((0, 0), 1, 1, fc='g')
m_proxy = plt.Rectangle((0, 0), 1, 1, fc='m')
c_proxy = plt.Rectangle((0, 0), 1, 1, fc='c')

plt.legend(handles=[red_proxy, green_proxy, m_proxy, c_proxy, acc_handle, loss_handle],
          labels=['L=16', 'L=64', 'L=256', 'L=1024', 'Accuracy', 'Loss'],
          loc='upper left')
plt.grid()

# %%
fig, ax1 = plt.subplots()
plt.title("Validation Accuracy and Loss Over Epochs (rf=16 and softmax)")
plt.xlabel("Epochs")

ax1.plot(val_acc_16_rf16, color='r', label='L=16')
ax1.plot(val_acc_64_rf16, color='g', label='L=64')
ax1.plot(val_acc_256_rf16, color='m', label='L=256')
ax1.plot(val_acc_1024_rf16, color='c', label='L=1024')
ax1.set_ylabel("Accuracy")

ax2 = ax1.twinx()
ax2.plot(val_loss_16_rf16, '-.', color='r', label='L=16')
ax2.plot(val_loss_64_rf16, '-.', color='g', label='L=64')
ax2.plot(val_loss_256_rf16, '-.', color='m', label='L=256')
ax2.plot(val_loss_1024_rf16, '-.', color='c', label='L=1024')
ax2.set_ylabel("Loss")

acc_handle = plt.Line2D([], [], linestyle='-')
loss_handle = plt.Line2D([], [], linestyle='-.')
red_proxy = plt.Rectangle((0, 0), 1, 1, fc='r')
green_proxy = plt.Rectangle((0, 0), 1, 1, fc='g')
m_proxy = plt.Rectangle((0, 0), 1, 1, fc='m')
c_proxy = plt.Rectangle((0, 0), 1, 1, fc='c')

plt.legend(handles=[red_proxy, green_proxy, m_proxy, c_proxy, acc_handle, loss_handle],
          labels=['L=16', 'L=64', 'L=256', 'L=1024', 'Accuracy', 'Loss'],
          loc='upper left')
plt.grid()

# %% [markdown]
# ## random_feature=32 (softmax)

# %%
log_name_16 = '\log\\fashion_mnist\ViP\\random_feature_32\L_16.pkl'
log_path_16 = curr_dir + log_name_16
with open(log_path_16, 'rb') as file:
    history16 = pickle.load(file)
train_acc_16_rf32 = history16['accuracy']  
train_loss_16_rf32 = history16['loss']
val_acc_16_rf32 = history16['val_accuracy']  
val_loss_16_rf32 = history16['val_loss']

log_name_64 = '\log\\fashion_mnist\ViP\\random_feature_32\L_64.pkl'
log_path_64 = curr_dir + log_name_64
with open(log_path_64, 'rb') as file:
    history64 = pickle.load(file)
train_acc_64_rf32 = history64['accuracy']      
train_loss_64_rf32 = history64['loss']
val_acc_64_rf32 = history64['val_accuracy']      
val_loss_64_rf32 = history64['val_loss']

log_name_256 = '\log\\fashion_mnist\ViP\\random_feature_32\L_256.pkl'
log_path_256 = curr_dir + log_name_256
with open(log_path_256, 'rb') as file:
    history256 = pickle.load(file)
train_acc_256_rf32 = history256['accuracy']  
train_loss_256_rf32 = history256['loss']
val_acc_256_rf32 = history256['val_accuracy']  
val_loss_256_rf32 = history256['val_loss']

log_name_1024 = '\log\\fashion_mnist\ViP\\random_feature_32\L_1024.pkl'
log_path_1024 = curr_dir + log_name_1024
with open(log_path_1024, 'rb') as file:
    history1024 = pickle.load(file)
train_acc_1024_rf32 = history1024['accuracy']  
train_loss_1024_rf32 = history1024['loss']
val_acc_1024_rf32 = history1024['val_accuracy']  
val_loss_1024_rf32 = history1024['val_loss']

total_inf_time = '\log\\fashion_mnist\ViP\\random_feature_32\\total_inf_time'
total_inf_time = curr_dir + total_inf_time
with open(total_inf_time, 'rb') as file:
    history_time_rf32 = pickle.load(file)
total_time_rf32 = history_time_rf32[0]  
inference_time_rf32 = history_time_rf32[1]

# %%
fig, ax1 = plt.subplots()
plt.title("Train Accuracy and Loss Over Epochs (rf=32 and softmax)")
plt.xlabel("Epochs")

ax1.plot(train_acc_16_rf32, color='r', label='L=16')
ax1.plot(train_acc_64_rf32, color='g', label='L=64')
ax1.plot(train_acc_256_rf32, color='m', label='L=256')
ax1.plot(train_acc_1024_rf32, color='c', label='L=1024')
ax1.set_ylabel("Accuracy")

ax2 = ax1.twinx()
ax2.plot(train_loss_16_rf32, '-.', color='r', label='L=16')
ax2.plot(train_loss_64_rf32, '-.', color='g', label='L=64')
ax2.plot(train_loss_256_rf32, '-.', color='m', label='L=256')
ax2.plot(train_loss_1024_rf32, '-.', color='c', label='L=1024')
ax2.set_ylabel("Loss")

acc_handle = plt.Line2D([], [], linestyle='-')
loss_handle = plt.Line2D([], [], linestyle='-.')
red_proxy = plt.Rectangle((0, 0), 1, 1, fc='r')
green_proxy = plt.Rectangle((0, 0), 1, 1, fc='g')
m_proxy = plt.Rectangle((0, 0), 1, 1, fc='m')
c_proxy = plt.Rectangle((0, 0), 1, 1, fc='c')

plt.legend(handles=[red_proxy, green_proxy, m_proxy, c_proxy, acc_handle, loss_handle],
          labels=['L=16', 'L=64', 'L=256', 'L=1024', 'Accuracy', 'Loss'],
          loc='upper left')
plt.grid()

# %%
fig, ax1 = plt.subplots()
plt.title("Validation Accuracy and Loss Over Epochs (rf=32 and softmax)")
plt.xlabel("Epochs")

ax1.plot(val_acc_16_rf32, color='r', label='L=16')
ax1.plot(val_acc_64_rf32, color='g', label='L=64')
ax1.plot(val_acc_256_rf32, color='m', label='L=256')
ax1.plot(val_acc_1024_rf32, color='c', label='L=1024')
ax1.set_ylabel("Accuracy")

ax2 = ax1.twinx()
ax2.plot(val_loss_16_rf32, '-.', color='r', label='L=16')
ax2.plot(val_loss_64_rf32, '-.', color='g', label='L=64')
ax2.plot(val_loss_256_rf32, '-.', color='m', label='L=256')
ax2.plot(val_loss_1024_rf32, '-.', color='c', label='L=1024')
ax2.set_ylabel("Loss")

acc_handle = plt.Line2D([], [], linestyle='-')
loss_handle = plt.Line2D([], [], linestyle='-.')
red_proxy = plt.Rectangle((0, 0), 1, 1, fc='r')
green_proxy = plt.Rectangle((0, 0), 1, 1, fc='g')
m_proxy = plt.Rectangle((0, 0), 1, 1, fc='m')
c_proxy = plt.Rectangle((0, 0), 1, 1, fc='c')

plt.legend(handles=[red_proxy, green_proxy, m_proxy, c_proxy, acc_handle, loss_handle],
          labels=['L=16', 'L=64', 'L=256', 'L=1024', 'Accuracy', 'Loss'],
          loc='upper left')
plt.grid()

# %% [markdown]
# # random_feature=64 (softmax)

# %%
log_name_16 = '\log\\fashion_mnist\ViP\\random_feature_64\L_16.pkl'
log_path_16 = curr_dir + log_name_16
with open(log_path_16, 'rb') as file:
    history16 = pickle.load(file)
train_acc_16_rf64 = history16['accuracy']  
train_loss_16_rf64 = history16['loss']
val_acc_16_rf64 = history16['val_accuracy']  
val_loss_16_rf64 = history16['val_loss']

log_name_64 = '\log\\fashion_mnist\ViP\\random_feature_64\L_64.pkl'
log_path_64 = curr_dir + log_name_64
with open(log_path_64, 'rb') as file:
    history64 = pickle.load(file)
train_acc_64_rf64 = history64['accuracy']      
train_loss_64_rf64 = history64['loss']
val_acc_64_rf64 = history64['val_accuracy']      
val_loss_64_rf64 = history64['val_loss']

log_name_256 = '\log\\fashion_mnist\ViP\\random_feature_64\L_256.pkl'
log_path_256 = curr_dir + log_name_256
with open(log_path_256, 'rb') as file:
    history256 = pickle.load(file)
train_acc_256_rf64 = history256['accuracy']  
train_loss_256_rf64 = history256['loss']
val_acc_256_rf64 = history256['val_accuracy']  
val_loss_256_rf64 = history256['val_loss']

log_name_1024 = '\log\\fashion_mnist\ViP\\random_feature_64\L_1024.pkl'
log_path_1024 = curr_dir + log_name_1024
with open(log_path_1024, 'rb') as file:
    history1024 = pickle.load(file)
train_acc_1024_rf64 = history1024['accuracy']  
train_loss_1024_rf64 = history1024['loss']
val_acc_1024_rf64 = history1024['val_accuracy']  
val_loss_1024_rf64 = history1024['val_loss']

total_inf_time = '\log\\fashion_mnist\ViP\\random_feature_64\\total_inf_time'
total_inf_time = curr_dir + total_inf_time
with open(total_inf_time, 'rb') as file:
    history_time_rf64 = pickle.load(file)
total_time_rf64 = history_time_rf64[0]  
inference_time_rf64 = history_time_rf64[1]

# %%
fig, ax1 = plt.subplots()
plt.title("Train Accuracy and Loss Over Epochs (rf=64 and softmax)")
plt.xlabel("Epochs")

ax1.plot(train_acc_16_rf64, color='r', label='L=16')
ax1.plot(train_acc_64_rf64, color='g', label='L=64')
ax1.plot(train_acc_256_rf64, color='m', label='L=256')
ax1.plot(train_acc_1024_rf64, color='c', label='L=1024')
ax1.set_ylabel("Accuracy")

ax2 = ax1.twinx()
ax2.plot(train_loss_16_rf64, '-.', color='r', label='L=16')
ax2.plot(train_loss_64_rf64, '-.', color='g', label='L=64')
ax2.plot(train_loss_256_rf64, '-.', color='m', label='L=256')
ax2.plot(train_loss_1024_rf64, '-.', color='c', label='L=1024')
ax2.set_ylabel("Loss")

acc_handle = plt.Line2D([], [], linestyle='-')
loss_handle = plt.Line2D([], [], linestyle='-.')
red_proxy = plt.Rectangle((0, 0), 1, 1, fc='r')
green_proxy = plt.Rectangle((0, 0), 1, 1, fc='g')
m_proxy = plt.Rectangle((0, 0), 1, 1, fc='m')
c_proxy = plt.Rectangle((0, 0), 1, 1, fc='c')

plt.legend(handles=[red_proxy, green_proxy, m_proxy, c_proxy, acc_handle, loss_handle],
          labels=['L=16', 'L=64', 'L=256', 'L=1024', 'Accuracy', 'Loss'],
          loc='upper left')
plt.grid()

# %%
fig, ax1 = plt.subplots()
plt.title("Validation Accuracy and Loss Over Epochs (rf=64 and softmax)")
plt.xlabel("Epochs")

ax1.plot(val_acc_16_rf64, color='r', label='L=16')
ax1.plot(val_acc_64_rf64, color='g', label='L=64')
ax1.plot(val_acc_256_rf64, color='m', label='L=256')
ax1.plot(val_acc_1024_rf64, color='c', label='L=1024')
ax1.set_ylabel("Accuracy")

ax2 = ax1.twinx()
ax2.plot(val_loss_16_rf64, '-.', color='r', label='L=16')
ax2.plot(val_loss_64_rf64, '-.', color='g', label='L=64')
ax2.plot(val_loss_256_rf64, '-.', color='m', label='L=256')
ax2.plot(val_loss_1024_rf64, '-.', color='c', label='L=1024')
ax2.set_ylabel("Loss")

acc_handle = plt.Line2D([], [], linestyle='-')
loss_handle = plt.Line2D([], [], linestyle='-.')
red_proxy = plt.Rectangle((0, 0), 1, 1, fc='r')
green_proxy = plt.Rectangle((0, 0), 1, 1, fc='g')
m_proxy = plt.Rectangle((0, 0), 1, 1, fc='m')
c_proxy = plt.Rectangle((0, 0), 1, 1, fc='c')

plt.legend(handles=[red_proxy, green_proxy, m_proxy, c_proxy, acc_handle, loss_handle],
          labels=['L=16', 'L=64', 'L=256', 'L=1024', 'Accuracy', 'Loss'],
          loc='upper left')
plt.grid()

# %% [markdown]
# # random_feature=128 (softmax)

# %%
log_name_16 = '\log\\fashion_mnist\ViP\\random_feature_128\L_16.pkl'
log_path_16 = curr_dir + log_name_16
with open(log_path_16, 'rb') as file:
    history16 = pickle.load(file)
train_acc_16_rf128 = history16['accuracy']  
train_loss_16_rf128 = history16['loss']
val_acc_16_rf128 = history16['val_accuracy']  
val_loss_16_rf128 = history16['val_loss']

log_name_64 = '\log\\fashion_mnist\ViP\\random_feature_128\L_64.pkl'
log_path_64 = curr_dir + log_name_64
with open(log_path_64, 'rb') as file:
    history64 = pickle.load(file)
train_acc_64_rf128 = history64['accuracy']      
train_loss_64_rf128 = history64['loss']
val_acc_64_rf128 = history64['val_accuracy']      
val_loss_64_rf128 = history64['val_loss']

log_name_256 = '\log\\fashion_mnist\ViP\\random_feature_128\L_256.pkl'
log_path_256 = curr_dir + log_name_256
with open(log_path_256, 'rb') as file:
    history256 = pickle.load(file)
train_acc_256_rf128 = history256['accuracy']  
train_loss_256_rf128 = history256['loss']
val_acc_256_rf128 = history256['val_accuracy']  
val_loss_256_rf128 = history256['val_loss']

log_name_1024 = '\log\\fashion_mnist\ViP\\random_feature_128\L_1024.pkl'
log_path_1024 = curr_dir + log_name_1024
with open(log_path_1024, 'rb') as file:
    history1024 = pickle.load(file)
train_acc_1024_rf128 = history1024['accuracy']  
train_loss_1024_rf128 = history1024['loss']
val_acc_1024_rf128 = history1024['val_accuracy']  
val_loss_1024_rf128 = history1024['val_loss']

total_inf_time = '\log\\fashion_mnist\ViP\\random_feature_128\\total_inf_time'
total_inf_time = curr_dir + total_inf_time
with open(total_inf_time, 'rb') as file:
    history_time_rf128 = pickle.load(file)
total_time_rf128 = history_time_rf128[0]  
inference_time_rf128 = history_time_rf128[1]

# %%
fig, ax1 = plt.subplots()
plt.title("Train Accuracy and Loss Over Epochs (rf=128 and softmax)")
plt.xlabel("Epochs")

ax1.plot(train_acc_16_rf128, color='r', label='L=16')
ax1.plot(train_acc_64_rf128, color='g', label='L=64')
ax1.plot(train_acc_256_rf128, color='m', label='L=256')
ax1.plot(train_acc_1024_rf128, color='c', label='L=1024')
ax1.set_ylabel("Accuracy")

ax2 = ax1.twinx()
ax2.plot(train_loss_16_rf128, '-.', color='r', label='L=16')
ax2.plot(train_loss_64_rf128, '-.', color='g', label='L=64')
ax2.plot(train_loss_256_rf128, '-.', color='m', label='L=256')
ax2.plot(train_loss_1024_rf128, '-.', color='c', label='L=1024')
ax2.set_ylabel("Loss")

acc_handle = plt.Line2D([], [], linestyle='-')
loss_handle = plt.Line2D([], [], linestyle='-.')
red_proxy = plt.Rectangle((0, 0), 1, 1, fc='r')
green_proxy = plt.Rectangle((0, 0), 1, 1, fc='g')
m_proxy = plt.Rectangle((0, 0), 1, 1, fc='m')
c_proxy = plt.Rectangle((0, 0), 1, 1, fc='c')

plt.legend(handles=[red_proxy, green_proxy, m_proxy, c_proxy, acc_handle, loss_handle],
          labels=['L=16', 'L=64', 'L=256', 'L=1024', 'Accuracy', 'Loss'],
          loc='upper left')
plt.grid()

# %%
fig, ax1 = plt.subplots()
plt.title("Validation Accuracy and Loss Over Epochs (rf=128 and softmax)")
plt.xlabel("Epochs")

ax1.plot(val_acc_16_rf128, color='r', label='L=16')
ax1.plot(val_acc_64_rf128, color='g', label='L=64')
ax1.plot(val_acc_256_rf128, color='m', label='L=256')
ax1.plot(val_acc_1024_rf128, color='c', label='L=1024')
ax1.set_ylabel("Accuracy")

ax2 = ax1.twinx()
ax2.plot(val_loss_16_rf128, '-.', color='r', label='L=16')
ax2.plot(val_loss_64_rf128, '-.', color='g', label='L=64')
ax2.plot(val_loss_256_rf128, '-.', color='m', label='L=256')
ax2.plot(val_loss_1024_rf128, '-.', color='c', label='L=1024')
ax2.set_ylabel("Loss")

acc_handle = plt.Line2D([], [], linestyle='-')
loss_handle = plt.Line2D([], [], linestyle='-.')
red_proxy = plt.Rectangle((0, 0), 1, 1, fc='r')
green_proxy = plt.Rectangle((0, 0), 1, 1, fc='g')
m_proxy = plt.Rectangle((0, 0), 1, 1, fc='m')
c_proxy = plt.Rectangle((0, 0), 1, 1, fc='c')

plt.legend(handles=[red_proxy, green_proxy, m_proxy, c_proxy, acc_handle, loss_handle],
          labels=['L=16', 'L=64', 'L=256', 'L=1024', 'Accuracy', 'Loss'],
          loc='upper left')
plt.grid()

# %% [markdown]
# # random_feature=16 (ReLu)

# %%
log_name_16 = '\log\\fashion_mnist\ViP\\random_feature_16_relu\L_16.pkl'
log_path_16 = curr_dir + log_name_16
with open(log_path_16, 'rb') as file:
    history16 = pickle.load(file)
train_acc_16_rf16_relu = history16['accuracy']  
train_loss_16_rf16_relu = history16['loss']
val_acc_16_rf16_relu = history16['val_accuracy']  
val_loss_16_rf16_relu = history16['val_loss']

log_name_64 = '\log\\fashion_mnist\ViP\\random_feature_16_relu\L_64.pkl'
log_path_64 = curr_dir + log_name_64
with open(log_path_64, 'rb') as file:
    history64 = pickle.load(file)
train_acc_64_rf16_relu = history64['accuracy']      
train_loss_64_rf16_relu = history64['loss']
val_acc_64_rf16_relu = history64['val_accuracy']      
val_loss_64_rf16_relu = history64['val_loss']

log_name_256 = '\log\\fashion_mnist\ViP\\random_feature_16_relu\L_256.pkl'
log_path_256 = curr_dir + log_name_256
with open(log_path_256, 'rb') as file:
    history256 = pickle.load(file)
train_acc_256_rf16_relu = history256['accuracy']  
train_loss_256_rf16_relu = history256['loss']
val_acc_256_rf16_relu = history256['val_accuracy']  
val_loss_256_rf16_relu = history256['val_loss']

log_name_1024 = '\log\\fashion_mnist\ViP\\random_feature_16_relu\L_1024.pkl'
log_path_1024 = curr_dir + log_name_1024
with open(log_path_1024, 'rb') as file:
    history1024 = pickle.load(file)
train_acc_1024_rf16_relu = history1024['accuracy']  
train_loss_1024_rf16_relu = history1024['loss']
val_acc_1024_rf16_relu = history1024['val_accuracy']  
val_loss_1024_rf16_relu = history1024['val_loss']

total_inf_time = '\log\\fashion_mnist\ViP\\random_feature_16_relu\\total_inf_time'
total_inf_time = curr_dir + total_inf_time
with open(total_inf_time, 'rb') as file:
    history_time_rf16_relu = pickle.load(file)
total_time_rf16_relu = history_time_rf16_relu[0]  
inference_time_rf16_relu = history_time_rf16_relu[1]

# %%
fig, ax1 = plt.subplots()
plt.title("Train Accuracy and Loss Over Epochs (rf=16 and ReLu)")
plt.xlabel("Epochs")

ax1.plot(train_acc_16_rf16_relu, color='r', label='L=16')
ax1.plot(train_acc_64_rf16_relu, color='g', label='L=64')
ax1.plot(train_acc_256_rf16_relu, color='m', label='L=256')
ax1.plot(train_acc_1024_rf16_relu, color='c', label='L=1024')
ax1.set_ylabel("Accuracy")

ax2 = ax1.twinx()
ax2.plot(train_loss_16_rf16_relu, '-.', color='r', label='L=16')
ax2.plot(train_loss_64_rf16_relu, '-.', color='g', label='L=64')
ax2.plot(train_loss_256_rf16_relu, '-.', color='m', label='L=256')
ax2.plot(train_loss_1024_rf16_relu, '-.', color='c', label='L=1024')
ax2.set_ylabel("Loss")

acc_handle = plt.Line2D([], [], linestyle='-')
loss_handle = plt.Line2D([], [], linestyle='-.')
red_proxy = plt.Rectangle((0, 0), 1, 1, fc='r')
green_proxy = plt.Rectangle((0, 0), 1, 1, fc='g')
m_proxy = plt.Rectangle((0, 0), 1, 1, fc='m')
c_proxy = plt.Rectangle((0, 0), 1, 1, fc='c')

plt.legend(handles=[red_proxy, green_proxy, m_proxy, c_proxy, acc_handle, loss_handle],
          labels=['L=16', 'L=64', 'L=256', 'L=1024', 'Accuracy', 'Loss'],
          loc='upper left')
plt.grid()

# %%
fig, ax1 = plt.subplots()
plt.title("Validation Accuracy and Loss Over Epochs (rf=16 and ReLu)")
plt.xlabel("Epochs")

ax1.plot(val_acc_16_rf16_relu, color='r', label='L=16')
ax1.plot(val_acc_64_rf16_relu, color='g', label='L=64')
ax1.plot(val_acc_256_rf16_relu, color='m', label='L=256')
ax1.plot(val_acc_1024_rf16_relu, color='c', label='L=1024')
ax1.set_ylabel("Accuracy")

ax2 = ax1.twinx()
ax2.plot(val_loss_16_rf16_relu, '-.', color='r', label='L=16')
ax2.plot(val_loss_64_rf16_relu, '-.', color='g', label='L=64')
ax2.plot(val_loss_256_rf16_relu, '-.', color='m', label='L=256')
ax2.plot(val_loss_1024_rf16_relu, '-.', color='c', label='L=1024')
ax2.set_ylabel("Loss")

acc_handle = plt.Line2D([], [], linestyle='-')
loss_handle = plt.Line2D([], [], linestyle='-.')
red_proxy = plt.Rectangle((0, 0), 1, 1, fc='r')
green_proxy = plt.Rectangle((0, 0), 1, 1, fc='g')
m_proxy = plt.Rectangle((0, 0), 1, 1, fc='m')
c_proxy = plt.Rectangle((0, 0), 1, 1, fc='c')

plt.legend(handles=[red_proxy, green_proxy, m_proxy, c_proxy, acc_handle, loss_handle],
          labels=['L=16', 'L=64', 'L=256', 'L=1024', 'Accuracy', 'Loss'],
          loc='upper left')
plt.grid()

# %% [markdown]
# # random_feature=32 (ReLu)

# %%
log_name_16 = '\log\\fashion_mnist\ViP\\random_feature_32_relu\L_16.pkl'
log_path_16 = curr_dir + log_name_16
with open(log_path_16, 'rb') as file:
    history16 = pickle.load(file)
train_acc_16_rf32_relu = history16['accuracy']  
train_loss_16_rf32_relu = history16['loss']
val_acc_16_rf32_relu = history16['val_accuracy']  
val_loss_16_rf32_relu = history16['val_loss']

log_name_64 = '\log\\fashion_mnist\ViP\\random_feature_32_relu\L_64.pkl'
log_path_64 = curr_dir + log_name_64
with open(log_path_64, 'rb') as file:
    history64 = pickle.load(file)
train_acc_64_rf32_relu = history64['accuracy']      
train_loss_64_rf32_relu = history64['loss']
val_acc_64_rf32_relu = history64['val_accuracy']      
val_loss_64_rf32_relu = history64['val_loss']

log_name_256 = '\log\\fashion_mnist\ViP\\random_feature_32_relu\L_256.pkl'
log_path_256 = curr_dir + log_name_256
with open(log_path_256, 'rb') as file:
    history256 = pickle.load(file)
train_acc_256_rf32_relu = history256['accuracy']  
train_loss_256_rf32_relu = history256['loss']
val_acc_256_rf32_relu = history256['val_accuracy']  
val_loss_256_rf32_relu = history256['val_loss']

log_name_1024 = '\log\\fashion_mnist\ViP\\random_feature_32_relu\L_1024.pkl'
log_path_1024 = curr_dir + log_name_1024
with open(log_path_1024, 'rb') as file:
    history1024 = pickle.load(file)
train_acc_1024_rf32_relu = history1024['accuracy']  
train_loss_1024_rf32_relu = history1024['loss']
val_acc_1024_rf32_relu = history1024['val_accuracy']  
val_loss_1024_rf32_relu = history1024['val_loss']

total_inf_time = '\log\\fashion_mnist\ViP\\random_feature_32_relu\\total_inf_time'
total_inf_time = curr_dir + total_inf_time
with open(total_inf_time, 'rb') as file:
    history_time_rf32_relu = pickle.load(file)
total_time_rf32_relu = history_time_rf32_relu[0]  
inference_time_rf32_relu = history_time_rf32_relu[1]

# %%
fig, ax1 = plt.subplots()
plt.title("Train Accuracy and Loss Over Epochs (rf=32 and ReLu)")
plt.xlabel("Epochs")

ax1.plot(train_acc_16_rf32_relu, color='r', label='L=16')
ax1.plot(train_acc_64_rf32_relu, color='g', label='L=64')
ax1.plot(train_acc_256_rf32_relu, color='m', label='L=256')
ax1.plot(train_acc_1024_rf32_relu, color='c', label='L=1024')
ax1.set_ylabel("Accuracy")

ax2 = ax1.twinx()
ax2.plot(train_loss_16_rf32_relu, '-.', color='r', label='L=16')
ax2.plot(train_loss_64_rf32_relu, '-.', color='g', label='L=64')
ax2.plot(train_loss_256_rf32_relu, '-.', color='m', label='L=256')
ax2.plot(train_loss_1024_rf32_relu, '-.', color='c', label='L=1024')
ax2.set_ylabel("Loss")

acc_handle = plt.Line2D([], [], linestyle='-')
loss_handle = plt.Line2D([], [], linestyle='-.')
red_proxy = plt.Rectangle((0, 0), 1, 1, fc='r')
green_proxy = plt.Rectangle((0, 0), 1, 1, fc='g')
m_proxy = plt.Rectangle((0, 0), 1, 1, fc='m')
c_proxy = plt.Rectangle((0, 0), 1, 1, fc='c')

plt.legend(handles=[red_proxy, green_proxy, m_proxy, c_proxy, acc_handle, loss_handle],
          labels=['L=16', 'L=64', 'L=256', 'L=1024', 'Accuracy', 'Loss'],
          loc='upper left')
plt.grid()

# %%
fig, ax1 = plt.subplots()
plt.title("Validation Accuracy and Loss Over Epochs (rf=32 and ReLu)")
plt.xlabel("Epochs")

ax1.plot(val_acc_16_rf32_relu, color='r', label='L=16')
ax1.plot(val_acc_64_rf32_relu, color='g', label='L=64')
ax1.plot(val_acc_256_rf32_relu, color='m', label='L=256')
ax1.plot(val_acc_1024_rf32_relu, color='c', label='L=1024')
ax1.set_ylabel("Accuracy")

ax2 = ax1.twinx()
ax2.plot(val_loss_16_rf32_relu, '-.', color='r', label='L=16')
ax2.plot(val_loss_64_rf32_relu, '-.', color='g', label='L=64')
ax2.plot(val_loss_256_rf32_relu, '-.', color='m', label='L=256')
ax2.plot(val_loss_1024_rf32_relu, '-.', color='c', label='L=1024')
ax2.set_ylabel("Loss")

acc_handle = plt.Line2D([], [], linestyle='-')
loss_handle = plt.Line2D([], [], linestyle='-.')
red_proxy = plt.Rectangle((0, 0), 1, 1, fc='r')
green_proxy = plt.Rectangle((0, 0), 1, 1, fc='g')
m_proxy = plt.Rectangle((0, 0), 1, 1, fc='m')
c_proxy = plt.Rectangle((0, 0), 1, 1, fc='c')

plt.legend(handles=[red_proxy, green_proxy, m_proxy, c_proxy, acc_handle, loss_handle],
          labels=['L=16', 'L=64', 'L=256', 'L=1024', 'Accuracy', 'Loss'],
          loc='upper left')
plt.grid()

# %% [markdown]
# # random_feature=64 (ReLu)

# %%
log_name_16 = '\log\\fashion_mnist\ViP\\random_feature_64_relu\L_16.pkl'
log_path_16 = curr_dir + log_name_16
with open(log_path_16, 'rb') as file:
    history16 = pickle.load(file)
train_acc_16_rf64_relu = history16['accuracy']  
train_loss_16_rf64_relu = history16['loss']
val_acc_16_rf64_relu = history16['val_accuracy']  
val_loss_16_rf64_relu = history16['val_loss']

log_name_64 = '\log\\fashion_mnist\ViP\\random_feature_64_relu\L_64.pkl'
log_path_64 = curr_dir + log_name_64
with open(log_path_64, 'rb') as file:
    history64 = pickle.load(file)
train_acc_64_rf64_relu = history64['accuracy']      
train_loss_64_rf64_relu = history64['loss']
val_acc_64_rf64_relu = history64['val_accuracy']      
val_loss_64_rf64_relu = history64['val_loss']

log_name_256 = '\log\\fashion_mnist\ViP\\random_feature_64_relu\L_256.pkl'
log_path_256 = curr_dir + log_name_256
with open(log_path_256, 'rb') as file:
    history256 = pickle.load(file)
train_acc_256_rf64_relu = history256['accuracy']  
train_loss_256_rf64_relu = history256['loss']
val_acc_256_rf64_relu = history256['val_accuracy']  
val_loss_256_rf64_relu = history256['val_loss']

log_name_1024 = '\log\\fashion_mnist\ViP\\random_feature_64_relu\L_1024.pkl'
log_path_1024 = curr_dir + log_name_1024
with open(log_path_1024, 'rb') as file:
    history1024 = pickle.load(file)
train_acc_1024_rf64_relu = history1024['accuracy']  
train_loss_1024_rf64_relu = history1024['loss']
val_acc_1024_rf64_relu = history1024['val_accuracy']  
val_loss_1024_rf64_relu = history1024['val_loss']

total_inf_time = '\log\\fashion_mnist\ViP\\random_feature_64_relu\\total_inf_time'
total_inf_time = curr_dir + total_inf_time
with open(total_inf_time, 'rb') as file:
    history_time_rf64_relu = pickle.load(file)
total_time_rf64_relu = history_time_rf64_relu[0]  
inference_time_rf64_relu = history_time_rf64_relu[1]

# %%
fig, ax1 = plt.subplots()
plt.title("Train Accuracy and Loss Over Epochs (rf=64 and ReLu)")
plt.xlabel("Epochs")

ax1.plot(train_acc_16_rf64_relu, color='r', label='L=16')
ax1.plot(train_acc_64_rf64_relu, color='g', label='L=64')
ax1.plot(train_acc_256_rf64_relu, color='m', label='L=256')
ax1.plot(train_acc_1024_rf64_relu, color='c', label='L=1024')
ax1.set_ylabel("Accuracy")

ax2 = ax1.twinx()
ax2.plot(train_loss_16_rf64_relu, '-.', color='r', label='L=16')
ax2.plot(train_loss_64_rf64_relu, '-.', color='g', label='L=64')
ax2.plot(train_loss_256_rf64_relu, '-.', color='m', label='L=256')
ax2.plot(train_loss_1024_rf64_relu, '-.', color='c', label='L=1024')
ax2.set_ylabel("Loss")

acc_handle = plt.Line2D([], [], linestyle='-')
loss_handle = plt.Line2D([], [], linestyle='-.')
red_proxy = plt.Rectangle((0, 0), 1, 1, fc='r')
green_proxy = plt.Rectangle((0, 0), 1, 1, fc='g')
m_proxy = plt.Rectangle((0, 0), 1, 1, fc='m')
c_proxy = plt.Rectangle((0, 0), 1, 1, fc='c')

plt.legend(handles=[red_proxy, green_proxy, m_proxy, c_proxy, acc_handle, loss_handle],
          labels=['L=16', 'L=64', 'L=256', 'L=1024', 'Accuracy', 'Loss'],
          loc='upper left')
plt.grid()

# %%
fig, ax1 = plt.subplots()
plt.title("Validation Accuracy and Loss Over Epochs (rf=64 and ReLu)")
plt.xlabel("Epochs")

ax1.plot(val_acc_16_rf64_relu, color='r', label='L=16')
ax1.plot(val_acc_64_rf64_relu, color='g', label='L=64')
ax1.plot(val_acc_256_rf64_relu, color='m', label='L=256')
ax1.plot(val_acc_1024_rf64_relu, color='c', label='L=1024')
ax1.set_ylabel("Accuracy")

ax2 = ax1.twinx()
ax2.plot(val_loss_16_rf64_relu, '-.', color='r', label='L=16')
ax2.plot(val_loss_64_rf64_relu, '-.', color='g', label='L=64')
ax2.plot(val_loss_256_rf64_relu, '-.', color='m', label='L=256')
ax2.plot(val_loss_1024_rf64_relu, '-.', color='c', label='L=1024')
ax2.set_ylabel("Loss")

acc_handle = plt.Line2D([], [], linestyle='-')
loss_handle = plt.Line2D([], [], linestyle='-.')
red_proxy = plt.Rectangle((0, 0), 1, 1, fc='r')
green_proxy = plt.Rectangle((0, 0), 1, 1, fc='g')
m_proxy = plt.Rectangle((0, 0), 1, 1, fc='m')
c_proxy = plt.Rectangle((0, 0), 1, 1, fc='c')

plt.legend(handles=[red_proxy, green_proxy, m_proxy, c_proxy, acc_handle, loss_handle],
          labels=['L=16', 'L=64', 'L=256', 'L=1024', 'Accuracy', 'Loss'],
          loc='upper left')
plt.grid()

# %% [markdown]
# # random_feature=128 (ReLu)

# %%
log_name_16 = '\log\\fashion_mnist\ViP\\random_feature_128_relu\L_16.pkl'
log_path_16 = curr_dir + log_name_16
with open(log_path_16, 'rb') as file:
    history16 = pickle.load(file)
train_acc_16_rf128_relu = history16['accuracy']  
train_loss_16_rf128_relu = history16['loss']
val_acc_16_rf128_relu = history16['val_accuracy']  
val_loss_16_rf128_relu = history16['val_loss']

log_name_64 = '\log\\fashion_mnist\ViP\\random_feature_128_relu\L_64.pkl'
log_path_64 = curr_dir + log_name_64
with open(log_path_64, 'rb') as file:
    history64 = pickle.load(file)
train_acc_64_rf128_relu = history64['accuracy']      
train_loss_64_rf128_relu = history64['loss']
val_acc_64_rf128_relu = history64['val_accuracy']      
val_loss_64_rf128_relu = history64['val_loss']

log_name_256 = '\log\\fashion_mnist\ViP\\random_feature_128_relu\L_256.pkl'
log_path_256 = curr_dir + log_name_256
with open(log_path_256, 'rb') as file:
    history256 = pickle.load(file)
train_acc_256_rf128_relu = history256['accuracy']  
train_loss_256_rf128_relu = history256['loss']
val_acc_256_rf128_relu = history256['val_accuracy']  
val_loss_256_rf128_relu = history256['val_loss']

log_name_1024 = '\log\\fashion_mnist\ViP\\random_feature_128_relu\L_1024.pkl'
log_path_1024 = curr_dir + log_name_1024
with open(log_path_1024, 'rb') as file:
    history1024 = pickle.load(file)
train_acc_1024_rf128_relu = history1024['accuracy']  
train_loss_1024_rf128_relu = history1024['loss']
val_acc_1024_rf128_relu = history1024['val_accuracy']  
val_loss_1024_rf128_relu = history1024['val_loss']

total_inf_time = '\log\\fashion_mnist\ViP\\random_feature_128_relu\\total_inf_time'
total_inf_time = curr_dir + total_inf_time
with open(total_inf_time, 'rb') as file:
    history_time_rf128_relu = pickle.load(file)
total_time_rf128_relu = history_time_rf128_relu[0]  
inference_time_rf128_relu = history_time_rf128_relu[1]

# %%
fig, ax1 = plt.subplots()
plt.title("Train Accuracy and Loss Over Epochs (rf=128 and ReLu)")
plt.xlabel("Epochs")

ax1.plot(train_acc_16_rf128_relu, color='r', label='L=16')
ax1.plot(train_acc_64_rf128_relu, color='g', label='L=64')
ax1.plot(train_acc_256_rf128_relu, color='m', label='L=256')
ax1.plot(train_acc_1024_rf128_relu, color='c', label='L=1024')
ax1.set_ylabel("Accuracy")

ax2 = ax1.twinx()
ax2.plot(train_loss_16_rf128_relu, '-.', color='r', label='L=16')
ax2.plot(train_loss_64_rf128_relu, '-.', color='g', label='L=64')
ax2.plot(train_loss_256_rf128_relu, '-.', color='m', label='L=256')
ax2.plot(train_loss_1024_rf128_relu, '-.', color='c', label='L=1024')
ax2.set_ylabel("Loss")

acc_handle = plt.Line2D([], [], linestyle='-')
loss_handle = plt.Line2D([], [], linestyle='-.')
red_proxy = plt.Rectangle((0, 0), 1, 1, fc='r')
green_proxy = plt.Rectangle((0, 0), 1, 1, fc='g')
m_proxy = plt.Rectangle((0, 0), 1, 1, fc='m')
c_proxy = plt.Rectangle((0, 0), 1, 1, fc='c')

plt.legend(handles=[red_proxy, green_proxy, m_proxy, c_proxy, acc_handle, loss_handle],
          labels=['L=16', 'L=64', 'L=256', 'L=1024', 'Accuracy', 'Loss'],
          loc='upper left')
plt.grid()

# %%
fig, ax1 = plt.subplots()
plt.title("Validation Accuracy and Loss Over Epochs (rf=128 and ReLu)")
plt.xlabel("Epochs")

ax1.plot(val_acc_16_rf128_relu, color='r', label='L=16')
ax1.plot(val_acc_64_rf128_relu, color='g', label='L=64')
ax1.plot(val_acc_256_rf128_relu, color='m', label='L=256')
ax1.plot(val_acc_1024_rf128_relu, color='c', label='L=1024')
ax1.set_ylabel("Accuracy")

ax2 = ax1.twinx()
ax2.plot(val_loss_16_rf128_relu, '-.', color='r', label='L=16')
ax2.plot(val_loss_64_rf128_relu, '-.', color='g', label='L=64')
ax2.plot(val_loss_256_rf128_relu, '-.', color='m', label='L=256')
ax2.plot(val_loss_1024_rf128_relu, '-.', color='c', label='L=1024')
ax2.set_ylabel("Loss")

acc_handle = plt.Line2D([], [], linestyle='-')
loss_handle = plt.Line2D([], [], linestyle='-.')
red_proxy = plt.Rectangle((0, 0), 1, 1, fc='r')
green_proxy = plt.Rectangle((0, 0), 1, 1, fc='g')
m_proxy = plt.Rectangle((0, 0), 1, 1, fc='m')
c_proxy = plt.Rectangle((0, 0), 1, 1, fc='c')

plt.legend(handles=[red_proxy, green_proxy, m_proxy, c_proxy, acc_handle, loss_handle],
          labels=['L=16', 'L=64', 'L=256', 'L=1024', 'Accuracy', 'Loss'],
          loc='upper left')
plt.grid()

# %% [markdown]
# # Comparisons

# %% [markdown]
# ## Accuracy and Loss (L=1024)

# %%
plt.title("Validation accuracy over different models (L=1024)")
plt.xlabel("Epochs")
plt.plot(val_acc_1024_rf16, color='r', label='ViP with RF_16_softmax')
plt.plot(val_acc_1024_rf32, color='g', label='ViP with RF_32_softmax')
plt.plot(val_acc_1024_rf64, color='m', label='ViP with RF_64_softmax')
plt.plot(val_acc_1024_rf128, color='c', label='ViP with RF_128_softmax')

plt.plot(val_acc_1024_rf16_relu, '-.', color='r', label='ViP with RF_16_softmax')
plt.plot(val_acc_1024_rf32_relu, '-.', color='g', label='ViP with RF_32_softmax')
plt.plot(val_acc_1024_rf64_relu, '-.', color='m', label='ViP with RF_64_softmax')
plt.plot(val_acc_1024_rf128_relu, '-.', color='c', label='ViP with RF_128_softmax')
plt.ylabel("Accuracy")

softmax_handle = plt.Line2D([], [], linestyle='-')
relu_handle = plt.Line2D([], [], linestyle='-.')
red_proxy = plt.Rectangle((0, 0), 1, 1, fc='r')
green_proxy = plt.Rectangle((0, 0), 1, 1, fc='g')
m_proxy = plt.Rectangle((0, 0), 1, 1, fc='m')
c_proxy = plt.Rectangle((0, 0), 1, 1, fc='c')

plt.legend(handles=[red_proxy, green_proxy, m_proxy, c_proxy, softmax_handle, relu_handle],
          labels=['random_features=16', 'random_features=32', 'random_features=64', 'random_features=128', 'softmax', 'relu'])
plt.grid()

# %%
plt.title("Validation loss over different models (L=1024)")
plt.xlabel("Epochs")
plt.plot(val_loss_1024_rf16, color='r', label='ViP with RF_16_softmax')
plt.plot(val_loss_1024_rf32, color='g', label='ViP with RF_32_softmax')
plt.plot(val_loss_1024_rf64, color='m', label='ViP with RF_64_softmax')
plt.plot(val_loss_1024_rf128, color='c', label='ViP with RF_128_softmax')

plt.plot(val_loss_1024_rf16_relu, '-.', color='r', label='ViP with RF_16_softmax')
plt.plot(val_loss_1024_rf32_relu, '-.', color='g', label='ViP with RF_32_softmax')
plt.plot(val_loss_1024_rf64_relu, '-.', color='m', label='ViP with RF_64_softmax')
plt.plot(val_loss_1024_rf128_relu, '-.', color='c', label='ViP with RF_128_softmax')
plt.ylabel("Accuracy")

softmax_handle = plt.Line2D([], [], linestyle='-')
relu_handle = plt.Line2D([], [], linestyle='-.')
red_proxy = plt.Rectangle((0, 0), 1, 1, fc='r')
green_proxy = plt.Rectangle((0, 0), 1, 1, fc='g')
m_proxy = plt.Rectangle((0, 0), 1, 1, fc='m')
c_proxy = plt.Rectangle((0, 0), 1, 1, fc='c')

plt.legend(handles=[red_proxy, green_proxy, m_proxy, c_proxy, softmax_handle, relu_handle],
          labels=['random_features=16', 'random_features=32', 'random_features=64', 'random_features=128', 'softmax', 'ReLu'])
plt.grid()

# %% [markdown]
# ## Comparison rf=128

# %%
fig, ax1 = plt.subplots()
plt.title("Validation Accuracy and Loss Over Epochs (L=1024 and rf=128)")
plt.xlabel("Epochs")
ax1.plot(val_acc_1024, color='r', label='ViT')
ax1.plot(val_acc_1024_rf128, color='g', label='softmax')
ax1.plot(val_acc_1024_rf128_relu, color='m', label='relu')
ax1.set_ylabel("Accuracy")

ax2 = ax1.twinx()
ax2.plot(val_loss_1024, '-.', color='r', label='ViT')
ax2.plot(val_loss_1024_rf128, '-.', color='g', label='softmax')
ax2.plot(val_loss_1024_rf128_relu, '-.', color='m', label='relu')
ax2.set_ylabel("Loss")

acc_handle = plt.Line2D([], [], linestyle='-')
loss_handle = plt.Line2D([], [], linestyle='-.')
red_proxy = plt.Rectangle((0, 0), 1, 1, fc='r')
green_proxy = plt.Rectangle((0, 0), 1, 1, fc='g')
m_proxy = plt.Rectangle((0, 0), 1, 1, fc='m')

plt.legend(handles=[red_proxy, green_proxy, m_proxy, acc_handle, loss_handle],
          labels=['ViT', 'ViP with softmax', 'ViP with ReLu', 'Accuracy', 'Loss'],
          loc='upper left')
plt.grid()

# %% [markdown]
# ## Time

# %%
plt.title(f'Total training time over {num_epochs} epochs (softmax)')
plt.xlabel('log2(L)')
plt.plot(logL, total_time, label='ViT')
plt.plot(logL, total_time_rf16, label='ViP with RF_16')
plt.plot(logL, total_time_rf32, label='ViP with RF_32')
plt.plot(logL, total_time_rf64, label='ViP with RF_64')
plt.plot(logL, total_time_rf128, label='ViP with RF_128')
plt.ylabel('Time (sec)')
plt.legend(loc='upper left')
plt.grid()

# %%
plt.title(f'Total training time over {num_epochs} epochs (ReLu)')
plt.xlabel('log2(L)')
plt.plot(logL, total_time, label='ViT')
plt.plot(logL, total_time_rf16_relu, label='ViP with RF_16')
plt.plot(logL, total_time_rf32_relu, label='ViP with RF_32')
plt.plot(logL, total_time_rf64_relu, label='ViP with RF_64')
plt.plot(logL, total_time_rf128_relu, label='ViP with RF_128')
plt.ylabel('Time (sec)')
plt.legend(loc='upper left')
plt.grid()

# %%
plt.title(f'Inference time over on validation dataset')
plt.xlabel('log2(L)')
plt.plot(logL, inference_time, label='ViT')
plt.plot(logL, inference_time_rf16, label='ViP with RF_16_softmax')
plt.plot(logL, inference_time_rf32, label='ViP with RF_32_softmax')
plt.plot(logL, inference_time_rf64, label='ViP with RF_64_softmax')
plt.plot(logL, inference_time_rf128, label='ViP with RF_128_softmax')
plt.plot(logL, inference_time_rf128_relu, label='ViP with RF_128_relu')
plt.ylabel('Time (ms)')
plt.legend(loc='upper right')
plt.grid()
