# %% [markdown]
# # ViT Classification on CIFAR-10

# %%
import tensorflow as tf
import tensorflow_addons as tfa
import numpy as np
import matplotlib.pyplot as plt
import time
import datetime
import sys
import os
import pickle

# check GPU
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import tensorflow_datasets as tfds
train_dataset, info = tfds.load('cifar10', split='train', shuffle_files=True, with_info=True)
val_dataset = tfds.load('cifar10', split='test', shuffle_files=False)

# number of samples
num_train_samples = tf.data.experimental.cardinality(train_dataset).numpy()
num_val_samples = tf.data.experimental.cardinality(val_dataset).numpy()
print('Number of training samples:', num_train_samples)
print('Number of validation samples:', num_val_samples)

# size of image
for example in train_dataset.take(1):
    image, label = example['image'], example['label']
print('Image size:', image.shape)

# number of classes
num_classes = info.features['label'].num_classes
print('Number of classes: ', num_classes)
# Out:
# Number of training samples: 50000
# Number of validation samples: 10000
# Image size: (32, 32, 3)
# Number of classes:  10

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
batch_size = 64

def extract_image_and_label(example):
    image, label = example['image'], example['label']
    image = tf.cast(image, tf.float32)
    return image, label

# extract image and label from dataloader
train_ds = train_dataset.map(extract_image_and_label)
val_ds = val_dataset.map(extract_image_and_label)

# batch train_ds and val_ds
train_ds = train_ds.batch(batch_size)
val_ds = val_ds.batch(batch_size)

# input pipeline optimization
train_ds = train_ds.cache().prefetch(AUTOTUNE)
val_ds = val_ds.cache().prefetch(AUTOTUNE)

# %%
curr_dir = os.getcwd() 
parent_dir = os.path.abspath(os.path.join(curr_dir, os.pardir))
implementation_dir = os.path.abspath(os.path.join(parent_dir, os.pardir))
main_dir = os.path.abspath(os.path.join(implementation_dir, os.pardir))

sys.path.append(main_dir)

# %%
from model.vision_transformer import VisionTransformer
# compiler attributes
lr = 1e-4
weight_decay = 1e-4
num_epochs = 50

# VisionTransformer attributes
input_shape = image.shape # [32, 32, 3]
image_size = image.shape[0] # 32
num_layers = 6
num_classes = num_classes # 10
d_model = 64
num_heads = 1
mlp_dim = 64

# %% [markdown]
# # L = 16

# %%
patch_size = 8
model_16 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=input_shape),
    VisionTransformer(image_size=image_size, patch_size=patch_size, num_layers=num_layers,
                      num_classes=num_classes, d_model=d_model, num_heads=num_heads, mlp_dim=mlp_dim),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(10, activation='softmax')
])

model_16.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
             optimizer=tfa.optimizers.AdamW(learning_rate=lr, weight_decay=weight_decay),
             metrics=['accuracy']) 

model_16.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vision_transformer (VisionT  (None, 10)               169738
#  ransformer)
#
#  flatten (Flatten)           (None, 10)                0
#
#  dense_39 (Dense)            (None, 10)                110
#
# =================================================================
# Total params: 169,848
# Trainable params: 169,848
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_name = 'L_16'
path = main_dir + '\model_checkpoints\cifar10\ViT\\' + model_name

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=path,
    save_best_only=True,
    save_weights_only=True,
    monitor='val_loss',
    mode='min'
)

#train model
start_time = time.time()
history_16 = model_16.fit(
    train_ds,
    epochs=num_epochs,
    validation_data=val_ds,
    callbacks=[model_checkpoint_callback]
)
end_time = time.time()
total_time_16 = end_time-start_time
# Out:
# Epoch 1/50
# 782/782 [==============================] - 61s 63ms/step - loss: 2.0627 - accuracy: 0.2177 - val_loss: 1.8960 - val_accuracy: 0.2851
# Epoch 2/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.8791 - accuracy: 0.3041 - val_loss: 1.7985 - val_accuracy: 0.3432
# Epoch 3/50
# 782/782 [==============================] - 47s 61ms/step - loss: 1.7969 - accuracy: 0.3406 - val_loss: 1.7253 - val_accuracy: 0.3743
# Epoch 4/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.7420 - accuracy: 0.3602 - val_loss: 1.7015 - val_accuracy: 0.3872
# Epoch 5/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.6987 - accuracy: 0.3769 - val_loss: 1.6694 - val_accuracy: 0.3972
# Epoch 6/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.6683 - accuracy: 0.3915 - val_loss: 1.6404 - val_accuracy: 0.4062
# Epoch 7/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.6445 - accuracy: 0.4012 - val_loss: 1.6092 - val_accuracy: 0.4189
# Epoch 8/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.6227 - accuracy: 0.4088 - val_loss: 1.6026 - val_accuracy: 0.4206
# Epoch 9/50
# 782/782 [==============================] - 48s 61ms/step - loss: 1.6073 - accuracy: 0.4152 - val_loss: 1.5765 - val_accuracy: 0.4286
# Epoch 10/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.5890 - accuracy: 0.4232 - val_loss: 1.5914 - val_accuracy: 0.4239
# Epoch 11/50
# 782/782 [==============================] - 47s 61ms/step - loss: 1.5784 - accuracy: 0.4258 - val_loss: 1.5815 - val_accuracy: 0.4220
# Epoch 12/50
# 782/782 [==============================] - 47s 61ms/step - loss: 1.5697 - accuracy: 0.4307 - val_loss: 1.5588 - val_accuracy: 0.4341
# Epoch 13/50
# 782/782 [==============================] - 47s 61ms/step - loss: 1.5586 - accuracy: 0.4355 - val_loss: 1.5422 - val_accuracy: 0.4404
# Epoch 14/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.5491 - accuracy: 0.4386 - val_loss: 1.5464 - val_accuracy: 0.4367
# Epoch 15/50
# 782/782 [==============================] - 48s 61ms/step - loss: 1.5433 - accuracy: 0.4408 - val_loss: 1.5374 - val_accuracy: 0.4393
# Epoch 16/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.5384 - accuracy: 0.4418 - val_loss: 1.5308 - val_accuracy: 0.4433
# Epoch 17/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.5317 - accuracy: 0.4443 - val_loss: 1.5325 - val_accuracy: 0.4441
# Epoch 18/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.5291 - accuracy: 0.4442 - val_loss: 1.5333 - val_accuracy: 0.4444
# Epoch 19/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.5212 - accuracy: 0.4479 - val_loss: 1.5221 - val_accuracy: 0.4451
# Epoch 20/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.5178 - accuracy: 0.4505 - val_loss: 1.4938 - val_accuracy: 0.4544
# 782/782 [==============================] - 47s 60ms/step - loss: 1.5058 - accuracy: 0.4531 - val_loss: 1.5611 - val_accuracy: 0.4207
# Epoch 41/50
# 782/782 [==============================] - 48s 61ms/step - loss: 1.5082 - accuracy: 0.4523 - val_loss: 1.5078 - val_accuracy: 0.4450
# Epoch 42/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.5090 - accuracy: 0.4502 - val_loss: 1.5390 - val_accuracy: 0.4302
# Epoch 43/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.5078 - accuracy: 0.4501 - val_loss: 1.5404 - val_accuracy: 0.4363
# Epoch 44/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.5080 - accuracy: 0.4504 - val_loss: 1.5393 - val_accuracy: 0.4357
# Epoch 45/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.5088 - accuracy: 0.4501 - val_loss: 1.5302 - val_accuracy: 0.4310
# Epoch 46/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.5052 - accuracy: 0.4530 - val_loss: 1.5651 - val_accuracy: 0.4245
# Epoch 47/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.5084 - accuracy: 0.4495 - val_loss: 1.5538 - val_accuracy: 0.4299
# Epoch 48/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.5072 - accuracy: 0.4502 - val_loss: 1.5366 - val_accuracy: 0.4310
# Epoch 49/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.5073 - accuracy: 0.4512 - val_loss: 1.5304 - val_accuracy: 0.4372
# Epoch 50/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.5082 - accuracy: 0.4497 - val_loss: 1.5281 - val_accuracy: 0.4376

# %%
from utils import inf_time_check
print(f'Training time {round((total_time_16),3)} sec for {num_epochs} epochs.')
inference_time_16 = inf_time_check(model_16, val_ds)
print(f'Inference time {inference_time_16} ms for {num_val_samples} samples.')
# Out:
# Training time 2369.183 sec for 50 epochs.
# 64/64 [==============================] - 2s 15ms/step
# 64/64 [==============================] - 1s 14ms/step
# 64/64 [==============================] - 1s 14ms/step
# 64/64 [==============================] - 1s 14ms/step
# 64/64 [==============================] - 1s 14ms/step
# Inference time 1123.014 ms for 10000 samples.

# %%
log_name_16 = '\log\cifar10\ViT\L_16.pkl'
log_path_16 = main_dir + log_name_16
with open(log_path_16, 'wb') as file:
    pickle.dump(history_16.history, file)

# %%
# plot accuracy curve
plt.plot(history_16.history["accuracy"], label="Train Accuracy")
plt.plot(history_16.history["val_accuracy"], label="Validation Accuracy")
plt.title("Train and Validation Accuracy Over Epochs L=16")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()

# %%
# plot loss curve
plt.plot(history_16.history["loss"], label="Train Loss")
plt.plot(history_16.history["val_loss"], label="Validation Loss")
plt.title("Train and Validation Loss Over Epochs L=16")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# %% [markdown]
# # L = 64

# %%
patch_size = 4
model_64 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=input_shape),
    VisionTransformer(image_size=image_size, patch_size=patch_size, num_layers=num_layers,
                      num_classes=num_classes, d_model=d_model, num_heads=num_heads, mlp_dim=mlp_dim),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(10, activation='softmax')
])

model_64.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
             optimizer=tfa.optimizers.AdamW(learning_rate=lr, weight_decay=weight_decay),
             metrics=['accuracy']) 

model_64.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vision_transformer_1 (Visio  (None, 10)               163594
#  nTransformer)
#
#  flatten_1 (Flatten)         (None, 10)                0
#
#  dense_79 (Dense)            (None, 10)                110
#
# =================================================================
# Total params: 163,704
# Trainable params: 163,704
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_name = 'L_64'
path = main_dir + '\model_checkpoints\cifar10\ViT\\' + model_name

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=path,
    save_best_only=True,
    save_weights_only=True,
    monitor='val_loss',
    mode='min'
)

#train model
start_time = time.time()
history_64 = model_64.fit(
    train_ds,
    epochs=num_epochs,
    validation_data=val_ds,
    callbacks=[model_checkpoint_callback]
)
end_time = time.time()
total_time_64 = end_time-start_time
# Out:
# Epoch 1/50
# 782/782 [==============================] - 49s 55ms/step - loss: 2.1058 - accuracy: 0.2050 - val_loss: 1.8908 - val_accuracy: 0.3011
# Epoch 2/50
# 782/782 [==============================] - 41s 53ms/step - loss: 1.8608 - accuracy: 0.3026 - val_loss: 1.7698 - val_accuracy: 0.3555
# Epoch 3/50
# 782/782 [==============================] - 41s 52ms/step - loss: 1.7654 - accuracy: 0.3478 - val_loss: 1.6989 - val_accuracy: 0.3818
# Epoch 4/50
# 782/782 [==============================] - 41s 53ms/step - loss: 1.7064 - accuracy: 0.3720 - val_loss: 1.6449 - val_accuracy: 0.3983
# Epoch 5/50
# 782/782 [==============================] - 41s 52ms/step - loss: 1.6631 - accuracy: 0.3901 - val_loss: 1.6260 - val_accuracy: 0.4061
# Epoch 6/50
# 782/782 [==============================] - 41s 53ms/step - loss: 1.6288 - accuracy: 0.4016 - val_loss: 1.5886 - val_accuracy: 0.4168
# Epoch 7/50
# 782/782 [==============================] - 41s 53ms/step - loss: 1.5952 - accuracy: 0.4188 - val_loss: 1.5481 - val_accuracy: 0.4316
# Epoch 8/50
# 782/782 [==============================] - 41s 53ms/step - loss: 1.5671 - accuracy: 0.4290 - val_loss: 1.5365 - val_accuracy: 0.4395
# Epoch 9/50
# 782/782 [==============================] - 41s 52ms/step - loss: 1.5398 - accuracy: 0.4384 - val_loss: 1.5250 - val_accuracy: 0.4428
# Epoch 10/50
# 782/782 [==============================] - 41s 53ms/step - loss: 1.5146 - accuracy: 0.4514 - val_loss: 1.5097 - val_accuracy: 0.4446
# Epoch 11/50
# 782/782 [==============================] - 41s 53ms/step - loss: 1.4929 - accuracy: 0.4595 - val_loss: 1.4750 - val_accuracy: 0.4593
# Epoch 12/50
# 782/782 [==============================] - 41s 52ms/step - loss: 1.4754 - accuracy: 0.4650 - val_loss: 1.4483 - val_accuracy: 0.4712
# Epoch 13/50
# 782/782 [==============================] - 41s 52ms/step - loss: 1.4634 - accuracy: 0.4696 - val_loss: 1.4612 - val_accuracy: 0.4614
# Epoch 14/50
# 782/782 [==============================] - 41s 53ms/step - loss: 1.4519 - accuracy: 0.4732 - val_loss: 1.4461 - val_accuracy: 0.4740
# Epoch 15/50
# Epoch 35/50
# 782/782 [==============================] - 41s 52ms/step - loss: 1.3958 - accuracy: 0.4953 - val_loss: 1.4624 - val_accuracy: 0.4615
# Epoch 36/50
# 782/782 [==============================] - 41s 52ms/step - loss: 1.3977 - accuracy: 0.4955 - val_loss: 1.4660 - val_accuracy: 0.4638
# Epoch 37/50
# 782/782 [==============================] - 41s 53ms/step - loss: 1.3995 - accuracy: 0.4946 - val_loss: 1.4641 - val_accuracy: 0.4589
# Epoch 38/50
# 782/782 [==============================] - 41s 52ms/step - loss: 1.4010 - accuracy: 0.4936 - val_loss: 1.5341 - val_accuracy: 0.4367
# Epoch 39/50
# 782/782 [==============================] - 41s 52ms/step - loss: 1.4031 - accuracy: 0.4914 - val_loss: 1.4259 - val_accuracy: 0.4730
# Epoch 40/50
# 782/782 [==============================] - 41s 53ms/step - loss: 1.4022 - accuracy: 0.4928 - val_loss: 1.4940 - val_accuracy: 0.4469
# Epoch 41/50
# 782/782 [==============================] - 41s 52ms/step - loss: 1.4034 - accuracy: 0.4940 - val_loss: 1.4507 - val_accuracy: 0.4670
# Epoch 42/50
# 782/782 [==============================] - 41s 52ms/step - loss: 1.4041 - accuracy: 0.4931 - val_loss: 1.4243 - val_accuracy: 0.4725
# Epoch 43/50
# 782/782 [==============================] - 41s 52ms/step - loss: 1.4023 - accuracy: 0.4940 - val_loss: 1.4249 - val_accuracy: 0.4756
# Epoch 44/50
# 782/782 [==============================] - 41s 52ms/step - loss: 1.4055 - accuracy: 0.4926 - val_loss: 1.4621 - val_accuracy: 0.4518
# Epoch 45/50
# 782/782 [==============================] - 40s 52ms/step - loss: 1.4067 - accuracy: 0.4900 - val_loss: 1.4171 - val_accuracy: 0.4767
# Epoch 46/50
# 782/782 [==============================] - 41s 52ms/step - loss: 1.4061 - accuracy: 0.4904 - val_loss: 1.4852 - val_accuracy: 0.4508
# Epoch 47/50
# 782/782 [==============================] - 41s 52ms/step - loss: 1.4066 - accuracy: 0.4904 - val_loss: 1.4307 - val_accuracy: 0.4684
# Epoch 48/50
# 782/782 [==============================] - 41s 52ms/step - loss: 1.4075 - accuracy: 0.4918 - val_loss: 1.4150 - val_accuracy: 0.4795
# Epoch 49/50
# 782/782 [==============================] - 41s 52ms/step - loss: 1.4012 - accuracy: 0.4939 - val_loss: 1.4324 - val_accuracy: 0.4779
# Epoch 50/50
# 782/782 [==============================] - 41s 52ms/step - loss: 1.4029 - accuracy: 0.4929 - val_loss: 1.3899 - val_accuracy: 0.4950

# %%
print(f'Training time {round((total_time_64),3)} sec for {num_epochs} epochs.')
inference_time_64 = inf_time_check(model_64, val_ds)
print(f'Inference time {inference_time_64} ms for {num_val_samples} samples.')
# Out:
# Training time 2052.402 sec for 50 epochs.
# 64/64 [==============================] - 2s 14ms/step
# 64/64 [==============================] - 1s 13ms/step
# 64/64 [==============================] - 1s 13ms/step
# 64/64 [==============================] - 1s 13ms/step
# 64/64 [==============================] - 1s 13ms/step
# Inference time 1041.853 ms for 10000 samples.

# %%
log_name_64 = '\log\cifar10\ViT\L_64.pkl'
log_path_64 = main_dir + log_name_64
with open(log_path_64, 'wb') as file:
    pickle.dump(history_64.history, file)

# %%
# plot accuracy curve
plt.plot(history_64.history["accuracy"], label="Train Accuracy")
plt.plot(history_64.history["val_accuracy"], label="Validation Accuracy")
plt.title("Train and Validation Accuracy Over Epochs L=64")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()

# %%
# plot loss curve
plt.plot(history_64.history["loss"], label="Train Loss")
plt.plot(history_64.history["val_loss"], label="Validation Loss")
plt.title("Train and Validation Loss Over Epochs L=64")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# %% [markdown]
# # L = 256

# %%
patch_size = 2
model_256 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=input_shape),
    VisionTransformer(image_size=image_size, patch_size=patch_size, num_layers=num_layers,
                      num_classes=num_classes, d_model=d_model, num_heads=num_heads, mlp_dim=mlp_dim),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(10, activation='softmax')
])

model_256.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
             optimizer=tfa.optimizers.AdamW(learning_rate=lr, weight_decay=weight_decay),
             metrics=['accuracy']) 

model_256.summary()
# Out:
# Model: "sequential_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vision_transformer_2 (Visio  (None, 10)               173578
#  nTransformer)
#
#  flatten_2 (Flatten)         (None, 10)                0
#
#  dense_119 (Dense)           (None, 10)                110
#
# =================================================================
# Total params: 173,688
# Trainable params: 173,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_name = 'L_256'
path = main_dir + '\model_checkpoints\cifar10\ViT\\' + model_name

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=path,
    save_best_only=True,
    save_weights_only=True,
    monitor='val_loss',
    mode='min'
)

#train model
start_time = time.time()
history_256 = model_256.fit(
    train_ds,
    epochs=num_epochs,
    validation_data=val_ds,
    callbacks=[model_checkpoint_callback]
)
end_time = time.time()
total_time_256 = end_time-start_time
# Out:
# Epoch 1/50
# 782/782 [==============================] - 61s 69ms/step - loss: 2.0246 - accuracy: 0.2325 - val_loss: 1.7776 - val_accuracy: 0.3394
# Epoch 2/50
# 782/782 [==============================] - 53s 67ms/step - loss: 1.7883 - accuracy: 0.3300 - val_loss: 1.6960 - val_accuracy: 0.3763
# Epoch 3/50
# 782/782 [==============================] - 53s 67ms/step - loss: 1.7078 - accuracy: 0.3690 - val_loss: 1.6603 - val_accuracy: 0.3903
# Epoch 4/50
# 782/782 [==============================] - 53s 67ms/step - loss: 1.6610 - accuracy: 0.3862 - val_loss: 1.6103 - val_accuracy: 0.4104
# Epoch 5/50
# 782/782 [==============================] - 53s 67ms/step - loss: 1.6214 - accuracy: 0.4027 - val_loss: 1.5819 - val_accuracy: 0.4207
# Epoch 6/50
# 782/782 [==============================] - 53s 67ms/step - loss: 1.5877 - accuracy: 0.4180 - val_loss: 1.5473 - val_accuracy: 0.4366
# Epoch 7/50
# 782/782 [==============================] - 53s 67ms/step - loss: 1.5512 - accuracy: 0.4311 - val_loss: 1.5129 - val_accuracy: 0.4486
# Epoch 8/50
# 782/782 [==============================] - 53s 67ms/step - loss: 1.5174 - accuracy: 0.4496 - val_loss: 1.4885 - val_accuracy: 0.4608
# Epoch 9/50
# 782/782 [==============================] - 52s 67ms/step - loss: 1.4864 - accuracy: 0.4618 - val_loss: 1.4664 - val_accuracy: 0.4694
# Epoch 10/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.3739 - accuracy: 0.5080 - val_loss: 1.3717 - val_accuracy: 0.4947
# Epoch 50/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.3786 - accuracy: 0.5027 - val_loss: 1.3711 - val_accuracy: 0.4970

# %%
from utils import inf_time_check
print(f'Training time {round((total_time_256),3)} sec for {num_epochs} epochs.')
inference_time_256 = inf_time_check(model_256, val_ds)
print(f'Inference time {inference_time_256} ms for {num_val_samples} samples.')
# Out:
# Training time 2636.716 sec for 50 epochs.
# 64/64 [==============================] - 1s 8ms/step
# 64/64 [==============================] - 1s 8ms/step
# 64/64 [==============================] - 1s 9ms/step
# 64/64 [==============================] - 1s 9ms/step
# 64/64 [==============================] - 1s 9ms/step
# Inference time 748.959 ms for 10000 samples.

# %%
log_name_256 = '\log\cifar10\ViT\L_256.pkl'
log_path_256 = main_dir + log_name_256
with open(log_path_256, 'wb') as file:
    pickle.dump(history_256.history, file)

# %%
# plot accuracy curve
plt.plot(history_256.history["accuracy"], label="Train Accuracy")
plt.plot(history_256.history["val_accuracy"], label="Validation Accuracy")
plt.title("Train and Validation Accuracy Over Epochs L=256")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()

# %%
# plot loss curve
plt.plot(history_256.history["loss"], label="Train Loss")
plt.plot(history_256.history["val_loss"], label="Validation Loss")
plt.title("Train and Validation Loss Over Epochs L=256")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# %% [markdown]
# # L = 1024

# %%
patch_size = 1
model_1024 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=input_shape),
    VisionTransformer(image_size=image_size, patch_size=patch_size, num_layers=num_layers,
                      num_classes=num_classes, d_model=d_model, num_heads=num_heads, mlp_dim=mlp_dim),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(10, activation='softmax')
])

model_1024.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
             optimizer=tfa.optimizers.AdamW(learning_rate=lr, weight_decay=weight_decay),
             metrics=['accuracy']) 

model_1024.summary()
# Out:
# Model: "sequential_31"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vision_transformer_3 (Visio  (None, 10)               222154
#  nTransformer)
#
#  flatten_3 (Flatten)         (None, 10)                0
#
#  dense_159 (Dense)           (None, 10)                110
#
# =================================================================
# Total params: 222,264
# Trainable params: 222,264
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_name = 'L_1024'
path = main_dir + '\model_checkpoints\cifar10\ViT\\' + model_name

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=path,
    save_best_only=True,
    save_weights_only=True,
    monitor='val_loss',
    mode='min'
)

#train model
start_time = time.time()
history_1024 = model_1024.fit(
    train_ds,
    epochs=num_epochs,
    validation_data=val_ds,
    callbacks=[model_checkpoint_callback]
)
end_time = time.time()
total_time_1024 = end_time-start_time
# Out:
# Epoch 1/50
# 782/782 [==============================] - 210s 260ms/step - loss: 2.0972 - accuracy: 0.2129 - val_loss: 1.9321 - val_accuracy: 0.2968
# Epoch 2/50
# 782/782 [==============================] - 202s 259ms/step - loss: 1.9008 - accuracy: 0.3018 - val_loss: 1.8180 - val_accuracy: 0.3384
# Epoch 3/50
# 782/782 [==============================] - 202s 259ms/step - loss: 1.8060 - accuracy: 0.3443 - val_loss: 1.7505 - val_accuracy: 0.3654
# Epoch 4/50
# 782/782 [==============================] - 202s 259ms/step - loss: 1.7441 - accuracy: 0.3714 - val_loss: 1.7050 - val_accuracy: 0.3863
# Epoch 44/50
# 782/782 [==============================] - 203s 259ms/step - loss: 1.5456 - accuracy: 0.4471 - val_loss: 1.5590 - val_accuracy: 0.4368
# Epoch 45/50
# 782/782 [==============================] - 203s 259ms/step - loss: 1.5478 - accuracy: 0.4486 - val_loss: 1.5703 - val_accuracy: 0.4311
# Epoch 46/50
# 782/782 [==============================] - 203s 259ms/step - loss: 1.5463 - accuracy: 0.4468 - val_loss: 1.5452 - val_accuracy: 0.4413
# Epoch 47/50
# 782/782 [==============================] - 203s 259ms/step - loss: 1.5441 - accuracy: 0.4487 - val_loss: 1.5696 - val_accuracy: 0.4336
# Epoch 48/50
# 782/782 [==============================] - 203s 259ms/step - loss: 1.5441 - accuracy: 0.4508 - val_loss: 1.5579 - val_accuracy: 0.4361
# Epoch 49/50
# 782/782 [==============================] - 203s 259ms/step - loss: 1.5459 - accuracy: 0.4466 - val_loss: 1.5539 - val_accuracy: 0.4356
# Epoch 50/50
# 782/782 [==============================] - 203s 259ms/step - loss: 1.5410 - accuracy: 0.4498 - val_loss: 1.5545 - val_accuracy: 0.4386

# %%
print(f'Training time {round((total_time_1024),3)} sec for {num_epochs} epochs.')
inference_time_1024 = inf_time_check(model_1024, val_ds)
print(f'Inference time {inference_time_1024} ms for {num_val_samples} samples.')
# Out:
# Training time 10139.954 sec for 50 epochs.
# 64/64 [==============================] - 1s 9ms/step
# 64/64 [==============================] - 1s 9ms/step
# 64/64 [==============================] - 1s 9ms/step
# 64/64 [==============================] - 1s 9ms/step
# 64/64 [==============================] - 1s 9ms/step
# Inference time 767.086 ms for 10000 samples.

# %%
log_name_1024 = '\log\cifar10\ViT\L_1024.pkl'
log_path_1024 = main_dir + log_name_1024
with open(log_path_1024, 'wb') as file:
    pickle.dump(history_1024.history, file)

# %%
# plot accuracy curve
plt.plot(history_1024.history["accuracy"], label="Train Accuracy")
plt.plot(history_1024.history["val_accuracy"], label="Validation Accuracy")
plt.title("Train and Validation Accuracy Over Epochs L=1024")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()

# %%
# plot loss curve
plt.plot(history_1024.history["loss"], label="Train Loss")
plt.plot(history_1024.history["val_loss"], label="Validation Loss")
plt.title("Train and Validation Loss Over Epochs L=1024")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# %%
total_time = [total_time_16, total_time_64, total_time_256, total_time_1024]
inference_time = [inference_time_16, inference_time_64, inference_time_256, inference_time_1024]
log = []
log.append(total_time)
log.append(inference_time)
log_name = '\log\cifar10\ViT\\total_inf_time'
log_path = main_dir + log_name
# log [total_time, inference_time]
with open(log_path, 'wb') as file:
    pickle.dump(log, file)

# %%
logL = np.log2([16, 64, 256, 1024])

fig, ax1 = plt.subplots()
plt.title(f'Inference time & Total training time over {num_epochs} epochs')
plt.xlabel('log2(L)')

ax1.plot(logL, total_time, color='blue', label='Total training time')
ax1.set_ylabel('Time (second)', color='blue')
ax1.legend(loc='upper right')

ax2 = ax1.twinx()
ax2.plot(logL, inference_time, color='red', label='Inference time')
ax2.set_ylabel('Time (ms)', color='red')
ax2.legend(loc='upper left')

plt.grid()
plt.show()
