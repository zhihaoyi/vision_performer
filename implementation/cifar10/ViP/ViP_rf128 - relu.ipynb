# %% [markdown]
# # ViP Classification on CIFAR-10

# %% [markdown]
# ## random_features=128 with ReLu

# %%
import tensorflow as tf
import tensorflow_addons as tfa
import numpy as np
import matplotlib.pyplot as plt
import time
import datetime
import sys
import os
import pickle

# check GPU
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import tensorflow_datasets as tfds
train_dataset, info = tfds.load('cifar10', split='train', shuffle_files=True, with_info=True)
val_dataset = tfds.load('cifar10', split='test', shuffle_files=False)

# number of samples
num_train_samples = tf.data.experimental.cardinality(train_dataset).numpy()
num_val_samples = tf.data.experimental.cardinality(val_dataset).numpy()
print('Number of training samples:', num_train_samples)
print('Number of validation samples:', num_val_samples)

# size of image
for example in train_dataset.take(1):
    image, label = example['image'], example['label']
print('Image size:', image.shape)

# number of classes
num_classes = info.features['label'].num_classes
print('Number of classes: ', num_classes)
# Out:
# Number of training samples: 50000
# Number of validation samples: 10000
# Image size: (32, 32, 3)
# Number of classes:  10

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
batch_size = 64

def extract_image_and_label(example):
    image, label = example['image'], example['label']
    image = tf.cast(image, tf.float32)
    return image, label

# extract image and label from dataloader
train_ds = train_dataset.map(extract_image_and_label)
val_ds = val_dataset.map(extract_image_and_label)

# batch train_ds and val_ds
train_ds = train_ds.batch(batch_size)
val_ds = val_ds.batch(batch_size)

# input pipeline optimization
train_ds = train_ds.cache().prefetch(AUTOTUNE)
val_ds = val_ds.cache().prefetch(AUTOTUNE)

# %%
curr_dir = os.getcwd() 
parent_dir = os.path.abspath(os.path.join(curr_dir, os.pardir))
implementation_dir = os.path.abspath(os.path.join(parent_dir, os.pardir))
main_dir = os.path.abspath(os.path.join(implementation_dir, os.pardir))
sys.path.append(main_dir)

# %%
from model.vision_performer import VisionPerformer
# compiler attributes
lr = 1e-4
weight_decay = 1e-4
num_epochs = 50

# VisionTransformer attributes
input_shape = image.shape # [32, 32, 3]
image_size = image.shape[0] # 32
num_layers = 6
num_classes = num_classes # 10
d_model = 64
num_heads = 1
mlp_dim = 64
# VisionPerformer attributes
random_features = 128
kernel_transformation = 'relu'

# %% [markdown]
# # L = 16

# %%
patch_size = 8
model_16 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=input_shape),
    VisionPerformer(image_size=image_size, patch_size=patch_size, num_layers=num_layers,
                      num_classes=num_classes, d_model=d_model, num_heads=num_heads, 
                  random_features=random_features, kernel_transformation=kernel_transformation,
                  mlp_dim=mlp_dim),
    tf.keras.layers.Dense(10, activation='softmax')
])

model_16.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
             optimizer=tfa.optimizers.AdamW(learning_rate=lr, weight_decay=weight_decay),
             metrics=['accuracy']) 

model_16.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vision_performer (VisionPer  (None, 10)               169738
#  former)
#
#  dense_39 (Dense)            (None, 10)                110
#
# =================================================================
# Total params: 169,848
# Trainable params: 169,848
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_name = 'L_16'
path = main_dir + '\model_checkpoints\cifar10\ViP\\random_feature_128_relu\\' + model_name

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=path,
    save_best_only=True,
    save_weights_only=True,
    monitor='val_loss',
    mode='min'
)

#train model
start_time = time.time()
history_16 = model_16.fit(
    train_ds,
    epochs=num_epochs,
    validation_data=val_ds,
    callbacks=[model_checkpoint_callback]
)
end_time = time.time()
total_time_16 = end_time-start_time
# Out:
# Epoch 1/50
# 782/782 [==============================] - 64s 71ms/step - loss: 2.1235 - accuracy: 0.1995 - val_loss: 1.9754 - val_accuracy: 0.2617
# Epoch 2/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.9599 - accuracy: 0.2622 - val_loss: 1.8878 - val_accuracy: 0.2938
# Epoch 3/50
# 782/782 [==============================] - 54s 69ms/step - loss: 1.8703 - accuracy: 0.2985 - val_loss: 1.7918 - val_accuracy: 0.3403
# Epoch 4/50
# 782/782 [==============================] - 54s 69ms/step - loss: 1.8072 - accuracy: 0.3296 - val_loss: 1.7390 - val_accuracy: 0.3563
# Epoch 5/50
# 782/782 [==============================] - 54s 69ms/step - loss: 1.7599 - accuracy: 0.3503 - val_loss: 1.6954 - val_accuracy: 0.3734
# Epoch 6/50
# 782/782 [==============================] - 54s 69ms/step - loss: 1.7178 - accuracy: 0.3681 - val_loss: 1.6583 - val_accuracy: 0.3919
# Epoch 7/50
# 782/782 [==============================] - 55s 71ms/step - loss: 1.6804 - accuracy: 0.3857 - val_loss: 1.6135 - val_accuracy: 0.4171
# Epoch 8/50
# 782/782 [==============================] - 54s 70ms/step - loss: 1.6440 - accuracy: 0.3965 - val_loss: 1.5865 - val_accuracy: 0.4262
# Epoch 9/50
# 782/782 [==============================] - 54s 69ms/step - loss: 1.6198 - accuracy: 0.4087 - val_loss: 1.5748 - val_accuracy: 0.4276
# Epoch 10/50
# 782/782 [==============================] - 54s 69ms/step - loss: 1.5940 - accuracy: 0.4219 - val_loss: 1.5442 - val_accuracy: 0.4412
# Epoch 11/50
# 782/782 [==============================] - 54s 69ms/step - loss: 1.5706 - accuracy: 0.4298 - val_loss: 1.5343 - val_accuracy: 0.4393
# Epoch 12/50
# 782/782 [==============================] - 54s 69ms/step - loss: 1.5541 - accuracy: 0.4358 - val_loss: 1.5189 - val_accuracy: 0.4445
# Epoch 13/50
# 782/782 [==============================] - 54s 69ms/step - loss: 1.5378 - accuracy: 0.4426 - val_loss: 1.5051 - val_accuracy: 0.4503
# Epoch 14/50
# 782/782 [==============================] - 54s 69ms/step - loss: 1.5231 - accuracy: 0.4475 - val_loss: 1.4989 - val_accuracy: 0.4518
# Epoch 15/50
# 782/782 [==============================] - 54s 69ms/step - loss: 1.5118 - accuracy: 0.4502 - val_loss: 1.4858 - val_accuracy: 0.4600
# Epoch 16/50
# 782/782 [==============================] - 54s 69ms/step - loss: 1.4992 - accuracy: 0.4575 - val_loss: 1.4832 - val_accuracy: 0.4617
# Epoch 17/50
# 782/782 [==============================] - 54s 69ms/step - loss: 1.4927 - accuracy: 0.4581 - val_loss: 1.4785 - val_accuracy: 0.4628
# Epoch 18/50
# 782/782 [==============================] - 54s 69ms/step - loss: 1.4853 - accuracy: 0.4591 - val_loss: 1.4867 - val_accuracy: 0.4550
# Epoch 19/50
# 782/782 [==============================] - 54s 69ms/step - loss: 1.4770 - accuracy: 0.4662 - val_loss: 1.4921 - val_accuracy: 0.4581
# Epoch 20/50
# 782/782 [==============================] - 54s 69ms/step - loss: 1.4635 - accuracy: 0.4689 - val_loss: 1.4535 - val_accuracy: 0.4657
# Epoch 41/50
# 782/782 [==============================] - 54s 69ms/step - loss: 1.4646 - accuracy: 0.4707 - val_loss: 1.5163 - val_accuracy: 0.4446
# Epoch 42/50
# 782/782 [==============================] - 54s 69ms/step - loss: 1.4613 - accuracy: 0.4704 - val_loss: 1.4855 - val_accuracy: 0.4575
# Epoch 43/50
# 782/782 [==============================] - 54s 69ms/step - loss: 1.4661 - accuracy: 0.4674 - val_loss: 1.5362 - val_accuracy: 0.4514
# Epoch 44/50
# 782/782 [==============================] - 54s 69ms/step - loss: 1.4667 - accuracy: 0.4660 - val_loss: 1.4685 - val_accuracy: 0.4649
# Epoch 45/50
# 782/782 [==============================] - 54s 69ms/step - loss: 1.4648 - accuracy: 0.4678 - val_loss: 1.4791 - val_accuracy: 0.4648
# Epoch 46/50
# 782/782 [==============================] - 54s 69ms/step - loss: 1.4663 - accuracy: 0.4650 - val_loss: 1.5041 - val_accuracy: 0.4574
# Epoch 47/50
# 782/782 [==============================] - 55s 70ms/step - loss: 1.4683 - accuracy: 0.4663 - val_loss: 1.5022 - val_accuracy: 0.4519
# Epoch 48/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.4683 - accuracy: 0.4665 - val_loss: 1.4925 - val_accuracy: 0.4646
# Epoch 49/50
# 782/782 [==============================] - 55s 70ms/step - loss: 1.4675 - accuracy: 0.4663 - val_loss: 1.5149 - val_accuracy: 0.4528
# Epoch 50/50
# 782/782 [==============================] - 55s 70ms/step - loss: 1.4734 - accuracy: 0.4660 - val_loss: 1.5029 - val_accuracy: 0.4543

# %%
from utils import inf_time_check
print(f'Training time {round((total_time_16),3)} sec for {num_epochs} epochs.')
inference_time_16 = inf_time_check(model_16, val_ds)
print(f'Inference time {inference_time_16} ms for {num_val_samples} samples.')
# Out:
# Training time 2712.082 sec for 50 epochs.
# 64/64 [==============================] - 2s 17ms/step
# 64/64 [==============================] - 1s 16ms/step
# 64/64 [==============================] - 1s 15ms/step
# 64/64 [==============================] - 1s 15ms/step
# 64/64 [==============================] - 1s 15ms/step
# Inference time 1230.264 ms for 10000 samples.

# %%
log_name_16 = '\log\cifar10\ViP\\random_feature_128_relu\L_16.pkl'
log_path_16 = main_dir + log_name_16
with open(log_path_16, 'wb') as file:
    pickle.dump(history_16.history, file)

# %%
# plot accuracy curve
plt.plot(history_16.history["accuracy"], label="Train Accuracy")
plt.plot(history_16.history["val_accuracy"], label="Validation Accuracy")
plt.title("Train and Validation Accuracy Over Epochs L=16")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()

# %%
# plot loss curve
plt.plot(history_16.history["loss"], label="Train Loss")
plt.plot(history_16.history["val_loss"], label="Validation Loss")
plt.title("Train and Validation Loss Over Epochs L=16")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# %% [markdown]
# # L = 64

# %%
patch_size = 4
model_64 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=input_shape),
    VisionPerformer(image_size=image_size, patch_size=patch_size, num_layers=num_layers,
                      num_classes=num_classes, d_model=d_model, num_heads=num_heads, 
                  random_features=random_features, kernel_transformation=kernel_transformation,
                  mlp_dim=mlp_dim),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(10, activation='softmax')
])

model_64.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
             optimizer=tfa.optimizers.AdamW(learning_rate=lr, weight_decay=weight_decay),
             metrics=['accuracy']) 

model_64.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vision_performer_1 (VisionP  (None, 10)               163594
#  erformer)
#
#  flatten (Flatten)           (None, 10)                0
#
#  dense_79 (Dense)            (None, 10)                110
#
# =================================================================
# Total params: 163,704
# Trainable params: 163,704
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_name = 'L_64'
path = main_dir + '\model_checkpoints\cifar10\ViP\\random_feature_128_relu\\' + model_name

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=path,
    save_best_only=True,
    save_weights_only=True,
    monitor='val_loss',
    mode='min'
)

#train model
start_time = time.time()
history_64 = model_64.fit(
    train_ds,
    epochs=num_epochs,
    validation_data=val_ds,
    callbacks=[model_checkpoint_callback]
)
end_time = time.time()
total_time_64 = end_time-start_time
# Out:
# Epoch 1/50
# 782/782 [==============================] - 55s 61ms/step - loss: 2.1045 - accuracy: 0.1986 - val_loss: 1.9353 - val_accuracy: 0.2825
# Epoch 2/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.9106 - accuracy: 0.2806 - val_loss: 1.8283 - val_accuracy: 0.3198
# Epoch 3/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.8197 - accuracy: 0.3190 - val_loss: 1.7431 - val_accuracy: 0.3593
# Epoch 4/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.7470 - accuracy: 0.3539 - val_loss: 1.6773 - val_accuracy: 0.3817
# Epoch 5/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.6890 - accuracy: 0.3790 - val_loss: 1.6413 - val_accuracy: 0.3981
# Epoch 6/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.6472 - accuracy: 0.3971 - val_loss: 1.6047 - val_accuracy: 0.4117
# Epoch 7/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.6094 - accuracy: 0.4133 - val_loss: 1.5571 - val_accuracy: 0.4321
# Epoch 8/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.5756 - accuracy: 0.4287 - val_loss: 1.5304 - val_accuracy: 0.4430
# Epoch 9/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.5461 - accuracy: 0.4406 - val_loss: 1.5037 - val_accuracy: 0.4511
# Epoch 10/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.5232 - accuracy: 0.4481 - val_loss: 1.4838 - val_accuracy: 0.4613
# Epoch 11/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.5006 - accuracy: 0.4577 - val_loss: 1.4623 - val_accuracy: 0.4674
# Epoch 12/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.4814 - accuracy: 0.4635 - val_loss: 1.4676 - val_accuracy: 0.4621
# Epoch 13/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.4638 - accuracy: 0.4711 - val_loss: 1.4287 - val_accuracy: 0.4785
# Epoch 14/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.4489 - accuracy: 0.4734 - val_loss: 1.4072 - val_accuracy: 0.4873
# Epoch 35/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.3133 - accuracy: 0.5275 - val_loss: 1.3251 - val_accuracy: 0.5161
# Epoch 36/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.3196 - accuracy: 0.5233 - val_loss: 1.3098 - val_accuracy: 0.5215
# Epoch 37/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.3171 - accuracy: 0.5231 - val_loss: 1.3281 - val_accuracy: 0.5077
# Epoch 38/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.3231 - accuracy: 0.5183 - val_loss: 1.3017 - val_accuracy: 0.5292
# Epoch 39/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.3238 - accuracy: 0.5206 - val_loss: 1.3464 - val_accuracy: 0.5143
# Epoch 40/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.3261 - accuracy: 0.5214 - val_loss: 1.3111 - val_accuracy: 0.5235
# Epoch 41/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.3228 - accuracy: 0.5211 - val_loss: 1.3060 - val_accuracy: 0.5323
# Epoch 42/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.3254 - accuracy: 0.5217 - val_loss: 1.3011 - val_accuracy: 0.5242
# Epoch 43/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.3264 - accuracy: 0.5204 - val_loss: 1.3318 - val_accuracy: 0.5220
# Epoch 44/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.3277 - accuracy: 0.5197 - val_loss: 1.3055 - val_accuracy: 0.5300
# Epoch 45/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.3305 - accuracy: 0.5172 - val_loss: 1.3096 - val_accuracy: 0.5228
# Epoch 46/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.3273 - accuracy: 0.5217 - val_loss: 1.3354 - val_accuracy: 0.5249
# Epoch 47/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.3283 - accuracy: 0.5211 - val_loss: 1.3291 - val_accuracy: 0.5184
# Epoch 48/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.3311 - accuracy: 0.5183 - val_loss: 1.3376 - val_accuracy: 0.5151
# Epoch 49/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.3282 - accuracy: 0.5215 - val_loss: 1.2990 - val_accuracy: 0.5330
# Epoch 50/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.3285 - accuracy: 0.5193 - val_loss: 1.3251 - val_accuracy: 0.5188

# %%
print(f'Training time {round((total_time_64),3)} sec for {num_epochs} epochs.')
inference_time_64 = inf_time_check(model_64, val_ds)
print(f'Inference time {inference_time_64} ms for {num_val_samples} samples.')
# Out:
# Training time 2312.132 sec for 50 epochs.
# 64/64 [==============================] - 2s 15ms/step
# 64/64 [==============================] - 1s 15ms/step
# 64/64 [==============================] - 1s 15ms/step
# 64/64 [==============================] - 1s 15ms/step
# 64/64 [==============================] - 1s 15ms/step
# Inference time 1216.193 ms for 10000 samples.

# %%
log_name_64 = '\log\cifar10\ViP\\random_feature_128_relu\L_64.pkl'
log_path_64 = main_dir + log_name_64
with open(log_path_64, 'wb') as file:
    pickle.dump(history_64.history, file)

# %%
# plot accuracy curve
plt.plot(history_64.history["accuracy"], label="Train Accuracy")
plt.plot(history_64.history["val_accuracy"], label="Validation Accuracy")
plt.title("Train and Validation Accuracy Over Epochs L=64")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()

# %%
# plot loss curve
plt.plot(history_64.history["loss"], label="Train Loss")
plt.plot(history_64.history["val_loss"], label="Validation Loss")
plt.title("Train and Validation Loss Over Epochs L=64")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# %% [markdown]
# # L = 256

# %%
patch_size = 2
model_256 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=input_shape),
    VisionPerformer(image_size=image_size, patch_size=patch_size, num_layers=num_layers,
                      num_classes=num_classes, d_model=d_model, num_heads=num_heads, 
                  random_features=random_features, kernel_transformation=kernel_transformation,
                  mlp_dim=mlp_dim),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(10, activation='softmax')
])

model_256.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
             optimizer=tfa.optimizers.AdamW(learning_rate=lr, weight_decay=weight_decay),
             metrics=['accuracy']) 

model_256.summary()
# Out:
# Model: "sequential_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vision_performer_2 (VisionP  (None, 10)               173578
#  erformer)
#
#  flatten_1 (Flatten)         (None, 10)                0
#
#  dense_119 (Dense)           (None, 10)                110
#
# =================================================================
# Total params: 173,688
# Trainable params: 173,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_name = 'L_256'
path = main_dir + '\model_checkpoints\cifar10\ViP\\random_feature_128_relu\\' + model_name

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=path,
    save_best_only=True,
    save_weights_only=True,
    monitor='val_loss',
    mode='min'
)

#train model
start_time = time.time()
history_256 = model_256.fit(
    train_ds,
    epochs=num_epochs,
    validation_data=val_ds,
    callbacks=[model_checkpoint_callback]
)
end_time = time.time()
total_time_256 = end_time-start_time
# Out:
# Epoch 1/50
# 782/782 [==============================] - 70s 80ms/step - loss: 2.1332 - accuracy: 0.2009 - val_loss: 1.9415 - val_accuracy: 0.2832
# Epoch 2/50
# 782/782 [==============================] - 62s 79ms/step - loss: 1.9281 - accuracy: 0.2820 - val_loss: 1.8671 - val_accuracy: 0.3119
# Epoch 3/50
# 782/782 [==============================] - 62s 79ms/step - loss: 1.8429 - accuracy: 0.3188 - val_loss: 1.8025 - val_accuracy: 0.3282
# Epoch 4/50
# 782/782 [==============================] - 62s 79ms/step - loss: 1.7881 - accuracy: 0.3438 - val_loss: 1.7459 - val_accuracy: 0.3553
# Epoch 5/50
# 782/782 [==============================] - 62s 79ms/step - loss: 1.7491 - accuracy: 0.3590 - val_loss: 1.6995 - val_accuracy: 0.3745
# Epoch 6/50
# 782/782 [==============================] - 62s 79ms/step - loss: 1.7121 - accuracy: 0.3722 - val_loss: 1.6553 - val_accuracy: 0.3908
# Epoch 7/50
# 782/782 [==============================] - 62s 79ms/step - loss: 1.6718 - accuracy: 0.3889 - val_loss: 1.6254 - val_accuracy: 0.4020
# Epoch 8/50
# 782/782 [==============================] - 62s 79ms/step - loss: 1.6314 - accuracy: 0.4040 - val_loss: 1.5813 - val_accuracy: 0.4258
# Epoch 9/50
# 782/782 [==============================] - 62s 79ms/step - loss: 1.5887 - accuracy: 0.4237 - val_loss: 1.5397 - val_accuracy: 0.4445
# Epoch 10/50
# 782/782 [==============================] - 62s 79ms/step - loss: 1.5497 - accuracy: 0.4376 - val_loss: 1.5143 - val_accuracy: 0.4502
# Epoch 11/50
# 782/782 [==============================] - 62s 79ms/step - loss: 1.5164 - accuracy: 0.4509 - val_loss: 1.4983 - val_accuracy: 0.4590
# Epoch 12/50
# 782/782 [==============================] - 62s 79ms/step - loss: 1.4877 - accuracy: 0.4640 - val_loss: 1.4907 - val_accuracy: 0.4619
# Epoch 13/50
# 782/782 [==============================] - 62s 79ms/step - loss: 1.4632 - accuracy: 0.4735 - val_loss: 1.4751 - val_accuracy: 0.4716
# Epoch 14/50
# 782/782 [==============================] - 62s 79ms/step - loss: 1.4428 - accuracy: 0.4822 - val_loss: 1.4401 - val_accuracy: 0.4836
# Epoch 15/50
# 782/782 [==============================] - 62s 79ms/step - loss: 1.4219 - accuracy: 0.4884 - val_loss: 1.4007 - val_accuracy: 0.4941
# Epoch 16/50
# 782/782 [==============================] - 62s 79ms/step - loss: 1.3999 - accuracy: 0.4958 - val_loss: 1.3964 - val_accuracy: 0.5016
# Epoch 17/50
# 782/782 [==============================] - 62s 79ms/step - loss: 1.3765 - accuracy: 0.5054 - val_loss: 1.3652 - val_accuracy: 0.5079
# Epoch 18/50
# 782/782 [==============================] - 62s 79ms/step - loss: 1.3629 - accuracy: 0.5105 - val_loss: 1.3315 - val_accuracy: 0.5220
# Epoch 19/50
# 782/782 [==============================] - 62s 79ms/step - loss: 1.3453 - accuracy: 0.5171 - val_loss: 1.3152 - val_accuracy: 0.5283
# Epoch 20/50
# 782/782 [==============================] - 61s 79ms/step - loss: 1.3263 - accuracy: 0.5235 - val_loss: 1.3247 - val_accuracy: 0.5265
# Epoch 21/50
# 782/782 [==============================] - 62s 79ms/step - loss: 1.3121 - accuracy: 0.5299 - val_loss: 1.3043 - val_accuracy: 0.5258
# Epoch 22/50
# 782/782 [==============================] - 62s 79ms/step - loss: 1.3016 - accuracy: 0.5328 - val_loss: 1.2879 - val_accuracy: 0.5364
# Epoch 23/50
# 782/782 [==============================] - 61s 79ms/step - loss: 1.2843 - accuracy: 0.5414 - val_loss: 1.2949 - val_accuracy: 0.5286
# Epoch 24/50
# 782/782 [==============================] - 62s 79ms/step - loss: 1.2820 - accuracy: 0.5400 - val_loss: 1.2559 - val_accuracy: 0.5464
# Epoch 25/50
# 782/782 [==============================] - 61s 79ms/step - loss: 1.2717 - accuracy: 0.5459 - val_loss: 1.2563 - val_accuracy: 0.5487
# Epoch 26/50
# 782/782 [==============================] - 61s 79ms/step - loss: 1.2692 - accuracy: 0.5455 - val_loss: 1.2560 - val_accuracy: 0.5500
# Epoch 27/50
# 782/782 [==============================] - 62s 79ms/step - loss: 1.2629 - accuracy: 0.5470 - val_loss: 1.2397 - val_accuracy: 0.5529
# Epoch 28/50
# 782/782 [==============================] - 62s 79ms/step - loss: 1.2586 - accuracy: 0.5502 - val_loss: 1.2358 - val_accuracy: 0.5521
# Epoch 29/50
# 782/782 [==============================] - 62s 79ms/step - loss: 1.2556 - accuracy: 0.5516 - val_loss: 1.2258 - val_accuracy: 0.5554
# Epoch 30/50
# 782/782 [==============================] - 61s 79ms/step - loss: 1.2556 - accuracy: 0.5509 - val_loss: 1.2376 - val_accuracy: 0.5540
# Epoch 31/50
# 782/782 [==============================] - 61s 79ms/step - loss: 1.2549 - accuracy: 0.5503 - val_loss: 1.2284 - val_accuracy: 0.5637
# Epoch 32/50
# 782/782 [==============================] - 62s 79ms/step - loss: 1.2534 - accuracy: 0.5521 - val_loss: 1.2207 - val_accuracy: 0.5526
# Epoch 33/50
# 782/782 [==============================] - 62s 79ms/step - loss: 1.2541 - accuracy: 0.5529 - val_loss: 1.2255 - val_accuracy: 0.5590
# Epoch 34/50
# 782/782 [==============================] - 62s 79ms/step - loss: 1.2602 - accuracy: 0.5481 - val_loss: 1.2141 - val_accuracy: 0.5619
# Epoch 35/50
# 782/782 [==============================] - 62s 79ms/step - loss: 1.2581 - accuracy: 0.5487 - val_loss: 1.2116 - val_accuracy: 0.5634
# Epoch 36/50
# 782/782 [==============================] - 61s 79ms/step - loss: 1.2593 - accuracy: 0.5484 - val_loss: 1.2416 - val_accuracy: 0.5552
# Epoch 37/50
# 782/782 [==============================] - 61s 79ms/step - loss: 1.2575 - accuracy: 0.5487 - val_loss: 1.2207 - val_accuracy: 0.5616
# Epoch 38/50
# 782/782 [==============================] - 61s 79ms/step - loss: 1.2639 - accuracy: 0.5458 - val_loss: 1.2214 - val_accuracy: 0.5593
# Epoch 39/50
# 782/782 [==============================] - 61s 79ms/step - loss: 1.2667 - accuracy: 0.5462 - val_loss: 1.2244 - val_accuracy: 0.5624
# Epoch 40/50
# 782/782 [==============================] - 61s 79ms/step - loss: 1.2629 - accuracy: 0.5473 - val_loss: 1.2170 - val_accuracy: 0.5616
# Epoch 41/50
# 782/782 [==============================] - 61s 79ms/step - loss: 1.2668 - accuracy: 0.5463 - val_loss: 1.2332 - val_accuracy: 0.5549
# Epoch 42/50
# 782/782 [==============================] - 62s 79ms/step - loss: 1.2610 - accuracy: 0.5479 - val_loss: 1.2299 - val_accuracy: 0.5537
# Epoch 43/50
# 782/782 [==============================] - 61s 79ms/step - loss: 1.2662 - accuracy: 0.5457 - val_loss: 1.2401 - val_accuracy: 0.5522
# Epoch 44/50
# 782/782 [==============================] - 61s 79ms/step - loss: 1.2680 - accuracy: 0.5465 - val_loss: 1.2539 - val_accuracy: 0.5509
# Epoch 45/50
# 782/782 [==============================] - 61s 79ms/step - loss: 1.2670 - accuracy: 0.5446 - val_loss: 1.2211 - val_accuracy: 0.5608
# Epoch 46/50
# 782/782 [==============================] - 61s 79ms/step - loss: 1.2659 - accuracy: 0.5455 - val_loss: 1.2253 - val_accuracy: 0.5572
# Epoch 47/50
# 782/782 [==============================] - 61s 79ms/step - loss: 1.2663 - accuracy: 0.5478 - val_loss: 1.2298 - val_accuracy: 0.5575
# Epoch 48/50
# 782/782 [==============================] - 61s 79ms/step - loss: 1.2680 - accuracy: 0.5440 - val_loss: 1.2196 - val_accuracy: 0.5591
# Epoch 49/50
# 782/782 [==============================] - 61s 79ms/step - loss: 1.2699 - accuracy: 0.5441 - val_loss: 1.2402 - val_accuracy: 0.5509
# Epoch 50/50
# 782/782 [==============================] - 61s 79ms/step - loss: 1.2649 - accuracy: 0.5436 - val_loss: 1.2345 - val_accuracy: 0.5565

# %%
from utils import inf_time_check
print(f'Training time {round((total_time_256),3)} sec for {num_epochs} epochs.')
inference_time_256 = inf_time_check(model_256, val_ds)
print(f'Inference time {inference_time_256} ms for {num_val_samples} samples.')
# Out:
# Training time 3087.703 sec for 50 epochs.
# 64/64 [==============================] - 2s 11ms/step
# 64/64 [==============================] - 1s 12ms/step
# 64/64 [==============================] - 1s 12ms/step
# 64/64 [==============================] - 1s 13ms/step
# 64/64 [==============================] - 1s 14ms/step
# Inference time 1041.665 ms for 10000 samples.

# %%
log_name_256 = '\log\cifar10\ViP\\random_feature_128_relu\L_256.pkl'
log_path_256 = main_dir + log_name_256
with open(log_path_256, 'wb') as file:
    pickle.dump(history_256.history, file)

# %%
# plot accuracy curve
plt.plot(history_256.history["accuracy"], label="Train Accuracy")
plt.plot(history_256.history["val_accuracy"], label="Validation Accuracy")
plt.title("Train and Validation Accuracy Over Epochs L=256")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()

# %%
# plot loss curve
plt.plot(history_256.history["loss"], label="Train Loss")
plt.plot(history_256.history["val_loss"], label="Validation Loss")
plt.title("Train and Validation Loss Over Epochs L=256")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# %% [markdown]
# # L = 1024

# %%
patch_size = 1
model_1024 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=input_shape),
    VisionPerformer(image_size=image_size, patch_size=patch_size, num_layers=num_layers,
                      num_classes=num_classes, d_model=d_model, num_heads=num_heads, 
                  random_features=random_features, kernel_transformation=kernel_transformation,
                  mlp_dim=mlp_dim),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(10, activation='softmax')
])

model_1024.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
             optimizer=tfa.optimizers.AdamW(learning_rate=lr, weight_decay=weight_decay),
             metrics=['accuracy']) 

model_1024.summary()
# Out:
# Model: "sequential_31"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vision_performer_3 (VisionP  (None, 10)               222154
#  erformer)
#
#  flatten_2 (Flatten)         (None, 10)                0
#
#  dense_159 (Dense)           (None, 10)                110
#
# =================================================================
# Total params: 222,264
# Trainable params: 222,264
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_name = 'L_1024'
path = main_dir + '\model_checkpoints\cifar10\ViP\\random_feature_128_relu\\' + model_name

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=path,
    save_best_only=True,
    save_weights_only=True,
    monitor='val_loss',
    mode='min'
)

#train model
start_time = time.time()
history_1024 = model_1024.fit(
    train_ds,
    epochs=num_epochs,
    validation_data=val_ds,
    callbacks=[model_checkpoint_callback]
)
end_time = time.time()
total_time_1024 = end_time-start_time
# Out:
# Epoch 1/50
# 782/782 [==============================] - 155s 188ms/step - loss: 2.1503 - accuracy: 0.1969 - val_loss: 1.9670 - val_accuracy: 0.2817
# Epoch 2/50
# 782/782 [==============================] - 146s 187ms/step - loss: 1.9187 - accuracy: 0.2953 - val_loss: 1.8501 - val_accuracy: 0.3238
# Epoch 3/50
# 782/782 [==============================] - 146s 187ms/step - loss: 1.8274 - accuracy: 0.3291 - val_loss: 1.7901 - val_accuracy: 0.3472
# Epoch 4/50
# Epoch 24/50
# 782/782 [==============================] - 147s 188ms/step - loss: 1.4591 - accuracy: 0.4825 - val_loss: 1.4495 - val_accuracy: 0.4820
# Epoch 25/50
# 782/782 [==============================] - 147s 188ms/step - loss: 1.4591 - accuracy: 0.4791 - val_loss: 1.4444 - val_accuracy: 0.4791
# Epoch 26/50
# 782/782 [==============================] - 147s 188ms/step - loss: 1.4523 - accuracy: 0.4843 - val_loss: 1.4352 - val_accuracy: 0.4886
# Epoch 27/50
# 782/782 [==============================] - 147s 188ms/step - loss: 1.4497 - accuracy: 0.4837 - val_loss: 1.4679 - val_accuracy: 0.4644
# Epoch 28/50
# 782/782 [==============================] - 147s 188ms/step - loss: 1.4505 - accuracy: 0.4829 - val_loss: 1.4291 - val_accuracy: 0.4815
# Epoch 29/50
# 782/782 [==============================] - 146s 187ms/step - loss: 1.4503 - accuracy: 0.4824 - val_loss: 1.4651 - val_accuracy: 0.4624
# Epoch 30/50
# 782/782 [==============================] - 146s 187ms/step - loss: 1.4421 - accuracy: 0.4856 - val_loss: 1.4264 - val_accuracy: 0.4822
# Epoch 31/50
# 782/782 [==============================] - 146s 187ms/step - loss: 1.4410 - accuracy: 0.4867 - val_loss: 1.4280 - val_accuracy: 0.4851
# Epoch 32/50
# 782/782 [==============================] - 146s 187ms/step - loss: 1.4392 - accuracy: 0.4876 - val_loss: 1.4311 - val_accuracy: 0.4804
# Epoch 33/50
# 782/782 [==============================] - 146s 187ms/step - loss: 1.4394 - accuracy: 0.4885 - val_loss: 1.4339 - val_accuracy: 0.4765
# Epoch 34/50
# 782/782 [==============================] - 147s 188ms/step - loss: 1.4410 - accuracy: 0.4858 - val_loss: 1.4231 - val_accuracy: 0.4873
# Epoch 35/50
# 782/782 [==============================] - 146s 187ms/step - loss: 1.4399 - accuracy: 0.4864 - val_loss: 1.4659 - val_accuracy: 0.4661
# Epoch 36/50
# 782/782 [==============================] - 146s 187ms/step - loss: 1.4367 - accuracy: 0.4866 - val_loss: 1.4373 - val_accuracy: 0.4784
# Epoch 37/50
# 782/782 [==============================] - 146s 187ms/step - loss: 1.4387 - accuracy: 0.4849 - val_loss: 1.4491 - val_accuracy: 0.4707
# Epoch 38/50
# 782/782 [==============================] - 146s 187ms/step - loss: 1.4357 - accuracy: 0.4873 - val_loss: 1.4500 - val_accuracy: 0.4706
# Epoch 39/50
# 782/782 [==============================] - 146s 187ms/step - loss: 1.4384 - accuracy: 0.4849 - val_loss: 1.4225 - val_accuracy: 0.4845
# Epoch 40/50
# 782/782 [==============================] - 146s 187ms/step - loss: 1.4380 - accuracy: 0.4866 - val_loss: 1.4190 - val_accuracy: 0.4831
# Epoch 41/50
# 782/782 [==============================] - 146s 187ms/step - loss: 1.4311 - accuracy: 0.4871 - val_loss: 1.4399 - val_accuracy: 0.4784
# Epoch 42/50
# 782/782 [==============================] - 146s 187ms/step - loss: 1.4344 - accuracy: 0.4863 - val_loss: 1.4374 - val_accuracy: 0.4728
# Epoch 43/50
# 782/782 [==============================] - 146s 187ms/step - loss: 1.4334 - accuracy: 0.4852 - val_loss: 1.4454 - val_accuracy: 0.4714
# Epoch 44/50
# 782/782 [==============================] - 146s 187ms/step - loss: 1.4377 - accuracy: 0.4864 - val_loss: 1.4339 - val_accuracy: 0.4796
# Epoch 45/50
# 782/782 [==============================] - 146s 187ms/step - loss: 1.4353 - accuracy: 0.4844 - val_loss: 1.4326 - val_accuracy: 0.4752
# Epoch 46/50
# 782/782 [==============================] - 146s 187ms/step - loss: 1.4314 - accuracy: 0.4869 - val_loss: 1.4237 - val_accuracy: 0.4818
# Epoch 47/50
# 782/782 [==============================] - 146s 187ms/step - loss: 1.4330 - accuracy: 0.4846 - val_loss: 1.4404 - val_accuracy: 0.4751
# Epoch 48/50
# 782/782 [==============================] - 147s 187ms/step - loss: 1.4283 - accuracy: 0.4887 - val_loss: 1.4417 - val_accuracy: 0.4727
# Epoch 49/50
# 782/782 [==============================] - 146s 187ms/step - loss: 1.4345 - accuracy: 0.4856 - val_loss: 1.4215 - val_accuracy: 0.4851
# Epoch 50/50
# 782/782 [==============================] - 146s 187ms/step - loss: 1.4314 - accuracy: 0.4861 - val_loss: 1.4261 - val_accuracy: 0.4758

# %%
print(f'Training time {round((total_time_1024),3)} sec for {num_epochs} epochs.')
inference_time_1024 = inf_time_check(model_1024, val_ds)
print(f'Inference time {inference_time_1024} ms for {num_val_samples} samples.')
# Out:
# Training time 7322.097 sec for 50 epochs.
# 64/64 [==============================] - 2s 12ms/step
# 64/64 [==============================] - 1s 13ms/step
# 64/64 [==============================] - 1s 13ms/step
# 64/64 [==============================] - 1s 14ms/step
# 64/64 [==============================] - 1s 15ms/step
# Inference time 1093.79 ms for 10000 samples.

# %%
log_name_1024 = '\log\cifar10\ViP\\random_feature_128_relu\L_1024.pkl'
log_path_1024 = main_dir + log_name_1024
with open(log_path_1024, 'wb') as file:
    pickle.dump(history_1024.history, file)

# %%
# plot accuracy curve
plt.plot(history_1024.history["accuracy"], label="Train Accuracy")
plt.plot(history_1024.history["val_accuracy"], label="Validation Accuracy")
plt.title("Train and Validation Accuracy Over Epochs L=1024")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()

# %%
# plot loss curve
plt.plot(history_1024.history["loss"], label="Train Loss")
plt.plot(history_1024.history["val_loss"], label="Validation Loss")
plt.title("Train and Validation Loss Over Epochs L=1024")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# %%
total_time = [total_time_16, total_time_64, total_time_256, total_time_1024]
inference_time = [inference_time_16, inference_time_64, inference_time_256, inference_time_1024]
log = []
log.append(total_time)
log.append(inference_time)
log_name = '\log\cifar10\ViP\\random_feature_128_relu\\total_inf_time'
log_path = main_dir + log_name
# log [total_time, inference_time]
with open(log_path, 'wb') as file:
    pickle.dump(log, file)

# %%
logL = np.log2([16, 64, 256, 1024])

fig, ax1 = plt.subplots()
plt.title(f'Inference time & Total training time over {num_epochs} epochs')
plt.xlabel('log2(L)')

ax1.plot(logL, total_time, color='blue', label='Total training time')
ax1.set_ylabel('Time (sec)', color='blue')
ax1.legend(loc='upper right')

ax2 = ax1.twinx()
ax2.plot(logL, inference_time, color='red', label='Inference time')
ax2.set_ylabel('Time (ms)', color='red')
ax2.legend(loc='upper left')

plt.grid()
plt.show()
