# %% [markdown]
# # ViP Classification on CIFAR-10

# %% [markdown]
# ## random_features=32 with ReLu

# %%
import tensorflow as tf
import tensorflow_addons as tfa
import numpy as np
import matplotlib.pyplot as plt
import time
import datetime
import sys
import os
import pickle

# check GPU
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import tensorflow_datasets as tfds
train_dataset, info = tfds.load('cifar10', split='train', shuffle_files=True, with_info=True)
val_dataset = tfds.load('cifar10', split='test', shuffle_files=False)

# number of samples
num_train_samples = tf.data.experimental.cardinality(train_dataset).numpy()
num_val_samples = tf.data.experimental.cardinality(val_dataset).numpy()
print('Number of training samples:', num_train_samples)
print('Number of validation samples:', num_val_samples)

# size of image
for example in train_dataset.take(1):
    image, label = example['image'], example['label']
print('Image size:', image.shape)

# number of classes
num_classes = info.features['label'].num_classes
print('Number of classes: ', num_classes)
# Out:
# Number of training samples: 50000
# Number of validation samples: 10000
# Image size: (32, 32, 3)
# Number of classes:  10

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
batch_size = 64

def extract_image_and_label(example):
    image, label = example['image'], example['label']
    image = tf.cast(image, tf.float32)
    return image, label

# extract image and label from dataloader
train_ds = train_dataset.map(extract_image_and_label)
val_ds = val_dataset.map(extract_image_and_label)

# batch train_ds and val_ds
train_ds = train_ds.batch(batch_size)
val_ds = val_ds.batch(batch_size)

# input pipeline optimization
train_ds = train_ds.cache().prefetch(AUTOTUNE)
val_ds = val_ds.cache().prefetch(AUTOTUNE)

# %%
curr_dir = os.getcwd() 
parent_dir = os.path.abspath(os.path.join(curr_dir, os.pardir))
implementation_dir = os.path.abspath(os.path.join(parent_dir, os.pardir))
main_dir = os.path.abspath(os.path.join(implementation_dir, os.pardir))
sys.path.append(main_dir)

# %%
from model.vision_performer import VisionPerformer
# compiler attributes
lr = 1e-4
weight_decay = 1e-4
num_epochs = 50

# VisionTransformer attributes
input_shape = image.shape # [32, 32, 3]
image_size = image.shape[0] # 32
num_layers = 6
num_classes = num_classes # 10
d_model = 64
num_heads = 1
mlp_dim = 64
# VisionPerformer attributes
random_features = 32
kernel_transformation = 'relu'

# %% [markdown]
# # L = 16

# %%
patch_size = 8
model_16 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=input_shape),
    VisionPerformer(image_size=image_size, patch_size=patch_size, num_layers=num_layers,
                      num_classes=num_classes, d_model=d_model, num_heads=num_heads, 
                  random_features=random_features, kernel_transformation=kernel_transformation,
                  mlp_dim=mlp_dim),
    tf.keras.layers.Dense(10, activation='softmax')
])

model_16.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
             optimizer=tfa.optimizers.AdamW(learning_rate=lr, weight_decay=weight_decay),
             metrics=['accuracy']) 

model_16.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vision_performer (VisionPer  (None, 10)               169738
#  former)
#
#  dense_39 (Dense)            (None, 10)                110
#
# =================================================================
# Total params: 169,848
# Trainable params: 169,848
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_name = 'L_16'
path = main_dir + '\model_checkpoints\cifar10\ViP\\random_feature_32_relu\\' + model_name

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=path,
    save_best_only=True,
    save_weights_only=True,
    monitor='val_loss',
    mode='min'
)

#train model
start_time = time.time()
history_16 = model_16.fit(
    train_ds,
    epochs=num_epochs,
    validation_data=val_ds,
    callbacks=[model_checkpoint_callback]
)
end_time = time.time()
total_time_16 = end_time-start_time
# Out:
# Epoch 1/50
# 782/782 [==============================] - 62s 69ms/step - loss: 2.0991 - accuracy: 0.2114 - val_loss: 1.9594 - val_accuracy: 0.2773
# Epoch 2/50
# 782/782 [==============================] - 51s 65ms/step - loss: 1.9549 - accuracy: 0.2721 - val_loss: 1.8879 - val_accuracy: 0.3059
# Epoch 3/50
# 782/782 [==============================] - 52s 66ms/step - loss: 1.8899 - accuracy: 0.2997 - val_loss: 1.8385 - val_accuracy: 0.3245
# Epoch 4/50
# 782/782 [==============================] - 51s 66ms/step - loss: 1.8351 - accuracy: 0.3256 - val_loss: 1.7805 - val_accuracy: 0.3424
# Epoch 5/50
# 782/782 [==============================] - 51s 65ms/step - loss: 1.7880 - accuracy: 0.3416 - val_loss: 1.7230 - val_accuracy: 0.3663
# Epoch 6/50
# 782/782 [==============================] - 51s 66ms/step - loss: 1.7486 - accuracy: 0.3589 - val_loss: 1.7147 - val_accuracy: 0.3755
# Epoch 7/50
# 782/782 [==============================] - 52s 66ms/step - loss: 1.7194 - accuracy: 0.3671 - val_loss: 1.6984 - val_accuracy: 0.3851
# Epoch 8/50
# 782/782 [==============================] - 51s 66ms/step - loss: 1.6943 - accuracy: 0.3783 - val_loss: 1.6720 - val_accuracy: 0.3956
# Epoch 9/50
# 782/782 [==============================] - 52s 66ms/step - loss: 1.6737 - accuracy: 0.3866 - val_loss: 1.6486 - val_accuracy: 0.4016
# Epoch 10/50
# 782/782 [==============================] - 52s 66ms/step - loss: 1.6543 - accuracy: 0.3932 - val_loss: 1.6458 - val_accuracy: 0.4054
# Epoch 11/50
# 782/782 [==============================] - 52s 66ms/step - loss: 1.6356 - accuracy: 0.4026 - val_loss: 1.6141 - val_accuracy: 0.4169
# Epoch 12/50
# 782/782 [==============================] - 52s 66ms/step - loss: 1.6161 - accuracy: 0.4117 - val_loss: 1.5967 - val_accuracy: 0.4191
# Epoch 13/50
# 782/782 [==============================] - 52s 66ms/step - loss: 1.5942 - accuracy: 0.4190 - val_loss: 1.5556 - val_accuracy: 0.4351
# Epoch 14/50
# 782/782 [==============================] - 52s 66ms/step - loss: 1.5778 - accuracy: 0.4255 - val_loss: 1.5541 - val_accuracy: 0.4391
# Epoch 15/50
# 782/782 [==============================] - 51s 65ms/step - loss: 1.5575 - accuracy: 0.4348 - val_loss: 1.5617 - val_accuracy: 0.4357
# Epoch 16/50
# 782/782 [==============================] - 51s 66ms/step - loss: 1.5446 - accuracy: 0.4394 - val_loss: 1.5300 - val_accuracy: 0.4457
# Epoch 17/50
# 782/782 [==============================] - 52s 66ms/step - loss: 1.5348 - accuracy: 0.4454 - val_loss: 1.4930 - val_accuracy: 0.4591
# Epoch 18/50
# 782/782 [==============================] - 51s 66ms/step - loss: 1.5206 - accuracy: 0.4506 - val_loss: 1.5249 - val_accuracy: 0.4448
# Epoch 19/50
# 782/782 [==============================] - 51s 65ms/step - loss: 1.5106 - accuracy: 0.4515 - val_loss: 1.4920 - val_accuracy: 0.4634
# Epoch 20/50
# 782/782 [==============================] - 51s 66ms/step - loss: 1.4876 - accuracy: 0.4627 - val_loss: 1.4926 - val_accuracy: 0.4584
# Epoch 41/50
# 782/782 [==============================] - 52s 66ms/step - loss: 1.4859 - accuracy: 0.4650 - val_loss: 1.4819 - val_accuracy: 0.4526
# Epoch 42/50
# 782/782 [==============================] - 51s 65ms/step - loss: 1.4848 - accuracy: 0.4646 - val_loss: 1.4700 - val_accuracy: 0.4601
# Epoch 43/50
# 782/782 [==============================] - 51s 65ms/step - loss: 1.4848 - accuracy: 0.4634 - val_loss: 1.4654 - val_accuracy: 0.4640
# Epoch 44/50
# 782/782 [==============================] - 51s 66ms/step - loss: 1.4856 - accuracy: 0.4619 - val_loss: 1.5425 - val_accuracy: 0.4422
# Epoch 45/50
# 782/782 [==============================] - 52s 67ms/step - loss: 1.4874 - accuracy: 0.4607 - val_loss: 1.5072 - val_accuracy: 0.4441
# Epoch 46/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.4853 - accuracy: 0.4630 - val_loss: 1.4888 - val_accuracy: 0.4617
# Epoch 47/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.4889 - accuracy: 0.4618 - val_loss: 1.4774 - val_accuracy: 0.4567
# Epoch 48/50
# 782/782 [==============================] - 53s 67ms/step - loss: 1.4889 - accuracy: 0.4610 - val_loss: 1.5075 - val_accuracy: 0.4525
# Epoch 49/50
# 782/782 [==============================] - 52s 67ms/step - loss: 1.4878 - accuracy: 0.4604 - val_loss: 1.5035 - val_accuracy: 0.4552
# Epoch 50/50
# 782/782 [==============================] - 53s 67ms/step - loss: 1.4908 - accuracy: 0.4611 - val_loss: 1.4639 - val_accuracy: 0.4684

# %%
from utils import inf_time_check
print(f'Training time {round((total_time_16),3)} sec for {num_epochs} epochs.')
inference_time_16 = inf_time_check(model_16, val_ds)
print(f'Inference time {inference_time_16} ms for {num_val_samples} samples.')
# Out:
# Training time 2589.29 sec for 50 epochs.
# 64/64 [==============================] - 2s 18ms/step
# 64/64 [==============================] - 1s 16ms/step
# 64/64 [==============================] - 1s 14ms/step
# 64/64 [==============================] - 1s 14ms/step
# 64/64 [==============================] - 1s 14ms/step
# Inference time 1234.403 ms for 10000 samples.

# %%
log_name_16 = '\log\cifar10\ViP\\random_feature_32_relu\L_16.pkl'
log_path_16 = main_dir + log_name_16
with open(log_path_16, 'wb') as file:
    pickle.dump(history_16.history, file)

# %%
# plot accuracy curve
plt.plot(history_16.history["accuracy"], label="Train Accuracy")
plt.plot(history_16.history["val_accuracy"], label="Validation Accuracy")
plt.title("Train and Validation Accuracy Over Epochs L=16")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()

# %%
# plot loss curve
plt.plot(history_16.history["loss"], label="Train Loss")
plt.plot(history_16.history["val_loss"], label="Validation Loss")
plt.title("Train and Validation Loss Over Epochs L=16")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# %% [markdown]
# # L = 64

# %%
patch_size = 4
model_64 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=input_shape),
    VisionPerformer(image_size=image_size, patch_size=patch_size, num_layers=num_layers,
                      num_classes=num_classes, d_model=d_model, num_heads=num_heads, 
                  random_features=random_features, kernel_transformation=kernel_transformation,
                  mlp_dim=mlp_dim),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(10, activation='softmax')
])

model_64.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
             optimizer=tfa.optimizers.AdamW(learning_rate=lr, weight_decay=weight_decay),
             metrics=['accuracy']) 

model_64.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vision_performer_1 (VisionP  (None, 10)               163594
#  erformer)
#
#  flatten (Flatten)           (None, 10)                0
#
#  dense_79 (Dense)            (None, 10)                110
#
# =================================================================
# Total params: 163,704
# Trainable params: 163,704
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_name = 'L_64'
path = main_dir + '\model_checkpoints\cifar10\ViP\\random_feature_32_relu\\' + model_name

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=path,
    save_best_only=True,
    save_weights_only=True,
    monitor='val_loss',
    mode='min'
)

#train model
start_time = time.time()
history_64 = model_64.fit(
    train_ds,
    epochs=num_epochs,
    validation_data=val_ds,
    callbacks=[model_checkpoint_callback]
)
end_time = time.time()
total_time_64 = end_time-start_time
# Out:
# Epoch 1/50
# 782/782 [==============================] - 54s 60ms/step - loss: 2.1278 - accuracy: 0.2011 - val_loss: 1.9740 - val_accuracy: 0.2754
# Epoch 2/50
# 782/782 [==============================] - 45s 58ms/step - loss: 1.9454 - accuracy: 0.2709 - val_loss: 1.8353 - val_accuracy: 0.3235
# Epoch 3/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.8410 - accuracy: 0.3118 - val_loss: 1.7784 - val_accuracy: 0.3435
# Epoch 4/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.7705 - accuracy: 0.3421 - val_loss: 1.7037 - val_accuracy: 0.3777
# Epoch 5/50
# 782/782 [==============================] - 46s 58ms/step - loss: 1.7205 - accuracy: 0.3654 - val_loss: 1.6752 - val_accuracy: 0.3892
# Epoch 6/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.6800 - accuracy: 0.3791 - val_loss: 1.6190 - val_accuracy: 0.4114
# Epoch 7/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.6447 - accuracy: 0.3969 - val_loss: 1.5993 - val_accuracy: 0.4218
# Epoch 8/50
# 782/782 [==============================] - 45s 58ms/step - loss: 1.6085 - accuracy: 0.4114 - val_loss: 1.5653 - val_accuracy: 0.4311
# Epoch 9/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.5761 - accuracy: 0.4228 - val_loss: 1.5297 - val_accuracy: 0.4453
# Epoch 10/50
# 782/782 [==============================] - 45s 57ms/step - loss: 1.5491 - accuracy: 0.4382 - val_loss: 1.4947 - val_accuracy: 0.4612
# Epoch 11/50
# 782/782 [==============================] - 45s 57ms/step - loss: 1.5248 - accuracy: 0.4461 - val_loss: 1.4775 - val_accuracy: 0.4674
# Epoch 12/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.5066 - accuracy: 0.4556 - val_loss: 1.4693 - val_accuracy: 0.4648
# Epoch 13/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.4889 - accuracy: 0.4605 - val_loss: 1.4430 - val_accuracy: 0.4743
# Epoch 14/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.4704 - accuracy: 0.4690 - val_loss: 1.4378 - val_accuracy: 0.4767
# Epoch 35/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.3451 - accuracy: 0.5173 - val_loss: 1.3529 - val_accuracy: 0.5059
# Epoch 36/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.3456 - accuracy: 0.5173 - val_loss: 1.3567 - val_accuracy: 0.5067
# Epoch 37/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.3424 - accuracy: 0.5184 - val_loss: 1.3235 - val_accuracy: 0.5157
# Epoch 38/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.3455 - accuracy: 0.5179 - val_loss: 1.3589 - val_accuracy: 0.4991
# Epoch 39/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.3481 - accuracy: 0.5154 - val_loss: 1.3477 - val_accuracy: 0.5108
# Epoch 40/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.3449 - accuracy: 0.5198 - val_loss: 1.3372 - val_accuracy: 0.5126
# Epoch 41/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.3461 - accuracy: 0.5178 - val_loss: 1.3611 - val_accuracy: 0.4995
# Epoch 42/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.3426 - accuracy: 0.5172 - val_loss: 1.3425 - val_accuracy: 0.5083
# Epoch 43/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.3441 - accuracy: 0.5168 - val_loss: 1.3559 - val_accuracy: 0.5020
# Epoch 44/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.3416 - accuracy: 0.5171 - val_loss: 1.3396 - val_accuracy: 0.5123
# Epoch 45/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.3501 - accuracy: 0.5141 - val_loss: 1.3515 - val_accuracy: 0.5021
# Epoch 46/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.3460 - accuracy: 0.5180 - val_loss: 1.3306 - val_accuracy: 0.5149
# Epoch 47/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.3501 - accuracy: 0.5134 - val_loss: 1.3295 - val_accuracy: 0.5131
# Epoch 48/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.3437 - accuracy: 0.5189 - val_loss: 1.3586 - val_accuracy: 0.5038
# Epoch 49/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.3437 - accuracy: 0.5193 - val_loss: 1.3247 - val_accuracy: 0.5154
# Epoch 50/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.3458 - accuracy: 0.5150 - val_loss: 1.3319 - val_accuracy: 0.5140

# %%
print(f'Training time {round((total_time_64),3)} sec for {num_epochs} epochs.')
inference_time_64 = inf_time_check(model_64, val_ds)
print(f'Inference time {inference_time_64} ms for {num_val_samples} samples.')
# Out:
# Training time 2312.038 sec for 50 epochs.
# 64/64 [==============================] - 2s 16ms/step
# 64/64 [==============================] - 1s 15ms/step
# 64/64 [==============================] - 1s 15ms/step
# 64/64 [==============================] - 1s 15ms/step
# 64/64 [==============================] - 1s 15ms/step
# Inference time 1238.108 ms for 10000 samples.

# %%
log_name_64 = '\log\cifar10\ViP\\random_feature_32_relu\L_64.pkl'
log_path_64 = main_dir + log_name_64
with open(log_path_64, 'wb') as file:
    pickle.dump(history_64.history, file)

# %%
# plot accuracy curve
plt.plot(history_64.history["accuracy"], label="Train Accuracy")
plt.plot(history_64.history["val_accuracy"], label="Validation Accuracy")
plt.title("Train and Validation Accuracy Over Epochs L=64")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()

# %%
# plot loss curve
plt.plot(history_64.history["loss"], label="Train Loss")
plt.plot(history_64.history["val_loss"], label="Validation Loss")
plt.title("Train and Validation Loss Over Epochs L=64")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# %% [markdown]
# # L = 256

# %%
patch_size = 2
model_256 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=input_shape),
    VisionPerformer(image_size=image_size, patch_size=patch_size, num_layers=num_layers,
                      num_classes=num_classes, d_model=d_model, num_heads=num_heads, 
                  random_features=random_features, kernel_transformation=kernel_transformation,
                  mlp_dim=mlp_dim),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(10, activation='softmax')
])

model_256.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
             optimizer=tfa.optimizers.AdamW(learning_rate=lr, weight_decay=weight_decay),
             metrics=['accuracy']) 

model_256.summary()
# Out:
# Model: "sequential_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vision_performer_2 (VisionP  (None, 10)               173578
#  erformer)
#
#  flatten_1 (Flatten)         (None, 10)                0
#
#  dense_119 (Dense)           (None, 10)                110
#
# =================================================================
# Total params: 173,688
# Trainable params: 173,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_name = 'L_256'
path = main_dir + '\model_checkpoints\cifar10\ViP\\random_feature_32_relu\\' + model_name

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=path,
    save_best_only=True,
    save_weights_only=True,
    monitor='val_loss',
    mode='min'
)

#train model
start_time = time.time()
history_256 = model_256.fit(
    train_ds,
    epochs=num_epochs,
    validation_data=val_ds,
    callbacks=[model_checkpoint_callback]
)
end_time = time.time()
total_time_256 = end_time-start_time
# Out:
# Epoch 1/50
# 782/782 [==============================] - 63s 71ms/step - loss: 2.1056 - accuracy: 0.2016 - val_loss: 1.9147 - val_accuracy: 0.2806
# Epoch 2/50
# 782/782 [==============================] - 54s 70ms/step - loss: 1.8959 - accuracy: 0.2847 - val_loss: 1.8004 - val_accuracy: 0.3298
# Epoch 3/50
# 782/782 [==============================] - 54s 69ms/step - loss: 1.7987 - accuracy: 0.3277 - val_loss: 1.7141 - val_accuracy: 0.3680
# Epoch 4/50
# 782/782 [==============================] - 54s 70ms/step - loss: 1.7306 - accuracy: 0.3550 - val_loss: 1.6753 - val_accuracy: 0.3826
# Epoch 5/50
# 782/782 [==============================] - 54s 70ms/step - loss: 1.6813 - accuracy: 0.3769 - val_loss: 1.6439 - val_accuracy: 0.3893
# Epoch 6/50
# 782/782 [==============================] - 55s 70ms/step - loss: 1.6507 - accuracy: 0.3912 - val_loss: 1.6099 - val_accuracy: 0.4036
# Epoch 7/50
# 782/782 [==============================] - 54s 70ms/step - loss: 1.6189 - accuracy: 0.4016 - val_loss: 1.5752 - val_accuracy: 0.4155
# Epoch 8/50
# 782/782 [==============================] - 54s 70ms/step - loss: 1.5908 - accuracy: 0.4174 - val_loss: 1.5471 - val_accuracy: 0.4298
# Epoch 9/50
# 782/782 [==============================] - 54s 69ms/step - loss: 1.5643 - accuracy: 0.4262 - val_loss: 1.5421 - val_accuracy: 0.4297
# 782/782 [==============================] - 54s 70ms/step - loss: 1.3065 - accuracy: 0.5295 - val_loss: 1.3254 - val_accuracy: 0.5159
# Epoch 50/50
# 782/782 [==============================] - 55s 70ms/step - loss: 1.3095 - accuracy: 0.5302 - val_loss: 1.3277 - val_accuracy: 0.5153

# %%
from utils import inf_time_check
print(f'Training time {round((total_time_256),3)} sec for {num_epochs} epochs.')
inference_time_256 = inf_time_check(model_256, val_ds)
print(f'Inference time {inference_time_256} ms for {num_val_samples} samples.')
# Out:
# Training time 2730.179 sec for 50 epochs.
# 64/64 [==============================] - 2s 11ms/step
# 64/64 [==============================] - 1s 12ms/step
# 64/64 [==============================] - 1s 12ms/step
# 64/64 [==============================] - 1s 12ms/step
# 64/64 [==============================] - 1s 14ms/step
# Inference time 1005.2 ms for 10000 samples.

# %%
log_name_256 = '\log\cifar10\ViP\\random_feature_32_relu\L_256.pkl'
log_path_256 = main_dir + log_name_256
with open(log_path_256, 'wb') as file:
    pickle.dump(history_256.history, file)

# %%
# plot accuracy curve
plt.plot(history_256.history["accuracy"], label="Train Accuracy")
plt.plot(history_256.history["val_accuracy"], label="Validation Accuracy")
plt.title("Train and Validation Accuracy Over Epochs L=256")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()

# %%
# plot loss curve
plt.plot(history_256.history["loss"], label="Train Loss")
plt.plot(history_256.history["val_loss"], label="Validation Loss")
plt.title("Train and Validation Loss Over Epochs L=256")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# %% [markdown]
# # L = 1024

# %%
patch_size = 1
model_1024 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=input_shape),
    VisionPerformer(image_size=image_size, patch_size=patch_size, num_layers=num_layers,
                      num_classes=num_classes, d_model=d_model, num_heads=num_heads, 
                  random_features=random_features, kernel_transformation=kernel_transformation,
                  mlp_dim=mlp_dim),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(10, activation='softmax')
])

model_1024.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
             optimizer=tfa.optimizers.AdamW(learning_rate=lr, weight_decay=weight_decay),
             metrics=['accuracy']) 

model_1024.summary()
# Out:
# Model: "sequential_31"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vision_performer_3 (VisionP  (None, 10)               222154
#  erformer)
#
#  flatten_2 (Flatten)         (None, 10)                0
#
#  dense_159 (Dense)           (None, 10)                110
#
# =================================================================
# Total params: 222,264
# Trainable params: 222,264
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_name = 'L_1024'
path = main_dir + '\model_checkpoints\cifar10\ViP\\random_feature_32_relu\\' + model_name

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=path,
    save_best_only=True,
    save_weights_only=True,
    monitor='val_loss',
    mode='min'
)

#train model
start_time = time.time()
history_1024 = model_1024.fit(
    train_ds,
    epochs=num_epochs,
    validation_data=val_ds,
    callbacks=[model_checkpoint_callback]
)
end_time = time.time()
total_time_1024 = end_time-start_time
# Out:
# Epoch 1/50
# 782/782 [==============================] - 125s 151ms/step - loss: 2.1235 - accuracy: 0.1973 - val_loss: 1.9652 - val_accuracy: 0.2681
# Epoch 2/50
# 782/782 [==============================] - 117s 149ms/step - loss: 1.9491 - accuracy: 0.2733 - val_loss: 1.8968 - val_accuracy: 0.3089
# Epoch 3/50
# 782/782 [==============================] - 117s 149ms/step - loss: 1.8710 - accuracy: 0.3122 - val_loss: 1.8504 - val_accuracy: 0.3272
# Epoch 4/50
# Epoch 24/50
# 782/782 [==============================] - 117s 150ms/step - loss: 1.5116 - accuracy: 0.4609 - val_loss: 1.5421 - val_accuracy: 0.4428
# Epoch 25/50
# 782/782 [==============================] - 117s 150ms/step - loss: 1.5066 - accuracy: 0.4605 - val_loss: 1.5369 - val_accuracy: 0.4412
# Epoch 26/50
# 782/782 [==============================] - 117s 150ms/step - loss: 1.5102 - accuracy: 0.4611 - val_loss: 1.5086 - val_accuracy: 0.4554
# Epoch 27/50
# 782/782 [==============================] - 117s 149ms/step - loss: 1.5093 - accuracy: 0.4594 - val_loss: 1.5231 - val_accuracy: 0.4491
# Epoch 28/50
# 782/782 [==============================] - 117s 150ms/step - loss: 1.5009 - accuracy: 0.4658 - val_loss: 1.5428 - val_accuracy: 0.4397
# Epoch 29/50
# 782/782 [==============================] - 117s 149ms/step - loss: 1.5051 - accuracy: 0.4647 - val_loss: 1.5340 - val_accuracy: 0.4397
# Epoch 30/50
# 782/782 [==============================] - 117s 150ms/step - loss: 1.5006 - accuracy: 0.4625 - val_loss: 1.5149 - val_accuracy: 0.4480
# Epoch 31/50
# 782/782 [==============================] - 117s 150ms/step - loss: 1.5001 - accuracy: 0.4648 - val_loss: 1.5143 - val_accuracy: 0.4510
# Epoch 32/50
# 782/782 [==============================] - 117s 149ms/step - loss: 1.4976 - accuracy: 0.4655 - val_loss: 1.5212 - val_accuracy: 0.4446
# Epoch 33/50
# 782/782 [==============================] - 117s 150ms/step - loss: 1.4941 - accuracy: 0.4642 - val_loss: 1.5019 - val_accuracy: 0.4568
# Epoch 34/50
# 782/782 [==============================] - 117s 149ms/step - loss: 1.4915 - accuracy: 0.4668 - val_loss: 1.4898 - val_accuracy: 0.4611
# Epoch 35/50
# 782/782 [==============================] - 117s 149ms/step - loss: 1.4883 - accuracy: 0.4688 - val_loss: 1.5142 - val_accuracy: 0.4554
# Epoch 36/50
# 782/782 [==============================] - 117s 149ms/step - loss: 1.4916 - accuracy: 0.4668 - val_loss: 1.4927 - val_accuracy: 0.4568
# Epoch 37/50
# 782/782 [==============================] - 118s 151ms/step - loss: 1.4881 - accuracy: 0.4681 - val_loss: 1.4946 - val_accuracy: 0.4568
# Epoch 38/50
# 782/782 [==============================] - 117s 150ms/step - loss: 1.4909 - accuracy: 0.4666 - val_loss: 1.4987 - val_accuracy: 0.4563
# Epoch 39/50
# 782/782 [==============================] - 117s 150ms/step - loss: 1.4865 - accuracy: 0.4667 - val_loss: 1.4858 - val_accuracy: 0.4577
# Epoch 40/50
# 782/782 [==============================] - 117s 150ms/step - loss: 1.4847 - accuracy: 0.4681 - val_loss: 1.4997 - val_accuracy: 0.4506
# Epoch 41/50
# 782/782 [==============================] - 117s 150ms/step - loss: 1.4804 - accuracy: 0.4673 - val_loss: 1.5051 - val_accuracy: 0.4526
# Epoch 42/50
# 782/782 [==============================] - 118s 150ms/step - loss: 1.4851 - accuracy: 0.4684 - val_loss: 1.4756 - val_accuracy: 0.4589
# Epoch 43/50
# 782/782 [==============================] - 117s 150ms/step - loss: 1.4798 - accuracy: 0.4708 - val_loss: 1.5210 - val_accuracy: 0.4424
# Epoch 44/50
# 782/782 [==============================] - 117s 150ms/step - loss: 1.4827 - accuracy: 0.4711 - val_loss: 1.5071 - val_accuracy: 0.4476
# Epoch 45/50
# 782/782 [==============================] - 117s 150ms/step - loss: 1.4776 - accuracy: 0.4705 - val_loss: 1.4807 - val_accuracy: 0.4560
# Epoch 46/50
# 782/782 [==============================] - 117s 150ms/step - loss: 1.4751 - accuracy: 0.4728 - val_loss: 1.4679 - val_accuracy: 0.4707
# Epoch 47/50
# 782/782 [==============================] - 117s 150ms/step - loss: 1.4725 - accuracy: 0.4743 - val_loss: 1.4876 - val_accuracy: 0.4587
# Epoch 48/50
# 782/782 [==============================] - 117s 150ms/step - loss: 1.4692 - accuracy: 0.4747 - val_loss: 1.4771 - val_accuracy: 0.4590
# Epoch 49/50
# 782/782 [==============================] - 117s 150ms/step - loss: 1.4672 - accuracy: 0.4753 - val_loss: 1.4733 - val_accuracy: 0.4605
# Epoch 50/50
# 782/782 [==============================] - 117s 150ms/step - loss: 1.4644 - accuracy: 0.4700 - val_loss: 1.4601 - val_accuracy: 0.4614

# %%
print(f'Training time {round((total_time_1024),3)} sec for {num_epochs} epochs.')
inference_time_1024 = inf_time_check(model_1024, val_ds)
print(f'Inference time {inference_time_1024} ms for {num_val_samples} samples.')
# Out:
# Training time 5856.258 sec for 50 epochs.
# 64/64 [==============================] - 2s 12ms/step
# 64/64 [==============================] - 1s 12ms/step
# 64/64 [==============================] - 1s 13ms/step
# 64/64 [==============================] - 1s 14ms/step
# 64/64 [==============================] - 1s 15ms/step
# Inference time 1076.906 ms for 10000 samples.

# %%
log_name_1024 = '\log\cifar10\ViP\\random_feature_32_relu\L_1024.pkl'
log_path_1024 = main_dir + log_name_1024
with open(log_path_1024, 'wb') as file:
    pickle.dump(history_1024.history, file)

# %%
# plot accuracy curve
plt.plot(history_1024.history["accuracy"], label="Train Accuracy")
plt.plot(history_1024.history["val_accuracy"], label="Validation Accuracy")
plt.title("Train and Validation Accuracy Over Epochs L=1024")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()

# %%
# plot loss curve
plt.plot(history_1024.history["loss"], label="Train Loss")
plt.plot(history_1024.history["val_loss"], label="Validation Loss")
plt.title("Train and Validation Loss Over Epochs L=1024")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# %%
total_time = [total_time_16, total_time_64, total_time_256, total_time_1024]
inference_time = [inference_time_16, inference_time_64, inference_time_256, inference_time_1024]
log = []
log.append(total_time)
log.append(inference_time)
log_name = '\log\cifar10\ViP\\random_feature_32_relu\\total_inf_time'
log_path = main_dir + log_name
# log [total_time, inference_time]
with open(log_path, 'wb') as file:
    pickle.dump(log, file)

# %%
logL = np.log2([16, 64, 256, 1024])

fig, ax1 = plt.subplots()
plt.title(f'Inference time & Total training time over {num_epochs} epochs')
plt.xlabel('log2(L)')

ax1.plot(logL, total_time, color='blue', label='Total training time')
ax1.set_ylabel('Time (sec)', color='blue')
ax1.legend(loc='upper right')

ax2 = ax1.twinx()
ax2.plot(logL, inference_time, color='red', label='Inference time')
ax2.set_ylabel('Time (ms)', color='red')
ax2.legend(loc='upper left')

plt.grid()
plt.show()
