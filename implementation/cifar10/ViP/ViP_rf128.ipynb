# %% [markdown]
# # ViP Classification on CIFAR-10

# %% [markdown]
# ## random_features=128

# %%
import tensorflow as tf
import tensorflow_addons as tfa
import numpy as np
import matplotlib.pyplot as plt
import time
import datetime
import sys
import os
import pickle

# check GPU
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import tensorflow_datasets as tfds
train_dataset, info = tfds.load('cifar10', split='train', shuffle_files=True, with_info=True)
val_dataset = tfds.load('cifar10', split='test', shuffle_files=False)

# number of samples
num_train_samples = tf.data.experimental.cardinality(train_dataset).numpy()
num_val_samples = tf.data.experimental.cardinality(val_dataset).numpy()
print('Number of training samples:', num_train_samples)
print('Number of validation samples:', num_val_samples)

# size of image
for example in train_dataset.take(1):
    image, label = example['image'], example['label']
print('Image size:', image.shape)

# number of classes
num_classes = info.features['label'].num_classes
print('Number of classes: ', num_classes)
# Out:
# Number of training samples: 50000
# Number of validation samples: 10000
# Image size: (32, 32, 3)
# Number of classes:  10

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
batch_size = 64

def extract_image_and_label(example):
    image, label = example['image'], example['label']
    image = tf.cast(image, tf.float32)
    return image, label

# extract image and label from dataloader
train_ds = train_dataset.map(extract_image_and_label)
val_ds = val_dataset.map(extract_image_and_label)

# batch train_ds and val_ds
train_ds = train_ds.batch(batch_size)
val_ds = val_ds.batch(batch_size)

# input pipeline optimization
train_ds = train_ds.cache().prefetch(AUTOTUNE)
val_ds = val_ds.cache().prefetch(AUTOTUNE)

# %%
curr_dir = os.getcwd() 
parent_dir = os.path.abspath(os.path.join(curr_dir, os.pardir))
implementation_dir = os.path.abspath(os.path.join(parent_dir, os.pardir))
main_dir = os.path.abspath(os.path.join(implementation_dir, os.pardir))
sys.path.append(main_dir)

# %%
from model.vision_performer import VisionPerformer
# compiler attributes
lr = 1e-4
weight_decay = 1e-4
num_epochs = 50

# VisionTransformer attributes
input_shape = image.shape # [32, 32, 3]
image_size = image.shape[0] # 32
num_layers = 6
num_classes = num_classes # 10
d_model = 64
num_heads = 1
mlp_dim = 64
# VisionPerformer attributes
random_features = 128
kernel_transformation = 'softmax'

# %% [markdown]
# # L = 16

# %%
patch_size = 8
model_16 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=input_shape),
    VisionPerformer(image_size=image_size, patch_size=patch_size, num_layers=num_layers,
                      num_classes=num_classes, d_model=d_model, num_heads=num_heads, 
                  random_features=random_features, kernel_transformation=kernel_transformation,
                  mlp_dim=mlp_dim),
    tf.keras.layers.Dense(10, activation='softmax')
])

model_16.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
             optimizer=tfa.optimizers.AdamW(learning_rate=lr, weight_decay=weight_decay),
             metrics=['accuracy']) 

model_16.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vision_performer (VisionPer  (None, 10)               169738
#  former)
#
#  dense_39 (Dense)            (None, 10)                110
#
# =================================================================
# Total params: 169,848
# Trainable params: 169,848
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_name = 'L_16'
path = main_dir + '\model_checkpoints\cifar10\ViP\\random_feature_128\\' + model_name

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=path,
    save_best_only=True,
    save_weights_only=True,
    monitor='val_loss',
    mode='min'
)

#train model
start_time = time.time()
history_16 = model_16.fit(
    train_ds,
    epochs=num_epochs,
    validation_data=val_ds,
    callbacks=[model_checkpoint_callback]
)
end_time = time.time()
total_time_16 = end_time-start_time
# Out:
# Epoch 1/50
# 782/782 [==============================] - 84s 84ms/step - loss: 2.1412 - accuracy: 0.1936 - val_loss: 1.9896 - val_accuracy: 0.2587
# Epoch 2/50
# 782/782 [==============================] - 62s 79ms/step - loss: 1.9742 - accuracy: 0.2646 - val_loss: 1.9193 - val_accuracy: 0.2973
# Epoch 3/50
# 782/782 [==============================] - 62s 79ms/step - loss: 1.8954 - accuracy: 0.2993 - val_loss: 1.8291 - val_accuracy: 0.3333
# Epoch 4/50
# 782/782 [==============================] - 62s 79ms/step - loss: 1.8350 - accuracy: 0.3257 - val_loss: 1.7701 - val_accuracy: 0.3543
# Epoch 5/50
# 782/782 [==============================] - 61s 78ms/step - loss: 1.7892 - accuracy: 0.3427 - val_loss: 1.7291 - val_accuracy: 0.3674
# Epoch 6/50
# 782/782 [==============================] - 62s 79ms/step - loss: 1.7526 - accuracy: 0.3591 - val_loss: 1.7131 - val_accuracy: 0.3770
# Epoch 7/50
# 782/782 [==============================] - 62s 79ms/step - loss: 1.7184 - accuracy: 0.3702 - val_loss: 1.6748 - val_accuracy: 0.3983
# Epoch 8/50
# 782/782 [==============================] - 61s 78ms/step - loss: 1.6920 - accuracy: 0.3788 - val_loss: 1.6383 - val_accuracy: 0.4042
# Epoch 9/50
# 782/782 [==============================] - 61s 78ms/step - loss: 1.6689 - accuracy: 0.3895 - val_loss: 1.6137 - val_accuracy: 0.4169
# Epoch 10/50
# 782/782 [==============================] - 61s 78ms/step - loss: 1.6520 - accuracy: 0.3965 - val_loss: 1.6122 - val_accuracy: 0.4137
# Epoch 11/50
# 782/782 [==============================] - 61s 78ms/step - loss: 1.6342 - accuracy: 0.4035 - val_loss: 1.5989 - val_accuracy: 0.4207
# Epoch 12/50
# 782/782 [==============================] - 61s 78ms/step - loss: 1.6201 - accuracy: 0.4089 - val_loss: 1.5928 - val_accuracy: 0.4182
# Epoch 13/50
# 782/782 [==============================] - 61s 78ms/step - loss: 1.6107 - accuracy: 0.4137 - val_loss: 1.5894 - val_accuracy: 0.4239
# Epoch 14/50
# 782/782 [==============================] - 61s 78ms/step - loss: 1.5948 - accuracy: 0.4145 - val_loss: 1.5952 - val_accuracy: 0.4196
# Epoch 15/50
# 782/782 [==============================] - 61s 79ms/step - loss: 1.5858 - accuracy: 0.4215 - val_loss: 1.5811 - val_accuracy: 0.4210
# Epoch 16/50
# 782/782 [==============================] - 61s 78ms/step - loss: 1.5724 - accuracy: 0.4244 - val_loss: 1.5766 - val_accuracy: 0.4314
# Epoch 17/50
# 782/782 [==============================] - 61s 78ms/step - loss: 1.5713 - accuracy: 0.4247 - val_loss: 1.5562 - val_accuracy: 0.4248
# Epoch 18/50
# 782/782 [==============================] - 60s 77ms/step - loss: 1.5656 - accuracy: 0.4297 - val_loss: 1.5723 - val_accuracy: 0.4259
# Epoch 19/50
# 782/782 [==============================] - 60s 77ms/step - loss: 1.5629 - accuracy: 0.4301 - val_loss: 1.5639 - val_accuracy: 0.4319
# Epoch 20/50
# 782/782 [==============================] - 62s 79ms/step - loss: 1.5520 - accuracy: 0.4268 - val_loss: 1.5124 - val_accuracy: 0.4413
# Epoch 41/50
# 782/782 [==============================] - 61s 78ms/step - loss: 1.5538 - accuracy: 0.4251 - val_loss: 1.5701 - val_accuracy: 0.4295
# Epoch 42/50
# 782/782 [==============================] - 61s 78ms/step - loss: 1.5542 - accuracy: 0.4238 - val_loss: 1.5365 - val_accuracy: 0.4283
# Epoch 43/50
# 782/782 [==============================] - 61s 78ms/step - loss: 1.5587 - accuracy: 0.4217 - val_loss: 1.5438 - val_accuracy: 0.4329
# Epoch 44/50
# 782/782 [==============================] - 61s 78ms/step - loss: 1.5545 - accuracy: 0.4244 - val_loss: 1.5648 - val_accuracy: 0.4239
# Epoch 45/50
# 782/782 [==============================] - 61s 78ms/step - loss: 1.5569 - accuracy: 0.4251 - val_loss: 1.5340 - val_accuracy: 0.4351
# Epoch 46/50
# 782/782 [==============================] - 61s 78ms/step - loss: 1.5569 - accuracy: 0.4224 - val_loss: 1.5397 - val_accuracy: 0.4327
# Epoch 47/50
# 782/782 [==============================] - 61s 78ms/step - loss: 1.5541 - accuracy: 0.4260 - val_loss: 1.5260 - val_accuracy: 0.4314
# Epoch 48/50
# 782/782 [==============================] - 61s 78ms/step - loss: 1.5553 - accuracy: 0.4244 - val_loss: 1.5885 - val_accuracy: 0.4125
# Epoch 49/50
# 782/782 [==============================] - 61s 78ms/step - loss: 1.5589 - accuracy: 0.4228 - val_loss: 1.5505 - val_accuracy: 0.4176
# Epoch 50/50
# 782/782 [==============================] - 61s 78ms/step - loss: 1.5580 - accuracy: 0.4223 - val_loss: 1.5638 - val_accuracy: 0.4209

# %%
from utils import inf_time_check
print(f'Training time {round((total_time_16),3)} sec for {num_epochs} epochs.')
inference_time_16 = inf_time_check(model_16, val_ds)
print(f'Inference time {inference_time_16} ms for {num_val_samples} samples.')
# Out:
# Training time 3076.192 sec for 50 epochs.
# 64/64 [==============================] - 2s 22ms/step
# 64/64 [==============================] - 1s 21ms/step
# 64/64 [==============================] - 1s 21ms/step
# 64/64 [==============================] - 1s 19ms/step
# 64/64 [==============================] - 1s 17ms/step
# Inference time 1574.038 ms for 10000 samples.

# %%
log_name_16 = '\log\cifar10\ViP\\random_feature_128\L_16.pkl'
log_path_16 = main_dir + log_name_16
with open(log_path_16, 'wb') as file:
    pickle.dump(history_16.history, file)

# %%
# plot accuracy curve
plt.plot(history_16.history["accuracy"], label="Train Accuracy")
plt.plot(history_16.history["val_accuracy"], label="Validation Accuracy")
plt.title("Train and Validation Accuracy Over Epochs L=16")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()

# %%
# plot loss curve
plt.plot(history_16.history["loss"], label="Train Loss")
plt.plot(history_16.history["val_loss"], label="Validation Loss")
plt.title("Train and Validation Loss Over Epochs L=16")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# %% [markdown]
# # L = 64

# %%
patch_size = 4
model_64 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=input_shape),
    VisionPerformer(image_size=image_size, patch_size=patch_size, num_layers=num_layers,
                      num_classes=num_classes, d_model=d_model, num_heads=num_heads, 
                  random_features=random_features, kernel_transformation=kernel_transformation,
                  mlp_dim=mlp_dim),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(10, activation='softmax')
])

model_64.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
             optimizer=tfa.optimizers.AdamW(learning_rate=lr, weight_decay=weight_decay),
             metrics=['accuracy']) 

model_64.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vision_performer_1 (VisionP  (None, 10)               163594
#  erformer)
#
#  flatten (Flatten)           (None, 10)                0
#
#  dense_79 (Dense)            (None, 10)                110
#
# =================================================================
# Total params: 163,704
# Trainable params: 163,704
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_name = 'L_64'
path = main_dir + '\model_checkpoints\cifar10\ViP\\random_feature_128\\' + model_name

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=path,
    save_best_only=True,
    save_weights_only=True,
    monitor='val_loss',
    mode='min'
)

#train model
start_time = time.time()
history_64 = model_64.fit(
    train_ds,
    epochs=num_epochs,
    validation_data=val_ds,
    callbacks=[model_checkpoint_callback]
)
end_time = time.time()
total_time_64 = end_time-start_time
# Out:
# Epoch 1/50
# 782/782 [==============================] - 62s 69ms/step - loss: 2.1202 - accuracy: 0.1934 - val_loss: 1.9735 - val_accuracy: 0.2591
# Epoch 2/50
# 782/782 [==============================] - 53s 67ms/step - loss: 1.9627 - accuracy: 0.2563 - val_loss: 1.8741 - val_accuracy: 0.2940
# Epoch 3/50
# 782/782 [==============================] - 53s 67ms/step - loss: 1.8708 - accuracy: 0.2978 - val_loss: 1.7853 - val_accuracy: 0.3350
# Epoch 4/50
# 782/782 [==============================] - 53s 67ms/step - loss: 1.7972 - accuracy: 0.3359 - val_loss: 1.7212 - val_accuracy: 0.3644
# Epoch 5/50
# 782/782 [==============================] - 53s 67ms/step - loss: 1.7405 - accuracy: 0.3622 - val_loss: 1.6727 - val_accuracy: 0.3767
# Epoch 6/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.6958 - accuracy: 0.3782 - val_loss: 1.6489 - val_accuracy: 0.3914
# Epoch 7/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.6567 - accuracy: 0.3900 - val_loss: 1.6068 - val_accuracy: 0.4057
# Epoch 8/50
# 782/782 [==============================] - 53s 67ms/step - loss: 1.6227 - accuracy: 0.4079 - val_loss: 1.5894 - val_accuracy: 0.4097
# Epoch 9/50
# 782/782 [==============================] - 53s 67ms/step - loss: 1.5909 - accuracy: 0.4208 - val_loss: 1.5647 - val_accuracy: 0.4182
# Epoch 10/50
# 782/782 [==============================] - 53s 67ms/step - loss: 1.5653 - accuracy: 0.4307 - val_loss: 1.5489 - val_accuracy: 0.4262
# Epoch 11/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.5433 - accuracy: 0.4394 - val_loss: 1.5154 - val_accuracy: 0.4426
# Epoch 12/50
# 782/782 [==============================] - 52s 67ms/step - loss: 1.5268 - accuracy: 0.4469 - val_loss: 1.4960 - val_accuracy: 0.4561
# Epoch 13/50
# 782/782 [==============================] - 54s 69ms/step - loss: 1.5107 - accuracy: 0.4535 - val_loss: 1.4952 - val_accuracy: 0.4498
# Epoch 14/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.4997 - accuracy: 0.4569 - val_loss: 1.4921 - val_accuracy: 0.4527
# Epoch 35/50
# 782/782 [==============================] - 53s 67ms/step - loss: 1.4276 - accuracy: 0.4839 - val_loss: 1.4921 - val_accuracy: 0.4448
# Epoch 36/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.4253 - accuracy: 0.4828 - val_loss: 1.4577 - val_accuracy: 0.4625
# Epoch 37/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.4305 - accuracy: 0.4794 - val_loss: 1.4644 - val_accuracy: 0.4456
# Epoch 38/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.4302 - accuracy: 0.4818 - val_loss: 1.4559 - val_accuracy: 0.4511
# Epoch 39/50
# 782/782 [==============================] - 52s 67ms/step - loss: 1.4286 - accuracy: 0.4835 - val_loss: 1.4661 - val_accuracy: 0.4564
# Epoch 40/50
# 782/782 [==============================] - 52s 67ms/step - loss: 1.4270 - accuracy: 0.4822 - val_loss: 1.4573 - val_accuracy: 0.4511
# Epoch 41/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.4298 - accuracy: 0.4833 - val_loss: 1.3898 - val_accuracy: 0.4845
# Epoch 42/50
# 782/782 [==============================] - 52s 67ms/step - loss: 1.4272 - accuracy: 0.4811 - val_loss: 1.3983 - val_accuracy: 0.4789
# Epoch 43/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.4309 - accuracy: 0.4796 - val_loss: 1.4030 - val_accuracy: 0.4773
# Epoch 44/50
# 782/782 [==============================] - 53s 67ms/step - loss: 1.4340 - accuracy: 0.4794 - val_loss: 1.4698 - val_accuracy: 0.4559
# Epoch 45/50
# 782/782 [==============================] - 53s 67ms/step - loss: 1.4285 - accuracy: 0.4805 - val_loss: 1.4393 - val_accuracy: 0.4732
# Epoch 46/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.4279 - accuracy: 0.4804 - val_loss: 1.4548 - val_accuracy: 0.4553
# Epoch 47/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.4317 - accuracy: 0.4786 - val_loss: 1.4139 - val_accuracy: 0.4784
# Epoch 48/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.4290 - accuracy: 0.4811 - val_loss: 1.4738 - val_accuracy: 0.4464
# Epoch 49/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.4290 - accuracy: 0.4801 - val_loss: 1.4380 - val_accuracy: 0.4633
# Epoch 50/50
# 782/782 [==============================] - 53s 67ms/step - loss: 1.4285 - accuracy: 0.4788 - val_loss: 1.4212 - val_accuracy: 0.4700

# %%
print(f'Training time {round((total_time_64),3)} sec for {num_epochs} epochs.')
inference_time_64 = inf_time_check(model_64, val_ds)
print(f'Inference time {inference_time_64} ms for {num_val_samples} samples.')
# Out:
# Training time 2650.384 sec for 50 epochs.
# 64/64 [==============================] - 2s 18ms/step
# 64/64 [==============================] - 1s 17ms/step
# 64/64 [==============================] - 1s 17ms/step
# 64/64 [==============================] - 1s 17ms/step
# 64/64 [==============================] - 1s 18ms/step
# Inference time 1371.553 ms for 10000 samples.

# %%
log_name_64 = '\log\cifar10\ViP\\random_feature_128\L_64.pkl'
log_path_64 = main_dir + log_name_64
with open(log_path_64, 'wb') as file:
    pickle.dump(history_64.history, file)

# %%
# plot accuracy curve
plt.plot(history_64.history["accuracy"], label="Train Accuracy")
plt.plot(history_64.history["val_accuracy"], label="Validation Accuracy")
plt.title("Train and Validation Accuracy Over Epochs L=64")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()

# %%
# plot loss curve
plt.plot(history_64.history["loss"], label="Train Loss")
plt.plot(history_64.history["val_loss"], label="Validation Loss")
plt.title("Train and Validation Loss Over Epochs L=64")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# %% [markdown]
# # L = 256

# %%
patch_size = 2
model_256 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=input_shape),
    VisionPerformer(image_size=image_size, patch_size=patch_size, num_layers=num_layers,
                      num_classes=num_classes, d_model=d_model, num_heads=num_heads, 
                  random_features=random_features, kernel_transformation=kernel_transformation,
                  mlp_dim=mlp_dim),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(10, activation='softmax')
])

model_256.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
             optimizer=tfa.optimizers.AdamW(learning_rate=lr, weight_decay=weight_decay),
             metrics=['accuracy']) 

model_256.summary()
# Out:
# Model: "sequential_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vision_performer_2 (VisionP  (None, 10)               173578
#  erformer)
#
#  flatten_1 (Flatten)         (None, 10)                0
#
#  dense_119 (Dense)           (None, 10)                110
#
# =================================================================
# Total params: 173,688
# Trainable params: 173,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_name = 'L_256'
path = main_dir + '\model_checkpoints\cifar10\ViP\\random_feature_128\\' + model_name

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=path,
    save_best_only=True,
    save_weights_only=True,
    monitor='val_loss',
    mode='min'
)

#train model
start_time = time.time()
history_256 = model_256.fit(
    train_ds,
    epochs=num_epochs,
    validation_data=val_ds,
    callbacks=[model_checkpoint_callback]
)
end_time = time.time()
total_time_256 = end_time-start_time
# Out:
# Epoch 1/50
# 782/782 [==============================] - 83s 95ms/step - loss: 2.1646 - accuracy: 0.1764 - val_loss: 1.9969 - val_accuracy: 0.2431
# Epoch 2/50
# 782/782 [==============================] - 73s 93ms/step - loss: 1.9606 - accuracy: 0.2491 - val_loss: 1.8652 - val_accuracy: 0.2909
# Epoch 3/50
# 782/782 [==============================] - 73s 93ms/step - loss: 1.8495 - accuracy: 0.3038 - val_loss: 1.7636 - val_accuracy: 0.3361
# Epoch 4/50
# 782/782 [==============================] - 73s 93ms/step - loss: 1.7664 - accuracy: 0.3404 - val_loss: 1.7068 - val_accuracy: 0.3632
# Epoch 5/50
# 782/782 [==============================] - 73s 93ms/step - loss: 1.7107 - accuracy: 0.3657 - val_loss: 1.6603 - val_accuracy: 0.3875
# Epoch 6/50
# 782/782 [==============================] - 73s 93ms/step - loss: 1.6671 - accuracy: 0.3877 - val_loss: 1.6340 - val_accuracy: 0.3978
# Epoch 7/50
# 782/782 [==============================] - 73s 93ms/step - loss: 1.6283 - accuracy: 0.3977 - val_loss: 1.6041 - val_accuracy: 0.4100
# Epoch 8/50
# 782/782 [==============================] - 73s 93ms/step - loss: 1.5975 - accuracy: 0.4130 - val_loss: 1.5542 - val_accuracy: 0.4391
# Epoch 9/50
# 782/782 [==============================] - 73s 93ms/step - loss: 1.5690 - accuracy: 0.4281 - val_loss: 1.5449 - val_accuracy: 0.4356
# 782/782 [==============================] - 73s 93ms/step - loss: 1.4327 - accuracy: 0.4827 - val_loss: 1.4337 - val_accuracy: 0.4680
# Epoch 50/50
# 782/782 [==============================] - 73s 93ms/step - loss: 1.4317 - accuracy: 0.4846 - val_loss: 1.4325 - val_accuracy: 0.4671

# %%
from utils import inf_time_check
print(f'Training time {round((total_time_256),3)} sec for {num_epochs} epochs.')
inference_time_256 = inf_time_check(model_256, val_ds)
print(f'Inference time {inference_time_256} ms for {num_val_samples} samples.')
# Out:
# Training time 3657.89 sec for 50 epochs.
# 64/64 [==============================] - 2s 13ms/step
# 64/64 [==============================] - 1s 14ms/step
# 64/64 [==============================] - 1s 15ms/step
# 64/64 [==============================] - 1s 15ms/step
# 64/64 [==============================] - 1s 17ms/step
# Inference time 1209.588 ms for 10000 samples.

# %%
log_name_256 = '\log\cifar10\ViP\\random_feature_128\L_256.pkl'
log_path_256 = main_dir + log_name_256
with open(log_path_256, 'wb') as file:
    pickle.dump(history_256.history, file)

# %%
# plot accuracy curve
plt.plot(history_256.history["accuracy"], label="Train Accuracy")
plt.plot(history_256.history["val_accuracy"], label="Validation Accuracy")
plt.title("Train and Validation Accuracy Over Epochs L=256")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()

# %%
# plot loss curve
plt.plot(history_256.history["loss"], label="Train Loss")
plt.plot(history_256.history["val_loss"], label="Validation Loss")
plt.title("Train and Validation Loss Over Epochs L=256")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# %% [markdown]
# # L = 1024

# %%
patch_size = 1
model_1024 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=input_shape),
    VisionPerformer(image_size=image_size, patch_size=patch_size, num_layers=num_layers,
                      num_classes=num_classes, d_model=d_model, num_heads=num_heads, 
                  random_features=random_features, kernel_transformation=kernel_transformation,
                  mlp_dim=mlp_dim),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(10, activation='softmax')
])

model_1024.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
             optimizer=tfa.optimizers.AdamW(learning_rate=lr, weight_decay=weight_decay),
             metrics=['accuracy']) 

model_1024.summary()
# Out:
# Model: "sequential_31"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vision_performer_3 (VisionP  (None, 10)               222154
#  erformer)
#
#  flatten_2 (Flatten)         (None, 10)                0
#
#  dense_159 (Dense)           (None, 10)                110
#
# =================================================================
# Total params: 222,264
# Trainable params: 222,264
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_name = 'L_1024'
path = main_dir + '\model_checkpoints\cifar10\ViP\\random_feature_128\\' + model_name

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=path,
    save_best_only=True,
    save_weights_only=True,
    monitor='val_loss',
    mode='min'
)

#train model
start_time = time.time()
history_1024 = model_1024.fit(
    train_ds,
    epochs=num_epochs,
    validation_data=val_ds,
    callbacks=[model_checkpoint_callback]
)
end_time = time.time()
total_time_1024 = end_time-start_time
# Out:
# Epoch 1/50
# 782/782 [==============================] - 186s 227ms/step - loss: 2.1654 - accuracy: 0.1867 - val_loss: 2.0207 - val_accuracy: 0.2322
# Epoch 2/50
# 782/782 [==============================] - 176s 225ms/step - loss: 1.9789 - accuracy: 0.2638 - val_loss: 1.8908 - val_accuracy: 0.3017
# Epoch 3/50
# 782/782 [==============================] - 176s 225ms/step - loss: 1.8801 - accuracy: 0.3101 - val_loss: 1.8378 - val_accuracy: 0.3290
# Epoch 4/50
# Epoch 44/50
# 782/782 [==============================] - 176s 226ms/step - loss: 1.5229 - accuracy: 0.4568 - val_loss: 1.5436 - val_accuracy: 0.4358
# Epoch 45/50
# 782/782 [==============================] - 176s 226ms/step - loss: 1.5244 - accuracy: 0.4549 - val_loss: 1.5508 - val_accuracy: 0.4350
# Epoch 46/50
# 782/782 [==============================] - 176s 226ms/step - loss: 1.5310 - accuracy: 0.4525 - val_loss: 1.5538 - val_accuracy: 0.4357
# Epoch 47/50
# 782/782 [==============================] - 178s 228ms/step - loss: 1.5206 - accuracy: 0.4579 - val_loss: 1.5657 - val_accuracy: 0.4310
# Epoch 48/50
# 782/782 [==============================] - 177s 227ms/step - loss: 1.5235 - accuracy: 0.4572 - val_loss: 1.5328 - val_accuracy: 0.4443
# Epoch 49/50
# 782/782 [==============================] - 177s 227ms/step - loss: 1.5238 - accuracy: 0.4550 - val_loss: 1.5408 - val_accuracy: 0.4434
# Epoch 50/50
# 782/782 [==============================] - 177s 227ms/step - loss: 1.5226 - accuracy: 0.4571 - val_loss: 1.5480 - val_accuracy: 0.4360

# %%
print(f'Training time {round((total_time_1024),3)} sec for {num_epochs} epochs.')
inference_time_1024 = inf_time_check(model_1024, val_ds)
print(f'Inference time {inference_time_1024} ms for {num_val_samples} samples.')
# Out:
# Training time 8831.603 sec for 50 epochs.
# 64/64 [==============================] - 2s 14ms/step
# 64/64 [==============================] - 1s 14ms/step
# 64/64 [==============================] - 1s 15ms/step
# 64/64 [==============================] - 1s 15ms/step
# 64/64 [==============================] - 1s 17ms/step
# Inference time 1248.886 ms for 10000 samples.

# %%
log_name_1024 = '\log\cifar10\ViP\\random_feature_128\L_1024.pkl'
log_path_1024 = main_dir + log_name_1024
with open(log_path_1024, 'wb') as file:
    pickle.dump(history_1024.history, file)

# %%
# plot accuracy curve
plt.plot(history_1024.history["accuracy"], label="Train Accuracy")
plt.plot(history_1024.history["val_accuracy"], label="Validation Accuracy")
plt.title("Train and Validation Accuracy Over Epochs L=1024")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()

# %%
# plot loss curve
plt.plot(history_1024.history["loss"], label="Train Loss")
plt.plot(history_1024.history["val_loss"], label="Validation Loss")
plt.title("Train and Validation Loss Over Epochs L=1024")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# %%
total_time = [total_time_16, total_time_64, total_time_256, total_time_1024]
inference_time = [inference_time_16, inference_time_64, inference_time_256, inference_time_1024]
log = []
log.append(total_time)
log.append(inference_time)
log_name = '\log\cifar10\ViP\\random_feature_128\\total_inf_time'
log_path = main_dir + log_name
# log [total_time, inference_time]
with open(log_path, 'wb') as file:
    pickle.dump(log, file)

# %%
logL = np.log2([16, 64, 256, 1024])

fig, ax1 = plt.subplots()
plt.title(f'Inference time & Total training time over {num_epochs} epochs')
plt.xlabel('log2(L)')

ax1.plot(logL, total_time, color='blue', label='Total training time')
ax1.set_ylabel('Time (sec)', color='blue')
ax1.legend(loc='upper right')

ax2 = ax1.twinx()
ax2.plot(logL, inference_time, color='red', label='Inference time')
ax2.set_ylabel('Time (ms)', color='red')
ax2.legend(loc='upper left')

plt.grid()
plt.show()
