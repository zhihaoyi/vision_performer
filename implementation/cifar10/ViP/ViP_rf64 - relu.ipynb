# %% [markdown]
# # ViP Classification on CIFAR-10

# %% [markdown]
# ## random_features=64 with ReLu

# %%
import tensorflow as tf
import tensorflow_addons as tfa
import numpy as np
import matplotlib.pyplot as plt
import time
import datetime
import sys
import os
import pickle

# check GPU
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import tensorflow_datasets as tfds
train_dataset, info = tfds.load('cifar10', split='train', shuffle_files=True, with_info=True)
val_dataset = tfds.load('cifar10', split='test', shuffle_files=False)

# number of samples
num_train_samples = tf.data.experimental.cardinality(train_dataset).numpy()
num_val_samples = tf.data.experimental.cardinality(val_dataset).numpy()
print('Number of training samples:', num_train_samples)
print('Number of validation samples:', num_val_samples)

# size of image
for example in train_dataset.take(1):
    image, label = example['image'], example['label']
print('Image size:', image.shape)

# number of classes
num_classes = info.features['label'].num_classes
print('Number of classes: ', num_classes)
# Out:
# Number of training samples: 50000
# Number of validation samples: 10000
# Image size: (32, 32, 3)
# Number of classes:  10

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
batch_size = 64

def extract_image_and_label(example):
    image, label = example['image'], example['label']
    image = tf.cast(image, tf.float32)
    return image, label

# extract image and label from dataloader
train_ds = train_dataset.map(extract_image_and_label)
val_ds = val_dataset.map(extract_image_and_label)

# batch train_ds and val_ds
train_ds = train_ds.batch(batch_size)
val_ds = val_ds.batch(batch_size)

# input pipeline optimization
train_ds = train_ds.cache().prefetch(AUTOTUNE)
val_ds = val_ds.cache().prefetch(AUTOTUNE)

# %%
curr_dir = os.getcwd() 
parent_dir = os.path.abspath(os.path.join(curr_dir, os.pardir))
implementation_dir = os.path.abspath(os.path.join(parent_dir, os.pardir))
main_dir = os.path.abspath(os.path.join(implementation_dir, os.pardir))
sys.path.append(main_dir)

# %%
from model.vision_performer import VisionPerformer
# compiler attributes
lr = 1e-4
weight_decay = 1e-4
num_epochs = 50

# VisionTransformer attributes
input_shape = image.shape # [32, 32, 3]
image_size = image.shape[0] # 32
num_layers = 6
num_classes = num_classes # 10
d_model = 64
num_heads = 1
mlp_dim = 64
# VisionPerformer attributes
random_features = 64
kernel_transformation = 'relu'

# %% [markdown]
# # L = 16

# %%
patch_size = 8
model_16 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=input_shape),
    VisionPerformer(image_size=image_size, patch_size=patch_size, num_layers=num_layers,
                      num_classes=num_classes, d_model=d_model, num_heads=num_heads, 
                  random_features=random_features, kernel_transformation=kernel_transformation,
                  mlp_dim=mlp_dim),
    tf.keras.layers.Dense(10, activation='softmax')
])

model_16.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
             optimizer=tfa.optimizers.AdamW(learning_rate=lr, weight_decay=weight_decay),
             metrics=['accuracy']) 

model_16.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vision_performer (VisionPer  (None, 10)               169738
#  former)
#
#  dense_39 (Dense)            (None, 10)                110
#
# =================================================================
# Total params: 169,848
# Trainable params: 169,848
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_name = 'L_16'
path = main_dir + '\model_checkpoints\cifar10\ViP\\random_feature_64_relu\\' + model_name

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=path,
    save_best_only=True,
    save_weights_only=True,
    monitor='val_loss',
    mode='min'
)

#train model
start_time = time.time()
history_16 = model_16.fit(
    train_ds,
    epochs=num_epochs,
    validation_data=val_ds,
    callbacks=[model_checkpoint_callback]
)
end_time = time.time()
total_time_16 = end_time-start_time
# Out:
# Epoch 1/50
# 782/782 [==============================] - 62s 69ms/step - loss: 2.1121 - accuracy: 0.2066 - val_loss: 1.9670 - val_accuracy: 0.2693
# Epoch 2/50
# 782/782 [==============================] - 52s 66ms/step - loss: 1.9464 - accuracy: 0.2775 - val_loss: 1.8339 - val_accuracy: 0.3215
# Epoch 3/50
# 782/782 [==============================] - 52s 66ms/step - loss: 1.8584 - accuracy: 0.3102 - val_loss: 1.7831 - val_accuracy: 0.3435
# Epoch 4/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.8008 - accuracy: 0.3324 - val_loss: 1.7711 - val_accuracy: 0.3484
# Epoch 5/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.7550 - accuracy: 0.3513 - val_loss: 1.6852 - val_accuracy: 0.3807
# Epoch 6/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.7196 - accuracy: 0.3679 - val_loss: 1.6721 - val_accuracy: 0.3907
# Epoch 7/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.6912 - accuracy: 0.3780 - val_loss: 1.6409 - val_accuracy: 0.4032
# Epoch 8/50
# 782/782 [==============================] - 52s 67ms/step - loss: 1.6648 - accuracy: 0.3898 - val_loss: 1.6146 - val_accuracy: 0.4095
# Epoch 9/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.6416 - accuracy: 0.3952 - val_loss: 1.5993 - val_accuracy: 0.4219
# Epoch 10/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.6226 - accuracy: 0.4069 - val_loss: 1.5851 - val_accuracy: 0.4293
# Epoch 11/50
# 782/782 [==============================] - 53s 67ms/step - loss: 1.6014 - accuracy: 0.4155 - val_loss: 1.5677 - val_accuracy: 0.4341
# Epoch 12/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.5786 - accuracy: 0.4257 - val_loss: 1.5390 - val_accuracy: 0.4441
# Epoch 13/50
# 782/782 [==============================] - 52s 67ms/step - loss: 1.5620 - accuracy: 0.4319 - val_loss: 1.5233 - val_accuracy: 0.4499
# Epoch 14/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.5448 - accuracy: 0.4389 - val_loss: 1.5167 - val_accuracy: 0.4530
# Epoch 15/50
# 782/782 [==============================] - 52s 66ms/step - loss: 1.5324 - accuracy: 0.4433 - val_loss: 1.5095 - val_accuracy: 0.4542
# Epoch 16/50
# 782/782 [==============================] - 51s 66ms/step - loss: 1.5245 - accuracy: 0.4484 - val_loss: 1.4952 - val_accuracy: 0.4559
# Epoch 17/50
# 782/782 [==============================] - 52s 66ms/step - loss: 1.5139 - accuracy: 0.4494 - val_loss: 1.4938 - val_accuracy: 0.4501
# Epoch 18/50
# 782/782 [==============================] - 52s 66ms/step - loss: 1.5055 - accuracy: 0.4536 - val_loss: 1.4833 - val_accuracy: 0.4629
# Epoch 19/50
# 782/782 [==============================] - 51s 66ms/step - loss: 1.4979 - accuracy: 0.4547 - val_loss: 1.4728 - val_accuracy: 0.4661
# Epoch 20/50
# 782/782 [==============================] - 52s 67ms/step - loss: 1.4940 - accuracy: 0.4584 - val_loss: 1.4723 - val_accuracy: 0.4667
# Epoch 21/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.4877 - accuracy: 0.4605 - val_loss: 1.4818 - val_accuracy: 0.4511
# Epoch 22/50
# 782/782 [==============================] - 52s 67ms/step - loss: 1.4832 - accuracy: 0.4590 - val_loss: 1.5115 - val_accuracy: 0.4524
# Epoch 23/50
# 782/782 [==============================] - 52s 67ms/step - loss: 1.4755 - accuracy: 0.4673 - val_loss: 1.4733 - val_accuracy: 0.4608
# Epoch 24/50
# 782/782 [==============================] - 53s 67ms/step - loss: 1.4754 - accuracy: 0.4638 - val_loss: 1.4593 - val_accuracy: 0.4692
# Epoch 25/50
# 782/782 [==============================] - 52s 67ms/step - loss: 1.4704 - accuracy: 0.4676 - val_loss: 1.4702 - val_accuracy: 0.4645
# Epoch 26/50
# 782/782 [==============================] - 53s 67ms/step - loss: 1.4691 - accuracy: 0.4698 - val_loss: 1.4589 - val_accuracy: 0.4685
# Epoch 27/50
# 782/782 [==============================] - 52s 66ms/step - loss: 1.4689 - accuracy: 0.4665 - val_loss: 1.4799 - val_accuracy: 0.4597
# Epoch 28/50
# 782/782 [==============================] - 53s 67ms/step - loss: 1.4645 - accuracy: 0.4719 - val_loss: 1.5020 - val_accuracy: 0.4446
# Epoch 29/50
# 782/782 [==============================] - 53s 67ms/step - loss: 1.4672 - accuracy: 0.4673 - val_loss: 1.4634 - val_accuracy: 0.4698
# Epoch 30/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.4695 - accuracy: 0.4663 - val_loss: 1.4569 - val_accuracy: 0.4710
# Epoch 31/50
# 782/782 [==============================] - 53s 67ms/step - loss: 1.4659 - accuracy: 0.4700 - val_loss: 1.4654 - val_accuracy: 0.4635
# Epoch 32/50
# 782/782 [==============================] - 53s 67ms/step - loss: 1.4682 - accuracy: 0.4685 - val_loss: 1.4902 - val_accuracy: 0.4540
# Epoch 33/50
# 782/782 [==============================] - 52s 67ms/step - loss: 1.4662 - accuracy: 0.4671 - val_loss: 1.4682 - val_accuracy: 0.4631
# Epoch 34/50
# 782/782 [==============================] - 52s 67ms/step - loss: 1.4700 - accuracy: 0.4664 - val_loss: 1.4882 - val_accuracy: 0.4621
# Epoch 35/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.4710 - accuracy: 0.4685 - val_loss: 1.4953 - val_accuracy: 0.4501
# Epoch 36/50
# 782/782 [==============================] - 52s 67ms/step - loss: 1.4689 - accuracy: 0.4690 - val_loss: 1.4670 - val_accuracy: 0.4676
# Epoch 37/50
# 782/782 [==============================] - 52s 67ms/step - loss: 1.4698 - accuracy: 0.4682 - val_loss: 1.4713 - val_accuracy: 0.4589
# Epoch 38/50
# 782/782 [==============================] - 52s 67ms/step - loss: 1.4695 - accuracy: 0.4669 - val_loss: 1.5057 - val_accuracy: 0.4532
# Epoch 39/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.4760 - accuracy: 0.4644 - val_loss: 1.5187 - val_accuracy: 0.4438
# Epoch 40/50
# 782/782 [==============================] - 52s 67ms/step - loss: 1.4725 - accuracy: 0.4669 - val_loss: 1.4680 - val_accuracy: 0.4626
# Epoch 41/50
# 782/782 [==============================] - 53s 67ms/step - loss: 1.4731 - accuracy: 0.4669 - val_loss: 1.4886 - val_accuracy: 0.4466
# Epoch 42/50
# 782/782 [==============================] - 52s 66ms/step - loss: 1.4755 - accuracy: 0.4640 - val_loss: 1.4779 - val_accuracy: 0.4593
# Epoch 43/50
# 782/782 [==============================] - 53s 67ms/step - loss: 1.4800 - accuracy: 0.4668 - val_loss: 1.5067 - val_accuracy: 0.4473
# Epoch 44/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.4761 - accuracy: 0.4654 - val_loss: 1.5743 - val_accuracy: 0.4296
# Epoch 45/50
# 782/782 [==============================] - 52s 67ms/step - loss: 1.4745 - accuracy: 0.4651 - val_loss: 1.5028 - val_accuracy: 0.4467
# Epoch 46/50
# 782/782 [==============================] - 50s 65ms/step - loss: 1.4767 - accuracy: 0.4655 - val_loss: 1.5075 - val_accuracy: 0.4420
# Epoch 47/50
# 782/782 [==============================] - 52s 67ms/step - loss: 1.4761 - accuracy: 0.4648 - val_loss: 1.4997 - val_accuracy: 0.4414
# Epoch 48/50
# 782/782 [==============================] - 52s 66ms/step - loss: 1.4787 - accuracy: 0.4654 - val_loss: 1.5365 - val_accuracy: 0.4386
# Epoch 49/50
# 782/782 [==============================] - 53s 67ms/step - loss: 1.4807 - accuracy: 0.4616 - val_loss: 1.5378 - val_accuracy: 0.4419
# Epoch 50/50
# 782/782 [==============================] - 53s 67ms/step - loss: 1.4808 - accuracy: 0.4625 - val_loss: 1.4765 - val_accuracy: 0.4551

# %%
from utils import inf_time_check
print(f'Training time {round((total_time_16),3)} sec for {num_epochs} epochs.')
inference_time_16 = inf_time_check(model_16, val_ds)
print(f'Inference time {inference_time_16} ms for {num_val_samples} samples.')
# Out:
# Training time 2630.573 sec for 50 epochs.
# 64/64 [==============================] - 2s 18ms/step
# 64/64 [==============================] - 1s 15ms/step
# 64/64 [==============================] - 1s 14ms/step
# 64/64 [==============================] - 1s 15ms/step
# 64/64 [==============================] - 1s 15ms/step
# Inference time 1215.949 ms for 10000 samples.

# %%
log_name_16 = '\log\cifar10\ViP\\random_feature_64_relu\L_16.pkl'
log_path_16 = main_dir + log_name_16
with open(log_path_16, 'wb') as file:
    pickle.dump(history_16.history, file)

# %%
# plot accuracy curve
plt.plot(history_16.history["accuracy"], label="Train Accuracy")
plt.plot(history_16.history["val_accuracy"], label="Validation Accuracy")
plt.title("Train and Validation Accuracy Over Epochs L=16")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()

# %%
# plot loss curve
plt.plot(history_16.history["loss"], label="Train Loss")
plt.plot(history_16.history["val_loss"], label="Validation Loss")
plt.title("Train and Validation Loss Over Epochs L=16")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# %% [markdown]
# # L = 64

# %%
patch_size = 4
model_64 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=input_shape),
    VisionPerformer(image_size=image_size, patch_size=patch_size, num_layers=num_layers,
                      num_classes=num_classes, d_model=d_model, num_heads=num_heads, 
                  random_features=random_features, kernel_transformation=kernel_transformation,
                  mlp_dim=mlp_dim),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(10, activation='softmax')
])

model_64.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
             optimizer=tfa.optimizers.AdamW(learning_rate=lr, weight_decay=weight_decay),
             metrics=['accuracy']) 

model_64.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vision_performer_1 (VisionP  (None, 10)               163594
#  erformer)
#
#  flatten (Flatten)           (None, 10)                0
#
#  dense_79 (Dense)            (None, 10)                110
#
# =================================================================
# Total params: 163,704
# Trainable params: 163,704
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_name = 'L_64'
path = main_dir + '\model_checkpoints\cifar10\ViP\\random_feature_64_relu\\' + model_name

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=path,
    save_best_only=True,
    save_weights_only=True,
    monitor='val_loss',
    mode='min'
)

#train model
start_time = time.time()
history_64 = model_64.fit(
    train_ds,
    epochs=num_epochs,
    validation_data=val_ds,
    callbacks=[model_checkpoint_callback]
)
end_time = time.time()
total_time_64 = end_time-start_time
# Out:
# Epoch 1/50
# 782/782 [==============================] - 55s 61ms/step - loss: 2.1174 - accuracy: 0.1979 - val_loss: 1.9456 - val_accuracy: 0.2756
# Epoch 2/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.9415 - accuracy: 0.2723 - val_loss: 1.8508 - val_accuracy: 0.3060
# Epoch 3/50
# 782/782 [==============================] - 47s 59ms/step - loss: 1.8458 - accuracy: 0.3119 - val_loss: 1.7662 - val_accuracy: 0.3369
# Epoch 4/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.7712 - accuracy: 0.3398 - val_loss: 1.6980 - val_accuracy: 0.3712
# Epoch 5/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.7070 - accuracy: 0.3673 - val_loss: 1.6489 - val_accuracy: 0.3914
# Epoch 6/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.6602 - accuracy: 0.3886 - val_loss: 1.6297 - val_accuracy: 0.4006
# Epoch 7/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.6187 - accuracy: 0.4054 - val_loss: 1.5918 - val_accuracy: 0.4102
# Epoch 8/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.5828 - accuracy: 0.4187 - val_loss: 1.5664 - val_accuracy: 0.4212
# Epoch 9/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.5535 - accuracy: 0.4348 - val_loss: 1.5266 - val_accuracy: 0.4430
# Epoch 10/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.5302 - accuracy: 0.4438 - val_loss: 1.5128 - val_accuracy: 0.4503
# Epoch 11/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.5117 - accuracy: 0.4524 - val_loss: 1.4895 - val_accuracy: 0.4558
# Epoch 12/50
# 782/782 [==============================] - 48s 61ms/step - loss: 1.4947 - accuracy: 0.4582 - val_loss: 1.4750 - val_accuracy: 0.4641
# Epoch 13/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.4793 - accuracy: 0.4653 - val_loss: 1.4490 - val_accuracy: 0.4767
# Epoch 14/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.4661 - accuracy: 0.4686 - val_loss: 1.4401 - val_accuracy: 0.4793
# Epoch 15/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.4508 - accuracy: 0.4759 - val_loss: 1.4371 - val_accuracy: 0.4719
# Epoch 16/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.4399 - accuracy: 0.4775 - val_loss: 1.4437 - val_accuracy: 0.4757
# Epoch 17/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.4312 - accuracy: 0.4812 - val_loss: 1.4141 - val_accuracy: 0.4870
# Epoch 18/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.4191 - accuracy: 0.4855 - val_loss: 1.4190 - val_accuracy: 0.4815
# Epoch 19/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.4110 - accuracy: 0.4882 - val_loss: 1.3988 - val_accuracy: 0.4938
# Epoch 20/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.4001 - accuracy: 0.4930 - val_loss: 1.4194 - val_accuracy: 0.4767
# Epoch 21/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.3914 - accuracy: 0.4951 - val_loss: 1.4320 - val_accuracy: 0.4725
# Epoch 22/50
# 782/782 [==============================] - 48s 61ms/step - loss: 1.3801 - accuracy: 0.5003 - val_loss: 1.3896 - val_accuracy: 0.4889
# Epoch 23/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.3679 - accuracy: 0.5092 - val_loss: 1.3816 - val_accuracy: 0.4909
# Epoch 24/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.3626 - accuracy: 0.5083 - val_loss: 1.3800 - val_accuracy: 0.4966
# Epoch 25/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.3570 - accuracy: 0.5102 - val_loss: 1.3812 - val_accuracy: 0.5011
# Epoch 26/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.3451 - accuracy: 0.5131 - val_loss: 1.3745 - val_accuracy: 0.4873
# Epoch 27/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.3435 - accuracy: 0.5158 - val_loss: 1.3705 - val_accuracy: 0.4947
# Epoch 28/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.3414 - accuracy: 0.5144 - val_loss: 1.3728 - val_accuracy: 0.4901
# Epoch 29/50
# 782/782 [==============================] - 48s 61ms/step - loss: 1.3343 - accuracy: 0.5199 - val_loss: 1.3458 - val_accuracy: 0.5051
# Epoch 30/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.3369 - accuracy: 0.5191 - val_loss: 1.3522 - val_accuracy: 0.4965
# Epoch 31/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.3399 - accuracy: 0.5183 - val_loss: 1.4028 - val_accuracy: 0.4784
# Epoch 32/50
# 782/782 [==============================] - 47s 61ms/step - loss: 1.3380 - accuracy: 0.5170 - val_loss: 1.3624 - val_accuracy: 0.4875
# Epoch 33/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.3359 - accuracy: 0.5194 - val_loss: 1.3450 - val_accuracy: 0.5084
# Epoch 34/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.3275 - accuracy: 0.5222 - val_loss: 1.3500 - val_accuracy: 0.5039
# Epoch 35/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.3339 - accuracy: 0.5183 - val_loss: 1.3464 - val_accuracy: 0.5016
# Epoch 36/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.3356 - accuracy: 0.5168 - val_loss: 1.3883 - val_accuracy: 0.4864
# Epoch 37/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.3363 - accuracy: 0.5174 - val_loss: 1.3668 - val_accuracy: 0.4983
# Epoch 38/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.3356 - accuracy: 0.5194 - val_loss: 1.3753 - val_accuracy: 0.4966
# Epoch 39/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.3412 - accuracy: 0.5146 - val_loss: 1.3782 - val_accuracy: 0.4982
# Epoch 40/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.3332 - accuracy: 0.5196 - val_loss: 1.3775 - val_accuracy: 0.4876
# Epoch 41/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.3441 - accuracy: 0.5162 - val_loss: 1.4062 - val_accuracy: 0.4767
# Epoch 42/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.3407 - accuracy: 0.5169 - val_loss: 1.3892 - val_accuracy: 0.4896
# Epoch 43/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.3417 - accuracy: 0.5172 - val_loss: 1.3389 - val_accuracy: 0.5025
# Epoch 44/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.3375 - accuracy: 0.5198 - val_loss: 1.3945 - val_accuracy: 0.5002
# Epoch 45/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.3413 - accuracy: 0.5164 - val_loss: 1.4012 - val_accuracy: 0.4835
# Epoch 46/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.3440 - accuracy: 0.5157 - val_loss: 1.3377 - val_accuracy: 0.5080
# Epoch 47/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.3425 - accuracy: 0.5174 - val_loss: 1.3542 - val_accuracy: 0.4999
# Epoch 48/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.3464 - accuracy: 0.5168 - val_loss: 1.3412 - val_accuracy: 0.5061
# Epoch 49/50
# 782/782 [==============================] - 47s 60ms/step - loss: 1.3413 - accuracy: 0.5192 - val_loss: 1.3832 - val_accuracy: 0.4921
# Epoch 50/50
# 782/782 [==============================] - 47s 59ms/step - loss: 1.3446 - accuracy: 0.5166 - val_loss: 1.3546 - val_accuracy: 0.4962

# %%
print(f'Training time {round((total_time_64),3)} sec for {num_epochs} epochs.')
inference_time_64 = inf_time_check(model_64, val_ds)
print(f'Inference time {inference_time_64} ms for {num_val_samples} samples.')
# Out:
# Training time 2349.979 sec for 50 epochs.
# 64/64 [==============================] - 2s 13ms/step
# 64/64 [==============================] - 1s 14ms/step
# 64/64 [==============================] - 1s 14ms/step
# 64/64 [==============================] - 1s 14ms/step
# 64/64 [==============================] - 1s 14ms/step
# Inference time 1121.566 ms for 10000 samples.

# %%
log_name_64 = '\log\cifar10\ViP\\random_feature_64_relu\L_64.pkl'
log_path_64 = main_dir + log_name_64
with open(log_path_64, 'wb') as file:
    pickle.dump(history_64.history, file)

# %%
# plot accuracy curve
plt.plot(history_64.history["accuracy"], label="Train Accuracy")
plt.plot(history_64.history["val_accuracy"], label="Validation Accuracy")
plt.title("Train and Validation Accuracy Over Epochs L=64")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()

# %%
# plot loss curve
plt.plot(history_64.history["loss"], label="Train Loss")
plt.plot(history_64.history["val_loss"], label="Validation Loss")
plt.title("Train and Validation Loss Over Epochs L=64")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# %% [markdown]
# # L = 256

# %%
patch_size = 2
model_256 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=input_shape),
    VisionPerformer(image_size=image_size, patch_size=patch_size, num_layers=num_layers,
                      num_classes=num_classes, d_model=d_model, num_heads=num_heads, 
                  random_features=random_features, kernel_transformation=kernel_transformation,
                  mlp_dim=mlp_dim),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(10, activation='softmax')
])

model_256.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
             optimizer=tfa.optimizers.AdamW(learning_rate=lr, weight_decay=weight_decay),
             metrics=['accuracy']) 

model_256.summary()
# Out:
# Model: "sequential_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vision_performer_2 (VisionP  (None, 10)               173578
#  erformer)
#
#  flatten_1 (Flatten)         (None, 10)                0
#
#  dense_119 (Dense)           (None, 10)                110
#
# =================================================================
# Total params: 173,688
# Trainable params: 173,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_name = 'L_256'
path = main_dir + '\model_checkpoints\cifar10\ViP\\random_feature_64_relu\\' + model_name

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=path,
    save_best_only=True,
    save_weights_only=True,
    monitor='val_loss',
    mode='min'
)

#train model
start_time = time.time()
history_256 = model_256.fit(
    train_ds,
    epochs=num_epochs,
    validation_data=val_ds,
    callbacks=[model_checkpoint_callback]
)
end_time = time.time()
total_time_256 = end_time-start_time
# Out:
# Epoch 1/50
# 782/782 [==============================] - 65s 73ms/step - loss: 2.1162 - accuracy: 0.1940 - val_loss: 1.9356 - val_accuracy: 0.2730
# Epoch 2/50
# 782/782 [==============================] - 56s 72ms/step - loss: 1.9145 - accuracy: 0.2754 - val_loss: 1.8110 - val_accuracy: 0.3116
# Epoch 3/50
# 782/782 [==============================] - 56s 71ms/step - loss: 1.8092 - accuracy: 0.3201 - val_loss: 1.7335 - val_accuracy: 0.3537
# Epoch 4/50
# 782/782 [==============================] - 56s 71ms/step - loss: 1.7331 - accuracy: 0.3541 - val_loss: 1.6654 - val_accuracy: 0.3922
# Epoch 5/50
# 782/782 [==============================] - 55s 71ms/step - loss: 1.6788 - accuracy: 0.3767 - val_loss: 1.6318 - val_accuracy: 0.3969
# Epoch 6/50
# 782/782 [==============================] - 56s 72ms/step - loss: 1.6338 - accuracy: 0.3997 - val_loss: 1.5784 - val_accuracy: 0.4203
# Epoch 7/50
# 782/782 [==============================] - 56s 71ms/step - loss: 1.5964 - accuracy: 0.4134 - val_loss: 1.5664 - val_accuracy: 0.4239
# Epoch 8/50
# 782/782 [==============================] - 56s 72ms/step - loss: 1.5631 - accuracy: 0.4305 - val_loss: 1.5453 - val_accuracy: 0.4354
# Epoch 9/50
# 782/782 [==============================] - 56s 72ms/step - loss: 1.5326 - accuracy: 0.4426 - val_loss: 1.4967 - val_accuracy: 0.4577
# Epoch 10/50
# 782/782 [==============================] - 56s 72ms/step - loss: 1.5058 - accuracy: 0.4536 - val_loss: 1.4814 - val_accuracy: 0.4638
# Epoch 11/50
# 782/782 [==============================] - 55s 70ms/step - loss: 1.4859 - accuracy: 0.4627 - val_loss: 1.4605 - val_accuracy: 0.4699
# Epoch 12/50
# 782/782 [==============================] - 56s 72ms/step - loss: 1.4655 - accuracy: 0.4700 - val_loss: 1.4476 - val_accuracy: 0.4727
# Epoch 13/50
# 782/782 [==============================] - 56s 71ms/step - loss: 1.4500 - accuracy: 0.4772 - val_loss: 1.4248 - val_accuracy: 0.4865
# Epoch 14/50
# 782/782 [==============================] - 56s 71ms/step - loss: 1.4325 - accuracy: 0.4825 - val_loss: 1.4112 - val_accuracy: 0.4943
# Epoch 15/50
# 782/782 [==============================] - 56s 71ms/step - loss: 1.4149 - accuracy: 0.4917 - val_loss: 1.4031 - val_accuracy: 0.4951
# Epoch 16/50
# 782/782 [==============================] - 56s 71ms/step - loss: 1.4030 - accuracy: 0.4937 - val_loss: 1.3935 - val_accuracy: 0.4955
# Epoch 17/50
# 782/782 [==============================] - 56s 71ms/step - loss: 1.3967 - accuracy: 0.4960 - val_loss: 1.3662 - val_accuracy: 0.5091
# Epoch 18/50
# 782/782 [==============================] - 56s 71ms/step - loss: 1.3838 - accuracy: 0.5030 - val_loss: 1.3628 - val_accuracy: 0.5103
# Epoch 19/50
# 782/782 [==============================] - 56s 71ms/step - loss: 1.3755 - accuracy: 0.5054 - val_loss: 1.3569 - val_accuracy: 0.5117
# Epoch 20/50
# 782/782 [==============================] - 55s 70ms/step - loss: 1.3658 - accuracy: 0.5086 - val_loss: 1.3638 - val_accuracy: 0.5127
# Epoch 21/50
# 782/782 [==============================] - 56s 71ms/step - loss: 1.3579 - accuracy: 0.5138 - val_loss: 1.3373 - val_accuracy: 0.5216
# Epoch 22/50
# 782/782 [==============================] - 56s 71ms/step - loss: 1.3447 - accuracy: 0.5170 - val_loss: 1.3338 - val_accuracy: 0.5231
# Epoch 23/50
# 782/782 [==============================] - 56s 71ms/step - loss: 1.3372 - accuracy: 0.5196 - val_loss: 1.3489 - val_accuracy: 0.5058
# Epoch 24/50
# 782/782 [==============================] - 55s 71ms/step - loss: 1.3295 - accuracy: 0.5217 - val_loss: 1.3167 - val_accuracy: 0.5320
# Epoch 25/50
# 782/782 [==============================] - 56s 71ms/step - loss: 1.3209 - accuracy: 0.5259 - val_loss: 1.3070 - val_accuracy: 0.5294
# Epoch 26/50
# 782/782 [==============================] - 56s 71ms/step - loss: 1.3123 - accuracy: 0.5275 - val_loss: 1.3140 - val_accuracy: 0.5278
# Epoch 27/50
# 782/782 [==============================] - 55s 71ms/step - loss: 1.3058 - accuracy: 0.5287 - val_loss: 1.3144 - val_accuracy: 0.5218
# Epoch 28/50
# 782/782 [==============================] - 56s 71ms/step - loss: 1.3048 - accuracy: 0.5335 - val_loss: 1.2648 - val_accuracy: 0.5489
# Epoch 29/50
# 782/782 [==============================] - 56s 71ms/step - loss: 1.2987 - accuracy: 0.5331 - val_loss: 1.2959 - val_accuracy: 0.5256
# Epoch 30/50
# 782/782 [==============================] - 56s 71ms/step - loss: 1.2937 - accuracy: 0.5351 - val_loss: 1.2827 - val_accuracy: 0.5374
# Epoch 31/50
# 782/782 [==============================] - 56s 71ms/step - loss: 1.2907 - accuracy: 0.5368 - val_loss: 1.2787 - val_accuracy: 0.5425
# Epoch 32/50
# 782/782 [==============================] - 55s 70ms/step - loss: 1.2932 - accuracy: 0.5357 - val_loss: 1.2831 - val_accuracy: 0.5365
# Epoch 33/50
# 782/782 [==============================] - 55s 71ms/step - loss: 1.2913 - accuracy: 0.5387 - val_loss: 1.2559 - val_accuracy: 0.5485
# Epoch 34/50
# 782/782 [==============================] - 56s 71ms/step - loss: 1.2875 - accuracy: 0.5376 - val_loss: 1.2640 - val_accuracy: 0.5453
# Epoch 35/50
# 782/782 [==============================] - 56s 71ms/step - loss: 1.2826 - accuracy: 0.5399 - val_loss: 1.2683 - val_accuracy: 0.5414
# Epoch 36/50
# 782/782 [==============================] - 56s 71ms/step - loss: 1.2801 - accuracy: 0.5378 - val_loss: 1.2755 - val_accuracy: 0.5421
# Epoch 37/50
# 782/782 [==============================] - 56s 71ms/step - loss: 1.2855 - accuracy: 0.5368 - val_loss: 1.2758 - val_accuracy: 0.5431
# Epoch 38/50
# 782/782 [==============================] - 56s 71ms/step - loss: 1.2813 - accuracy: 0.5392 - val_loss: 1.2722 - val_accuracy: 0.5430
# Epoch 39/50
# 782/782 [==============================] - 55s 70ms/step - loss: 1.2849 - accuracy: 0.5384 - val_loss: 1.2659 - val_accuracy: 0.5438
# Epoch 40/50
# 782/782 [==============================] - 56s 71ms/step - loss: 1.2838 - accuracy: 0.5403 - val_loss: 1.2814 - val_accuracy: 0.5367
# Epoch 41/50
# 782/782 [==============================] - 56s 72ms/step - loss: 1.2821 - accuracy: 0.5377 - val_loss: 1.2881 - val_accuracy: 0.5369
# Epoch 42/50
# 782/782 [==============================] - 56s 71ms/step - loss: 1.2839 - accuracy: 0.5369 - val_loss: 1.2798 - val_accuracy: 0.5363
# Epoch 43/50
# 782/782 [==============================] - 56s 71ms/step - loss: 1.2800 - accuracy: 0.5383 - val_loss: 1.2924 - val_accuracy: 0.5354
# Epoch 44/50
# 782/782 [==============================] - 56s 71ms/step - loss: 1.2812 - accuracy: 0.5393 - val_loss: 1.2902 - val_accuracy: 0.5373
# Epoch 45/50
# 782/782 [==============================] - 55s 71ms/step - loss: 1.2834 - accuracy: 0.5389 - val_loss: 1.2417 - val_accuracy: 0.5482
# Epoch 46/50
# 782/782 [==============================] - 56s 71ms/step - loss: 1.2785 - accuracy: 0.5422 - val_loss: 1.2878 - val_accuracy: 0.5371
# Epoch 47/50
# 782/782 [==============================] - 56s 71ms/step - loss: 1.2785 - accuracy: 0.5396 - val_loss: 1.2537 - val_accuracy: 0.5465
# Epoch 48/50
# 782/782 [==============================] - 56s 71ms/step - loss: 1.2767 - accuracy: 0.5433 - val_loss: 1.3238 - val_accuracy: 0.5260
# Epoch 49/50
# 782/782 [==============================] - 56s 71ms/step - loss: 1.2766 - accuracy: 0.5392 - val_loss: 1.2655 - val_accuracy: 0.5436
# Epoch 50/50
# 782/782 [==============================] - 56s 71ms/step - loss: 1.2753 - accuracy: 0.5400 - val_loss: 1.2806 - val_accuracy: 0.5401

# %%
from utils import inf_time_check
print(f'Training time {round((total_time_256),3)} sec for {num_epochs} epochs.')
inference_time_256 = inf_time_check(model_256, val_ds)
print(f'Inference time {inference_time_256} ms for {num_val_samples} samples.')
# Out:
# Training time 2792.267 sec for 50 epochs.
# 64/64 [==============================] - 2s 11ms/step
# 64/64 [==============================] - 1s 11ms/step
# 64/64 [==============================] - 1s 11ms/step
# 64/64 [==============================] - 1s 12ms/step
# 64/64 [==============================] - 1s 13ms/step
# Inference time 978.925 ms for 10000 samples.

# %%
log_name_256 = '\log\cifar10\ViP\\random_feature_64_relu\L_256.pkl'
log_path_256 = main_dir + log_name_256
with open(log_path_256, 'wb') as file:
    pickle.dump(history_256.history, file)

# %%
# plot accuracy curve
plt.plot(history_256.history["accuracy"], label="Train Accuracy")
plt.plot(history_256.history["val_accuracy"], label="Validation Accuracy")
plt.title("Train and Validation Accuracy Over Epochs L=256")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()

# %%
# plot loss curve
plt.plot(history_256.history["loss"], label="Train Loss")
plt.plot(history_256.history["val_loss"], label="Validation Loss")
plt.title("Train and Validation Loss Over Epochs L=256")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# %% [markdown]
# # L = 1024

# %%
patch_size = 1
model_1024 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=input_shape),
    VisionPerformer(image_size=image_size, patch_size=patch_size, num_layers=num_layers,
                      num_classes=num_classes, d_model=d_model, num_heads=num_heads, 
                  random_features=random_features, kernel_transformation=kernel_transformation,
                  mlp_dim=mlp_dim),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(10, activation='softmax')
])

model_1024.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
             optimizer=tfa.optimizers.AdamW(learning_rate=lr, weight_decay=weight_decay),
             metrics=['accuracy']) 

model_1024.summary()
# Out:
# Model: "sequential_31"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vision_performer_3 (VisionP  (None, 10)               222154
#  erformer)
#
#  flatten_2 (Flatten)         (None, 10)                0
#
#  dense_159 (Dense)           (None, 10)                110
#
# =================================================================
# Total params: 222,264
# Trainable params: 222,264
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_name = 'L_1024'
path = main_dir + '\model_checkpoints\cifar10\ViP\\random_feature_64_relu\\' + model_name

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=path,
    save_best_only=True,
    save_weights_only=True,
    monitor='val_loss',
    mode='min'
)

#train model
start_time = time.time()
history_1024 = model_1024.fit(
    train_ds,
    epochs=num_epochs,
    validation_data=val_ds,
    callbacks=[model_checkpoint_callback]
)
end_time = time.time()
total_time_1024 = end_time-start_time
# Out:
# Epoch 1/50
# 782/782 [==============================] - 133s 161ms/step - loss: 2.0785 - accuracy: 0.2168 - val_loss: 1.9333 - val_accuracy: 0.2819
# Epoch 2/50
# 782/782 [==============================] - 125s 160ms/step - loss: 1.9075 - accuracy: 0.2986 - val_loss: 1.8432 - val_accuracy: 0.3316
# Epoch 3/50
# 782/782 [==============================] - 125s 160ms/step - loss: 1.8202 - accuracy: 0.3356 - val_loss: 1.7579 - val_accuracy: 0.3644
# Epoch 4/50
# 782/782 [==============================] - 125s 160ms/step - loss: 1.7595 - accuracy: 0.3607 - val_loss: 1.7053 - val_accuracy: 0.3833
# Epoch 5/50
# 782/782 [==============================] - 125s 160ms/step - loss: 1.7181 - accuracy: 0.3792 - val_loss: 1.6721 - val_accuracy: 0.3980
# Epoch 6/50
# 782/782 [==============================] - 125s 160ms/step - loss: 1.6875 - accuracy: 0.3904 - val_loss: 1.6452 - val_accuracy: 0.4101
# Epoch 7/50
# 782/782 [==============================] - 125s 160ms/step - loss: 1.6535 - accuracy: 0.4038 - val_loss: 1.6257 - val_accuracy: 0.4132
# Epoch 8/50
# 782/782 [==============================] - 125s 160ms/step - loss: 1.6260 - accuracy: 0.4151 - val_loss: 1.5931 - val_accuracy: 0.4260
# Epoch 9/50
# 782/782 [==============================] - 125s 160ms/step - loss: 1.6031 - accuracy: 0.4252 - val_loss: 1.5904 - val_accuracy: 0.4331
# Epoch 10/50
# 782/782 [==============================] - 125s 160ms/step - loss: 1.5806 - accuracy: 0.4371 - val_loss: 1.5596 - val_accuracy: 0.4418
# Epoch 11/50
# 782/782 [==============================] - 125s 160ms/step - loss: 1.5634 - accuracy: 0.4425 - val_loss: 1.5429 - val_accuracy: 0.4507
# Epoch 12/50
# 782/782 [==============================] - 125s 159ms/step - loss: 1.5450 - accuracy: 0.4506 - val_loss: 1.5605 - val_accuracy: 0.4504
# Epoch 13/50
# 782/782 [==============================] - 125s 160ms/step - loss: 1.5339 - accuracy: 0.4540 - val_loss: 1.5225 - val_accuracy: 0.4643
# Epoch 14/50
# 782/782 [==============================] - 125s 160ms/step - loss: 1.5248 - accuracy: 0.4585 - val_loss: 1.5313 - val_accuracy: 0.4625
# Epoch 15/50
# 782/782 [==============================] - 125s 159ms/step - loss: 1.5172 - accuracy: 0.4599 - val_loss: 1.5308 - val_accuracy: 0.4638
# Epoch 16/50
# 782/782 [==============================] - 125s 160ms/step - loss: 1.5132 - accuracy: 0.4593 - val_loss: 1.5274 - val_accuracy: 0.4603
# Epoch 17/50
# 782/782 [==============================] - 125s 160ms/step - loss: 1.5046 - accuracy: 0.4649 - val_loss: 1.5117 - val_accuracy: 0.4639
# Epoch 18/50
# 782/782 [==============================] - 125s 160ms/step - loss: 1.5018 - accuracy: 0.4635 - val_loss: 1.5613 - val_accuracy: 0.4508
# Epoch 19/50
# 782/782 [==============================] - 125s 160ms/step - loss: 1.4959 - accuracy: 0.4674 - val_loss: 1.5009 - val_accuracy: 0.4696
# Epoch 20/50
# 782/782 [==============================] - 125s 160ms/step - loss: 1.4904 - accuracy: 0.4682 - val_loss: 1.5051 - val_accuracy: 0.4635
# Epoch 21/50
# 782/782 [==============================] - 125s 160ms/step - loss: 1.4911 - accuracy: 0.4689 - val_loss: 1.4827 - val_accuracy: 0.4709
# Epoch 22/50
# 782/782 [==============================] - 125s 160ms/step - loss: 1.4876 - accuracy: 0.4681 - val_loss: 1.4784 - val_accuracy: 0.4719
# Epoch 23/50
# 782/782 [==============================] - 125s 159ms/step - loss: 1.4849 - accuracy: 0.4707 - val_loss: 1.4825 - val_accuracy: 0.4696
# Epoch 24/50
# 782/782 [==============================] - 125s 160ms/step - loss: 1.4830 - accuracy: 0.4696 - val_loss: 1.4680 - val_accuracy: 0.4775
# Epoch 25/50
# 782/782 [==============================] - 125s 159ms/step - loss: 1.4852 - accuracy: 0.4687 - val_loss: 1.4588 - val_accuracy: 0.4794
# Epoch 26/50
# 782/782 [==============================] - 125s 160ms/step - loss: 1.4838 - accuracy: 0.4674 - val_loss: 1.4690 - val_accuracy: 0.4751
# Epoch 27/50
# 782/782 [==============================] - 125s 160ms/step - loss: 1.4841 - accuracy: 0.4688 - val_loss: 1.5008 - val_accuracy: 0.4608
# Epoch 28/50
# 782/782 [==============================] - 125s 160ms/step - loss: 1.4856 - accuracy: 0.4695 - val_loss: 1.4722 - val_accuracy: 0.4717
# Epoch 29/50
# 782/782 [==============================] - 125s 160ms/step - loss: 1.4818 - accuracy: 0.4710 - val_loss: 1.4727 - val_accuracy: 0.4717
# Epoch 30/50
# 782/782 [==============================] - 125s 160ms/step - loss: 1.4850 - accuracy: 0.4697 - val_loss: 1.4617 - val_accuracy: 0.4749
# Epoch 31/50
# 782/782 [==============================] - 125s 160ms/step - loss: 1.4829 - accuracy: 0.4706 - val_loss: 1.4692 - val_accuracy: 0.4675
# Epoch 32/50
# 782/782 [==============================] - 125s 160ms/step - loss: 1.4882 - accuracy: 0.4661 - val_loss: 1.4697 - val_accuracy: 0.4685
# Epoch 33/50
# 782/782 [==============================] - 125s 160ms/step - loss: 1.4834 - accuracy: 0.4712 - val_loss: 1.4561 - val_accuracy: 0.4761
# Epoch 34/50
# 782/782 [==============================] - 125s 160ms/step - loss: 1.4852 - accuracy: 0.4696 - val_loss: 1.4715 - val_accuracy: 0.4712
# Epoch 35/50
# 782/782 [==============================] - 126s 161ms/step - loss: 1.4863 - accuracy: 0.4692 - val_loss: 1.4552 - val_accuracy: 0.4821
# Epoch 36/50
# 782/782 [==============================] - 125s 160ms/step - loss: 1.4836 - accuracy: 0.4716 - val_loss: 1.4703 - val_accuracy: 0.4671
# Epoch 37/50
# 782/782 [==============================] - 125s 160ms/step - loss: 1.4810 - accuracy: 0.4693 - val_loss: 1.4756 - val_accuracy: 0.4608
# Epoch 38/50
# 782/782 [==============================] - 125s 160ms/step - loss: 1.4809 - accuracy: 0.4721 - val_loss: 1.4663 - val_accuracy: 0.4663
# Epoch 39/50
# 782/782 [==============================] - 125s 160ms/step - loss: 1.4785 - accuracy: 0.4715 - val_loss: 1.4583 - val_accuracy: 0.4705
# Epoch 40/50
# 782/782 [==============================] - 125s 160ms/step - loss: 1.4779 - accuracy: 0.4732 - val_loss: 1.4707 - val_accuracy: 0.4717
# Epoch 41/50
# 782/782 [==============================] - 125s 160ms/step - loss: 1.4792 - accuracy: 0.4701 - val_loss: 1.4552 - val_accuracy: 0.4755
# Epoch 42/50
# 782/782 [==============================] - 125s 160ms/step - loss: 1.4763 - accuracy: 0.4726 - val_loss: 1.4559 - val_accuracy: 0.4703
# Epoch 43/50
# 782/782 [==============================] - 125s 160ms/step - loss: 1.4771 - accuracy: 0.4711 - val_loss: 1.4916 - val_accuracy: 0.4627
# Epoch 44/50
# 782/782 [==============================] - 125s 160ms/step - loss: 1.4745 - accuracy: 0.4728 - val_loss: 1.4683 - val_accuracy: 0.4681
# Epoch 45/50
# 782/782 [==============================] - 125s 160ms/step - loss: 1.4766 - accuracy: 0.4720 - val_loss: 1.4585 - val_accuracy: 0.4714
# Epoch 46/50
# 782/782 [==============================] - 125s 160ms/step - loss: 1.4695 - accuracy: 0.4757 - val_loss: 1.4508 - val_accuracy: 0.4714
# Epoch 47/50
# 782/782 [==============================] - 125s 160ms/step - loss: 1.4694 - accuracy: 0.4751 - val_loss: 1.4559 - val_accuracy: 0.4775
# Epoch 48/50
# 782/782 [==============================] - 125s 160ms/step - loss: 1.4638 - accuracy: 0.4762 - val_loss: 1.4498 - val_accuracy: 0.4759
# Epoch 49/50
# 782/782 [==============================] - 125s 160ms/step - loss: 1.4619 - accuracy: 0.4765 - val_loss: 1.4694 - val_accuracy: 0.4626
# Epoch 50/50
# 782/782 [==============================] - 125s 160ms/step - loss: 1.4641 - accuracy: 0.4774 - val_loss: 1.4361 - val_accuracy: 0.4786

# %%
print(f'Training time {round((total_time_1024),3)} sec for {num_epochs} epochs.')
inference_time_1024 = inf_time_check(model_1024, val_ds)
print(f'Inference time {inference_time_1024} ms for {num_val_samples} samples.')
# Out:
# Training time 6257.905 sec for 50 epochs.
# 64/64 [==============================] - 2s 11ms/step
# 64/64 [==============================] - 1s 12ms/step
# 64/64 [==============================] - 1s 13ms/step
# 64/64 [==============================] - 1s 14ms/step
# 64/64 [==============================] - 1s 14ms/step
# Inference time 1040.072 ms for 10000 samples.

# %%
log_name_1024 = '\log\cifar10\ViP\\random_feature_64_relu\L_1024.pkl'
log_path_1024 = main_dir + log_name_1024
with open(log_path_1024, 'wb') as file:
    pickle.dump(history_1024.history, file)

# %%
# plot accuracy curve
plt.plot(history_1024.history["accuracy"], label="Train Accuracy")
plt.plot(history_1024.history["val_accuracy"], label="Validation Accuracy")
plt.title("Train and Validation Accuracy Over Epochs L=1024")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()

# %%
# plot loss curve
plt.plot(history_1024.history["loss"], label="Train Loss")
plt.plot(history_1024.history["val_loss"], label="Validation Loss")
plt.title("Train and Validation Loss Over Epochs L=1024")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# %%
total_time = [total_time_16, total_time_64, total_time_256, total_time_1024]
inference_time = [inference_time_16, inference_time_64, inference_time_256, inference_time_1024]
log = []
log.append(total_time)
log.append(inference_time)
log_name = '\log\cifar10\ViP\\random_feature_64_relu\\total_inf_time'
log_path = main_dir + log_name
# log [total_time, inference_time]
with open(log_path, 'wb') as file:
    pickle.dump(log, file)

# %%
logL = np.log2([16, 64, 256, 1024])

fig, ax1 = plt.subplots()
plt.title(f'Inference time & Total training time over {num_epochs} epochs')
plt.xlabel('log2(L)')

ax1.plot(logL, total_time, color='blue', label='Total training time')
ax1.set_ylabel('Time (sec)', color='blue')
ax1.legend(loc='upper right')

ax2 = ax1.twinx()
ax2.plot(logL, inference_time, color='red', label='Inference time')
ax2.set_ylabel('Time (ms)', color='red')
ax2.legend(loc='upper left')

plt.grid()
plt.show()
