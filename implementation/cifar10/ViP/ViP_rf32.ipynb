# %% [markdown]
# # ViP Classification on CIFAR-10

# %% [markdown]
# ## random_features=32

# %%
import tensorflow as tf
import tensorflow_addons as tfa
import numpy as np
import matplotlib.pyplot as plt
import time
import datetime
import sys
import os
import pickle

# check GPU
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import tensorflow_datasets as tfds
train_dataset, info = tfds.load('cifar10', split='train', shuffle_files=True, with_info=True)
val_dataset = tfds.load('cifar10', split='test', shuffle_files=False)

# number of samples
num_train_samples = tf.data.experimental.cardinality(train_dataset).numpy()
num_val_samples = tf.data.experimental.cardinality(val_dataset).numpy()
print('Number of training samples:', num_train_samples)
print('Number of validation samples:', num_val_samples)

# size of image
for example in train_dataset.take(1):
    image, label = example['image'], example['label']
print('Image size:', image.shape)

# number of classes
num_classes = info.features['label'].num_classes
print('Number of classes: ', num_classes)
# Out:
# Number of training samples: 50000
# Number of validation samples: 10000
# Image size: (32, 32, 3)
# Number of classes:  10

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
batch_size = 64

def extract_image_and_label(example):
    image, label = example['image'], example['label']
    image = tf.cast(image, tf.float32)
    return image, label

# extract image and label from dataloader
train_ds = train_dataset.map(extract_image_and_label)
val_ds = val_dataset.map(extract_image_and_label)

# batch train_ds and val_ds
train_ds = train_ds.batch(batch_size)
val_ds = val_ds.batch(batch_size)

# input pipeline optimization
train_ds = train_ds.cache().prefetch(AUTOTUNE)
val_ds = val_ds.cache().prefetch(AUTOTUNE)

# %%
curr_dir = os.getcwd() 
parent_dir = os.path.abspath(os.path.join(curr_dir, os.pardir))
implementation_dir = os.path.abspath(os.path.join(parent_dir, os.pardir))
main_dir = os.path.abspath(os.path.join(implementation_dir, os.pardir))
sys.path.append(main_dir)

# %%
from model.vision_performer import VisionPerformer
# compiler attributes
lr = 1e-4
weight_decay = 1e-4
num_epochs = 50

# VisionTransformer attributes
input_shape = image.shape # [32, 32, 3]
image_size = image.shape[0] # 32
num_layers = 6
num_classes = num_classes # 10
d_model = 64
num_heads = 1
mlp_dim = 64
# VisionPerformer attributes
random_features = 32
kernel_transformation = 'softmax'

# %% [markdown]
# # L = 16

# %%
patch_size = 8
model_16 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=input_shape),
    VisionPerformer(image_size=image_size, patch_size=patch_size, num_layers=num_layers,
                      num_classes=num_classes, d_model=d_model, num_heads=num_heads, 
                  random_features=random_features, kernel_transformation=kernel_transformation,
                  mlp_dim=mlp_dim),
    tf.keras.layers.Dense(10, activation='softmax')
])

model_16.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
             optimizer=tfa.optimizers.AdamW(learning_rate=lr, weight_decay=weight_decay),
             metrics=['accuracy']) 

model_16.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vision_performer (VisionPer  (None, 10)               169738
#  former)
#
#  dense_39 (Dense)            (None, 10)                110
#
# =================================================================
# Total params: 169,848
# Trainable params: 169,848
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_name = 'L_16'
path = main_dir + '\model_checkpoints\cifar10\ViP\\random_feature_32\\' + model_name

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=path,
    save_best_only=True,
    save_weights_only=True,
    monitor='val_loss',
    mode='min'
)

#train model
start_time = time.time()
history_16 = model_16.fit(
    train_ds,
    epochs=num_epochs,
    validation_data=val_ds,
    callbacks=[model_checkpoint_callback]
)
end_time = time.time()
total_time_16 = end_time-start_time
# Out:
# Epoch 1/50
# 782/782 [==============================] - 74s 78ms/step - loss: 2.1471 - accuracy: 0.1882 - val_loss: 1.9897 - val_accuracy: 0.2602
# Epoch 2/50
# 782/782 [==============================] - 59s 76ms/step - loss: 1.9728 - accuracy: 0.2657 - val_loss: 1.8745 - val_accuracy: 0.3128
# Epoch 3/50
# 782/782 [==============================] - 60s 76ms/step - loss: 1.8928 - accuracy: 0.2986 - val_loss: 1.8112 - val_accuracy: 0.3369
# Epoch 4/50
# 782/782 [==============================] - 60s 77ms/step - loss: 1.8409 - accuracy: 0.3202 - val_loss: 1.7720 - val_accuracy: 0.3514
# Epoch 5/50
# 782/782 [==============================] - 60s 77ms/step - loss: 1.7968 - accuracy: 0.3357 - val_loss: 1.7290 - val_accuracy: 0.3695
# Epoch 6/50
# 782/782 [==============================] - 59s 76ms/step - loss: 1.7639 - accuracy: 0.3459 - val_loss: 1.7085 - val_accuracy: 0.3717
# Epoch 7/50
# 782/782 [==============================] - 58s 75ms/step - loss: 1.7360 - accuracy: 0.3557 - val_loss: 1.6740 - val_accuracy: 0.3853
# Epoch 8/50
# 782/782 [==============================] - 60s 76ms/step - loss: 1.7091 - accuracy: 0.3701 - val_loss: 1.6555 - val_accuracy: 0.3904
# Epoch 9/50
# 782/782 [==============================] - 59s 76ms/step - loss: 1.6875 - accuracy: 0.3771 - val_loss: 1.6289 - val_accuracy: 0.3969
# Epoch 10/50
# 782/782 [==============================] - 59s 75ms/step - loss: 1.6655 - accuracy: 0.3828 - val_loss: 1.5974 - val_accuracy: 0.4145
# Epoch 11/50
# 782/782 [==============================] - 59s 75ms/step - loss: 1.6441 - accuracy: 0.3950 - val_loss: 1.5858 - val_accuracy: 0.4178
# Epoch 12/50
# 782/782 [==============================] - 59s 75ms/step - loss: 1.6288 - accuracy: 0.4011 - val_loss: 1.5860 - val_accuracy: 0.4218
# Epoch 13/50
# 782/782 [==============================] - 59s 76ms/step - loss: 1.6110 - accuracy: 0.4076 - val_loss: 1.5773 - val_accuracy: 0.4167
# Epoch 14/50
# 782/782 [==============================] - 59s 75ms/step - loss: 1.6039 - accuracy: 0.4122 - val_loss: 1.5726 - val_accuracy: 0.4271
# Epoch 15/50
# 782/782 [==============================] - 59s 75ms/step - loss: 1.5921 - accuracy: 0.4148 - val_loss: 1.5513 - val_accuracy: 0.4365
# Epoch 16/50
# 782/782 [==============================] - 59s 76ms/step - loss: 1.5820 - accuracy: 0.4192 - val_loss: 1.5503 - val_accuracy: 0.4407
# Epoch 17/50
# 782/782 [==============================] - 57s 73ms/step - loss: 1.5791 - accuracy: 0.4209 - val_loss: 1.5514 - val_accuracy: 0.4318
# Epoch 18/50
# 782/782 [==============================] - 58s 74ms/step - loss: 1.5734 - accuracy: 0.4261 - val_loss: 1.5543 - val_accuracy: 0.4314
# Epoch 19/50
# 782/782 [==============================] - 58s 75ms/step - loss: 1.5697 - accuracy: 0.4249 - val_loss: 1.5563 - val_accuracy: 0.4334
# Epoch 20/50
# 782/782 [==============================] - 59s 76ms/step - loss: 1.5718 - accuracy: 0.4222 - val_loss: 1.5763 - val_accuracy: 0.4257
# Epoch 41/50
# 782/782 [==============================] - 58s 74ms/step - loss: 1.5692 - accuracy: 0.4208 - val_loss: 1.5412 - val_accuracy: 0.4320
# Epoch 42/50
# 782/782 [==============================] - 58s 75ms/step - loss: 1.5703 - accuracy: 0.4226 - val_loss: 1.5912 - val_accuracy: 0.4100
# Epoch 43/50
# 782/782 [==============================] - 59s 75ms/step - loss: 1.5734 - accuracy: 0.4210 - val_loss: 1.5554 - val_accuracy: 0.4362
# Epoch 44/50
# 782/782 [==============================] - 58s 74ms/step - loss: 1.5720 - accuracy: 0.4196 - val_loss: 1.5824 - val_accuracy: 0.4258
# Epoch 45/50
# 782/782 [==============================] - 59s 75ms/step - loss: 1.5772 - accuracy: 0.4185 - val_loss: 1.5201 - val_accuracy: 0.4434
# Epoch 46/50
# 782/782 [==============================] - 59s 75ms/step - loss: 1.5721 - accuracy: 0.4201 - val_loss: 1.5435 - val_accuracy: 0.4296
# Epoch 47/50
# 782/782 [==============================] - 59s 75ms/step - loss: 1.5690 - accuracy: 0.4198 - val_loss: 1.5498 - val_accuracy: 0.4284
# Epoch 48/50
# 782/782 [==============================] - 58s 75ms/step - loss: 1.5734 - accuracy: 0.4188 - val_loss: 1.5272 - val_accuracy: 0.4418
# Epoch 49/50
# 782/782 [==============================] - 58s 74ms/step - loss: 1.5723 - accuracy: 0.4212 - val_loss: 1.5305 - val_accuracy: 0.4383
# Epoch 50/50
# 782/782 [==============================] - 59s 75ms/step - loss: 1.5671 - accuracy: 0.4217 - val_loss: 1.5468 - val_accuracy: 0.4329

# %%
from utils import inf_time_check
print(f'Training time {round((total_time_16),3)} sec for {num_epochs} epochs.')
inference_time_16 = inf_time_check(model_16, val_ds)
print(f'Inference time {inference_time_16} ms for {num_val_samples} samples.')
# Out:
# Training time 2951.326 sec for 50 epochs.
# 64/64 [==============================] - 2s 21ms/step
# 64/64 [==============================] - 1s 20ms/step
# 64/64 [==============================] - 1s 20ms/step
# 64/64 [==============================] - 1s 20ms/step
# 64/64 [==============================] - 1s 20ms/step
# Inference time 1569.588 ms for 10000 samples.

# %%
log_name_16 = '\log\cifar10\ViP\\random_feature_32\L_16.pkl'
log_path_16 = main_dir + log_name_16
with open(log_path_16, 'wb') as file:
    pickle.dump(history_16.history, file)

# %%
# plot accuracy curve
plt.plot(history_16.history["accuracy"], label="Train Accuracy")
plt.plot(history_16.history["val_accuracy"], label="Validation Accuracy")
plt.title("Train and Validation Accuracy Over Epochs L=16")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()

# %%
# plot loss curve
plt.plot(history_16.history["loss"], label="Train Loss")
plt.plot(history_16.history["val_loss"], label="Validation Loss")
plt.title("Train and Validation Loss Over Epochs L=16")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# %% [markdown]
# # L = 64

# %%
patch_size = 4
model_64 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=input_shape),
    VisionPerformer(image_size=image_size, patch_size=patch_size, num_layers=num_layers,
                      num_classes=num_classes, d_model=d_model, num_heads=num_heads, 
                  random_features=random_features, kernel_transformation=kernel_transformation,
                  mlp_dim=mlp_dim),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(10, activation='softmax')
])

model_64.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
             optimizer=tfa.optimizers.AdamW(learning_rate=lr, weight_decay=weight_decay),
             metrics=['accuracy']) 

model_64.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vision_performer_1 (VisionP  (None, 10)               163594
#  erformer)
#
#  flatten (Flatten)           (None, 10)                0
#
#  dense_79 (Dense)            (None, 10)                110
#
# =================================================================
# Total params: 163,704
# Trainable params: 163,704
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_name = 'L_64'
path = main_dir + '\model_checkpoints\cifar10\ViP\\random_feature_32\\' + model_name

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=path,
    save_best_only=True,
    save_weights_only=True,
    monitor='val_loss',
    mode='min'
)

#train model
start_time = time.time()
history_64 = model_64.fit(
    train_ds,
    epochs=num_epochs,
    validation_data=val_ds,
    callbacks=[model_checkpoint_callback]
)
end_time = time.time()
total_time_64 = end_time-start_time
# Out:
# Epoch 1/50
# 782/782 [==============================] - 61s 68ms/step - loss: 2.1715 - accuracy: 0.1833 - val_loss: 1.9876 - val_accuracy: 0.2656
# Epoch 2/50
# 782/782 [==============================] - 51s 65ms/step - loss: 1.9596 - accuracy: 0.2647 - val_loss: 1.8612 - val_accuracy: 0.3081
# Epoch 3/50
# 782/782 [==============================] - 51s 65ms/step - loss: 1.8603 - accuracy: 0.3034 - val_loss: 1.7714 - val_accuracy: 0.3421
# Epoch 4/50
# 782/782 [==============================] - 51s 66ms/step - loss: 1.7869 - accuracy: 0.3349 - val_loss: 1.7102 - val_accuracy: 0.3637
# Epoch 5/50
# 782/782 [==============================] - 51s 65ms/step - loss: 1.7414 - accuracy: 0.3556 - val_loss: 1.6786 - val_accuracy: 0.3756
# Epoch 6/50
# 782/782 [==============================] - 51s 65ms/step - loss: 1.7064 - accuracy: 0.3679 - val_loss: 1.6622 - val_accuracy: 0.3808
# Epoch 7/50
# 782/782 [==============================] - 52s 66ms/step - loss: 1.6746 - accuracy: 0.3818 - val_loss: 1.6403 - val_accuracy: 0.3941
# Epoch 8/50
# 782/782 [==============================] - 51s 65ms/step - loss: 1.6480 - accuracy: 0.3909 - val_loss: 1.5915 - val_accuracy: 0.4137
# Epoch 9/50
# 782/782 [==============================] - 51s 65ms/step - loss: 1.6190 - accuracy: 0.4039 - val_loss: 1.5730 - val_accuracy: 0.4225
# Epoch 10/50
# 782/782 [==============================] - 50s 64ms/step - loss: 1.5960 - accuracy: 0.4158 - val_loss: 1.5481 - val_accuracy: 0.4322
# Epoch 11/50
# 782/782 [==============================] - 51s 66ms/step - loss: 1.5766 - accuracy: 0.4219 - val_loss: 1.5345 - val_accuracy: 0.4344
# Epoch 12/50
# 782/782 [==============================] - 51s 65ms/step - loss: 1.5579 - accuracy: 0.4332 - val_loss: 1.5039 - val_accuracy: 0.4562
# Epoch 13/50
# 782/782 [==============================] - 52s 66ms/step - loss: 1.5432 - accuracy: 0.4369 - val_loss: 1.5025 - val_accuracy: 0.4506
# Epoch 14/50
# 782/782 [==============================] - 51s 65ms/step - loss: 1.5306 - accuracy: 0.4406 - val_loss: 1.4920 - val_accuracy: 0.4593
# Epoch 35/50
# 782/782 [==============================] - 52s 66ms/step - loss: 1.4563 - accuracy: 0.4707 - val_loss: 1.4478 - val_accuracy: 0.4666
# Epoch 36/50
# 782/782 [==============================] - 51s 65ms/step - loss: 1.4485 - accuracy: 0.4743 - val_loss: 1.4879 - val_accuracy: 0.4448
# Epoch 37/50
# 782/782 [==============================] - 51s 66ms/step - loss: 1.4476 - accuracy: 0.4760 - val_loss: 1.4912 - val_accuracy: 0.4401
# Epoch 38/50
# 782/782 [==============================] - 51s 65ms/step - loss: 1.4512 - accuracy: 0.4727 - val_loss: 1.5035 - val_accuracy: 0.4419
# Epoch 39/50
# 782/782 [==============================] - 51s 66ms/step - loss: 1.4505 - accuracy: 0.4741 - val_loss: 1.4902 - val_accuracy: 0.4374
# Epoch 40/50
# 782/782 [==============================] - 50s 65ms/step - loss: 1.4507 - accuracy: 0.4750 - val_loss: 1.4775 - val_accuracy: 0.4411
# Epoch 41/50
# 782/782 [==============================] - 51s 65ms/step - loss: 1.4531 - accuracy: 0.4725 - val_loss: 1.5189 - val_accuracy: 0.4337
# Epoch 42/50
# 782/782 [==============================] - 51s 66ms/step - loss: 1.4505 - accuracy: 0.4754 - val_loss: 1.4482 - val_accuracy: 0.4758
# Epoch 43/50
# 782/782 [==============================] - 51s 65ms/step - loss: 1.4525 - accuracy: 0.4736 - val_loss: 1.4367 - val_accuracy: 0.4798
# Epoch 44/50
# 782/782 [==============================] - 51s 65ms/step - loss: 1.4563 - accuracy: 0.4724 - val_loss: 1.4637 - val_accuracy: 0.4597
# Epoch 45/50
# 782/782 [==============================] - 51s 65ms/step - loss: 1.4537 - accuracy: 0.4734 - val_loss: 1.4939 - val_accuracy: 0.4444
# Epoch 46/50
# 782/782 [==============================] - 51s 65ms/step - loss: 1.4522 - accuracy: 0.4743 - val_loss: 1.5068 - val_accuracy: 0.4335
# Epoch 47/50
# 782/782 [==============================] - 51s 66ms/step - loss: 1.4555 - accuracy: 0.4724 - val_loss: 1.4998 - val_accuracy: 0.4345
# Epoch 48/50
# 782/782 [==============================] - 51s 65ms/step - loss: 1.4549 - accuracy: 0.4707 - val_loss: 1.4794 - val_accuracy: 0.4562
# Epoch 49/50
# 782/782 [==============================] - 51s 65ms/step - loss: 1.4542 - accuracy: 0.4723 - val_loss: 1.4688 - val_accuracy: 0.4612
# Epoch 50/50
# 782/782 [==============================] - 51s 65ms/step - loss: 1.4486 - accuracy: 0.4735 - val_loss: 1.4727 - val_accuracy: 0.4594

# %%
print(f'Training time {round((total_time_64),3)} sec for {num_epochs} epochs.')
inference_time_64 = inf_time_check(model_64, val_ds)
print(f'Inference time {inference_time_64} ms for {num_val_samples} samples.')
# Out:
# Training time 2561.672 sec for 50 epochs.
# 64/64 [==============================] - 2s 16ms/step
# 64/64 [==============================] - 1s 16ms/step
# 64/64 [==============================] - 1s 16ms/step
# 64/64 [==============================] - 1s 16ms/step
# 64/64 [==============================] - 1s 16ms/step
# Inference time 1267.227 ms for 10000 samples.

# %%
log_name_64 = '\log\cifar10\ViP\\random_feature_32\L_64.pkl'
log_path_64 = main_dir + log_name_64
with open(log_path_64, 'wb') as file:
    pickle.dump(history_64.history, file)

# %%
# plot accuracy curve
plt.plot(history_64.history["accuracy"], label="Train Accuracy")
plt.plot(history_64.history["val_accuracy"], label="Validation Accuracy")
plt.title("Train and Validation Accuracy Over Epochs L=64")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()

# %%
# plot loss curve
plt.plot(history_64.history["loss"], label="Train Loss")
plt.plot(history_64.history["val_loss"], label="Validation Loss")
plt.title("Train and Validation Loss Over Epochs L=64")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# %% [markdown]
# # L = 256

# %%
patch_size = 2
model_256 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=input_shape),
    VisionPerformer(image_size=image_size, patch_size=patch_size, num_layers=num_layers,
                      num_classes=num_classes, d_model=d_model, num_heads=num_heads, 
                  random_features=random_features, kernel_transformation=kernel_transformation,
                  mlp_dim=mlp_dim),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(10, activation='softmax')
])

model_256.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
             optimizer=tfa.optimizers.AdamW(learning_rate=lr, weight_decay=weight_decay),
             metrics=['accuracy']) 

model_256.summary()
# Out:
# Model: "sequential_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vision_performer_2 (VisionP  (None, 10)               173578
#  erformer)
#
#  flatten_1 (Flatten)         (None, 10)                0
#
#  dense_119 (Dense)           (None, 10)                110
#
# =================================================================
# Total params: 173,688
# Trainable params: 173,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_name = 'L_256'
path = main_dir + '\model_checkpoints\cifar10\ViP\\random_feature_32\\' + model_name

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=path,
    save_best_only=True,
    save_weights_only=True,
    monitor='val_loss',
    mode='min'
)

#train model
start_time = time.time()
history_256 = model_256.fit(
    train_ds,
    epochs=num_epochs,
    validation_data=val_ds,
    callbacks=[model_checkpoint_callback]
)
end_time = time.time()
total_time_256 = end_time-start_time
# Out:
# Epoch 1/50
# 782/782 [==============================] - 70s 79ms/step - loss: 2.1795 - accuracy: 0.1773 - val_loss: 2.0090 - val_accuracy: 0.2393
# Epoch 2/50
# 782/782 [==============================] - 60s 77ms/step - loss: 1.9505 - accuracy: 0.2629 - val_loss: 1.8618 - val_accuracy: 0.3093
# Epoch 3/50
# 782/782 [==============================] - 60s 77ms/step - loss: 1.8233 - accuracy: 0.3176 - val_loss: 1.7967 - val_accuracy: 0.3386
# Epoch 4/50
# 782/782 [==============================] - 61s 77ms/step - loss: 1.7536 - accuracy: 0.3526 - val_loss: 1.7252 - val_accuracy: 0.3746
# Epoch 5/50
# 782/782 [==============================] - 60s 76ms/step - loss: 1.7044 - accuracy: 0.3770 - val_loss: 1.6760 - val_accuracy: 0.3938
# Epoch 6/50
# 782/782 [==============================] - 61s 78ms/step - loss: 1.6664 - accuracy: 0.3927 - val_loss: 1.6404 - val_accuracy: 0.4049
# Epoch 7/50
# 782/782 [==============================] - 60s 77ms/step - loss: 1.6371 - accuracy: 0.4027 - val_loss: 1.6710 - val_accuracy: 0.3982
# Epoch 8/50
# 782/782 [==============================] - 60s 77ms/step - loss: 1.6131 - accuracy: 0.4113 - val_loss: 1.6422 - val_accuracy: 0.4073
# Epoch 9/50
# 782/782 [==============================] - 60s 77ms/step - loss: 1.5930 - accuracy: 0.4192 - val_loss: 1.5762 - val_accuracy: 0.4325
# 782/782 [==============================] - 61s 78ms/step - loss: 1.4261 - accuracy: 0.4838 - val_loss: 1.4153 - val_accuracy: 0.4874
# Epoch 50/50
# 782/782 [==============================] - 61s 78ms/step - loss: 1.4252 - accuracy: 0.4849 - val_loss: 1.4493 - val_accuracy: 0.4853

# %%
from utils import inf_time_check
print(f'Training time {round((total_time_256),3)} sec for {num_epochs} epochs.')
inference_time_256 = inf_time_check(model_256, val_ds)
print(f'Inference time {inference_time_256} ms for {num_val_samples} samples.')
# Out:
# Training time 3053.037 sec for 50 epochs.
# 64/64 [==============================] - 2s 12ms/step
# 64/64 [==============================] - 1s 13ms/step
# 64/64 [==============================] - 1s 13ms/step
# 64/64 [==============================] - 1s 13ms/step
# 64/64 [==============================] - 1s 15ms/step
# Inference time 1099.344 ms for 10000 samples.

# %%
log_name_256 = '\log\cifar10\ViP\\random_feature_32\L_256.pkl'
log_path_256 = main_dir + log_name_256
with open(log_path_256, 'wb') as file:
    pickle.dump(history_256.history, file)

# %%
# plot accuracy curve
plt.plot(history_256.history["accuracy"], label="Train Accuracy")
plt.plot(history_256.history["val_accuracy"], label="Validation Accuracy")
plt.title("Train and Validation Accuracy Over Epochs L=256")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()

# %%
# plot loss curve
plt.plot(history_256.history["loss"], label="Train Loss")
plt.plot(history_256.history["val_loss"], label="Validation Loss")
plt.title("Train and Validation Loss Over Epochs L=256")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# %% [markdown]
# # L = 1024

# %%
patch_size = 1
model_1024 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=input_shape),
    VisionPerformer(image_size=image_size, patch_size=patch_size, num_layers=num_layers,
                      num_classes=num_classes, d_model=d_model, num_heads=num_heads, 
                  random_features=random_features, kernel_transformation=kernel_transformation,
                  mlp_dim=mlp_dim),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(10, activation='softmax')
])

model_1024.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
             optimizer=tfa.optimizers.AdamW(learning_rate=lr, weight_decay=weight_decay),
             metrics=['accuracy']) 

model_1024.summary()
# Out:
# Model: "sequential_31"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vision_performer_3 (VisionP  (None, 10)               222154
#  erformer)
#
#  flatten_2 (Flatten)         (None, 10)                0
#
#  dense_159 (Dense)           (None, 10)                110
#
# =================================================================
# Total params: 222,264
# Trainable params: 222,264
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_name = 'L_1024'
path = main_dir + '\model_checkpoints\cifar10\ViP\\random_feature_32\\' + model_name

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=path,
    save_best_only=True,
    save_weights_only=True,
    monitor='val_loss',
    mode='min'
)

#train model
start_time = time.time()
history_1024 = model_1024.fit(
    train_ds,
    epochs=num_epochs,
    validation_data=val_ds,
    callbacks=[model_checkpoint_callback]
)
end_time = time.time()
total_time_1024 = end_time-start_time
# Out:
# Epoch 1/50
# 782/782 [==============================] - 142s 171ms/step - loss: 2.1241 - accuracy: 0.2017 - val_loss: 1.9621 - val_accuracy: 0.2689
# Epoch 2/50
# 782/782 [==============================] - 133s 170ms/step - loss: 1.9610 - accuracy: 0.2662 - val_loss: 1.9046 - val_accuracy: 0.2878
# Epoch 3/50
# 782/782 [==============================] - 132s 169ms/step - loss: 1.8970 - accuracy: 0.2952 - val_loss: 1.8492 - val_accuracy: 0.3132
# Epoch 4/50
# Epoch 24/50
# 782/782 [==============================] - 132s 169ms/step - loss: 1.5331 - accuracy: 0.4541 - val_loss: 1.5429 - val_accuracy: 0.4436
# Epoch 25/50
# 782/782 [==============================] - 132s 169ms/step - loss: 1.5355 - accuracy: 0.4543 - val_loss: 1.5451 - val_accuracy: 0.4463
# Epoch 26/50
# 782/782 [==============================] - 132s 169ms/step - loss: 1.5392 - accuracy: 0.4506 - val_loss: 1.5468 - val_accuracy: 0.4409
# Epoch 27/50
# 782/782 [==============================] - 132s 169ms/step - loss: 1.5396 - accuracy: 0.4491 - val_loss: 1.5398 - val_accuracy: 0.4415
# Epoch 28/50
# 782/782 [==============================] - 132s 169ms/step - loss: 1.5395 - accuracy: 0.4488 - val_loss: 1.5491 - val_accuracy: 0.4378
# Epoch 29/50
# 782/782 [==============================] - 132s 169ms/step - loss: 1.5431 - accuracy: 0.4484 - val_loss: 1.5512 - val_accuracy: 0.4377
# Epoch 30/50
# 782/782 [==============================] - 132s 169ms/step - loss: 1.5488 - accuracy: 0.4462 - val_loss: 1.5326 - val_accuracy: 0.4428
# Epoch 31/50
# 782/782 [==============================] - 132s 169ms/step - loss: 1.5488 - accuracy: 0.4474 - val_loss: 1.5594 - val_accuracy: 0.4367
# Epoch 32/50
# 782/782 [==============================] - 132s 169ms/step - loss: 1.5478 - accuracy: 0.4488 - val_loss: 1.5558 - val_accuracy: 0.4359
# Epoch 33/50
# 782/782 [==============================] - 132s 169ms/step - loss: 1.5505 - accuracy: 0.4446 - val_loss: 1.5511 - val_accuracy: 0.4408
# Epoch 34/50
# 782/782 [==============================] - 132s 169ms/step - loss: 1.5541 - accuracy: 0.4442 - val_loss: 1.5713 - val_accuracy: 0.4321
# Epoch 35/50
# 782/782 [==============================] - 132s 169ms/step - loss: 1.5547 - accuracy: 0.4441 - val_loss: 1.5622 - val_accuracy: 0.4359
# Epoch 36/50
# 782/782 [==============================] - 132s 169ms/step - loss: 1.5588 - accuracy: 0.4422 - val_loss: 1.5486 - val_accuracy: 0.4367
# Epoch 37/50
# 782/782 [==============================] - 132s 169ms/step - loss: 1.5547 - accuracy: 0.4467 - val_loss: 1.5512 - val_accuracy: 0.4370
# Epoch 38/50
# 782/782 [==============================] - 132s 169ms/step - loss: 1.5551 - accuracy: 0.4446 - val_loss: 1.5436 - val_accuracy: 0.4443
# Epoch 39/50
# 782/782 [==============================] - 132s 169ms/step - loss: 1.5573 - accuracy: 0.4422 - val_loss: 1.5901 - val_accuracy: 0.4269
# Epoch 40/50
# 782/782 [==============================] - 132s 169ms/step - loss: 1.5577 - accuracy: 0.4422 - val_loss: 1.5497 - val_accuracy: 0.4405
# Epoch 41/50
# 782/782 [==============================] - 132s 169ms/step - loss: 1.5573 - accuracy: 0.4424 - val_loss: 1.5580 - val_accuracy: 0.4392
# Epoch 42/50
# 782/782 [==============================] - 132s 169ms/step - loss: 1.5590 - accuracy: 0.4431 - val_loss: 1.5360 - val_accuracy: 0.4456
# Epoch 43/50
# 782/782 [==============================] - 132s 169ms/step - loss: 1.5572 - accuracy: 0.4433 - val_loss: 1.5506 - val_accuracy: 0.4378
# Epoch 44/50
# 782/782 [==============================] - 132s 169ms/step - loss: 1.5570 - accuracy: 0.4427 - val_loss: 1.5402 - val_accuracy: 0.4443
# Epoch 45/50
# 782/782 [==============================] - 133s 170ms/step - loss: 1.5616 - accuracy: 0.4398 - val_loss: 1.5228 - val_accuracy: 0.4479
# Epoch 46/50
# 782/782 [==============================] - 132s 169ms/step - loss: 1.5574 - accuracy: 0.4417 - val_loss: 1.5294 - val_accuracy: 0.4436
# Epoch 47/50
# 782/782 [==============================] - 132s 169ms/step - loss: 1.5585 - accuracy: 0.4406 - val_loss: 1.5461 - val_accuracy: 0.4359
# Epoch 48/50
# 782/782 [==============================] - 132s 169ms/step - loss: 1.5574 - accuracy: 0.4402 - val_loss: 1.5566 - val_accuracy: 0.4356
# Epoch 49/50
# 782/782 [==============================] - 132s 169ms/step - loss: 1.5565 - accuracy: 0.4418 - val_loss: 1.5348 - val_accuracy: 0.4430
# Epoch 50/50
# 782/782 [==============================] - 132s 169ms/step - loss: 1.5549 - accuracy: 0.4412 - val_loss: 1.5551 - val_accuracy: 0.4364

# %%
print(f'Training time {round((total_time_1024),3)} sec for {num_epochs} epochs.')
inference_time_1024 = inf_time_check(model_1024, val_ds)
print(f'Inference time {inference_time_1024} ms for {num_val_samples} samples.')
# Out:
# Training time 6629.39 sec for 50 epochs.
# 64/64 [==============================] - 2s 12ms/step
# 64/64 [==============================] - 1s 13ms/step
# 64/64 [==============================] - 1s 14ms/step
# 64/64 [==============================] - 1s 15ms/step
# 64/64 [==============================] - 1s 16ms/step
# Inference time 1160.454 ms for 10000 samples.

# %%
log_name_1024 = '\log\cifar10\ViP\\random_feature_32\L_1024.pkl'
log_path_1024 = main_dir + log_name_1024
with open(log_path_1024, 'wb') as file:
    pickle.dump(history_1024.history, file)

# %%
# plot accuracy curve
plt.plot(history_1024.history["accuracy"], label="Train Accuracy")
plt.plot(history_1024.history["val_accuracy"], label="Validation Accuracy")
plt.title("Train and Validation Accuracy Over Epochs L=1024")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()

# %%
# plot loss curve
plt.plot(history_1024.history["loss"], label="Train Loss")
plt.plot(history_1024.history["val_loss"], label="Validation Loss")
plt.title("Train and Validation Loss Over Epochs L=1024")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# %%
total_time = [total_time_16, total_time_64, total_time_256, total_time_1024]
inference_time = [inference_time_16, inference_time_64, inference_time_256, inference_time_1024]
log = []
log.append(total_time)
log.append(inference_time)
log_name = '\log\cifar10\ViP\\random_feature_32\\total_inf_time'
log_path = main_dir + log_name
# log [total_time, inference_time]
with open(log_path, 'wb') as file:
    pickle.dump(log, file)

# %%
logL = np.log2([16, 64, 256, 1024])

fig, ax1 = plt.subplots()
plt.title(f'Inference time & Total training time over {num_epochs} epochs')
plt.xlabel('log2(L)')

ax1.plot(logL, total_time, color='blue', label='Total training time')
ax1.set_ylabel('Time (sec)', color='blue')
ax1.legend(loc='upper right')

ax2 = ax1.twinx()
ax2.plot(logL, inference_time, color='red', label='Inference time')
ax2.set_ylabel('Time (ms)', color='red')
ax2.legend(loc='upper left')

plt.grid()
plt.show()
