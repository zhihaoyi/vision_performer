# %% [markdown]
# # ViP Classification on CIFAR-10

# %% [markdown]
# ## random_features=16

# %%
import tensorflow as tf
import tensorflow_addons as tfa
import numpy as np
import matplotlib.pyplot as plt
import time
import datetime
import sys
import os
import pickle

# check GPU
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import tensorflow_datasets as tfds
train_dataset, info = tfds.load('cifar10', split='train', shuffle_files=True, with_info=True)
val_dataset = tfds.load('cifar10', split='test', shuffle_files=False)

# number of samples
num_train_samples = tf.data.experimental.cardinality(train_dataset).numpy()
num_val_samples = tf.data.experimental.cardinality(val_dataset).numpy()
print('Number of training samples:', num_train_samples)
print('Number of validation samples:', num_val_samples)

# size of image
for example in train_dataset.take(1):
    image, label = example['image'], example['label']
print('Image size:', image.shape)

# number of classes
num_classes = info.features['label'].num_classes
print('Number of classes: ', num_classes)
# Out:
# Number of training samples: 50000
# Number of validation samples: 10000
# Image size: (32, 32, 3)
# Number of classes:  10

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
batch_size = 64

def extract_image_and_label(example):
    image, label = example['image'], example['label']
    image = tf.cast(image, tf.float32)
    return image, label

# extract image and label from dataloader
train_ds = train_dataset.map(extract_image_and_label)
val_ds = val_dataset.map(extract_image_and_label)

# batch train_ds and val_ds
train_ds = train_ds.batch(batch_size)
val_ds = val_ds.batch(batch_size)

# input pipeline optimization
train_ds = train_ds.cache().prefetch(AUTOTUNE)
val_ds = val_ds.cache().prefetch(AUTOTUNE)

# %%
curr_dir = os.getcwd() 
parent_dir = os.path.abspath(os.path.join(curr_dir, os.pardir))
implementation_dir = os.path.abspath(os.path.join(parent_dir, os.pardir))
main_dir = os.path.abspath(os.path.join(implementation_dir, os.pardir))
sys.path.append(main_dir)

# %%
from model.vision_performer import VisionPerformer
# compiler attributes
lr = 1e-4
weight_decay = 1e-4
num_epochs = 50

# VisionTransformer attributes
input_shape = image.shape # [32, 32, 3]
image_size = image.shape[0] # 32
num_layers = 6
num_classes = num_classes # 10
d_model = 64
num_heads = 1
mlp_dim = 64
# VisionPerformer attributes
random_features = 16
kernel_transformation = 'softmax'

# %% [markdown]
# # L = 16

# %%
patch_size = 8
model_16 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=input_shape),
    VisionPerformer(image_size=image_size, patch_size=patch_size, num_layers=num_layers,
                      num_classes=num_classes, d_model=d_model, num_heads=num_heads, 
                  random_features=random_features, kernel_transformation=kernel_transformation,
                  mlp_dim=mlp_dim),
    tf.keras.layers.Dense(10, activation='softmax')
])

model_16.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
             optimizer=tfa.optimizers.AdamW(learning_rate=lr, weight_decay=weight_decay),
             metrics=['accuracy']) 

model_16.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vision_performer (VisionPer  (None, 10)               169738
#  former)
#
#  dense_39 (Dense)            (None, 10)                110
#
# =================================================================
# Total params: 169,848
# Trainable params: 169,848
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_name = 'L_16'
path = main_dir + '\model_checkpoints\cifar10\ViP\\random_feature_16\\' + model_name

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=path,
    save_best_only=True,
    save_weights_only=True,
    monitor='val_loss',
    mode='min'
)

#train model
start_time = time.time()
history_16 = model_16.fit(
    train_ds,
    epochs=num_epochs,
    validation_data=val_ds,
    callbacks=[model_checkpoint_callback]
)
end_time = time.time()
total_time_16 = end_time-start_time
# Out:
# Epoch 1/50
# 782/782 [==============================] - 71s 79ms/step - loss: 2.1315 - accuracy: 0.1961 - val_loss: 1.9812 - val_accuracy: 0.2725
# Epoch 2/50
# 782/782 [==============================] - 59s 75ms/step - loss: 1.9807 - accuracy: 0.2618 - val_loss: 1.8997 - val_accuracy: 0.2960
# Epoch 3/50
# 782/782 [==============================] - 59s 75ms/step - loss: 1.9120 - accuracy: 0.2934 - val_loss: 1.8519 - val_accuracy: 0.3208
# Epoch 4/50
# 782/782 [==============================] - 59s 75ms/step - loss: 1.8564 - accuracy: 0.3148 - val_loss: 1.8209 - val_accuracy: 0.3355
# Epoch 5/50
# 782/782 [==============================] - 59s 75ms/step - loss: 1.8139 - accuracy: 0.3358 - val_loss: 1.7660 - val_accuracy: 0.3539
# Epoch 6/50
# 782/782 [==============================] - 58s 74ms/step - loss: 1.7827 - accuracy: 0.3430 - val_loss: 1.7866 - val_accuracy: 0.3513
# Epoch 7/50
# 782/782 [==============================] - 59s 75ms/step - loss: 1.7551 - accuracy: 0.3525 - val_loss: 1.7429 - val_accuracy: 0.3652
# Epoch 8/50
# 782/782 [==============================] - 59s 75ms/step - loss: 1.7370 - accuracy: 0.3618 - val_loss: 1.6955 - val_accuracy: 0.3767
# Epoch 9/50
# 782/782 [==============================] - 61s 78ms/step - loss: 1.7113 - accuracy: 0.3680 - val_loss: 1.6747 - val_accuracy: 0.3816
# Epoch 10/50
# 782/782 [==============================] - 61s 78ms/step - loss: 1.6925 - accuracy: 0.3777 - val_loss: 1.6651 - val_accuracy: 0.3864
# Epoch 11/50
# 782/782 [==============================] - 60s 77ms/step - loss: 1.6746 - accuracy: 0.3809 - val_loss: 1.6522 - val_accuracy: 0.3824
# Epoch 12/50
# 782/782 [==============================] - 60s 76ms/step - loss: 1.6599 - accuracy: 0.3892 - val_loss: 1.6243 - val_accuracy: 0.4037
# Epoch 13/50
# 782/782 [==============================] - 60s 76ms/step - loss: 1.6477 - accuracy: 0.3929 - val_loss: 1.6004 - val_accuracy: 0.4088
# Epoch 14/50
# 782/782 [==============================] - 60s 77ms/step - loss: 1.6388 - accuracy: 0.3946 - val_loss: 1.6182 - val_accuracy: 0.3973
# Epoch 15/50
# 782/782 [==============================] - 60s 77ms/step - loss: 1.6355 - accuracy: 0.3961 - val_loss: 1.6128 - val_accuracy: 0.4085
# Epoch 16/50
# 782/782 [==============================] - 61s 78ms/step - loss: 1.6259 - accuracy: 0.4002 - val_loss: 1.5865 - val_accuracy: 0.4125
# Epoch 17/50
# 782/782 [==============================] - 61s 78ms/step - loss: 1.6175 - accuracy: 0.4044 - val_loss: 1.5937 - val_accuracy: 0.4162
# Epoch 18/50
# 782/782 [==============================] - 60s 76ms/step - loss: 1.6157 - accuracy: 0.4030 - val_loss: 1.5971 - val_accuracy: 0.4102
# Epoch 19/50
# 782/782 [==============================] - 60s 77ms/step - loss: 1.6134 - accuracy: 0.4046 - val_loss: 1.5807 - val_accuracy: 0.4171
# Epoch 20/50
# 782/782 [==============================] - 60s 77ms/step - loss: 1.6334 - accuracy: 0.3959 - val_loss: 1.6031 - val_accuracy: 0.4164
# Epoch 41/50
# 782/782 [==============================] - 60s 77ms/step - loss: 1.6366 - accuracy: 0.3886 - val_loss: 1.5918 - val_accuracy: 0.4163
# Epoch 42/50
# 782/782 [==============================] - 61s 78ms/step - loss: 1.6365 - accuracy: 0.3906 - val_loss: 1.6663 - val_accuracy: 0.3920
# Epoch 43/50
# 782/782 [==============================] - 60s 77ms/step - loss: 1.6385 - accuracy: 0.3916 - val_loss: 1.6129 - val_accuracy: 0.4101
# Epoch 44/50
# 782/782 [==============================] - 60s 77ms/step - loss: 1.6369 - accuracy: 0.3910 - val_loss: 1.6585 - val_accuracy: 0.4036
# Epoch 45/50
# 782/782 [==============================] - 60s 77ms/step - loss: 1.6389 - accuracy: 0.3909 - val_loss: 1.6349 - val_accuracy: 0.4045
# Epoch 46/50
# 782/782 [==============================] - 60s 77ms/step - loss: 1.6433 - accuracy: 0.3890 - val_loss: 1.6311 - val_accuracy: 0.4067
# Epoch 47/50
# 782/782 [==============================] - 59s 76ms/step - loss: 1.6405 - accuracy: 0.3896 - val_loss: 1.6550 - val_accuracy: 0.3973
# Epoch 48/50
# 782/782 [==============================] - 59s 75ms/step - loss: 1.6401 - accuracy: 0.3873 - val_loss: 1.6706 - val_accuracy: 0.3907
# Epoch 49/50
# 782/782 [==============================] - 60s 76ms/step - loss: 1.6406 - accuracy: 0.3889 - val_loss: 1.7126 - val_accuracy: 0.3862
# Epoch 50/50
# 782/782 [==============================] - 61s 78ms/step - loss: 1.6401 - accuracy: 0.3906 - val_loss: 1.6758 - val_accuracy: 0.3915

# %%
from utils import inf_time_check
print(f'Training time {round((total_time_16),3)} sec for {num_epochs} epochs.')
inference_time_16 = inf_time_check(model_16, val_ds)
print(f'Inference time {inference_time_16} ms for {num_val_samples} samples.')
# Out:
# Training time 3007.937 sec for 50 epochs.
# 64/64 [==============================] - 2s 22ms/step
# 64/64 [==============================] - 1s 21ms/step
# 64/64 [==============================] - 1s 21ms/step
# 64/64 [==============================] - 1s 21ms/step
# 64/64 [==============================] - 1s 21ms/step
# Inference time 1628.222 ms for 10000 samples.

# %%
log_name_16 = '\log\cifar10\ViP\\random_feature_16\L_16.pkl'
log_path_16 = main_dir + log_name_16
with open(log_path_16, 'wb') as file:
    pickle.dump(history_16.history, file)

# %%
# plot accuracy curve
plt.plot(history_16.history["accuracy"], label="Train Accuracy")
plt.plot(history_16.history["val_accuracy"], label="Validation Accuracy")
plt.title("Train and Validation Accuracy Over Epochs L=16")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()

# %%
# plot loss curve
plt.plot(history_16.history["loss"], label="Train Loss")
plt.plot(history_16.history["val_loss"], label="Validation Loss")
plt.title("Train and Validation Loss Over Epochs L=16")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# %% [markdown]
# # L = 64

# %%
patch_size = 4
model_64 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=input_shape),
    VisionPerformer(image_size=image_size, patch_size=patch_size, num_layers=num_layers,
                      num_classes=num_classes, d_model=d_model, num_heads=num_heads, 
                  random_features=random_features, kernel_transformation=kernel_transformation,
                  mlp_dim=mlp_dim),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(10, activation='softmax')
])

model_64.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
             optimizer=tfa.optimizers.AdamW(learning_rate=lr, weight_decay=weight_decay),
             metrics=['accuracy']) 

model_64.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vision_performer_1 (VisionP  (None, 10)               163594
#  erformer)
#
#  flatten (Flatten)           (None, 10)                0
#
#  dense_79 (Dense)            (None, 10)                110
#
# =================================================================
# Total params: 163,704
# Trainable params: 163,704
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_name = 'L_64'
path = main_dir + '\model_checkpoints\cifar10\ViP\\random_feature_16\\' + model_name

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=path,
    save_best_only=True,
    save_weights_only=True,
    monitor='val_loss',
    mode='min'
)

#train model
start_time = time.time()
history_64 = model_64.fit(
    train_ds,
    epochs=num_epochs,
    validation_data=val_ds,
    callbacks=[model_checkpoint_callback]
)
end_time = time.time()
total_time_64 = end_time-start_time
# Out:
# Epoch 1/50
# 782/782 [==============================] - 63s 69ms/step - loss: 2.1611 - accuracy: 0.1881 - val_loss: 2.0402 - val_accuracy: 0.2347
# Epoch 2/50
# 782/782 [==============================] - 51s 65ms/step - loss: 2.0051 - accuracy: 0.2490 - val_loss: 1.8870 - val_accuracy: 0.2956
# Epoch 3/50
# 782/782 [==============================] - 52s 66ms/step - loss: 1.8821 - accuracy: 0.2932 - val_loss: 1.8104 - val_accuracy: 0.3265
# Epoch 4/50
# 782/782 [==============================] - 52s 67ms/step - loss: 1.8105 - accuracy: 0.3247 - val_loss: 1.7707 - val_accuracy: 0.3483
# Epoch 5/50
# 782/782 [==============================] - 52s 67ms/step - loss: 1.7592 - accuracy: 0.3470 - val_loss: 1.6971 - val_accuracy: 0.3705
# Epoch 6/50
# 782/782 [==============================] - 53s 67ms/step - loss: 1.7237 - accuracy: 0.3654 - val_loss: 1.6843 - val_accuracy: 0.3768
# Epoch 7/50
# 782/782 [==============================] - 51s 65ms/step - loss: 1.6892 - accuracy: 0.3785 - val_loss: 1.6426 - val_accuracy: 0.3966
# Epoch 8/50
# 782/782 [==============================] - 52s 66ms/step - loss: 1.6601 - accuracy: 0.3916 - val_loss: 1.6089 - val_accuracy: 0.4131
# Epoch 9/50
# 782/782 [==============================] - 52s 67ms/step - loss: 1.6405 - accuracy: 0.4013 - val_loss: 1.5965 - val_accuracy: 0.4111
# Epoch 10/50
# 782/782 [==============================] - 52s 67ms/step - loss: 1.6208 - accuracy: 0.4079 - val_loss: 1.5764 - val_accuracy: 0.4173
# Epoch 11/50
# 782/782 [==============================] - 52s 67ms/step - loss: 1.6000 - accuracy: 0.4133 - val_loss: 1.6021 - val_accuracy: 0.4057
# Epoch 12/50
# 782/782 [==============================] - 52s 67ms/step - loss: 1.5848 - accuracy: 0.4188 - val_loss: 1.5432 - val_accuracy: 0.4343
# Epoch 13/50
# 782/782 [==============================] - 51s 65ms/step - loss: 1.5671 - accuracy: 0.4270 - val_loss: 1.5617 - val_accuracy: 0.4180
# Epoch 14/50
# 782/782 [==============================] - 52s 66ms/step - loss: 1.5474 - accuracy: 0.4347 - val_loss: 1.5305 - val_accuracy: 0.4342
# Epoch 35/50
# 782/782 [==============================] - 51s 65ms/step - loss: 1.4618 - accuracy: 0.4697 - val_loss: 1.4690 - val_accuracy: 0.4631
# Epoch 36/50
# 782/782 [==============================] - 51s 66ms/step - loss: 1.4632 - accuracy: 0.4694 - val_loss: 1.4825 - val_accuracy: 0.4517
# Epoch 37/50
# 782/782 [==============================] - 51s 66ms/step - loss: 1.4644 - accuracy: 0.4673 - val_loss: 1.4964 - val_accuracy: 0.4471
# Epoch 38/50
# 782/782 [==============================] - 51s 65ms/step - loss: 1.4653 - accuracy: 0.4659 - val_loss: 1.5475 - val_accuracy: 0.4219
# Epoch 39/50
# 782/782 [==============================] - 51s 65ms/step - loss: 1.4673 - accuracy: 0.4667 - val_loss: 1.4899 - val_accuracy: 0.4493
# Epoch 40/50
# 782/782 [==============================] - 51s 65ms/step - loss: 1.4667 - accuracy: 0.4674 - val_loss: 1.4605 - val_accuracy: 0.4585
# Epoch 41/50
# 782/782 [==============================] - 51s 65ms/step - loss: 1.4669 - accuracy: 0.4664 - val_loss: 1.4479 - val_accuracy: 0.4745
# Epoch 42/50
# 782/782 [==============================] - 51s 65ms/step - loss: 1.4660 - accuracy: 0.4666 - val_loss: 1.4801 - val_accuracy: 0.4498
# Epoch 43/50
# 782/782 [==============================] - 52s 66ms/step - loss: 1.4709 - accuracy: 0.4654 - val_loss: 1.4756 - val_accuracy: 0.4592
# Epoch 44/50
# 782/782 [==============================] - 51s 65ms/step - loss: 1.4666 - accuracy: 0.4674 - val_loss: 1.4880 - val_accuracy: 0.4475
# Epoch 45/50
# 782/782 [==============================] - 50s 64ms/step - loss: 1.4708 - accuracy: 0.4635 - val_loss: 1.5202 - val_accuracy: 0.4394
# Epoch 46/50
# 782/782 [==============================] - 51s 65ms/step - loss: 1.4726 - accuracy: 0.4618 - val_loss: 1.4808 - val_accuracy: 0.4453
# Epoch 47/50
# 782/782 [==============================] - 51s 66ms/step - loss: 1.4681 - accuracy: 0.4639 - val_loss: 1.4504 - val_accuracy: 0.4612
# Epoch 48/50
# 782/782 [==============================] - 50s 64ms/step - loss: 1.4672 - accuracy: 0.4650 - val_loss: 1.5386 - val_accuracy: 0.4230
# Epoch 49/50
# 782/782 [==============================] - 51s 65ms/step - loss: 1.4695 - accuracy: 0.4660 - val_loss: 1.4421 - val_accuracy: 0.4805
# Epoch 50/50
# 782/782 [==============================] - 51s 65ms/step - loss: 1.4702 - accuracy: 0.4652 - val_loss: 1.4751 - val_accuracy: 0.4544

# %%
print(f'Training time {round((total_time_64),3)} sec for {num_epochs} epochs.')
inference_time_64 = inf_time_check(model_64, val_ds)
print(f'Inference time {inference_time_64} ms for {num_val_samples} samples.')
# Out:
# Training time 2580.258 sec for 50 epochs.
# 64/64 [==============================] - 2s 20ms/step
# 64/64 [==============================] - 1s 20ms/step
# 64/64 [==============================] - 1s 20ms/step
# 64/64 [==============================] - 1s 20ms/step
# 64/64 [==============================] - 1s 20ms/step
# Inference time 1549.934 ms for 10000 samples.

# %%
log_name_64 = '\log\cifar10\ViP\\random_feature_16\L_64.pkl'
log_path_64 = main_dir + log_name_64
with open(log_path_64, 'wb') as file:
    pickle.dump(history_64.history, file)

# %%
# plot accuracy curve
plt.plot(history_64.history["accuracy"], label="Train Accuracy")
plt.plot(history_64.history["val_accuracy"], label="Validation Accuracy")
plt.title("Train and Validation Accuracy Over Epochs L=64")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()

# %%
# plot loss curve
plt.plot(history_64.history["loss"], label="Train Loss")
plt.plot(history_64.history["val_loss"], label="Validation Loss")
plt.title("Train and Validation Loss Over Epochs L=64")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# %% [markdown]
# # L = 256

# %%
patch_size = 2
model_256 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=input_shape),
    VisionPerformer(image_size=image_size, patch_size=patch_size, num_layers=num_layers,
                      num_classes=num_classes, d_model=d_model, num_heads=num_heads, 
                  random_features=random_features, kernel_transformation=kernel_transformation,
                  mlp_dim=mlp_dim),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(10, activation='softmax')
])

model_256.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
             optimizer=tfa.optimizers.AdamW(learning_rate=lr, weight_decay=weight_decay),
             metrics=['accuracy']) 

model_256.summary()
# Out:
# Model: "sequential_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vision_performer_2 (VisionP  (None, 10)               173578
#  erformer)
#
#  flatten_1 (Flatten)         (None, 10)                0
#
#  dense_119 (Dense)           (None, 10)                110
#
# =================================================================
# Total params: 173,688
# Trainable params: 173,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_name = 'L_256'
path = main_dir + '\model_checkpoints\cifar10\ViP\\random_feature_16\\' + model_name

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=path,
    save_best_only=True,
    save_weights_only=True,
    monitor='val_loss',
    mode='min'
)

#train model
start_time = time.time()
history_256 = model_256.fit(
    train_ds,
    epochs=num_epochs,
    validation_data=val_ds,
    callbacks=[model_checkpoint_callback]
)
end_time = time.time()
total_time_256 = end_time-start_time
# Out:
# Epoch 1/50
# 782/782 [==============================] - 70s 79ms/step - loss: 2.1176 - accuracy: 0.2054 - val_loss: 1.9492 - val_accuracy: 0.2664
# Epoch 2/50
# 782/782 [==============================] - 59s 76ms/step - loss: 1.9237 - accuracy: 0.2730 - val_loss: 1.8389 - val_accuracy: 0.3060
# Epoch 3/50
# 782/782 [==============================] - 60s 76ms/step - loss: 1.8274 - accuracy: 0.3149 - val_loss: 1.7551 - val_accuracy: 0.3464
# Epoch 4/50
# 782/782 [==============================] - 60s 76ms/step - loss: 1.7550 - accuracy: 0.3479 - val_loss: 1.6997 - val_accuracy: 0.3761
# Epoch 5/50
# 782/782 [==============================] - 60s 76ms/step - loss: 1.7004 - accuracy: 0.3700 - val_loss: 1.6546 - val_accuracy: 0.3922
# Epoch 6/50
# 782/782 [==============================] - 60s 76ms/step - loss: 1.6681 - accuracy: 0.3849 - val_loss: 1.6243 - val_accuracy: 0.4060
# Epoch 7/50
# 782/782 [==============================] - 60s 77ms/step - loss: 1.6380 - accuracy: 0.3990 - val_loss: 1.6053 - val_accuracy: 0.4130
# Epoch 8/50
# 782/782 [==============================] - 60s 77ms/step - loss: 1.6071 - accuracy: 0.4136 - val_loss: 1.5701 - val_accuracy: 0.4311
# Epoch 9/50
# 782/782 [==============================] - 60s 77ms/step - loss: 1.5802 - accuracy: 0.4234 - val_loss: 1.5302 - val_accuracy: 0.4458
# 782/782 [==============================] - 60s 77ms/step - loss: 1.4082 - accuracy: 0.4927 - val_loss: 1.3978 - val_accuracy: 0.4944
# Epoch 30/50
# 782/782 [==============================] - 60s 77ms/step - loss: 1.4135 - accuracy: 0.4919 - val_loss: 1.4071 - val_accuracy: 0.4916
# Epoch 31/50
# 782/782 [==============================] - 60s 77ms/step - loss: 1.4098 - accuracy: 0.4929 - val_loss: 1.4079 - val_accuracy: 0.4917
# Epoch 32/50
# 782/782 [==============================] - 60s 77ms/step - loss: 1.4184 - accuracy: 0.4894 - val_loss: 1.4597 - val_accuracy: 0.4635
# Epoch 33/50
# 782/782 [==============================] - 60s 77ms/step - loss: 1.4171 - accuracy: 0.4908 - val_loss: 1.4016 - val_accuracy: 0.4997
# Epoch 34/50
# 782/782 [==============================] - 60s 77ms/step - loss: 1.4194 - accuracy: 0.4903 - val_loss: 1.4338 - val_accuracy: 0.4864
# Epoch 35/50
# 782/782 [==============================] - 60s 77ms/step - loss: 1.4237 - accuracy: 0.4871 - val_loss: 1.4020 - val_accuracy: 0.4905
# Epoch 36/50
# 782/782 [==============================] - 60s 76ms/step - loss: 1.4250 - accuracy: 0.4866 - val_loss: 1.4280 - val_accuracy: 0.4790
# Epoch 37/50
# 782/782 [==============================] - 61s 77ms/step - loss: 1.4234 - accuracy: 0.4897 - val_loss: 1.4255 - val_accuracy: 0.4804
# Epoch 38/50
# 782/782 [==============================] - 60s 77ms/step - loss: 1.4210 - accuracy: 0.4879 - val_loss: 1.3939 - val_accuracy: 0.4961
# Epoch 39/50
# 782/782 [==============================] - 60s 77ms/step - loss: 1.4226 - accuracy: 0.4883 - val_loss: 1.4365 - val_accuracy: 0.4815
# Epoch 40/50
# 782/782 [==============================] - 61s 78ms/step - loss: 1.4263 - accuracy: 0.4862 - val_loss: 1.3815 - val_accuracy: 0.5030
# Epoch 41/50
# 782/782 [==============================] - 60s 77ms/step - loss: 1.4240 - accuracy: 0.4861 - val_loss: 1.4657 - val_accuracy: 0.4751
# Epoch 42/50
# 782/782 [==============================] - 60s 77ms/step - loss: 1.4242 - accuracy: 0.4883 - val_loss: 1.4472 - val_accuracy: 0.4678
# Epoch 43/50
# 782/782 [==============================] - 60s 77ms/step - loss: 1.4242 - accuracy: 0.4857 - val_loss: 1.3989 - val_accuracy: 0.4900
# Epoch 44/50
# 782/782 [==============================] - 60s 77ms/step - loss: 1.4260 - accuracy: 0.4868 - val_loss: 1.4356 - val_accuracy: 0.4863
# Epoch 45/50
# 782/782 [==============================] - 60s 76ms/step - loss: 1.4295 - accuracy: 0.4865 - val_loss: 1.4136 - val_accuracy: 0.4927
# Epoch 46/50
# 782/782 [==============================] - 60s 77ms/step - loss: 1.4278 - accuracy: 0.4846 - val_loss: 1.4135 - val_accuracy: 0.4933
# Epoch 47/50
# 782/782 [==============================] - 60s 77ms/step - loss: 1.4275 - accuracy: 0.4827 - val_loss: 1.4239 - val_accuracy: 0.4845
# Epoch 48/50
# 782/782 [==============================] - 60s 77ms/step - loss: 1.4241 - accuracy: 0.4845 - val_loss: 1.4185 - val_accuracy: 0.4880
# Epoch 49/50
# 782/782 [==============================] - 60s 77ms/step - loss: 1.4244 - accuracy: 0.4851 - val_loss: 1.3858 - val_accuracy: 0.5059
# Epoch 50/50
# 782/782 [==============================] - 61s 77ms/step - loss: 1.4249 - accuracy: 0.4877 - val_loss: 1.3934 - val_accuracy: 0.4989

# %%
from utils import inf_time_check
print(f'Training time {round((total_time_256),3)} sec for {num_epochs} epochs.')
inference_time_256 = inf_time_check(model_256, val_ds)
print(f'Inference time {inference_time_256} ms for {num_val_samples} samples.')
# Out:
# Training time 3014.943 sec for 50 epochs.
# 64/64 [==============================] - 2s 13ms/step
# 64/64 [==============================] - 1s 14ms/step
# 64/64 [==============================] - 1s 14ms/step
# 64/64 [==============================] - 1s 15ms/step
# 64/64 [==============================] - 1s 16ms/step
# Inference time 1175.706 ms for 10000 samples.

# %%
log_name_256 = '\log\cifar10\ViP\\random_feature_16\L_256.pkl'
log_path_256 = main_dir + log_name_256
with open(log_path_256, 'wb') as file:
    pickle.dump(history_256.history, file)

# %%
# plot accuracy curve
plt.plot(history_256.history["accuracy"], label="Train Accuracy")
plt.plot(history_256.history["val_accuracy"], label="Validation Accuracy")
plt.title("Train and Validation Accuracy Over Epochs L=256")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()

# %%
# plot loss curve
plt.plot(history_256.history["loss"], label="Train Loss")
plt.plot(history_256.history["val_loss"], label="Validation Loss")
plt.title("Train and Validation Loss Over Epochs L=256")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# %% [markdown]
# # L = 1024

# %%
patch_size = 1
model_1024 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=input_shape),
    VisionPerformer(image_size=image_size, patch_size=patch_size, num_layers=num_layers,
                      num_classes=num_classes, d_model=d_model, num_heads=num_heads, 
                  random_features=random_features, kernel_transformation=kernel_transformation,
                  mlp_dim=mlp_dim),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(10, activation='softmax')
])

model_1024.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
             optimizer=tfa.optimizers.AdamW(learning_rate=lr, weight_decay=weight_decay),
             metrics=['accuracy']) 

model_1024.summary()
# Out:
# Model: "sequential_31"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vision_performer_3 (VisionP  (None, 10)               222154
#  erformer)
#
#  flatten_2 (Flatten)         (None, 10)                0
#
#  dense_159 (Dense)           (None, 10)                110
#
# =================================================================
# Total params: 222,264
# Trainable params: 222,264
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_name = 'L_1024'
path = main_dir + '\model_checkpoints\cifar10\ViP\\random_feature_16\\' + model_name

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=path,
    save_best_only=True,
    save_weights_only=True,
    monitor='val_loss',
    mode='min'
)

#train model
start_time = time.time()
history_1024 = model_1024.fit(
    train_ds,
    epochs=num_epochs,
    validation_data=val_ds,
    callbacks=[model_checkpoint_callback]
)
end_time = time.time()
total_time_1024 = end_time-start_time
# Out:
# Epoch 1/50
# 782/782 [==============================] - 138s 165ms/step - loss: 2.1276 - accuracy: 0.1923 - val_loss: 1.9924 - val_accuracy: 0.2513
# Epoch 2/50
# 782/782 [==============================] - 128s 163ms/step - loss: 1.9756 - accuracy: 0.2529 - val_loss: 1.9368 - val_accuracy: 0.2865
# Epoch 3/50
# 782/782 [==============================] - 129s 164ms/step - loss: 1.9084 - accuracy: 0.2886 - val_loss: 1.8878 - val_accuracy: 0.3097
# Epoch 4/50
# 782/782 [==============================] - 128s 163ms/step - loss: 1.8620 - accuracy: 0.3158 - val_loss: 1.8668 - val_accuracy: 0.3168
# Epoch 5/50
# 782/782 [==============================] - 128s 164ms/step - loss: 1.8251 - accuracy: 0.3317 - val_loss: 1.8177 - val_accuracy: 0.3410
# Epoch 6/50
# 782/782 [==============================] - 128s 164ms/step - loss: 1.7912 - accuracy: 0.3504 - val_loss: 1.7631 - val_accuracy: 0.3633
# Epoch 7/50
# 782/782 [==============================] - 128s 164ms/step - loss: 1.7641 - accuracy: 0.3626 - val_loss: 1.7160 - val_accuracy: 0.3753
# Epoch 8/50
# 782/782 [==============================] - 128s 163ms/step - loss: 1.7400 - accuracy: 0.3696 - val_loss: 1.6983 - val_accuracy: 0.3867
# Epoch 9/50
# 782/782 [==============================] - 128s 163ms/step - loss: 1.7218 - accuracy: 0.3802 - val_loss: 1.6965 - val_accuracy: 0.3896
# Epoch 10/50
# 782/782 [==============================] - 128s 163ms/step - loss: 1.7063 - accuracy: 0.3825 - val_loss: 1.6817 - val_accuracy: 0.3948
# Epoch 11/50
# 782/782 [==============================] - 128s 163ms/step - loss: 1.6895 - accuracy: 0.3908 - val_loss: 1.6659 - val_accuracy: 0.4000
# Epoch 12/50
# 782/782 [==============================] - 128s 164ms/step - loss: 1.6716 - accuracy: 0.3959 - val_loss: 1.6495 - val_accuracy: 0.4090
# Epoch 13/50
# 782/782 [==============================] - 128s 164ms/step - loss: 1.6550 - accuracy: 0.4035 - val_loss: 1.6233 - val_accuracy: 0.4205
# Epoch 14/50
# 782/782 [==============================] - 128s 164ms/step - loss: 1.6412 - accuracy: 0.4083 - val_loss: 1.6075 - val_accuracy: 0.4240
# Epoch 15/50
# 782/782 [==============================] - 128s 164ms/step - loss: 1.6207 - accuracy: 0.4194 - val_loss: 1.5897 - val_accuracy: 0.4273
# Epoch 16/50
# 782/782 [==============================] - 128s 163ms/step - loss: 1.6073 - accuracy: 0.4252 - val_loss: 1.5933 - val_accuracy: 0.4290
# Epoch 17/50
# 782/782 [==============================] - 128s 163ms/step - loss: 1.5926 - accuracy: 0.4282 - val_loss: 1.5998 - val_accuracy: 0.4206
# Epoch 18/50
# 782/782 [==============================] - 128s 163ms/step - loss: 1.5843 - accuracy: 0.4317 - val_loss: 1.5945 - val_accuracy: 0.4323
# Epoch 19/50
# 782/782 [==============================] - 128s 164ms/step - loss: 1.5754 - accuracy: 0.4344 - val_loss: 1.5687 - val_accuracy: 0.4338
# Epoch 20/50
# 782/782 [==============================] - 128s 163ms/step - loss: 1.5734 - accuracy: 0.4384 - val_loss: 1.5533 - val_accuracy: 0.4464
# Epoch 21/50
# 782/782 [==============================] - 128s 164ms/step - loss: 1.5670 - accuracy: 0.4402 - val_loss: 1.5494 - val_accuracy: 0.4419
# Epoch 22/50
# 782/782 [==============================] - 127s 163ms/step - loss: 1.5673 - accuracy: 0.4413 - val_loss: 1.5571 - val_accuracy: 0.4406
# Epoch 23/50
# 782/782 [==============================] - 127s 163ms/step - loss: 1.5649 - accuracy: 0.4417 - val_loss: 1.5635 - val_accuracy: 0.4353
# Epoch 24/50
# 782/782 [==============================] - 128s 163ms/step - loss: 1.5658 - accuracy: 0.4421 - val_loss: 1.5795 - val_accuracy: 0.4297
# Epoch 25/50
# 782/782 [==============================] - 128s 163ms/step - loss: 1.5675 - accuracy: 0.4414 - val_loss: 1.5637 - val_accuracy: 0.4330
# Epoch 26/50
# 782/782 [==============================] - 128s 163ms/step - loss: 1.5637 - accuracy: 0.4407 - val_loss: 1.5682 - val_accuracy: 0.4238
# Epoch 27/50
# 782/782 [==============================] - 127s 163ms/step - loss: 1.5659 - accuracy: 0.4399 - val_loss: 1.5813 - val_accuracy: 0.4223
# Epoch 28/50
# 782/782 [==============================] - 128s 163ms/step - loss: 1.5680 - accuracy: 0.4403 - val_loss: 1.5830 - val_accuracy: 0.4238
# Epoch 29/50
# 782/782 [==============================] - 128s 163ms/step - loss: 1.5687 - accuracy: 0.4386 - val_loss: 1.5800 - val_accuracy: 0.4238
# Epoch 30/50
# 782/782 [==============================] - 128s 163ms/step - loss: 1.5699 - accuracy: 0.4369 - val_loss: 1.5751 - val_accuracy: 0.4300
# Epoch 31/50
# 782/782 [==============================] - 128s 163ms/step - loss: 1.5687 - accuracy: 0.4388 - val_loss: 1.5610 - val_accuracy: 0.4331
# Epoch 32/50
# 782/782 [==============================] - 128s 163ms/step - loss: 1.5739 - accuracy: 0.4368 - val_loss: 1.5702 - val_accuracy: 0.4285
# Epoch 33/50
# 782/782 [==============================] - 128s 164ms/step - loss: 1.5708 - accuracy: 0.4369 - val_loss: 1.5751 - val_accuracy: 0.4262
# Epoch 34/50
# 782/782 [==============================] - 128s 164ms/step - loss: 1.5755 - accuracy: 0.4351 - val_loss: 1.6148 - val_accuracy: 0.4198
# Epoch 35/50
# 782/782 [==============================] - 128s 164ms/step - loss: 1.5756 - accuracy: 0.4360 - val_loss: 1.5851 - val_accuracy: 0.4261
# Epoch 36/50
# 782/782 [==============================] - 128s 164ms/step - loss: 1.5695 - accuracy: 0.4384 - val_loss: 1.6060 - val_accuracy: 0.4142
# Epoch 37/50
# 782/782 [==============================] - 128s 163ms/step - loss: 1.5720 - accuracy: 0.4391 - val_loss: 1.6123 - val_accuracy: 0.4153
# Epoch 38/50
# 782/782 [==============================] - 128s 163ms/step - loss: 1.5760 - accuracy: 0.4360 - val_loss: 1.5830 - val_accuracy: 0.4235
# Epoch 39/50
# 782/782 [==============================] - 128s 164ms/step - loss: 1.5732 - accuracy: 0.4377 - val_loss: 1.6421 - val_accuracy: 0.3991
# Epoch 40/50
# 782/782 [==============================] - 128s 164ms/step - loss: 1.5733 - accuracy: 0.4388 - val_loss: 1.5939 - val_accuracy: 0.4225
# Epoch 41/50
# 782/782 [==============================] - 128s 163ms/step - loss: 1.5745 - accuracy: 0.4341 - val_loss: 1.5764 - val_accuracy: 0.4312
# Epoch 42/50
# 782/782 [==============================] - 128s 163ms/step - loss: 1.5743 - accuracy: 0.4358 - val_loss: 1.5720 - val_accuracy: 0.4297
# Epoch 43/50
# 782/782 [==============================] - 128s 163ms/step - loss: 1.5722 - accuracy: 0.4350 - val_loss: 1.6130 - val_accuracy: 0.4228
# Epoch 44/50
# 782/782 [==============================] - 128s 164ms/step - loss: 1.5731 - accuracy: 0.4364 - val_loss: 1.5764 - val_accuracy: 0.4250
# Epoch 45/50
# 782/782 [==============================] - 128s 163ms/step - loss: 1.5721 - accuracy: 0.4370 - val_loss: 1.6094 - val_accuracy: 0.4134
# Epoch 46/50
# 782/782 [==============================] - 128s 163ms/step - loss: 1.5712 - accuracy: 0.4367 - val_loss: 1.5630 - val_accuracy: 0.4368
# Epoch 47/50
# 782/782 [==============================] - 128s 163ms/step - loss: 1.5681 - accuracy: 0.4383 - val_loss: 1.5882 - val_accuracy: 0.4221
# Epoch 48/50
# 782/782 [==============================] - 128s 164ms/step - loss: 1.5698 - accuracy: 0.4385 - val_loss: 1.5753 - val_accuracy: 0.4248
# Epoch 49/50
# 782/782 [==============================] - 128s 164ms/step - loss: 1.5726 - accuracy: 0.4360 - val_loss: 1.6344 - val_accuracy: 0.4087
# Epoch 50/50
# 782/782 [==============================] - 128s 164ms/step - loss: 1.5704 - accuracy: 0.4371 - val_loss: 1.5619 - val_accuracy: 0.4326

# %%
print(f'Training time {round((total_time_1024),3)} sec for {num_epochs} epochs.')
inference_time_1024 = inf_time_check(model_1024, val_ds)
print(f'Inference time {inference_time_1024} ms for {num_val_samples} samples.')
# Out:
# Training time 6400.811 sec for 50 epochs.
# 64/64 [==============================] - 2s 12ms/step
# 64/64 [==============================] - 1s 13ms/step
# 64/64 [==============================] - 1s 14ms/step
# 64/64 [==============================] - 1s 14ms/step
# 64/64 [==============================] - 1s 14ms/step
# Inference time 1127.23 ms for 10000 samples.

# %%
log_name_1024 = '\log\cifar10\ViP\\random_feature_16\L_1024.pkl'
log_path_1024 = main_dir + log_name_1024
with open(log_path_1024, 'wb') as file:
    pickle.dump(history_1024.history, file)

# %%
# plot accuracy curve
plt.plot(history_1024.history["accuracy"], label="Train Accuracy")
plt.plot(history_1024.history["val_accuracy"], label="Validation Accuracy")
plt.title("Train and Validation Accuracy Over Epochs L=1024")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()

# %%
# plot loss curve
plt.plot(history_1024.history["loss"], label="Train Loss")
plt.plot(history_1024.history["val_loss"], label="Validation Loss")
plt.title("Train and Validation Loss Over Epochs L=1024")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# %%
total_time = [total_time_16, total_time_64, total_time_256, total_time_1024]
inference_time = [inference_time_16, inference_time_64, inference_time_256, inference_time_1024]
log = []
log.append(total_time)
log.append(inference_time)
log_name = '\log\cifar10\ViP\\random_feature_16\\total_inf_time'
log_path = main_dir + log_name
# log [total_time, inference_time]
with open(log_path, 'wb') as file:
    pickle.dump(log, file)

# %%
logL = np.log2([16, 64, 256, 1024])

fig, ax1 = plt.subplots()
plt.title(f'Inference time & Total training time over {num_epochs} epochs')
plt.xlabel('log2(L)')

ax1.plot(logL, total_time, color='blue', label='Total training time')
ax1.set_ylabel('Time (sec)', color='blue')
ax1.legend(loc='upper right')

ax2 = ax1.twinx()
ax2.plot(logL, inference_time, color='red', label='Inference time')
ax2.set_ylabel('Time (ms)', color='red')
ax2.legend(loc='upper left')

plt.grid()
plt.show()
