# %% [markdown]
# # ViP Classification on CIFAR-10

# %% [markdown]
# ## random_features=64

# %%
import tensorflow as tf
import tensorflow_addons as tfa
import numpy as np
import matplotlib.pyplot as plt
import time
import datetime
import sys
import os
import pickle

# check GPU
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import tensorflow_datasets as tfds
train_dataset, info = tfds.load('cifar10', split='train', shuffle_files=True, with_info=True)
val_dataset = tfds.load('cifar10', split='test', shuffle_files=False)

# number of samples
num_train_samples = tf.data.experimental.cardinality(train_dataset).numpy()
num_val_samples = tf.data.experimental.cardinality(val_dataset).numpy()
print('Number of training samples:', num_train_samples)
print('Number of validation samples:', num_val_samples)

# size of image
for example in train_dataset.take(1):
    image, label = example['image'], example['label']
print('Image size:', image.shape)

# number of classes
num_classes = info.features['label'].num_classes
print('Number of classes: ', num_classes)
# Out:
# Number of training samples: 50000
# Number of validation samples: 10000
# Image size: (32, 32, 3)
# Number of classes:  10

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
batch_size = 64

def extract_image_and_label(example):
    image, label = example['image'], example['label']
    image = tf.cast(image, tf.float32)
    return image, label

# extract image and label from dataloader
train_ds = train_dataset.map(extract_image_and_label)
val_ds = val_dataset.map(extract_image_and_label)

# batch train_ds and val_ds
train_ds = train_ds.batch(batch_size)
val_ds = val_ds.batch(batch_size)

# input pipeline optimization
train_ds = train_ds.cache().prefetch(AUTOTUNE)
val_ds = val_ds.cache().prefetch(AUTOTUNE)

# %%
curr_dir = os.getcwd() 
parent_dir = os.path.abspath(os.path.join(curr_dir, os.pardir))
implementation_dir = os.path.abspath(os.path.join(parent_dir, os.pardir))
main_dir = os.path.abspath(os.path.join(implementation_dir, os.pardir))
sys.path.append(main_dir)

# %%
from model.vision_performer import VisionPerformer
# compiler attributes
lr = 1e-4
weight_decay = 1e-4
num_epochs = 50

# VisionTransformer attributes
input_shape = image.shape # [32, 32, 3]
image_size = image.shape[0] # 32
num_layers = 6
num_classes = num_classes # 10
d_model = 64
num_heads = 1
mlp_dim = 64
# VisionPerformer attributes
random_features = 64
kernel_transformation = 'softmax'

# %% [markdown]
# # L = 16

# %%
patch_size = 8
model_16 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=input_shape),
    VisionPerformer(image_size=image_size, patch_size=patch_size, num_layers=num_layers,
                      num_classes=num_classes, d_model=d_model, num_heads=num_heads, 
                  random_features=random_features, kernel_transformation=kernel_transformation,
                  mlp_dim=mlp_dim),
    tf.keras.layers.Dense(10, activation='softmax')
])

model_16.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
             optimizer=tfa.optimizers.AdamW(learning_rate=lr, weight_decay=weight_decay),
             metrics=['accuracy']) 

model_16.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vision_performer (VisionPer  (None, 10)               169738
#  former)
#
#  dense_39 (Dense)            (None, 10)                110
#
# =================================================================
# Total params: 169,848
# Trainable params: 169,848
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_name = 'L_16'
path = main_dir + '\model_checkpoints\cifar10\ViP\\random_feature_64\\' + model_name

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=path,
    save_best_only=True,
    save_weights_only=True,
    monitor='val_loss',
    mode='min'
)

#train model
start_time = time.time()
history_16 = model_16.fit(
    train_ds,
    epochs=num_epochs,
    validation_data=val_ds,
    callbacks=[model_checkpoint_callback]
)
end_time = time.time()
total_time_16 = end_time-start_time
# Out:
# Epoch 1/50
# 782/782 [==============================] - 72s 81ms/step - loss: 2.1835 - accuracy: 0.1807 - val_loss: 2.0049 - val_accuracy: 0.2508
# Epoch 2/50
# 782/782 [==============================] - 58s 74ms/step - loss: 1.9882 - accuracy: 0.2594 - val_loss: 1.8853 - val_accuracy: 0.3058
# Epoch 3/50
# 782/782 [==============================] - 59s 75ms/step - loss: 1.9073 - accuracy: 0.2920 - val_loss: 1.8290 - val_accuracy: 0.3262
# Epoch 4/50
# 782/782 [==============================] - 59s 76ms/step - loss: 1.8461 - accuracy: 0.3174 - val_loss: 1.7766 - val_accuracy: 0.3502
# Epoch 5/50
# 782/782 [==============================] - 59s 76ms/step - loss: 1.8003 - accuracy: 0.3390 - val_loss: 1.7293 - val_accuracy: 0.3598
# Epoch 6/50
# 782/782 [==============================] - 59s 76ms/step - loss: 1.7622 - accuracy: 0.3510 - val_loss: 1.7112 - val_accuracy: 0.3716
# Epoch 7/50
# 782/782 [==============================] - 60s 76ms/step - loss: 1.7326 - accuracy: 0.3623 - val_loss: 1.6727 - val_accuracy: 0.3918
# Epoch 8/50
# 782/782 [==============================] - 61s 78ms/step - loss: 1.7066 - accuracy: 0.3731 - val_loss: 1.6522 - val_accuracy: 0.3987
# Epoch 9/50
# 782/782 [==============================] - 61s 78ms/step - loss: 1.6854 - accuracy: 0.3799 - val_loss: 1.6217 - val_accuracy: 0.4067
# Epoch 10/50
# 782/782 [==============================] - 61s 77ms/step - loss: 1.6619 - accuracy: 0.3867 - val_loss: 1.6097 - val_accuracy: 0.4138
# Epoch 11/50
# 782/782 [==============================] - 60s 76ms/step - loss: 1.6438 - accuracy: 0.3919 - val_loss: 1.5906 - val_accuracy: 0.4177
# Epoch 12/50
# 782/782 [==============================] - 59s 75ms/step - loss: 1.6320 - accuracy: 0.3986 - val_loss: 1.5963 - val_accuracy: 0.4146
# Epoch 13/50
# 782/782 [==============================] - 59s 76ms/step - loss: 1.6200 - accuracy: 0.4011 - val_loss: 1.5787 - val_accuracy: 0.4228
# Epoch 14/50
# 782/782 [==============================] - 59s 75ms/step - loss: 1.6099 - accuracy: 0.4034 - val_loss: 1.5726 - val_accuracy: 0.4214
# Epoch 15/50
# 782/782 [==============================] - 60s 76ms/step - loss: 1.5994 - accuracy: 0.4083 - val_loss: 1.5617 - val_accuracy: 0.4286
# Epoch 16/50
# 782/782 [==============================] - 60s 77ms/step - loss: 1.5936 - accuracy: 0.4109 - val_loss: 1.5489 - val_accuracy: 0.4334
# Epoch 17/50
# 782/782 [==============================] - 59s 76ms/step - loss: 1.5893 - accuracy: 0.4118 - val_loss: 1.5482 - val_accuracy: 0.4325
# Epoch 18/50
# 782/782 [==============================] - 59s 76ms/step - loss: 1.5847 - accuracy: 0.4132 - val_loss: 1.5543 - val_accuracy: 0.4336
# Epoch 19/50
# 782/782 [==============================] - 58s 74ms/step - loss: 1.5840 - accuracy: 0.4155 - val_loss: 1.5505 - val_accuracy: 0.4260
# Epoch 20/50
# 782/782 [==============================] - 58s 75ms/step - loss: 1.6065 - accuracy: 0.3994 - val_loss: 1.5864 - val_accuracy: 0.4161
# Epoch 41/50
# 782/782 [==============================] - 59s 75ms/step - loss: 1.6136 - accuracy: 0.3964 - val_loss: 1.6029 - val_accuracy: 0.4131
# Epoch 42/50
# 782/782 [==============================] - 59s 76ms/step - loss: 1.6020 - accuracy: 0.4012 - val_loss: 1.6483 - val_accuracy: 0.4016
# Epoch 43/50
# 782/782 [==============================] - 58s 75ms/step - loss: 1.6095 - accuracy: 0.3979 - val_loss: 1.6026 - val_accuracy: 0.4119
# Epoch 44/50
# 782/782 [==============================] - 59s 76ms/step - loss: 1.6083 - accuracy: 0.3983 - val_loss: 1.5727 - val_accuracy: 0.4171
# Epoch 45/50
# 782/782 [==============================] - 59s 76ms/step - loss: 1.6109 - accuracy: 0.3950 - val_loss: 1.5837 - val_accuracy: 0.4152
# Epoch 46/50
# 782/782 [==============================] - 59s 75ms/step - loss: 1.6103 - accuracy: 0.3956 - val_loss: 1.6472 - val_accuracy: 0.4008
# Epoch 47/50
# 782/782 [==============================] - 59s 76ms/step - loss: 1.6138 - accuracy: 0.3953 - val_loss: 1.5828 - val_accuracy: 0.4154
# Epoch 48/50
# 782/782 [==============================] - 60s 76ms/step - loss: 1.6111 - accuracy: 0.3981 - val_loss: 1.5805 - val_accuracy: 0.4198
# Epoch 49/50
# 782/782 [==============================] - 59s 76ms/step - loss: 1.6068 - accuracy: 0.3999 - val_loss: 1.5960 - val_accuracy: 0.4160
# Epoch 50/50
# 782/782 [==============================] - 58s 74ms/step - loss: 1.6152 - accuracy: 0.3963 - val_loss: 1.6269 - val_accuracy: 0.4084

# %%
from utils import inf_time_check
print(f'Training time {round((total_time_16),3)} sec for {num_epochs} epochs.')
inference_time_16 = inf_time_check(model_16, val_ds)
print(f'Inference time {inference_time_16} ms for {num_val_samples} samples.')
# Out:
# Training time 2967.088 sec for 50 epochs.
# 64/64 [==============================] - 2s 20ms/step
# 64/64 [==============================] - 1s 20ms/step
# 64/64 [==============================] - 1s 19ms/step
# 64/64 [==============================] - 1s 19ms/step
# 64/64 [==============================] - 1s 20ms/step
# Inference time 1512.862 ms for 10000 samples.

# %%
log_name_16 = '\log\cifar10\ViP\\random_feature_64\L_16.pkl'
log_path_16 = main_dir + log_name_16
with open(log_path_16, 'wb') as file:
    pickle.dump(history_16.history, file)

# %%
# plot accuracy curve
plt.plot(history_16.history["accuracy"], label="Train Accuracy")
plt.plot(history_16.history["val_accuracy"], label="Validation Accuracy")
plt.title("Train and Validation Accuracy Over Epochs L=16")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()

# %%
# plot loss curve
plt.plot(history_16.history["loss"], label="Train Loss")
plt.plot(history_16.history["val_loss"], label="Validation Loss")
plt.title("Train and Validation Loss Over Epochs L=16")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# %% [markdown]
# # L = 64

# %%
patch_size = 4
model_64 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=input_shape),
    VisionPerformer(image_size=image_size, patch_size=patch_size, num_layers=num_layers,
                      num_classes=num_classes, d_model=d_model, num_heads=num_heads, 
                  random_features=random_features, kernel_transformation=kernel_transformation,
                  mlp_dim=mlp_dim),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(10, activation='softmax')
])

model_64.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
             optimizer=tfa.optimizers.AdamW(learning_rate=lr, weight_decay=weight_decay),
             metrics=['accuracy']) 

model_64.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vision_performer_1 (VisionP  (None, 10)               163594
#  erformer)
#
#  flatten (Flatten)           (None, 10)                0
#
#  dense_79 (Dense)            (None, 10)                110
#
# =================================================================
# Total params: 163,704
# Trainable params: 163,704
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_name = 'L_64'
path = main_dir + '\model_checkpoints\cifar10\ViP\\random_feature_64\\' + model_name

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=path,
    save_best_only=True,
    save_weights_only=True,
    monitor='val_loss',
    mode='min'
)

#train model
start_time = time.time()
history_64 = model_64.fit(
    train_ds,
    epochs=num_epochs,
    validation_data=val_ds,
    callbacks=[model_checkpoint_callback]
)
end_time = time.time()
total_time_64 = end_time-start_time
# Out:
# Epoch 1/50
# 782/782 [==============================] - 61s 67ms/step - loss: 2.1442 - accuracy: 0.1937 - val_loss: 1.9516 - val_accuracy: 0.2801
# Epoch 2/50
# 782/782 [==============================] - 50s 64ms/step - loss: 1.9512 - accuracy: 0.2749 - val_loss: 1.8369 - val_accuracy: 0.3266
# Epoch 3/50
# 782/782 [==============================] - 50s 64ms/step - loss: 1.8436 - accuracy: 0.3214 - val_loss: 1.7435 - val_accuracy: 0.3643
# Epoch 4/50
# 782/782 [==============================] - 51s 65ms/step - loss: 1.7768 - accuracy: 0.3474 - val_loss: 1.7214 - val_accuracy: 0.3630
# Epoch 5/50
# 782/782 [==============================] - 51s 65ms/step - loss: 1.7255 - accuracy: 0.3672 - val_loss: 1.6669 - val_accuracy: 0.3873
# Epoch 6/50
# 782/782 [==============================] - 51s 65ms/step - loss: 1.6885 - accuracy: 0.3783 - val_loss: 1.6340 - val_accuracy: 0.3974
# Epoch 7/50
# 782/782 [==============================] - 50s 64ms/step - loss: 1.6555 - accuracy: 0.3927 - val_loss: 1.6117 - val_accuracy: 0.4031
# Epoch 8/50
# 782/782 [==============================] - 50s 65ms/step - loss: 1.6297 - accuracy: 0.4010 - val_loss: 1.5830 - val_accuracy: 0.4203
# Epoch 9/50
# 782/782 [==============================] - 51s 65ms/step - loss: 1.6044 - accuracy: 0.4119 - val_loss: 1.5600 - val_accuracy: 0.4271
# Epoch 10/50
# 782/782 [==============================] - 51s 65ms/step - loss: 1.5841 - accuracy: 0.4218 - val_loss: 1.5459 - val_accuracy: 0.4382
# Epoch 11/50
# 782/782 [==============================] - 50s 64ms/step - loss: 1.5610 - accuracy: 0.4314 - val_loss: 1.5280 - val_accuracy: 0.4418
# Epoch 12/50
# 782/782 [==============================] - 51s 65ms/step - loss: 1.5424 - accuracy: 0.4377 - val_loss: 1.5058 - val_accuracy: 0.4493
# Epoch 13/50
# 782/782 [==============================] - 50s 64ms/step - loss: 1.5240 - accuracy: 0.4448 - val_loss: 1.4774 - val_accuracy: 0.4606
# Epoch 14/50
# 782/782 [==============================] - 50s 64ms/step - loss: 1.5105 - accuracy: 0.4521 - val_loss: 1.4790 - val_accuracy: 0.4650
# Epoch 35/50
# 782/782 [==============================] - 50s 64ms/step - loss: 1.4193 - accuracy: 0.4861 - val_loss: 1.4761 - val_accuracy: 0.4657
# Epoch 36/50
# 782/782 [==============================] - 50s 64ms/step - loss: 1.4213 - accuracy: 0.4846 - val_loss: 1.4461 - val_accuracy: 0.4685
# Epoch 37/50
# 782/782 [==============================] - 50s 64ms/step - loss: 1.4218 - accuracy: 0.4855 - val_loss: 1.5351 - val_accuracy: 0.4344
# Epoch 38/50
# 782/782 [==============================] - 50s 63ms/step - loss: 1.4252 - accuracy: 0.4837 - val_loss: 1.4600 - val_accuracy: 0.4579
# Epoch 39/50
# 782/782 [==============================] - 50s 64ms/step - loss: 1.4263 - accuracy: 0.4833 - val_loss: 1.4336 - val_accuracy: 0.4738
# Epoch 40/50
# 782/782 [==============================] - 50s 64ms/step - loss: 1.4259 - accuracy: 0.4842 - val_loss: 1.4746 - val_accuracy: 0.4530
# Epoch 41/50
# 782/782 [==============================] - 50s 64ms/step - loss: 1.4284 - accuracy: 0.4827 - val_loss: 1.4596 - val_accuracy: 0.4574
# Epoch 42/50
# 782/782 [==============================] - 50s 64ms/step - loss: 1.4245 - accuracy: 0.4845 - val_loss: 1.4484 - val_accuracy: 0.4582
# Epoch 43/50
# 782/782 [==============================] - 50s 64ms/step - loss: 1.4287 - accuracy: 0.4818 - val_loss: 1.4686 - val_accuracy: 0.4567
# Epoch 44/50
# 782/782 [==============================] - 50s 64ms/step - loss: 1.4274 - accuracy: 0.4823 - val_loss: 1.4429 - val_accuracy: 0.4762
# Epoch 45/50
# 782/782 [==============================] - 51s 65ms/step - loss: 1.4277 - accuracy: 0.4818 - val_loss: 1.4815 - val_accuracy: 0.4644
# Epoch 46/50
# 782/782 [==============================] - 50s 64ms/step - loss: 1.4361 - accuracy: 0.4794 - val_loss: 1.4489 - val_accuracy: 0.4638
# Epoch 47/50
# 782/782 [==============================] - 50s 64ms/step - loss: 1.4307 - accuracy: 0.4818 - val_loss: 1.4507 - val_accuracy: 0.4671
# Epoch 48/50
# 782/782 [==============================] - 50s 64ms/step - loss: 1.4321 - accuracy: 0.4795 - val_loss: 1.4773 - val_accuracy: 0.4530
# Epoch 49/50
# 782/782 [==============================] - 50s 64ms/step - loss: 1.4297 - accuracy: 0.4811 - val_loss: 1.4770 - val_accuracy: 0.4482
# Epoch 50/50
# 782/782 [==============================] - 51s 65ms/step - loss: 1.4252 - accuracy: 0.4815 - val_loss: 1.5074 - val_accuracy: 0.4408

# %%
print(f'Training time {round((total_time_64),3)} sec for {num_epochs} epochs.')
inference_time_64 = inf_time_check(model_64, val_ds)
print(f'Inference time {inference_time_64} ms for {num_val_samples} samples.')
# Out:
# Training time 2525.247 sec for 50 epochs.
# 64/64 [==============================] - 2s 15ms/step
# 64/64 [==============================] - 1s 15ms/step
# 64/64 [==============================] - 1s 15ms/step
# 64/64 [==============================] - 1s 16ms/step
# 64/64 [==============================] - 1s 16ms/step
# Inference time 1239.156 ms for 10000 samples.

# %%
log_name_64 = '\log\cifar10\ViP\\random_feature_64\L_64.pkl'
log_path_64 = main_dir + log_name_64
with open(log_path_64, 'wb') as file:
    pickle.dump(history_64.history, file)

# %%
# plot accuracy curve
plt.plot(history_64.history["accuracy"], label="Train Accuracy")
plt.plot(history_64.history["val_accuracy"], label="Validation Accuracy")
plt.title("Train and Validation Accuracy Over Epochs L=64")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()

# %%
# plot loss curve
plt.plot(history_64.history["loss"], label="Train Loss")
plt.plot(history_64.history["val_loss"], label="Validation Loss")
plt.title("Train and Validation Loss Over Epochs L=64")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# %% [markdown]
# # L = 256

# %%
patch_size = 2
model_256 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=input_shape),
    VisionPerformer(image_size=image_size, patch_size=patch_size, num_layers=num_layers,
                      num_classes=num_classes, d_model=d_model, num_heads=num_heads, 
                  random_features=random_features, kernel_transformation=kernel_transformation,
                  mlp_dim=mlp_dim),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(10, activation='softmax')
])

model_256.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
             optimizer=tfa.optimizers.AdamW(learning_rate=lr, weight_decay=weight_decay),
             metrics=['accuracy']) 

model_256.summary()
# Out:
# Model: "sequential_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vision_performer_2 (VisionP  (None, 10)               173578
#  erformer)
#
#  flatten_1 (Flatten)         (None, 10)                0
#
#  dense_119 (Dense)           (None, 10)                110
#
# =================================================================
# Total params: 173,688
# Trainable params: 173,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_name = 'L_256'
path = main_dir + '\model_checkpoints\cifar10\ViP\\random_feature_64\\' + model_name

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=path,
    save_best_only=True,
    save_weights_only=True,
    monitor='val_loss',
    mode='min'
)

#train model
start_time = time.time()
history_256 = model_256.fit(
    train_ds,
    epochs=num_epochs,
    validation_data=val_ds,
    callbacks=[model_checkpoint_callback]
)
end_time = time.time()
total_time_256 = end_time-start_time
# Out:
# Epoch 1/50
# 782/782 [==============================] - 73s 83ms/step - loss: 2.1230 - accuracy: 0.1978 - val_loss: 1.9675 - val_accuracy: 0.2581
# Epoch 2/50
# 782/782 [==============================] - 63s 80ms/step - loss: 1.9104 - accuracy: 0.2808 - val_loss: 1.8025 - val_accuracy: 0.3292
# Epoch 3/50
# 782/782 [==============================] - 63s 80ms/step - loss: 1.8014 - accuracy: 0.3271 - val_loss: 1.7336 - val_accuracy: 0.3519
# Epoch 4/50
# 782/782 [==============================] - 63s 80ms/step - loss: 1.7384 - accuracy: 0.3513 - val_loss: 1.6883 - val_accuracy: 0.3702
# Epoch 5/50
# 782/782 [==============================] - 63s 80ms/step - loss: 1.6929 - accuracy: 0.3704 - val_loss: 1.6587 - val_accuracy: 0.3785
# Epoch 6/50
# 782/782 [==============================] - 63s 80ms/step - loss: 1.6561 - accuracy: 0.3861 - val_loss: 1.6184 - val_accuracy: 0.4072
# Epoch 7/50
# 782/782 [==============================] - 63s 80ms/step - loss: 1.6223 - accuracy: 0.4025 - val_loss: 1.5919 - val_accuracy: 0.4201
# Epoch 8/50
# 782/782 [==============================] - 63s 80ms/step - loss: 1.5904 - accuracy: 0.4133 - val_loss: 1.5607 - val_accuracy: 0.4323
# Epoch 9/50
# 782/782 [==============================] - 62s 80ms/step - loss: 1.5678 - accuracy: 0.4267 - val_loss: 1.5535 - val_accuracy: 0.4399
# 782/782 [==============================] - 63s 80ms/step - loss: 1.4505 - accuracy: 0.4754 - val_loss: 1.4176 - val_accuracy: 0.4813
# Epoch 50/50
# 782/782 [==============================] - 63s 80ms/step - loss: 1.4507 - accuracy: 0.4746 - val_loss: 1.4130 - val_accuracy: 0.4885

# %%
from utils import inf_time_check
print(f'Training time {round((total_time_256),3)} sec for {num_epochs} epochs.')
inference_time_256 = inf_time_check(model_256, val_ds)
print(f'Inference time {inference_time_256} ms for {num_val_samples} samples.')
# Out:
# Training time 3138.896 sec for 50 epochs.
# 64/64 [==============================] - 2s 12ms/step
# 64/64 [==============================] - 1s 13ms/step
# 64/64 [==============================] - 1s 13ms/step
# 64/64 [==============================] - 1s 13ms/step
# 64/64 [==============================] - 1s 16ms/step
# Inference time 1108.234 ms for 10000 samples.

# %%
log_name_256 = '\log\cifar10\ViP\\random_feature_64\L_256.pkl'
log_path_256 = main_dir + log_name_256
with open(log_path_256, 'wb') as file:
    pickle.dump(history_256.history, file)

# %%
# plot accuracy curve
plt.plot(history_256.history["accuracy"], label="Train Accuracy")
plt.plot(history_256.history["val_accuracy"], label="Validation Accuracy")
plt.title("Train and Validation Accuracy Over Epochs L=256")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()

# %%
# plot loss curve
plt.plot(history_256.history["loss"], label="Train Loss")
plt.plot(history_256.history["val_loss"], label="Validation Loss")
plt.title("Train and Validation Loss Over Epochs L=256")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# %% [markdown]
# # L = 1024

# %%
patch_size = 1
model_1024 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=input_shape),
    VisionPerformer(image_size=image_size, patch_size=patch_size, num_layers=num_layers,
                      num_classes=num_classes, d_model=d_model, num_heads=num_heads, 
                  random_features=random_features, kernel_transformation=kernel_transformation,
                  mlp_dim=mlp_dim),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(10, activation='softmax')
])

model_1024.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
             optimizer=tfa.optimizers.AdamW(learning_rate=lr, weight_decay=weight_decay),
             metrics=['accuracy']) 

model_1024.summary()
# Out:
# Model: "sequential_31"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vision_performer_3 (VisionP  (None, 10)               222154
#  erformer)
#
#  flatten_2 (Flatten)         (None, 10)                0
#
#  dense_159 (Dense)           (None, 10)                110
#
# =================================================================
# Total params: 222,264
# Trainable params: 222,264
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_name = 'L_1024'
path = main_dir + '\model_checkpoints\cifar10\ViP\\random_feature_64\\' + model_name

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=path,
    save_best_only=True,
    save_weights_only=True,
    monitor='val_loss',
    mode='min'
)

#train model
start_time = time.time()
history_1024 = model_1024.fit(
    train_ds,
    epochs=num_epochs,
    validation_data=val_ds,
    callbacks=[model_checkpoint_callback]
)
end_time = time.time()
total_time_1024 = end_time-start_time
# Out:
# Epoch 1/50
# 782/782 [==============================] - 155s 187ms/step - loss: 2.1463 - accuracy: 0.1967 - val_loss: 2.0103 - val_accuracy: 0.2497
# Epoch 2/50
# 782/782 [==============================] - 145s 185ms/step - loss: 1.9885 - accuracy: 0.2596 - val_loss: 1.9047 - val_accuracy: 0.3005
# Epoch 3/50
# 782/782 [==============================] - 145s 185ms/step - loss: 1.8877 - accuracy: 0.3035 - val_loss: 1.8562 - val_accuracy: 0.3207
# Epoch 4/50
# Epoch 44/50
# 782/782 [==============================] - 147s 188ms/step - loss: 1.5555 - accuracy: 0.4425 - val_loss: 1.5259 - val_accuracy: 0.4478
# Epoch 45/50
# 782/782 [==============================] - 146s 187ms/step - loss: 1.5523 - accuracy: 0.4445 - val_loss: 1.5555 - val_accuracy: 0.4349
# Epoch 46/50
# 782/782 [==============================] - 146s 187ms/step - loss: 1.5527 - accuracy: 0.4428 - val_loss: 1.5554 - val_accuracy: 0.4368
# Epoch 47/50
# 782/782 [==============================] - 147s 187ms/step - loss: 1.5526 - accuracy: 0.4451 - val_loss: 1.5237 - val_accuracy: 0.4499
# Epoch 48/50
# 782/782 [==============================] - 146s 187ms/step - loss: 1.5504 - accuracy: 0.4451 - val_loss: 1.5553 - val_accuracy: 0.4394
# Epoch 49/50
# 782/782 [==============================] - 146s 187ms/step - loss: 1.5490 - accuracy: 0.4456 - val_loss: 1.5211 - val_accuracy: 0.4526
# Epoch 50/50
# 782/782 [==============================] - 146s 187ms/step - loss: 1.5514 - accuracy: 0.4431 - val_loss: 1.5304 - val_accuracy: 0.4475

# %%
print(f'Training time {round((total_time_1024),3)} sec for {num_epochs} epochs.')
inference_time_1024 = inf_time_check(model_1024, val_ds)
print(f'Inference time {inference_time_1024} ms for {num_val_samples} samples.')
# Out:
# Training time 7283.535 sec for 50 epochs.
# 64/64 [==============================] - 2s 13ms/step
# 64/64 [==============================] - 1s 15ms/step
# 64/64 [==============================] - 1s 17ms/step
# 64/64 [==============================] - 1s 16ms/step
# 64/64 [==============================] - 1s 16ms/step
# Inference time 1229.228 ms for 10000 samples.

# %%
log_name_1024 = '\log\cifar10\ViP\\random_feature_64\L_1024.pkl'
log_path_1024 = main_dir + log_name_1024
with open(log_path_1024, 'wb') as file:
    pickle.dump(history_1024.history, file)

# %%
# plot accuracy curve
plt.plot(history_1024.history["accuracy"], label="Train Accuracy")
plt.plot(history_1024.history["val_accuracy"], label="Validation Accuracy")
plt.title("Train and Validation Accuracy Over Epochs L=1024")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()

# %%
# plot loss curve
plt.plot(history_1024.history["loss"], label="Train Loss")
plt.plot(history_1024.history["val_loss"], label="Validation Loss")
plt.title("Train and Validation Loss Over Epochs L=1024")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# %%
total_time = [total_time_16, total_time_64, total_time_256, total_time_1024]
inference_time = [inference_time_16, inference_time_64, inference_time_256, inference_time_1024]
log = []
log.append(total_time)
log.append(inference_time)
log_name = '\log\cifar10\ViP\\random_feature_64\\total_inf_time'
log_path = main_dir + log_name
# log [total_time, inference_time]
with open(log_path, 'wb') as file:
    pickle.dump(log, file)

# %%
logL = np.log2([16, 64, 256, 1024])

fig, ax1 = plt.subplots()
plt.title(f'Inference time & Total training time over {num_epochs} epochs')
plt.xlabel('log2(L)')

ax1.plot(logL, total_time, color='blue', label='Total training time')
ax1.set_ylabel('Time (sec)', color='blue')
ax1.legend(loc='upper right')

ax2 = ax1.twinx()
ax2.plot(logL, inference_time, color='red', label='Inference time')
ax2.set_ylabel('Time (ms)', color='red')
ax2.legend(loc='upper left')

plt.grid()
plt.show()
