# %% [markdown]
# # ViP Classification on CIFAR-10

# %% [markdown]
# ## random_features=16 with ReLu

# %%
import tensorflow as tf
import tensorflow_addons as tfa
import numpy as np
import matplotlib.pyplot as plt
import time
import datetime
import sys
import os
import pickle

# check GPU
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import tensorflow_datasets as tfds
train_dataset, info = tfds.load('cifar10', split='train', shuffle_files=True, with_info=True)
val_dataset = tfds.load('cifar10', split='test', shuffle_files=False)

# number of samples
num_train_samples = tf.data.experimental.cardinality(train_dataset).numpy()
num_val_samples = tf.data.experimental.cardinality(val_dataset).numpy()
print('Number of training samples:', num_train_samples)
print('Number of validation samples:', num_val_samples)

# size of image
for example in train_dataset.take(1):
    image, label = example['image'], example['label']
print('Image size:', image.shape)

# number of classes
num_classes = info.features['label'].num_classes
print('Number of classes: ', num_classes)
# Out:
# Number of training samples: 50000
# Number of validation samples: 10000
# Image size: (32, 32, 3)
# Number of classes:  10

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
batch_size = 64

def extract_image_and_label(example):
    image, label = example['image'], example['label']
    image = tf.cast(image, tf.float32)
    return image, label

# extract image and label from dataloader
train_ds = train_dataset.map(extract_image_and_label)
val_ds = val_dataset.map(extract_image_and_label)

# batch train_ds and val_ds
train_ds = train_ds.batch(batch_size)
val_ds = val_ds.batch(batch_size)

# input pipeline optimization
train_ds = train_ds.cache().prefetch(AUTOTUNE)
val_ds = val_ds.cache().prefetch(AUTOTUNE)

# %%
curr_dir = os.getcwd() 
parent_dir = os.path.abspath(os.path.join(curr_dir, os.pardir))
implementation_dir = os.path.abspath(os.path.join(parent_dir, os.pardir))
main_dir = os.path.abspath(os.path.join(implementation_dir, os.pardir))
sys.path.append(main_dir)

# %%
from model.vision_performer import VisionPerformer
# compiler attributes
lr = 1e-4
weight_decay = 1e-4
num_epochs = 50

# VisionTransformer attributes
input_shape = image.shape # [32, 32, 3]
image_size = image.shape[0] # 32
num_layers = 6
num_classes = num_classes # 10
d_model = 64
num_heads = 1
mlp_dim = 64
# VisionPerformer attributes
random_features = 16
kernel_transformation = 'relu'

# %% [markdown]
# # L = 16

# %%
patch_size = 8
model_16 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=input_shape),
    VisionPerformer(image_size=image_size, patch_size=patch_size, num_layers=num_layers,
                      num_classes=num_classes, d_model=d_model, num_heads=num_heads, 
                  random_features=random_features, kernel_transformation=kernel_transformation,
                  mlp_dim=mlp_dim),
    tf.keras.layers.Dense(10, activation='softmax')
])

model_16.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
             optimizer=tfa.optimizers.AdamW(learning_rate=lr, weight_decay=weight_decay),
             metrics=['accuracy']) 

model_16.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vision_performer (VisionPer  (None, 10)               169738
#  former)
#
#  dense_39 (Dense)            (None, 10)                110
#
# =================================================================
# Total params: 169,848
# Trainable params: 169,848
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_name = 'L_16'
path = main_dir + '\model_checkpoints\cifar10\ViP\\random_feature_16_relu\\' + model_name

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=path,
    save_best_only=True,
    save_weights_only=True,
    monitor='val_loss',
    mode='min'
)

#train model
start_time = time.time()
history_16 = model_16.fit(
    train_ds,
    epochs=num_epochs,
    validation_data=val_ds,
    callbacks=[model_checkpoint_callback]
)
end_time = time.time()
total_time_16 = end_time-start_time
# Out:
# Epoch 1/50
# 782/782 [==============================] - 66s 69ms/step - loss: 2.1520 - accuracy: 0.1881 - val_loss: 2.0248 - val_accuracy: 0.2432
# Epoch 2/50
# 782/782 [==============================] - 52s 66ms/step - loss: 2.0105 - accuracy: 0.2484 - val_loss: 1.9293 - val_accuracy: 0.2856
# Epoch 3/50
# 782/782 [==============================] - 52s 67ms/step - loss: 1.9291 - accuracy: 0.2832 - val_loss: 1.8505 - val_accuracy: 0.3116
# Epoch 4/50
# 782/782 [==============================] - 53s 67ms/step - loss: 1.8669 - accuracy: 0.3051 - val_loss: 1.8193 - val_accuracy: 0.3308
# Epoch 5/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.8267 - accuracy: 0.3179 - val_loss: 1.7709 - val_accuracy: 0.3473
# Epoch 6/50
# 782/782 [==============================] - 52s 67ms/step - loss: 1.7954 - accuracy: 0.3322 - val_loss: 1.7333 - val_accuracy: 0.3634
# Epoch 7/50
# 782/782 [==============================] - 52s 66ms/step - loss: 1.7651 - accuracy: 0.3502 - val_loss: 1.6950 - val_accuracy: 0.3783
# Epoch 8/50
# 782/782 [==============================] - 52s 67ms/step - loss: 1.7337 - accuracy: 0.3577 - val_loss: 1.6715 - val_accuracy: 0.3911
# Epoch 9/50
# 782/782 [==============================] - 52s 66ms/step - loss: 1.7103 - accuracy: 0.3678 - val_loss: 1.6502 - val_accuracy: 0.4023
# Epoch 10/50
# 782/782 [==============================] - 51s 66ms/step - loss: 1.6850 - accuracy: 0.3796 - val_loss: 1.6228 - val_accuracy: 0.4099
# Epoch 11/50
# 782/782 [==============================] - 52s 66ms/step - loss: 1.6679 - accuracy: 0.3837 - val_loss: 1.6191 - val_accuracy: 0.4071
# Epoch 12/50
# 782/782 [==============================] - 52s 67ms/step - loss: 1.6513 - accuracy: 0.3906 - val_loss: 1.5919 - val_accuracy: 0.4185
# Epoch 13/50
# 782/782 [==============================] - 52s 66ms/step - loss: 1.6336 - accuracy: 0.4003 - val_loss: 1.5832 - val_accuracy: 0.4224
# Epoch 14/50
# 782/782 [==============================] - 52s 66ms/step - loss: 1.6217 - accuracy: 0.4049 - val_loss: 1.5780 - val_accuracy: 0.4284
# Epoch 15/50
# 782/782 [==============================] - 52s 66ms/step - loss: 1.6073 - accuracy: 0.4107 - val_loss: 1.5664 - val_accuracy: 0.4296
# Epoch 16/50
# 782/782 [==============================] - 52s 66ms/step - loss: 1.5937 - accuracy: 0.4168 - val_loss: 1.5527 - val_accuracy: 0.4312
# Epoch 17/50
# 782/782 [==============================] - 51s 66ms/step - loss: 1.5858 - accuracy: 0.4209 - val_loss: 1.5574 - val_accuracy: 0.4344
# Epoch 18/50
# 782/782 [==============================] - 51s 66ms/step - loss: 1.5734 - accuracy: 0.4269 - val_loss: 1.5289 - val_accuracy: 0.4447
# Epoch 19/50
# 782/782 [==============================] - 52s 66ms/step - loss: 1.5644 - accuracy: 0.4293 - val_loss: 1.5300 - val_accuracy: 0.4397
# Epoch 20/50
# 782/782 [==============================] - 51s 66ms/step - loss: 1.5219 - accuracy: 0.4437 - val_loss: 1.5012 - val_accuracy: 0.4515
# Epoch 41/50
# 782/782 [==============================] - 51s 66ms/step - loss: 1.5230 - accuracy: 0.4420 - val_loss: 1.4883 - val_accuracy: 0.4552
# Epoch 42/50
# 782/782 [==============================] - 51s 66ms/step - loss: 1.5202 - accuracy: 0.4437 - val_loss: 1.5009 - val_accuracy: 0.4509
# Epoch 43/50
# 782/782 [==============================] - 51s 66ms/step - loss: 1.5220 - accuracy: 0.4437 - val_loss: 1.5006 - val_accuracy: 0.4461
# Epoch 44/50
# 782/782 [==============================] - 52s 66ms/step - loss: 1.5182 - accuracy: 0.4442 - val_loss: 1.4965 - val_accuracy: 0.4572
# Epoch 45/50
# 782/782 [==============================] - 52s 66ms/step - loss: 1.5236 - accuracy: 0.4414 - val_loss: 1.5187 - val_accuracy: 0.4427
# Epoch 46/50
# 782/782 [==============================] - 52s 66ms/step - loss: 1.5283 - accuracy: 0.4406 - val_loss: 1.4961 - val_accuracy: 0.4558
# Epoch 47/50
# 782/782 [==============================] - 51s 66ms/step - loss: 1.5182 - accuracy: 0.4435 - val_loss: 1.5038 - val_accuracy: 0.4500
# Epoch 48/50
# 782/782 [==============================] - 52s 66ms/step - loss: 1.5194 - accuracy: 0.4427 - val_loss: 1.4891 - val_accuracy: 0.4495
# Epoch 49/50
# 782/782 [==============================] - 51s 65ms/step - loss: 1.5183 - accuracy: 0.4438 - val_loss: 1.5587 - val_accuracy: 0.4261
# Epoch 50/50
# 782/782 [==============================] - 51s 65ms/step - loss: 1.5168 - accuracy: 0.4456 - val_loss: 1.4928 - val_accuracy: 0.4571

# %%
from utils import inf_time_check
print(f'Training time {round((total_time_16),3)} sec for {num_epochs} epochs.')
inference_time_16 = inf_time_check(model_16, val_ds)
print(f'Inference time {inference_time_16} ms for {num_val_samples} samples.')
# Out:
# Training time 2598.131 sec for 50 epochs.
# 64/64 [==============================] - 2s 18ms/step
# 64/64 [==============================] - 1s 16ms/step
# 64/64 [==============================] - 1s 15ms/step
# 64/64 [==============================] - 1s 14ms/step
# 64/64 [==============================] - 1s 16ms/step
# Inference time 1254.51 ms for 10000 samples.

# %%
log_name_16 = '\log\cifar10\ViP\\random_feature_16_relu\L_16.pkl'
log_path_16 = main_dir + log_name_16
with open(log_path_16, 'wb') as file:
    pickle.dump(history_16.history, file)

# %%
# plot accuracy curve
plt.plot(history_16.history["accuracy"], label="Train Accuracy")
plt.plot(history_16.history["val_accuracy"], label="Validation Accuracy")
plt.title("Train and Validation Accuracy Over Epochs L=16")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()

# %%
# plot loss curve
plt.plot(history_16.history["loss"], label="Train Loss")
plt.plot(history_16.history["val_loss"], label="Validation Loss")
plt.title("Train and Validation Loss Over Epochs L=16")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# %% [markdown]
# # L = 64

# %%
patch_size = 4
model_64 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=input_shape),
    VisionPerformer(image_size=image_size, patch_size=patch_size, num_layers=num_layers,
                      num_classes=num_classes, d_model=d_model, num_heads=num_heads, 
                  random_features=random_features, kernel_transformation=kernel_transformation,
                  mlp_dim=mlp_dim),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(10, activation='softmax')
])

model_64.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
             optimizer=tfa.optimizers.AdamW(learning_rate=lr, weight_decay=weight_decay),
             metrics=['accuracy']) 

model_64.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vision_performer_1 (VisionP  (None, 10)               163594
#  erformer)
#
#  flatten (Flatten)           (None, 10)                0
#
#  dense_79 (Dense)            (None, 10)                110
#
# =================================================================
# Total params: 163,704
# Trainable params: 163,704
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_name = 'L_64'
path = main_dir + '\model_checkpoints\cifar10\ViP\\random_feature_16_relu\\' + model_name

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=path,
    save_best_only=True,
    save_weights_only=True,
    monitor='val_loss',
    mode='min'
)

#train model
start_time = time.time()
history_64 = model_64.fit(
    train_ds,
    epochs=num_epochs,
    validation_data=val_ds,
    callbacks=[model_checkpoint_callback]
)
end_time = time.time()
total_time_64 = end_time-start_time
# Out:
# Epoch 1/50
# 782/782 [==============================] - 54s 60ms/step - loss: 2.1372 - accuracy: 0.1928 - val_loss: 2.0076 - val_accuracy: 0.2602
# Epoch 2/50
# 782/782 [==============================] - 46s 58ms/step - loss: 1.9881 - accuracy: 0.2587 - val_loss: 1.9053 - val_accuracy: 0.2967
# Epoch 3/50
# 782/782 [==============================] - 46s 58ms/step - loss: 1.9085 - accuracy: 0.2922 - val_loss: 1.8363 - val_accuracy: 0.3196
# Epoch 4/50
# 782/782 [==============================] - 45s 58ms/step - loss: 1.8416 - accuracy: 0.3179 - val_loss: 1.7789 - val_accuracy: 0.3405
# Epoch 5/50
# 782/782 [==============================] - 46s 58ms/step - loss: 1.7858 - accuracy: 0.3372 - val_loss: 1.7338 - val_accuracy: 0.3579
# Epoch 6/50
# 782/782 [==============================] - 46s 58ms/step - loss: 1.7439 - accuracy: 0.3533 - val_loss: 1.6842 - val_accuracy: 0.3798
# Epoch 7/50
# 782/782 [==============================] - 46s 58ms/step - loss: 1.7100 - accuracy: 0.3659 - val_loss: 1.6590 - val_accuracy: 0.3913
# Epoch 8/50
# 782/782 [==============================] - 46s 59ms/step - loss: 1.6778 - accuracy: 0.3800 - val_loss: 1.6290 - val_accuracy: 0.3955
# Epoch 9/50
# 782/782 [==============================] - 46s 58ms/step - loss: 1.6507 - accuracy: 0.3883 - val_loss: 1.6012 - val_accuracy: 0.4049
# Epoch 10/50
# 782/782 [==============================] - 46s 58ms/step - loss: 1.6219 - accuracy: 0.4033 - val_loss: 1.5875 - val_accuracy: 0.4095
# Epoch 11/50
# 782/782 [==============================] - 45s 58ms/step - loss: 1.5969 - accuracy: 0.4132 - val_loss: 1.5576 - val_accuracy: 0.4231
# Epoch 12/50
# 782/782 [==============================] - 45s 58ms/step - loss: 1.5721 - accuracy: 0.4267 - val_loss: 1.5646 - val_accuracy: 0.4227
# Epoch 13/50
# 782/782 [==============================] - 46s 58ms/step - loss: 1.5504 - accuracy: 0.4344 - val_loss: 1.5280 - val_accuracy: 0.4387
# Epoch 14/50
# 782/782 [==============================] - 45s 58ms/step - loss: 1.5316 - accuracy: 0.4411 - val_loss: 1.5070 - val_accuracy: 0.4506
# Epoch 35/50
# 782/782 [==============================] - 45s 57ms/step - loss: 1.3738 - accuracy: 0.5055 - val_loss: 1.3899 - val_accuracy: 0.4819
# Epoch 36/50
# 782/782 [==============================] - 45s 57ms/step - loss: 1.3794 - accuracy: 0.5026 - val_loss: 1.4111 - val_accuracy: 0.4758
# Epoch 37/50
# 782/782 [==============================] - 45s 58ms/step - loss: 1.3762 - accuracy: 0.5055 - val_loss: 1.3902 - val_accuracy: 0.4856
# Epoch 38/50
# 782/782 [==============================] - 45s 58ms/step - loss: 1.3811 - accuracy: 0.5045 - val_loss: 1.3888 - val_accuracy: 0.4944
# Epoch 39/50
# 782/782 [==============================] - 45s 57ms/step - loss: 1.3748 - accuracy: 0.5063 - val_loss: 1.3791 - val_accuracy: 0.4864
# Epoch 40/50
# 782/782 [==============================] - 45s 57ms/step - loss: 1.3754 - accuracy: 0.5022 - val_loss: 1.3813 - val_accuracy: 0.4941
# Epoch 41/50
# 782/782 [==============================] - 45s 58ms/step - loss: 1.3760 - accuracy: 0.5063 - val_loss: 1.3527 - val_accuracy: 0.5031
# Epoch 42/50
# 782/782 [==============================] - 45s 57ms/step - loss: 1.3759 - accuracy: 0.5032 - val_loss: 1.3488 - val_accuracy: 0.5068
# Epoch 43/50
# 782/782 [==============================] - 45s 57ms/step - loss: 1.3816 - accuracy: 0.5045 - val_loss: 1.3753 - val_accuracy: 0.4917
# Epoch 44/50
# 782/782 [==============================] - 45s 58ms/step - loss: 1.3770 - accuracy: 0.5030 - val_loss: 1.3716 - val_accuracy: 0.4978
# Epoch 45/50
# 782/782 [==============================] - 44s 57ms/step - loss: 1.3774 - accuracy: 0.5055 - val_loss: 1.3841 - val_accuracy: 0.4928
# Epoch 46/50
# 782/782 [==============================] - 45s 58ms/step - loss: 1.3723 - accuracy: 0.5052 - val_loss: 1.3839 - val_accuracy: 0.4875
# Epoch 47/50
# 782/782 [==============================] - 45s 58ms/step - loss: 1.3696 - accuracy: 0.5070 - val_loss: 1.3680 - val_accuracy: 0.4938
# Epoch 48/50
# 782/782 [==============================] - 45s 58ms/step - loss: 1.3725 - accuracy: 0.5046 - val_loss: 1.3756 - val_accuracy: 0.4911
# Epoch 49/50
# 782/782 [==============================] - 45s 58ms/step - loss: 1.3740 - accuracy: 0.5045 - val_loss: 1.3948 - val_accuracy: 0.4859
# Epoch 50/50
# 782/782 [==============================] - 45s 58ms/step - loss: 1.3740 - accuracy: 0.5046 - val_loss: 1.3470 - val_accuracy: 0.5067

# %%
print(f'Training time {round((total_time_64),3)} sec for {num_epochs} epochs.')
inference_time_64 = inf_time_check(model_64, val_ds)
print(f'Inference time {inference_time_64} ms for {num_val_samples} samples.')
# Out:
# Training time 2270.181 sec for 50 epochs.
# 64/64 [==============================] - 2s 16ms/step
# 64/64 [==============================] - 1s 14ms/step
# 64/64 [==============================] - 1s 14ms/step
# 64/64 [==============================] - 1s 15ms/step
# 64/64 [==============================] - 1s 15ms/step
# Inference time 1164.414 ms for 10000 samples.

# %%
log_name_64 = '\log\cifar10\ViP\\random_feature_16_relu\L_64.pkl'
log_path_64 = main_dir + log_name_64
with open(log_path_64, 'wb') as file:
    pickle.dump(history_64.history, file)

# %%
# plot accuracy curve
plt.plot(history_64.history["accuracy"], label="Train Accuracy")
plt.plot(history_64.history["val_accuracy"], label="Validation Accuracy")
plt.title("Train and Validation Accuracy Over Epochs L=64")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()

# %%
# plot loss curve
plt.plot(history_64.history["loss"], label="Train Loss")
plt.plot(history_64.history["val_loss"], label="Validation Loss")
plt.title("Train and Validation Loss Over Epochs L=64")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# %% [markdown]
# # L = 256

# %%
patch_size = 2
model_256 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=input_shape),
    VisionPerformer(image_size=image_size, patch_size=patch_size, num_layers=num_layers,
                      num_classes=num_classes, d_model=d_model, num_heads=num_heads, 
                  random_features=random_features, kernel_transformation=kernel_transformation,
                  mlp_dim=mlp_dim),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(10, activation='softmax')
])

model_256.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
             optimizer=tfa.optimizers.AdamW(learning_rate=lr, weight_decay=weight_decay),
             metrics=['accuracy']) 

model_256.summary()
# Out:
# Model: "sequential_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vision_performer_2 (VisionP  (None, 10)               173578
#  erformer)
#
#  flatten_1 (Flatten)         (None, 10)                0
#
#  dense_119 (Dense)           (None, 10)                110
#
# =================================================================
# Total params: 173,688
# Trainable params: 173,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_name = 'L_256'
path = main_dir + '\model_checkpoints\cifar10\ViP\\random_feature_16_relu\\' + model_name

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=path,
    save_best_only=True,
    save_weights_only=True,
    monitor='val_loss',
    mode='min'
)

#train model
start_time = time.time()
history_256 = model_256.fit(
    train_ds,
    epochs=num_epochs,
    validation_data=val_ds,
    callbacks=[model_checkpoint_callback]
)
end_time = time.time()
total_time_256 = end_time-start_time
# Out:
# Epoch 1/50
# 782/782 [==============================] - 62s 70ms/step - loss: 2.1621 - accuracy: 0.1861 - val_loss: 2.0243 - val_accuracy: 0.2631
# Epoch 2/50
# 782/782 [==============================] - 53s 68ms/step - loss: 2.0089 - accuracy: 0.2545 - val_loss: 1.9286 - val_accuracy: 0.2888
# Epoch 3/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.9183 - accuracy: 0.2877 - val_loss: 1.8570 - val_accuracy: 0.3199
# Epoch 4/50
# 782/782 [==============================] - 53s 67ms/step - loss: 1.8456 - accuracy: 0.3200 - val_loss: 1.8076 - val_accuracy: 0.3388
# Epoch 5/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.7960 - accuracy: 0.3362 - val_loss: 1.7451 - val_accuracy: 0.3632
# Epoch 6/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.7586 - accuracy: 0.3539 - val_loss: 1.7165 - val_accuracy: 0.3777
# Epoch 7/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.7223 - accuracy: 0.3680 - val_loss: 1.6763 - val_accuracy: 0.3906
# Epoch 8/50
# 782/782 [==============================] - 54s 68ms/step - loss: 1.6949 - accuracy: 0.3807 - val_loss: 1.6446 - val_accuracy: 0.3977
# Epoch 9/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.6645 - accuracy: 0.3894 - val_loss: 1.6331 - val_accuracy: 0.4028
# Epoch 10/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.6344 - accuracy: 0.4011 - val_loss: 1.6049 - val_accuracy: 0.4137
# Epoch 11/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.6106 - accuracy: 0.4133 - val_loss: 1.5842 - val_accuracy: 0.4229
# Epoch 12/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.5859 - accuracy: 0.4216 - val_loss: 1.5694 - val_accuracy: 0.4308
# Epoch 13/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.5618 - accuracy: 0.4322 - val_loss: 1.5210 - val_accuracy: 0.4455
# Epoch 14/50
# 782/782 [==============================] - 53s 67ms/step - loss: 1.5376 - accuracy: 0.4428 - val_loss: 1.5142 - val_accuracy: 0.4490
# Epoch 15/50
# 782/782 [==============================] - 52s 67ms/step - loss: 1.5188 - accuracy: 0.4508 - val_loss: 1.5169 - val_accuracy: 0.4521
# Epoch 16/50
# 782/782 [==============================] - 53s 67ms/step - loss: 1.4992 - accuracy: 0.4601 - val_loss: 1.4736 - val_accuracy: 0.4714
# Epoch 17/50
# 782/782 [==============================] - 52s 67ms/step - loss: 1.4890 - accuracy: 0.4662 - val_loss: 1.4758 - val_accuracy: 0.4699
# Epoch 18/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.4708 - accuracy: 0.4703 - val_loss: 1.4534 - val_accuracy: 0.4749
# Epoch 19/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.4629 - accuracy: 0.4739 - val_loss: 1.5102 - val_accuracy: 0.4606
# Epoch 20/50
# 782/782 [==============================] - 54s 68ms/step - loss: 1.4500 - accuracy: 0.4803 - val_loss: 1.4240 - val_accuracy: 0.4961
# Epoch 21/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.4388 - accuracy: 0.4844 - val_loss: 1.4392 - val_accuracy: 0.4855
# Epoch 22/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.4292 - accuracy: 0.4890 - val_loss: 1.4080 - val_accuracy: 0.4990
# Epoch 23/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.4102 - accuracy: 0.4957 - val_loss: 1.3966 - val_accuracy: 0.4971
# Epoch 24/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.4049 - accuracy: 0.4957 - val_loss: 1.3795 - val_accuracy: 0.5002
# Epoch 25/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.3903 - accuracy: 0.5013 - val_loss: 1.3885 - val_accuracy: 0.4965
# Epoch 26/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.3783 - accuracy: 0.5062 - val_loss: 1.3603 - val_accuracy: 0.5066
# Epoch 27/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.3746 - accuracy: 0.5087 - val_loss: 1.3770 - val_accuracy: 0.5021
# Epoch 28/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.3645 - accuracy: 0.5134 - val_loss: 1.3880 - val_accuracy: 0.5003
# Epoch 29/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.3565 - accuracy: 0.5167 - val_loss: 1.3417 - val_accuracy: 0.5116
# Epoch 30/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.3554 - accuracy: 0.5165 - val_loss: 1.3302 - val_accuracy: 0.5188
# Epoch 31/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.3473 - accuracy: 0.5182 - val_loss: 1.3652 - val_accuracy: 0.5110
# Epoch 32/50
# 782/782 [==============================] - 52s 67ms/step - loss: 1.3509 - accuracy: 0.5188 - val_loss: 1.3541 - val_accuracy: 0.5038
# Epoch 33/50
# 782/782 [==============================] - 53s 67ms/step - loss: 1.3447 - accuracy: 0.5220 - val_loss: 1.3715 - val_accuracy: 0.5008
# Epoch 34/50
# 782/782 [==============================] - 53s 67ms/step - loss: 1.3468 - accuracy: 0.5205 - val_loss: 1.3169 - val_accuracy: 0.5291
# Epoch 35/50
# 782/782 [==============================] - 52s 67ms/step - loss: 1.3452 - accuracy: 0.5192 - val_loss: 1.3708 - val_accuracy: 0.4942
# Epoch 36/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.3500 - accuracy: 0.5176 - val_loss: 1.3666 - val_accuracy: 0.5054
# Epoch 37/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.3463 - accuracy: 0.5227 - val_loss: 1.3205 - val_accuracy: 0.5238
# Epoch 38/50
# 782/782 [==============================] - 52s 67ms/step - loss: 1.3416 - accuracy: 0.5217 - val_loss: 1.3616 - val_accuracy: 0.5014
# Epoch 39/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.3357 - accuracy: 0.5233 - val_loss: 1.3002 - val_accuracy: 0.5290
# Epoch 40/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.3428 - accuracy: 0.5192 - val_loss: 1.3481 - val_accuracy: 0.5060
# Epoch 41/50
# 782/782 [==============================] - 54s 69ms/step - loss: 1.3374 - accuracy: 0.5216 - val_loss: 1.2992 - val_accuracy: 0.5316
# Epoch 42/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.3309 - accuracy: 0.5270 - val_loss: 1.3346 - val_accuracy: 0.5186
# Epoch 43/50
# 782/782 [==============================] - 53s 67ms/step - loss: 1.3351 - accuracy: 0.5231 - val_loss: 1.3056 - val_accuracy: 0.5244
# Epoch 44/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.3397 - accuracy: 0.5220 - val_loss: 1.3219 - val_accuracy: 0.5210
# Epoch 45/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.3297 - accuracy: 0.5275 - val_loss: 1.3067 - val_accuracy: 0.5299
# Epoch 46/50
# 782/782 [==============================] - 53s 67ms/step - loss: 1.3289 - accuracy: 0.5267 - val_loss: 1.3039 - val_accuracy: 0.5317
# Epoch 47/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.3264 - accuracy: 0.5259 - val_loss: 1.3086 - val_accuracy: 0.5252
# Epoch 48/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.3195 - accuracy: 0.5294 - val_loss: 1.3538 - val_accuracy: 0.4962
# Epoch 49/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.3243 - accuracy: 0.5255 - val_loss: 1.3571 - val_accuracy: 0.5168
# Epoch 50/50
# 782/782 [==============================] - 53s 68ms/step - loss: 1.3245 - accuracy: 0.5241 - val_loss: 1.3233 - val_accuracy: 0.5261

# %%
from utils import inf_time_check
print(f'Training time {round((total_time_256),3)} sec for {num_epochs} epochs.')
inference_time_256 = inf_time_check(model_256, val_ds)
print(f'Inference time {inference_time_256} ms for {num_val_samples} samples.')
# Out:
# Training time 2661.717 sec for 50 epochs.
# 64/64 [==============================] - 2s 11ms/step
# 64/64 [==============================] - 1s 11ms/step
# 64/64 [==============================] - 1s 12ms/step
# 64/64 [==============================] - 1s 12ms/step
# 64/64 [==============================] - 1s 13ms/step
# Inference time 987.478 ms for 10000 samples.

# %%
log_name_256 = '\log\cifar10\ViP\\random_feature_16_relu\L_256.pkl'
log_path_256 = main_dir + log_name_256
with open(log_path_256, 'wb') as file:
    pickle.dump(history_256.history, file)

# %%
# plot accuracy curve
plt.plot(history_256.history["accuracy"], label="Train Accuracy")
plt.plot(history_256.history["val_accuracy"], label="Validation Accuracy")
plt.title("Train and Validation Accuracy Over Epochs L=256")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()

# %%
# plot loss curve
plt.plot(history_256.history["loss"], label="Train Loss")
plt.plot(history_256.history["val_loss"], label="Validation Loss")
plt.title("Train and Validation Loss Over Epochs L=256")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# %% [markdown]
# # L = 1024

# %%
patch_size = 1
model_1024 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=input_shape),
    VisionPerformer(image_size=image_size, patch_size=patch_size, num_layers=num_layers,
                      num_classes=num_classes, d_model=d_model, num_heads=num_heads, 
                  random_features=random_features, kernel_transformation=kernel_transformation,
                  mlp_dim=mlp_dim),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(10, activation='softmax')
])

model_1024.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
             optimizer=tfa.optimizers.AdamW(learning_rate=lr, weight_decay=weight_decay),
             metrics=['accuracy']) 

model_1024.summary()
# Out:
# Model: "sequential_31"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vision_performer_3 (VisionP  (None, 10)               222154
#  erformer)
#
#  flatten_2 (Flatten)         (None, 10)                0
#
#  dense_159 (Dense)           (None, 10)                110
#
# =================================================================
# Total params: 222,264
# Trainable params: 222,264
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_name = 'L_1024'
path = main_dir + '\model_checkpoints\cifar10\ViP\\random_feature_16_relu\\' + model_name

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=path,
    save_best_only=True,
    save_weights_only=True,
    monitor='val_loss',
    mode='min'
)

#train model
start_time = time.time()
history_1024 = model_1024.fit(
    train_ds,
    epochs=num_epochs,
    validation_data=val_ds,
    callbacks=[model_checkpoint_callback]
)
end_time = time.time()
total_time_1024 = end_time-start_time
# Out:
# Epoch 1/50
# 782/782 [==============================] - 122s 146ms/step - loss: 2.1248 - accuracy: 0.1948 - val_loss: 2.0123 - val_accuracy: 0.2478
# Epoch 2/50
# 782/782 [==============================] - 113s 145ms/step - loss: 1.9824 - accuracy: 0.2495 - val_loss: 1.9302 - val_accuracy: 0.2869
# Epoch 3/50
# 782/782 [==============================] - 113s 145ms/step - loss: 1.9195 - accuracy: 0.2873 - val_loss: 1.8837 - val_accuracy: 0.3087
# Epoch 4/50
# 782/782 [==============================] - 113s 145ms/step - loss: 1.8678 - accuracy: 0.3107 - val_loss: 1.8665 - val_accuracy: 0.3166
# Epoch 5/50
# 782/782 [==============================] - 113s 145ms/step - loss: 1.8274 - accuracy: 0.3288 - val_loss: 1.8114 - val_accuracy: 0.3398
# Epoch 6/50
# 782/782 [==============================] - 113s 144ms/step - loss: 1.7949 - accuracy: 0.3407 - val_loss: 1.7586 - val_accuracy: 0.3567
# Epoch 7/50
# 782/782 [==============================] - 113s 145ms/step - loss: 1.7696 - accuracy: 0.3517 - val_loss: 1.7505 - val_accuracy: 0.3636
# Epoch 8/50
# 782/782 [==============================] - 113s 145ms/step - loss: 1.7474 - accuracy: 0.3621 - val_loss: 1.7146 - val_accuracy: 0.3770
# Epoch 9/50
# 782/782 [==============================] - 113s 145ms/step - loss: 1.7277 - accuracy: 0.3709 - val_loss: 1.7009 - val_accuracy: 0.3830
# Epoch 10/50
# 782/782 [==============================] - 113s 144ms/step - loss: 1.7090 - accuracy: 0.3804 - val_loss: 1.6897 - val_accuracy: 0.3891
# Epoch 11/50
# 782/782 [==============================] - 113s 144ms/step - loss: 1.6929 - accuracy: 0.3873 - val_loss: 1.6837 - val_accuracy: 0.3942
# Epoch 12/50
# 782/782 [==============================] - 113s 144ms/step - loss: 1.6702 - accuracy: 0.3970 - val_loss: 1.6315 - val_accuracy: 0.4192
# Epoch 13/50
# 782/782 [==============================] - 113s 145ms/step - loss: 1.6509 - accuracy: 0.4048 - val_loss: 1.6170 - val_accuracy: 0.4207
# Epoch 14/50
# 782/782 [==============================] - 113s 145ms/step - loss: 1.6280 - accuracy: 0.4156 - val_loss: 1.5971 - val_accuracy: 0.4314
# Epoch 15/50
# 782/782 [==============================] - 113s 145ms/step - loss: 1.6107 - accuracy: 0.4222 - val_loss: 1.5894 - val_accuracy: 0.4278
# Epoch 16/50
# 782/782 [==============================] - 113s 144ms/step - loss: 1.5946 - accuracy: 0.4276 - val_loss: 1.5963 - val_accuracy: 0.4288
# Epoch 17/50
# 782/782 [==============================] - 113s 145ms/step - loss: 1.5750 - accuracy: 0.4367 - val_loss: 1.5767 - val_accuracy: 0.4366
# Epoch 18/50
# 782/782 [==============================] - 113s 145ms/step - loss: 1.5625 - accuracy: 0.4414 - val_loss: 1.5404 - val_accuracy: 0.4486
# Epoch 19/50
# 782/782 [==============================] - 113s 144ms/step - loss: 1.5491 - accuracy: 0.4446 - val_loss: 1.5413 - val_accuracy: 0.4461
# Epoch 20/50
# 782/782 [==============================] - 113s 145ms/step - loss: 1.5384 - accuracy: 0.4488 - val_loss: 1.5297 - val_accuracy: 0.4514
# Epoch 21/50
# 782/782 [==============================] - 113s 145ms/step - loss: 1.5380 - accuracy: 0.4487 - val_loss: 1.5247 - val_accuracy: 0.4551
# Epoch 22/50
# 782/782 [==============================] - 113s 144ms/step - loss: 1.5302 - accuracy: 0.4525 - val_loss: 1.5081 - val_accuracy: 0.4613
# Epoch 23/50
# 782/782 [==============================] - 113s 145ms/step - loss: 1.5225 - accuracy: 0.4547 - val_loss: 1.5073 - val_accuracy: 0.4583
# Epoch 44/50
# 782/782 [==============================] - 113s 145ms/step - loss: 1.4728 - accuracy: 0.4714 - val_loss: 1.4770 - val_accuracy: 0.4640
# Epoch 45/50
# 782/782 [==============================] - 113s 144ms/step - loss: 1.4680 - accuracy: 0.4760 - val_loss: 1.5235 - val_accuracy: 0.4444
# Epoch 46/50
# 782/782 [==============================] - 113s 144ms/step - loss: 1.4667 - accuracy: 0.4740 - val_loss: 1.4963 - val_accuracy: 0.4554
# Epoch 47/50
# 782/782 [==============================] - 113s 144ms/step - loss: 1.4628 - accuracy: 0.4758 - val_loss: 1.4895 - val_accuracy: 0.4582
# Epoch 48/50
# 782/782 [==============================] - 113s 144ms/step - loss: 1.4609 - accuracy: 0.4753 - val_loss: 1.5371 - val_accuracy: 0.4358
# Epoch 49/50
# 782/782 [==============================] - 113s 144ms/step - loss: 1.4669 - accuracy: 0.4746 - val_loss: 1.4882 - val_accuracy: 0.4561
# Epoch 50/50
# 782/782 [==============================] - 113s 145ms/step - loss: 1.4649 - accuracy: 0.4741 - val_loss: 1.4674 - val_accuracy: 0.4719

# %%
print(f'Training time {round((total_time_1024),3)} sec for {num_epochs} epochs.')
inference_time_1024 = inf_time_check(model_1024, val_ds)
print(f'Inference time {inference_time_1024} ms for {num_val_samples} samples.')
# Out:
# Training time 5654.462 sec for 50 epochs.
# 64/64 [==============================] - 2s 11ms/step
# 64/64 [==============================] - 1s 12ms/step
# 64/64 [==============================] - 1s 12ms/step
# 64/64 [==============================] - 1s 12ms/step
# 64/64 [==============================] - 1s 12ms/step
# Inference time 967.568 ms for 10000 samples.

# %%
log_name_1024 = '\log\cifar10\ViP\\random_feature_16_relu\L_1024.pkl'
log_path_1024 = main_dir + log_name_1024
with open(log_path_1024, 'wb') as file:
    pickle.dump(history_1024.history, file)

# %%
# plot accuracy curve
plt.plot(history_1024.history["accuracy"], label="Train Accuracy")
plt.plot(history_1024.history["val_accuracy"], label="Validation Accuracy")
plt.title("Train and Validation Accuracy Over Epochs L=1024")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()

# %%
# plot loss curve
plt.plot(history_1024.history["loss"], label="Train Loss")
plt.plot(history_1024.history["val_loss"], label="Validation Loss")
plt.title("Train and Validation Loss Over Epochs L=1024")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# %%
total_time = [total_time_16, total_time_64, total_time_256, total_time_1024]
inference_time = [inference_time_16, inference_time_64, inference_time_256, inference_time_1024]
log = []
log.append(total_time)
log.append(inference_time)
log_name = '\log\cifar10\ViP\\random_feature_16_relu\\total_inf_time'
log_path = main_dir + log_name
# log [total_time, inference_time]
with open(log_path, 'wb') as file:
    pickle.dump(log, file)

# %%
logL = np.log2([16, 64, 256, 1024])

fig, ax1 = plt.subplots()
plt.title(f'Inference time & Total training time over {num_epochs} epochs')
plt.xlabel('log2(L)')

ax1.plot(logL, total_time, color='blue', label='Total training time')
ax1.set_ylabel('Time (sec)', color='blue')
ax1.legend(loc='upper right')

ax2 = ax1.twinx()
ax2.plot(logL, inference_time, color='red', label='Inference time')
ax2.set_ylabel('Time (ms)', color='red')
ax2.legend(loc='upper left')

plt.grid()
plt.show()
