# %% [markdown]
# # ViT Classification on fashion_mnist

# %%
import tensorflow as tf
import tensorflow_addons as tfa
import numpy as np
import matplotlib.pyplot as plt
import time
import datetime
import sys
import os
import pickle

# check GPU
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import tensorflow_datasets as tfds
train_dataset, info = tfds.load('fashion_mnist', split='train', shuffle_files=True, with_info=True)
val_dataset = tfds.load('fashion_mnist', split='test', shuffle_files=False)

# number of samples
num_train_samples = tf.data.experimental.cardinality(train_dataset).numpy()
num_val_samples = tf.data.experimental.cardinality(val_dataset).numpy()
print('Number of training samples:', num_train_samples)
print('Number of validation samples:', num_val_samples)

# size of image
for example in train_dataset.take(1):
    image, label = example['image'], example['label']
print('Image size:', image.shape)

# number of classes
num_classes = info.features['label'].num_classes
print('Number of classes: ', num_classes)
# Out:
# Number of training samples: 60000
# Number of validation samples: 10000
# Image size: (28, 28, 1)
# Number of classes:  10

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
batch_size = 64

def extract_image_and_label(example):
    image, label = example['image'], example['label']
    image = tf.cast(image, tf.float32)
    return image, label

# extract image and label from dataloader
train_ds = train_dataset.map(extract_image_and_label)
val_ds = val_dataset.map(extract_image_and_label)

# batch train_ds and val_ds
train_ds = train_ds.batch(batch_size)
val_ds = val_ds.batch(batch_size)

# input pipeline optimization
train_ds = train_ds.cache().prefetch(AUTOTUNE)
val_ds = val_ds.cache().prefetch(AUTOTUNE)

# %%
curr_dir = os.getcwd() 
parent_dir = os.path.abspath(os.path.join(curr_dir, os.pardir))
implementation_dir = os.path.abspath(os.path.join(parent_dir, os.pardir))
main_dir = os.path.abspath(os.path.join(implementation_dir, os.pardir))

sys.path.append(main_dir)

# %%
from model.vision_transformer import VisionTransformer
# compiler attributes
lr = 1e-4
weight_decay = 1e-4
num_epochs = 30

# VisionTransformer attributes
input_shape = image.shape # [28, 28, 1]
image_size = image.shape[0] # 28
channels = image.shape[2] # 1
num_layers = 6
num_classes = num_classes # 10
d_model = 64
num_heads = 1
mlp_dim = 64

# %% [markdown]
# # L = 16

# %%
patch_size = 8
model_16 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=input_shape),
    VisionTransformer(image_size=image_size, patch_size=patch_size, num_layers=num_layers, num_classes=num_classes, 
                      d_model=d_model, num_heads=num_heads, mlp_dim=mlp_dim, channels=channels),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(10, activation='softmax')
])

model_16.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
             optimizer=tfa.optimizers.AdamW(learning_rate=lr, weight_decay=weight_decay),
             metrics=['accuracy']) 

model_16.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vision_transformer (VisionT  (None, 10)               161098
#  ransformer)
#
#  flatten (Flatten)           (None, 10)                0
#
#  dense_39 (Dense)            (None, 10)                110
#
# =================================================================
# Total params: 161,208
# Trainable params: 161,208
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_name = 'L_16'
path = main_dir + '\model_checkpoints\\fashion_mnist\ViT\\' + model_name

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=path,
    save_best_only=True,
    save_weights_only=True,
    monitor='val_loss',
    mode='min'
)

#train model
start_time = time.time()
history_16 = model_16.fit(
    train_ds,
    epochs=num_epochs,
    validation_data=val_ds,
    callbacks=[model_checkpoint_callback]
)
end_time = time.time()
total_time_16 = end_time-start_time
# Out:
# Epoch 1/30
# 938/938 [==============================] - 66s 63ms/step - loss: 1.0973 - accuracy: 0.6131 - val_loss: 0.7478 - val_accuracy: 0.7382
# Epoch 2/30
# 938/938 [==============================] - 58s 61ms/step - loss: 0.7258 - accuracy: 0.7491 - val_loss: 0.6230 - val_accuracy: 0.7778
# Epoch 3/30
# 938/938 [==============================] - 58s 62ms/step - loss: 0.6316 - accuracy: 0.7809 - val_loss: 0.5757 - val_accuracy: 0.7917
# Epoch 4/30
# 938/938 [==============================] - 58s 61ms/step - loss: 0.5890 - accuracy: 0.7929 - val_loss: 0.5507 - val_accuracy: 0.7994
# Epoch 5/30
# 938/938 [==============================] - 58s 62ms/step - loss: 0.5631 - accuracy: 0.8021 - val_loss: 0.5334 - val_accuracy: 0.8059
# Epoch 6/30
# 938/938 [==============================] - 58s 61ms/step - loss: 0.5462 - accuracy: 0.8083 - val_loss: 0.5176 - val_accuracy: 0.8125
# Epoch 7/30
# 938/938 [==============================] - 58s 61ms/step - loss: 0.5325 - accuracy: 0.8127 - val_loss: 0.5145 - val_accuracy: 0.8150
# Epoch 8/30
# 938/938 [==============================] - 57s 61ms/step - loss: 0.5237 - accuracy: 0.8164 - val_loss: 0.5037 - val_accuracy: 0.8161
# Epoch 9/30
# 938/938 [==============================] - 56s 60ms/step - loss: 0.5194 - accuracy: 0.8158 - val_loss: 0.5071 - val_accuracy: 0.8151
# Epoch 10/30
# 938/938 [==============================] - 57s 61ms/step - loss: 0.5124 - accuracy: 0.8196 - val_loss: 0.4981 - val_accuracy: 0.8189
# Epoch 11/30
# 938/938 [==============================] - 57s 61ms/step - loss: 0.5089 - accuracy: 0.8203 - val_loss: 0.4937 - val_accuracy: 0.8189
# Epoch 12/30
# 938/938 [==============================] - 57s 61ms/step - loss: 0.5051 - accuracy: 0.8201 - val_loss: 0.4922 - val_accuracy: 0.8198
# Epoch 13/30
# 938/938 [==============================] - 58s 62ms/step - loss: 0.5023 - accuracy: 0.8219 - val_loss: 0.4886 - val_accuracy: 0.8217
# Epoch 14/30
# 938/938 [==============================] - 57s 60ms/step - loss: 0.4963 - accuracy: 0.8234 - val_loss: 0.4848 - val_accuracy: 0.8249
# Epoch 15/30
# 938/938 [==============================] - 57s 61ms/step - loss: 0.4940 - accuracy: 0.8263 - val_loss: 0.4871 - val_accuracy: 0.8236
# Epoch 16/30
# 938/938 [==============================] - 56s 60ms/step - loss: 0.4917 - accuracy: 0.8262 - val_loss: 0.4879 - val_accuracy: 0.8224
# Epoch 17/30
# 938/938 [==============================] - 57s 60ms/step - loss: 0.4882 - accuracy: 0.8290 - val_loss: 0.4961 - val_accuracy: 0.8206
# Epoch 18/30
# 938/938 [==============================] - 56s 60ms/step - loss: 0.4858 - accuracy: 0.8286 - val_loss: 0.4889 - val_accuracy: 0.8207
# Epoch 19/30
# 938/938 [==============================] - 57s 61ms/step - loss: 0.4854 - accuracy: 0.8295 - val_loss: 0.4881 - val_accuracy: 0.8206
# Epoch 20/30
# 938/938 [==============================] - 57s 61ms/step - loss: 0.4842 - accuracy: 0.8296 - val_loss: 0.4941 - val_accuracy: 0.8216
# Epoch 21/30
# 938/938 [==============================] - 57s 60ms/step - loss: 0.4858 - accuracy: 0.8284 - val_loss: 0.5009 - val_accuracy: 0.8155
# Epoch 22/30
# 938/938 [==============================] - 57s 61ms/step - loss: 0.4836 - accuracy: 0.8293 - val_loss: 0.4975 - val_accuracy: 0.8162
# Epoch 23/30
# 938/938 [==============================] - 56s 59ms/step - loss: 0.4837 - accuracy: 0.8294 - val_loss: 0.4922 - val_accuracy: 0.8205
# Epoch 24/30
# 938/938 [==============================] - 57s 61ms/step - loss: 0.4865 - accuracy: 0.8288 - val_loss: 0.4893 - val_accuracy: 0.8237
# Epoch 25/30
# 938/938 [==============================] - 57s 61ms/step - loss: 0.4840 - accuracy: 0.8301 - val_loss: 0.4896 - val_accuracy: 0.8248
# Epoch 26/30
# 938/938 [==============================] - 57s 60ms/step - loss: 0.4860 - accuracy: 0.8283 - val_loss: 0.4911 - val_accuracy: 0.8259
# Epoch 27/30
# 938/938 [==============================] - 57s 61ms/step - loss: 0.4845 - accuracy: 0.8304 - val_loss: 0.5022 - val_accuracy: 0.8189
# Epoch 28/30
# 938/938 [==============================] - 57s 61ms/step - loss: 0.4871 - accuracy: 0.8276 - val_loss: 0.4854 - val_accuracy: 0.8236
# Epoch 29/30
# 938/938 [==============================] - 57s 60ms/step - loss: 0.4864 - accuracy: 0.8307 - val_loss: 0.5054 - val_accuracy: 0.8179
# Epoch 30/30
# 938/938 [==============================] - 57s 60ms/step - loss: 0.4871 - accuracy: 0.8292 - val_loss: 0.4960 - val_accuracy: 0.8262

# %%
from utils import inf_time_check
print(f'Training time {round((total_time_16),3)} sec for {num_epochs} epochs.')
inference_time_16 = inf_time_check(model_16, val_ds)
print(f'Inference time {inference_time_16} ms for {num_val_samples} samples.')
# Out:
# Training time 1720.745 sec for 30 epochs.
# 64/64 [==============================] - 2s 14ms/step
# 64/64 [==============================] - 1s 13ms/step
# 64/64 [==============================] - 1s 13ms/step
# 64/64 [==============================] - 1s 13ms/step
# 64/64 [==============================] - 1s 13ms/step
# Inference time 1042.215 ms for 10000 samples.

# %%
log_name_16 = '\log\\fashion_mnist\ViT\L_16.pkl'
log_path_16 = main_dir + log_name_16
with open(log_path_16, 'wb') as file:
    pickle.dump(history_16.history, file)

# %%
# plot accuracy curve
plt.plot(history_16.history["accuracy"], label="Train Accuracy")
plt.plot(history_16.history["val_accuracy"], label="Validation Accuracy")
plt.title("Train and Validation Accuracy Over Epochs L=16")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()

# %%
# plot loss curve
plt.plot(history_16.history["loss"], label="Train Loss")
plt.plot(history_16.history["val_loss"], label="Validation Loss")
plt.title("Train and Validation Loss Over Epochs L=16")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# %% [markdown]
# # L = 64

# %%
patch_size = 4
model_64 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=input_shape),
    VisionTransformer(image_size=image_size, patch_size=patch_size, num_layers=num_layers, num_classes=num_classes, 
                      d_model=d_model, num_heads=num_heads, mlp_dim=mlp_dim, channels=channels),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(10, activation='softmax')
])

model_64.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
             optimizer=tfa.optimizers.AdamW(learning_rate=lr, weight_decay=weight_decay),
             metrics=['accuracy']) 

model_64.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vision_transformer_1 (Visio  (None, 10)               160586
#  nTransformer)
#
#  flatten_1 (Flatten)         (None, 10)                0
#
#  dense_79 (Dense)            (None, 10)                110
#
# =================================================================
# Total params: 160,696
# Trainable params: 160,696
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_name = 'L_64'
path = main_dir + '\model_checkpoints\\fashion_mnist\ViT\\' + model_name

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=path,
    save_best_only=True,
    save_weights_only=True,
    monitor='val_loss',
    mode='min'
)

#train model
start_time = time.time()
history_64 = model_64.fit(
    train_ds,
    epochs=num_epochs,
    validation_data=val_ds,
    callbacks=[model_checkpoint_callback]
)
end_time = time.time()
total_time_64 = end_time-start_time
# Out:
# Epoch 1/30
# 938/938 [==============================] - 59s 56ms/step - loss: 1.1577 - accuracy: 0.5819 - val_loss: 0.7024 - val_accuracy: 0.7505
# Epoch 2/30
# 938/938 [==============================] - 50s 53ms/step - loss: 0.6647 - accuracy: 0.7667 - val_loss: 0.5822 - val_accuracy: 0.7905
# Epoch 3/30
# 938/938 [==============================] - 50s 54ms/step - loss: 0.5828 - accuracy: 0.7991 - val_loss: 0.5463 - val_accuracy: 0.8054
# Epoch 4/30
# 938/938 [==============================] - 50s 54ms/step - loss: 0.5484 - accuracy: 0.8089 - val_loss: 0.5384 - val_accuracy: 0.8072
# Epoch 5/30
# 938/938 [==============================] - 50s 53ms/step - loss: 0.5265 - accuracy: 0.8159 - val_loss: 0.5240 - val_accuracy: 0.8141
# Epoch 6/30
# 938/938 [==============================] - 50s 53ms/step - loss: 0.5150 - accuracy: 0.8211 - val_loss: 0.5210 - val_accuracy: 0.8166
# Epoch 7/30
# 938/938 [==============================] - 50s 53ms/step - loss: 0.5071 - accuracy: 0.8236 - val_loss: 0.5212 - val_accuracy: 0.8130
# Epoch 8/30
# 938/938 [==============================] - 51s 55ms/step - loss: 0.4984 - accuracy: 0.8272 - val_loss: 0.5147 - val_accuracy: 0.8162
# Epoch 9/30
# 938/938 [==============================] - 50s 54ms/step - loss: 0.4940 - accuracy: 0.8275 - val_loss: 0.5294 - val_accuracy: 0.8106
# Epoch 10/30
# 938/938 [==============================] - 50s 54ms/step - loss: 0.4900 - accuracy: 0.8288 - val_loss: 0.5250 - val_accuracy: 0.8114
# Epoch 11/30
# 938/938 [==============================] - 50s 54ms/step - loss: 0.4869 - accuracy: 0.8318 - val_loss: 0.5003 - val_accuracy: 0.8204
# Epoch 12/30
# 938/938 [==============================] - 50s 53ms/step - loss: 0.4828 - accuracy: 0.8323 - val_loss: 0.5069 - val_accuracy: 0.8176
# Epoch 13/30
# 938/938 [==============================] - 50s 53ms/step - loss: 0.4796 - accuracy: 0.8331 - val_loss: 0.4840 - val_accuracy: 0.8248
# Epoch 14/30
# 938/938 [==============================] - 50s 54ms/step - loss: 0.4824 - accuracy: 0.8329 - val_loss: 0.4775 - val_accuracy: 0.8266
# Epoch 15/30
# 938/938 [==============================] - 49s 52ms/step - loss: 0.4784 - accuracy: 0.8360 - val_loss: 0.4795 - val_accuracy: 0.8261
# Epoch 16/30
# 938/938 [==============================] - 50s 53ms/step - loss: 0.4770 - accuracy: 0.8372 - val_loss: 0.4843 - val_accuracy: 0.8248
# Epoch 17/30
# 938/938 [==============================] - 50s 54ms/step - loss: 0.4757 - accuracy: 0.8357 - val_loss: 0.4732 - val_accuracy: 0.8286
# Epoch 18/30
# 938/938 [==============================] - 50s 54ms/step - loss: 0.4735 - accuracy: 0.8373 - val_loss: 0.4690 - val_accuracy: 0.8339
# Epoch 19/30
# 938/938 [==============================] - 50s 54ms/step - loss: 0.4724 - accuracy: 0.8376 - val_loss: 0.4583 - val_accuracy: 0.8350
# Epoch 20/30
# 938/938 [==============================] - 49s 53ms/step - loss: 0.4713 - accuracy: 0.8376 - val_loss: 0.4505 - val_accuracy: 0.8406
# Epoch 21/30
# 938/938 [==============================] - 49s 52ms/step - loss: 0.4686 - accuracy: 0.8383 - val_loss: 0.4510 - val_accuracy: 0.8407
# Epoch 22/30
# 938/938 [==============================] - 49s 52ms/step - loss: 0.4682 - accuracy: 0.8384 - val_loss: 0.4525 - val_accuracy: 0.8395
# Epoch 23/30
# 938/938 [==============================] - 50s 53ms/step - loss: 0.4683 - accuracy: 0.8384 - val_loss: 0.4527 - val_accuracy: 0.8417
# Epoch 24/30
# 938/938 [==============================] - 51s 54ms/step - loss: 0.4657 - accuracy: 0.8398 - val_loss: 0.4435 - val_accuracy: 0.8435
# Epoch 25/30
# 938/938 [==============================] - 50s 53ms/step - loss: 0.4667 - accuracy: 0.8385 - val_loss: 0.4516 - val_accuracy: 0.8398
# Epoch 26/30
# 938/938 [==============================] - 50s 53ms/step - loss: 0.4682 - accuracy: 0.8376 - val_loss: 0.4445 - val_accuracy: 0.8418
# Epoch 27/30
# 938/938 [==============================] - 48s 51ms/step - loss: 0.4662 - accuracy: 0.8384 - val_loss: 0.4480 - val_accuracy: 0.8443
# Epoch 28/30
# 938/938 [==============================] - 49s 53ms/step - loss: 0.4681 - accuracy: 0.8383 - val_loss: 0.4382 - val_accuracy: 0.8437
# Epoch 29/30
# 938/938 [==============================] - 49s 52ms/step - loss: 0.4654 - accuracy: 0.8408 - val_loss: 0.4486 - val_accuracy: 0.8401
# Epoch 30/30
# 938/938 [==============================] - 49s 52ms/step - loss: 0.4671 - accuracy: 0.8375 - val_loss: 0.4497 - val_accuracy: 0.8399

# %%
print(f'Training time {round((total_time_64),3)} sec for {num_epochs} epochs.')
inference_time_64 = inf_time_check(model_64, val_ds)
print(f'Inference time {inference_time_64} ms for {num_val_samples} samples.')
# Out:
# Training time 1504.11 sec for 30 epochs.
# 64/64 [==============================] - 2s 14ms/step
# 64/64 [==============================] - 1s 14ms/step
# 64/64 [==============================] - 1s 14ms/step
# 64/64 [==============================] - 1s 14ms/step
# 64/64 [==============================] - 1s 14ms/step
# Inference time 1065.747 ms for 10000 samples.

# %%
log_name_64 = '\log\\fashion_mnist\ViT\L_64.pkl'
log_path_64 = main_dir + log_name_64
with open(log_path_64, 'wb') as file:
    pickle.dump(history_64.history, file)

# %%
# plot accuracy curve
plt.plot(history_64.history["accuracy"], label="Train Accuracy")
plt.plot(history_64.history["val_accuracy"], label="Validation Accuracy")
plt.title("Train and Validation Accuracy Over Epochs L=64")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()

# %%
# plot loss curve
plt.plot(history_64.history["loss"], label="Train Loss")
plt.plot(history_64.history["val_loss"], label="Validation Loss")
plt.title("Train and Validation Loss Over Epochs L=64")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# %% [markdown]
# # L = 256

# %%
patch_size = 2
model_256 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=input_shape),
    VisionTransformer(image_size=image_size, patch_size=patch_size, num_layers=num_layers, num_classes=num_classes, 
                      d_model=d_model, num_heads=num_heads, mlp_dim=mlp_dim, channels=channels),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(10, activation='softmax')
])

model_256.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
             optimizer=tfa.optimizers.AdamW(learning_rate=lr, weight_decay=weight_decay),
             metrics=['accuracy']) 

model_256.summary()
# Out:
# Model: "sequential_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vision_transformer_2 (Visio  (None, 10)               169226
#  nTransformer)
#
#  flatten_2 (Flatten)         (None, 10)                0
#
#  dense_119 (Dense)           (None, 10)                110
#
# =================================================================
# Total params: 169,336
# Trainable params: 169,336
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_name = 'L_256'
path = main_dir + '\model_checkpoints\\fashion_mnist\ViT\\' + model_name

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=path,
    save_best_only=True,
    save_weights_only=True,
    monitor='val_loss',
    mode='min'
)

#train model
start_time = time.time()
history_256 = model_256.fit(
    train_ds,
    epochs=num_epochs,
    validation_data=val_ds,
    callbacks=[model_checkpoint_callback]
)
end_time = time.time()
total_time_256 = end_time-start_time
# Out:
# Epoch 1/30
# 938/938 [==============================] - 64s 60ms/step - loss: 1.0894 - accuracy: 0.6065 - val_loss: 0.6694 - val_accuracy: 0.7556
# Epoch 2/30
# 938/938 [==============================] - 54s 58ms/step - loss: 0.6283 - accuracy: 0.7770 - val_loss: 0.5721 - val_accuracy: 0.7960
# Epoch 3/30
# 938/938 [==============================] - 54s 58ms/step - loss: 0.5505 - accuracy: 0.8071 - val_loss: 0.5337 - val_accuracy: 0.8099
# Epoch 4/30
# 938/938 [==============================] - 54s 58ms/step - loss: 0.5149 - accuracy: 0.8209 - val_loss: 0.4874 - val_accuracy: 0.8252
# Epoch 5/30
# 938/938 [==============================] - 54s 58ms/step - loss: 0.4940 - accuracy: 0.8291 - val_loss: 0.4770 - val_accuracy: 0.8307
# Epoch 6/30
# 938/938 [==============================] - 55s 58ms/step - loss: 0.4805 - accuracy: 0.8320 - val_loss: 0.4684 - val_accuracy: 0.8338
# Epoch 7/30
# 938/938 [==============================] - 55s 59ms/step - loss: 0.4734 - accuracy: 0.8352 - val_loss: 0.4665 - val_accuracy: 0.8328
# Epoch 8/30
# 938/938 [==============================] - 55s 58ms/step - loss: 0.4655 - accuracy: 0.8390 - val_loss: 0.4670 - val_accuracy: 0.8333
# Epoch 9/30
# 938/938 [==============================] - 55s 59ms/step - loss: 0.4625 - accuracy: 0.8404 - val_loss: 0.4619 - val_accuracy: 0.8376
# Epoch 10/30
# 938/938 [==============================] - 55s 59ms/step - loss: 0.4617 - accuracy: 0.8402 - val_loss: 0.4707 - val_accuracy: 0.8353
# Epoch 11/30
# 938/938 [==============================] - 55s 59ms/step - loss: 0.4596 - accuracy: 0.8414 - val_loss: 0.4644 - val_accuracy: 0.8371
# Epoch 12/30
# 938/938 [==============================] - 55s 59ms/step - loss: 0.4567 - accuracy: 0.8425 - val_loss: 0.4531 - val_accuracy: 0.8400
# Epoch 13/30
# 938/938 [==============================] - 55s 58ms/step - loss: 0.4555 - accuracy: 0.8430 - val_loss: 0.4533 - val_accuracy: 0.8421
# Epoch 14/30
# 938/938 [==============================] - 55s 58ms/step - loss: 0.4554 - accuracy: 0.8426 - val_loss: 0.4695 - val_accuracy: 0.8331
# Epoch 15/30
# 938/938 [==============================] - 55s 59ms/step - loss: 0.4527 - accuracy: 0.8452 - val_loss: 0.4484 - val_accuracy: 0.8408
# Epoch 16/30
# 938/938 [==============================] - 55s 58ms/step - loss: 0.4542 - accuracy: 0.8436 - val_loss: 0.4667 - val_accuracy: 0.8346
# Epoch 17/30
# 938/938 [==============================] - 55s 58ms/step - loss: 0.4538 - accuracy: 0.8451 - val_loss: 0.4681 - val_accuracy: 0.8329
# Epoch 18/30
# 938/938 [==============================] - 55s 58ms/step - loss: 0.4508 - accuracy: 0.8456 - val_loss: 0.4649 - val_accuracy: 0.8342
# Epoch 19/30
# 938/938 [==============================] - 55s 59ms/step - loss: 0.4524 - accuracy: 0.8450 - val_loss: 0.4515 - val_accuracy: 0.8402
# Epoch 20/30
# 938/938 [==============================] - 55s 59ms/step - loss: 0.4531 - accuracy: 0.8446 - val_loss: 0.4443 - val_accuracy: 0.8452
# Epoch 21/30
# 938/938 [==============================] - 55s 59ms/step - loss: 0.4523 - accuracy: 0.8452 - val_loss: 0.4499 - val_accuracy: 0.8407
# Epoch 22/30
# 938/938 [==============================] - 55s 59ms/step - loss: 0.4491 - accuracy: 0.8464 - val_loss: 0.4701 - val_accuracy: 0.8340
# Epoch 23/30
# 938/938 [==============================] - 55s 59ms/step - loss: 0.4504 - accuracy: 0.8459 - val_loss: 0.4585 - val_accuracy: 0.8399
# Epoch 24/30
# 938/938 [==============================] - 55s 59ms/step - loss: 0.4515 - accuracy: 0.8458 - val_loss: 0.4654 - val_accuracy: 0.8388
# Epoch 25/30
# 938/938 [==============================] - 55s 59ms/step - loss: 0.4502 - accuracy: 0.8462 - val_loss: 0.4631 - val_accuracy: 0.8409
# Epoch 26/30
# 938/938 [==============================] - 55s 59ms/step - loss: 0.4517 - accuracy: 0.8448 - val_loss: 0.4565 - val_accuracy: 0.8406
# Epoch 27/30
# 938/938 [==============================] - 55s 58ms/step - loss: 0.4517 - accuracy: 0.8468 - val_loss: 0.4603 - val_accuracy: 0.8411
# Epoch 28/30
# 938/938 [==============================] - 55s 58ms/step - loss: 0.4535 - accuracy: 0.8458 - val_loss: 0.4651 - val_accuracy: 0.8401
# Epoch 29/30
# 938/938 [==============================] - 55s 58ms/step - loss: 0.4541 - accuracy: 0.8432 - val_loss: 0.4585 - val_accuracy: 0.8414
# Epoch 30/30
# 938/938 [==============================] - 55s 59ms/step - loss: 0.4562 - accuracy: 0.8434 - val_loss: 0.4695 - val_accuracy: 0.8389

# %%
from utils import inf_time_check
print(f'Training time {round((total_time_256),3)} sec for {num_epochs} epochs.')
inference_time_256 = inf_time_check(model_256, val_ds)
print(f'Inference time {inference_time_256} ms for {num_val_samples} samples.')
# Out:
# Training time 1654.15 sec for 30 epochs.
# 64/64 [==============================] - 1s 9ms/step
# 64/64 [==============================] - 1s 9ms/step
# 64/64 [==============================] - 1s 9ms/step
# 64/64 [==============================] - 1s 9ms/step
# 64/64 [==============================] - 1s 10ms/step
# Inference time 779.215 ms for 10000 samples.

# %%
log_name_256 = '\log\\fashion_mnist\ViT\L_256.pkl'
log_path_256 = main_dir + log_name_256
with open(log_path_256, 'wb') as file:
    pickle.dump(history_256.history, file)

# %%
# plot accuracy curve
plt.plot(history_256.history["accuracy"], label="Train Accuracy")
plt.plot(history_256.history["val_accuracy"], label="Validation Accuracy")
plt.title("Train and Validation Accuracy Over Epochs L=256")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()

# %%
# plot loss curve
plt.plot(history_256.history["loss"], label="Train Loss")
plt.plot(history_256.history["val_loss"], label="Validation Loss")
plt.title("Train and Validation Loss Over Epochs L=256")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# %% [markdown]
# # L = 1024

# %%
patch_size = 1
model_1024 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=input_shape),
    VisionTransformer(image_size=image_size, patch_size=patch_size, num_layers=num_layers, num_classes=num_classes, 
                      d_model=d_model, num_heads=num_heads, mlp_dim=mlp_dim, channels=channels),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(10, activation='softmax')
])

model_1024.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
             optimizer=tfa.optimizers.AdamW(learning_rate=lr, weight_decay=weight_decay),
             metrics=['accuracy']) 

model_1024.summary()
# Out:
# Model: "sequential_31"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vision_transformer_3 (Visio  (None, 10)               206666
#  nTransformer)
#
#  flatten_3 (Flatten)         (None, 10)                0
#
#  dense_159 (Dense)           (None, 10)                110
#
# =================================================================
# Total params: 206,776
# Trainable params: 206,776
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_name = 'L_1024'
path = main_dir + '\model_checkpoints\\fashion_mnist\ViT\\' + model_name

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=path,
    save_best_only=True,
    save_weights_only=True,
    monitor='val_loss',
    mode='min'
)

#train model
start_time = time.time()
history_1024 = model_1024.fit(
    train_ds,
    epochs=num_epochs,
    validation_data=val_ds,
    callbacks=[model_checkpoint_callback]
)
end_time = time.time()
total_time_1024 = end_time-start_time
# Out:
# Epoch 1/30
# 938/938 [==============================] - 180s 185ms/step - loss: 0.9372 - accuracy: 0.6737 - val_loss: 0.5762 - val_accuracy: 0.7970
# Epoch 2/30
# 938/938 [==============================] - 172s 183ms/step - loss: 0.5305 - accuracy: 0.8176 - val_loss: 0.5302 - val_accuracy: 0.8134
# Epoch 3/30
# 938/938 [==============================] - 172s 183ms/step - loss: 0.4705 - accuracy: 0.8396 - val_loss: 0.4984 - val_accuracy: 0.8261
# Epoch 4/30
# 938/938 [==============================] - 172s 183ms/step - loss: 0.4415 - accuracy: 0.8491 - val_loss: 0.4654 - val_accuracy: 0.8408
# Epoch 5/30
# 938/938 [==============================] - 172s 183ms/step - loss: 0.4280 - accuracy: 0.8520 - val_loss: 0.4577 - val_accuracy: 0.8433
# Epoch 6/30
# 938/938 [==============================] - 172s 183ms/step - loss: 0.4168 - accuracy: 0.8582 - val_loss: 0.4467 - val_accuracy: 0.8466
# Epoch 7/30
# 938/938 [==============================] - 172s 183ms/step - loss: 0.4128 - accuracy: 0.8579 - val_loss: 0.4377 - val_accuracy: 0.8480
# Epoch 8/30
# 938/938 [==============================] - 172s 183ms/step - loss: 0.4074 - accuracy: 0.8606 - val_loss: 0.4306 - val_accuracy: 0.8518
# Epoch 9/30
# 938/938 [==============================] - 172s 183ms/step - loss: 0.4053 - accuracy: 0.8605 - val_loss: 0.4472 - val_accuracy: 0.8437
# Epoch 10/30
# 938/938 [==============================] - 172s 183ms/step - loss: 0.4028 - accuracy: 0.8617 - val_loss: 0.4361 - val_accuracy: 0.8472
# Epoch 11/30
# 938/938 [==============================] - 172s 183ms/step - loss: 0.4031 - accuracy: 0.8618 - val_loss: 0.4529 - val_accuracy: 0.8408
# Epoch 12/30
# 938/938 [==============================] - 172s 184ms/step - loss: 0.4028 - accuracy: 0.8637 - val_loss: 0.4641 - val_accuracy: 0.8377
# Epoch 13/30
# 938/938 [==============================] - 172s 184ms/step - loss: 0.4055 - accuracy: 0.8625 - val_loss: 0.4439 - val_accuracy: 0.8452
# Epoch 14/30
# 938/938 [==============================] - 173s 184ms/step - loss: 0.4071 - accuracy: 0.8615 - val_loss: 0.4576 - val_accuracy: 0.8389
# Epoch 15/30
# 938/938 [==============================] - 173s 184ms/step - loss: 0.4083 - accuracy: 0.8612 - val_loss: 0.4587 - val_accuracy: 0.8376
# Epoch 16/30
# 938/938 [==============================] - 172s 184ms/step - loss: 0.4114 - accuracy: 0.8596 - val_loss: 0.4826 - val_accuracy: 0.8299
# Epoch 17/30
# 938/938 [==============================] - 173s 185ms/step - loss: 0.4136 - accuracy: 0.8598 - val_loss: 0.4736 - val_accuracy: 0.8361
# Epoch 18/30
# 938/938 [==============================] - 172s 184ms/step - loss: 0.4139 - accuracy: 0.8601 - val_loss: 0.4797 - val_accuracy: 0.8318
# Epoch 19/30
# 938/938 [==============================] - 172s 184ms/step - loss: 0.4172 - accuracy: 0.8581 - val_loss: 0.4513 - val_accuracy: 0.8416
# Epoch 20/30
# 938/938 [==============================] - 173s 185ms/step - loss: 0.4225 - accuracy: 0.8567 - val_loss: 0.4658 - val_accuracy: 0.8372
# Epoch 21/30
# 938/938 [==============================] - 172s 184ms/step - loss: 0.4239 - accuracy: 0.8559 - val_loss: 0.4623 - val_accuracy: 0.8370
# Epoch 22/30
# 938/938 [==============================] - 172s 183ms/step - loss: 0.4286 - accuracy: 0.8548 - val_loss: 0.4722 - val_accuracy: 0.8355
# Epoch 23/30
# 938/938 [==============================] - 172s 184ms/step - loss: 0.4288 - accuracy: 0.8544 - val_loss: 0.4617 - val_accuracy: 0.8396
# Epoch 24/30
# 938/938 [==============================] - 172s 183ms/step - loss: 0.4333 - accuracy: 0.8518 - val_loss: 0.4401 - val_accuracy: 0.8505
# Epoch 25/30
# 938/938 [==============================] - 172s 184ms/step - loss: 0.4315 - accuracy: 0.8540 - val_loss: 0.4304 - val_accuracy: 0.8489
# Epoch 26/30
# 938/938 [==============================] - 172s 184ms/step - loss: 0.4388 - accuracy: 0.8519 - val_loss: 0.4398 - val_accuracy: 0.8473
# Epoch 27/30
# 938/938 [==============================] - 172s 184ms/step - loss: 0.4380 - accuracy: 0.8512 - val_loss: 0.4476 - val_accuracy: 0.8453
# Epoch 28/30
# 938/938 [==============================] - 172s 184ms/step - loss: 0.4406 - accuracy: 0.8503 - val_loss: 0.4543 - val_accuracy: 0.8410
# Epoch 29/30
# 938/938 [==============================] - 173s 184ms/step - loss: 0.4382 - accuracy: 0.8507 - val_loss: 0.4636 - val_accuracy: 0.8394
# Epoch 30/30
# 938/938 [==============================] - 172s 184ms/step - loss: 0.4370 - accuracy: 0.8501 - val_loss: 0.4503 - val_accuracy: 0.8451

# %%
print(f'Training time {round((total_time_1024),3)} sec for {num_epochs} epochs.')
inference_time_1024 = inf_time_check(model_1024, val_ds)
print(f'Inference time {inference_time_1024} ms for {num_val_samples} samples.')
# Out:
# Training time 5175.816 sec for 30 epochs.
# 64/64 [==============================] - 1s 8ms/step
# 64/64 [==============================] - 1s 8ms/step
# 64/64 [==============================] - 1s 9ms/step
# 64/64 [==============================] - 1s 11ms/step
# 64/64 [==============================] - 1s 11ms/step
# Inference time 795.948 ms for 10000 samples.

# %%
log_name_1024 = '\log\\fashion_mnist\ViT\L_1024.pkl'
log_path_1024 = main_dir + log_name_1024
with open(log_path_1024, 'wb') as file:
    pickle.dump(history_1024.history, file)

# %%
# plot accuracy curve
plt.plot(history_1024.history["accuracy"], label="Train Accuracy")
plt.plot(history_1024.history["val_accuracy"], label="Validation Accuracy")
plt.title("Train and Validation Accuracy Over Epochs L=1024")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()

# %%
# plot loss curve
plt.plot(history_1024.history["loss"], label="Train Loss")
plt.plot(history_1024.history["val_loss"], label="Validation Loss")
plt.title("Train and Validation Loss Over Epochs L=1024")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# %%
total_time = [total_time_16, total_time_64, total_time_256, total_time_1024]
inference_time = [inference_time_16, inference_time_64, inference_time_256, inference_time_1024]
log = []
log.append(total_time)
log.append(inference_time)
log_name = '\log\\fashion_mnist\ViT\\total_inf_time'
log_path = main_dir + log_name
# log [total_time, inference_time]
with open(log_path, 'wb') as file:
    pickle.dump(log, file)

# %%
logL = np.log2([16, 64, 256, 1024])

fig, ax1 = plt.subplots()
plt.title(f'Inference time & Total training time over {num_epochs} epochs')
plt.xlabel('log2(L)')

ax1.plot(logL, total_time, color='blue', label='Total training time')
ax1.set_ylabel('Time (second)', color='blue')
ax1.legend(loc='upper right')

ax2 = ax1.twinx()
ax2.plot(logL, inference_time, color='red', label='Inference time')
ax2.set_ylabel('Time (ms)', color='red')
ax2.legend(loc='upper left')

plt.grid()
plt.show()
